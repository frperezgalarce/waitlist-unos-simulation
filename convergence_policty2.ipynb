# %%
import pandas as pd 

df = pd.read_csv('data/data_to_simulate.csv', index_col=0)
df.dropna(inplace=True)
print(df.columns)
columns = ['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON', 'AGE', 'DIAB',
                'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI', 'SERUM_CREAT',
                'CREAT_TRR', 'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC','CREAT_TRRg1.5', 'SERUM_CREATg1.2',
                'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
                'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE','TX_DATE', 'PT_CODE', 'ABO', 'ABO_DON']

predictors = ['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'WGT_KG_DON_CALC',
                    'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'COD_CAD_DON', 'ETHCAT_DON', 'ABO_MAT', 
                    'HLAMIS', 'DIALYSIS_DATE', 'AGE', 'DIAB', 'DIALYSIS_DATEle0.0', 'CREAT_TRRg1.5', 'SERUM_CREATg1.2']

donor = df[['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 
            'HIST_HYPERTENS_DON', 'ABO_DON', 'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2']]

print(donor.columns)
donor.to_csv('data/donors.csv')

recipient = df[[ 'DIALYSIS_DATE', 'AGE', 'DIAB', 'ETHCAT', 'GENDER', 'ABO', 'DIALYSIS_DATEle0.0']]
recipient.to_csv('data/recipients.csv')
# Out:
# Index(['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON',
#        'AGE', 'DIAB', 'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI',
#        'SERUM_CREAT', 'ABO_MAT', 'AMIS', 'BMIS', 'DRMIS', 'CREAT_TRR',
#        'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC', 'ABO_DON',
#        'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
#        'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE', 'TX_DATE',
#        'PT_CODE', 'COMPOSITE_DEATH_DATE', 'ABO', 'T', 'Tag_date', 'DIAB_1',
#        'DIAB_998', 'HIST_DIABETES_DON_1', 'HIST_DIABETES_DON_998',
#        'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2',
#        'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype='object')
# Index(['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC',
#        'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'ABO_DON',
#        'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2'],
#       dtype='object')

# %%
recipient.ABO.unique()
# Out:
# array(['B', 'A', 'O', 'AB', 'A2', 'A1', 'A1B', 'A2B'], dtype=object)

# %%
blood_type_compatibility = {
    "A": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A1": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A2": ["A", "A1", "A2", "AB", "A1B", "A2B", "B"],
    "B":  ["B", "AB", "A1B", "A2B"],
    "AB": ["AB", "A1B", "A2B"],
    "A1B": ["A1B"],
    "A2B": ["A2B", "AB"],
    "O": ["A", "A1", "A2", "B", "AB", "A1B", "A2B", "O"]
}

# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
path = Path("C:/Users/HP/Desktop/UNOS data/codes/simulation-waitline-unos").resolve()  # Get the absolute path
os.chdir(path)
import pandas as pd
import numpy as np
import scipy as sc
import recipient as rec
import prediction as pred 
import donor as don
from event import Event

# %%
def create_list_of_events(n_events = 5000):
    events = Event(number_of_events= n_events, 
                    time_between_arrivals_recipients=12, 
                    time_between_arrivals_donor= 15) #average time in days
    events.create_events()
    return events

# %%
TARGET_TIME  = 5 * 365
SIMULATION_TIME = 365*40 
predictor = pred.SurvivalPredictionModel(model_path='models\decision_tree_2511.pkl')
#9.1% leave the list
#theshold_leave_list = 0.091 
recipients_for_initialization = 100
time_before_starting_simulation = 0
released_recipients = []
# Out:
# models\decision_tree_2511.pkl
# ok
# Model loaded successfully from models\decision_tree_2511.pkl.
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\HP\AppData\Local\Temp\ipykernel_26596\2509753757.py:3: SyntaxWarning: invalid escape sequence '\d'
#   predictor = pred.SurvivalPredictionModel(model_path='models\decision_tree_2511.pkl')

# %%
predictor.model.feature_names_in_
# Out:
# array(['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS',
#        'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'DIALYSIS_DATE', 'AGE',
#        'DIAB', 'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80',
#        'COD_CAD_DON_2', 'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype=object)

# %%
df = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
df_leaves = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
waiting_time_convergence = []
wait_list_length = []
leave_list_global = []



def run_simulation(T=10, replicates=1, verbose=False):
    waiting_time_convergence_r = []
    wait_list_length_r = []
    average_waiting_times = []
    number_of_matches_list = []
    
    for r in range(replicates):
        events = create_list_of_events(n_events = 5000)
        print('Replicate #', str(r))
        wait_list = []  # Initialize an empty waitlist for each replicate
        leave_list = []
        next_in_leave_the_list = []
        total_waiting_time = 0  # Track the total waiting time for this replicate
        num_matched_patients = 0  # Track the number of matched patients
        current_t = 0  # Start time    
    
        for i in range(recipients_for_initialization):
                new_recipient = rec.Recipient(time_before_starting_simulation) 
                new_recipient.create_recipient()
                wait_list.append(new_recipient)
                next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                next_in_leave_the_list = sorted(next_in_leave_the_list)
                
        while current_t < T:  
            (time_aux, _)  = events.list_of_events[0]
            (time2_aux, _, _) = next_in_leave_the_list[0]
            
            if time_aux + current_t < time2_aux:
                (time, event_type)  = events.list_of_events.pop(0)
                ID = None
                print(time+current_t, event_type, ID)
            else: 
                (time, event_type, ID) = next_in_leave_the_list.pop(0)
                print(time, event_type, ID)
                   
            #print(time, event_type)         
            match event_type:
                case "new_donor":
                    current_t += time
                    donor = don.Donor(current_t)
                    donor.create_donor()
                    
                    if len(wait_list) < 1:
                        raise('The waitlist length is 0, check the setup please')            
                    
                    survival_probs = [predictor.predict_survival_prob(recipient, donor, TARGET_TIME) 
                                    for recipient in wait_list 
                                    if donor.blood in blood_type_compatibility[recipient.blood]]
                    
                    arrival_times = [recipient.arrival_time for recipient in wait_list 
                                     if donor.blood in blood_type_compatibility[recipient.blood]]
                    
                    if len(survival_probs)>0: 
                        best_match_index = np.argmin(arrival_times)
                        recipient_best = wait_list[best_match_index]
                        _, predicted_survival_function = predictor.predict_survival_prob(recipient_best, donor, TARGET_TIME, surv_function=True)
                        
                        mean_survival_time = sum(
                        (predicted_survival_function[0].x[i + 1] - predicted_survival_function[0].x[i]) *
                        predicted_survival_function[0].y[i]
                        for i in range(len(predicted_survival_function[0].x) - 1)
)
                        
                        best_patient = wait_list.pop(best_match_index)
                        next_leave_time = [(a, b, c) for (a, b, c) in next_in_leave_the_list if c==best_patient.ID]
                        _index = next_in_leave_the_list.index(next_leave_time[0])   
                        _ = next_in_leave_the_list.pop(_index)
                        
                        print(f'A donation was done with expected life {mean_survival_time} and probabity {survival_probs[best_match_index]}. Day: ', str(current_t))
                        waiting_time = current_t - best_patient.arrival_time
                        
                        if current_t > 8*365.25:
                            total_waiting_time += waiting_time
                            
                        best_patient.waiting_time = waiting_time
                        
                        
                        if current_t > 8*365.25:
                            df.loc[len(df)] = [r, best_patient.ethcat, best_patient.gender, best_patient.waiting_time, mean_survival_time, current_t]
                            released_recipients.append(best_patient)
                            num_matched_patients += 1
                
                case "new_recipient":            
                    current_t += time
                    new_recipient = rec.Recipient(current_t) 
                    new_recipient.create_recipient()
                    wait_list.append(new_recipient)
                    next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                    next_in_leave_the_list = sorted(next_in_leave_the_list)
                    print('A new recipient has arrived. Day: ', str(current_t))
                
                case "leave_list":
                    current_t = time
                    next_leave_time = [p for p in wait_list if p.ID==ID]
                    _index = wait_list.index(next_leave_time[0])   
                    out_of_list = wait_list.pop(_index)
                    leave_list.append(out_of_list)
                    
                    if current_t > 8*365.25:
                        df_leaves.loc[len(df)] = [r, out_of_list.ethcat, out_of_list.gender, out_of_list.waiting_time, _, current_t]
                        print('----------------------- One patient left the waitlist. Day: ', str(current_t), out_of_list.ID) 
                    
                    

            if num_matched_patients>0:
                if current_t > 8*365.25:
                    average_time = total_waiting_time / num_matched_patients
                    #we collect data after 8 years
                    waiting_time_convergence_r.append([current_t, average_time])
                wait_list_length_r.append([current_t, len(wait_list)])
            else: 
                average_time = 'INF'
            if verbose:
                print(f'Number of matches: {num_matched_patients}, recipients in wait list: {len(wait_list)},'
                      f'average time in waitlist {average_time}, patients which leave the list {len(leave_list)}')        
        if num_matched_patients > 0:
            average_waiting_times.append(total_waiting_time / num_matched_patients)
            waiting_time_convergence.append(waiting_time_convergence_r)
            wait_list_length.append(wait_list_length_r)
            number_of_matches_list.append(num_matched_patients)
            leave_list_global.append(leave_list)
        else:
            average_waiting_times.append(0)
            
    return average_waiting_times, number_of_matches_list

# %%
run_simulation(T=SIMULATION_TIME, replicates=1, verbose=True)
# Out:
# Replicate # 0
# 4.6634575713946876e-132 leave_list 20471
# Number of matches: 0, recipients in wait list: 99,average time in waitlist INF, patients which leave the list 1
# 2.6904450781812365e-71 leave_list 14451
# Number of matches: 0, recipients in wait list: 98,average time in waitlist INF, patients which leave the list 2
# 5.016792275665182e-50 leave_list 5432
# Number of matches: 0, recipients in wait list: 97,average time in waitlist INF, patients which leave the list 3
# 1.0659752228690465e-32 leave_list 4468
# Number of matches: 0, recipients in wait list: 96,average time in waitlist INF, patients which leave the list 4
# 19.306247106564093 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  19.306247106564093
# Number of matches: 0, recipients in wait list: 95,average time in waitlist INF, patients which leave the list 4
# 22.456401126053418 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  22.456401126053418
# Number of matches: 0, recipients in wait list: 94,average time in waitlist INF, patients which leave the list 4
# 29.080556100861525 new_recipient None
# A new recipient has arrived. Day:  29.080556100861525
# Number of matches: 0, recipients in wait list: 95,average time in waitlist INF, patients which leave the list 4
# 34.46901379105667 new_recipient None
# A new recipient has arrived. Day:  34.46901379105667
# Number of matches: 0, recipients in wait list: 96,average time in waitlist INF, patients which leave the list 4
# 41.91286314376081 new_recipient None
# A new recipient has arrived. Day:  41.91286314376081
# Number of matches: 0, recipients in wait list: 97,average time in waitlist INF, patients which leave the list 4
# 53.702343157286016 new_recipient None
# A new recipient has arrived. Day:  53.702343157286016
# Number of matches: 0, recipients in wait list: 98,average time in waitlist INF, patients which leave the list 4
# 56.83198253088205 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  56.83198253088205
# Number of matches: 0, recipients in wait list: 97,average time in waitlist INF, patients which leave the list 4
# 57.74285780652067 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  57.74285780652067
# Number of matches: 0, recipients in wait list: 96,average time in waitlist INF, patients which leave the list 4
# 62.2380374774081 new_recipient None
# A new recipient has arrived. Day:  62.2380374774081
# Number of matches: 0, recipients in wait list: 97,average time in waitlist INF, patients which leave the list 4
# 65.99866255131204 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  65.99866255131204
# Number of matches: 0, recipients in wait list: 96,average time in waitlist INF, patients which leave the list 4
# 71.68766139849396 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  71.68766139849396
# Number of matches: 0, recipients in wait list: 95,average time in waitlist INF, patients which leave the list 4
# 87.58170873001055 new_recipient None
# A new recipient has arrived. Day:  87.58170873001055
# Number of matches: 0, recipients in wait list: 96,average time in waitlist INF, patients which leave the list 4
# 91.17762228728354 new_recipient None
# A new recipient has arrived. Day:  91.17762228728354
# Number of matches: 0, recipients in wait list: 97,average time in waitlist INF, patients which leave the list 4
# 107.05370334637637 new_recipient None
# A new recipient has arrived. Day:  107.05370334637637
# Number of matches: 0, recipients in wait list: 98,average time in waitlist INF, patients which leave the list 4
# 109.25241549753791 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  109.25241549753791
# Number of matches: 0, recipients in wait list: 97,average time in waitlist INF, patients which leave the list 4
# 111.90354817571298 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  111.90354817571298
# Number of matches: 0, recipients in wait list: 96,average time in waitlist INF, patients which leave the list 4
# 117.93112068148568 new_recipient None
# A new recipient has arrived. Day:  117.93112068148568
# Number of matches: 0, recipients in wait list: 97,average time in waitlist INF, patients which leave the list 4
# 121.49663866172398 new_recipient None
# A new recipient has arrived. Day:  121.49663866172398
# Number of matches: 0, recipients in wait list: 98,average time in waitlist INF, patients which leave the list 4
# 124.94673686746505 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  124.94673686746505
# Number of matches: 0, recipients in wait list: 97,average time in waitlist INF, patients which leave the list 4
# 130.23344478758133 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7069534320897705. Day:  130.23344478758133
# Number of matches: 0, recipients in wait list: 96,average time in waitlist INF, patients which leave the list 4
# 132.7739686569478 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  132.7739686569478
# Number of matches: 0, recipients in wait list: 95,average time in waitlist INF, patients which leave the list 4
# 138.48641153866882 new_recipient None
# A new recipient has arrived. Day:  138.48641153866882
# Number of matches: 0, recipients in wait list: 96,average time in waitlist INF, patients which leave the list 4
# 140.63898096335387 new_recipient None
# A new recipient has arrived. Day:  140.63898096335387
# Number of matches: 0, recipients in wait list: 97,average time in waitlist INF, patients which leave the list 4
# 143.8268954788214 new_recipient None
# A new recipient has arrived. Day:  143.8268954788214
# Number of matches: 0, recipients in wait list: 98,average time in waitlist INF, patients which leave the list 4
# 149.29662885014773 new_recipient None
# A new recipient has arrived. Day:  149.29662885014773
# Number of matches: 0, recipients in wait list: 99,average time in waitlist INF, patients which leave the list 4
# 153.454412885655 new_recipient None
# A new recipient has arrived. Day:  153.454412885655
# Number of matches: 0, recipients in wait list: 100,average time in waitlist INF, patients which leave the list 4
# 153.64498818513823 new_donor None
# A donation was done with expected life 1260.2857142856165 and probabity 0.14285714285714288. Day:  153.64498818513823
# Number of matches: 0, recipients in wait list: 99,average time in waitlist INF, patients which leave the list 4
# 153.98503987487274 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  153.98503987487274
# Number of matches: 0, recipients in wait list: 98,average time in waitlist INF, patients which leave the list 4
# 154.09879416346516 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  154.09879416346516
# Number of matches: 0, recipients in wait list: 97,average time in waitlist INF, patients which leave the list 4
# 164.86127194808543 new_recipient None
# A new recipient has arrived. Day:  164.86127194808543
# Number of matches: 0, recipients in wait list: 98,average time in waitlist INF, patients which leave the list 4
# 179.5939636553969 new_recipient None
# A new recipient has arrived. Day:  179.5939636553969
# Number of matches: 0, recipients in wait list: 99,average time in waitlist INF, patients which leave the list 4
# 192.6485380424638 new_recipient None
# A new recipient has arrived. Day:  192.6485380424638
# Number of matches: 0, recipients in wait list: 100,average time in waitlist INF, patients which leave the list 4
# 198.9694957708102 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  198.9694957708102
# Number of matches: 0, recipients in wait list: 99,average time in waitlist INF, patients which leave the list 4
# 210.03766066636607 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  210.03766066636607
# Number of matches: 0, recipients in wait list: 98,average time in waitlist INF, patients which leave the list 4
# 217.66651287971857 new_recipient None
# A new recipient has arrived. Day:  217.66651287971857
# Number of matches: 0, recipients in wait list: 99,average time in waitlist INF, patients which leave the list 4
# 221.664319804063 new_recipient None
# A new recipient has arrived. Day:  221.664319804063
# Number of matches: 0, recipients in wait list: 100,average time in waitlist INF, patients which leave the list 4
# 232.13395176441983 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  232.13395176441983
# Number of matches: 0, recipients in wait list: 99,average time in waitlist INF, patients which leave the list 4
# 234.63089637054514 new_recipient None
# A new recipient has arrived. Day:  234.63089637054514
# Number of matches: 0, recipients in wait list: 100,average time in waitlist INF, patients which leave the list 4
# 236.01221915505258 new_recipient None
# A new recipient has arrived. Day:  236.01221915505258
# Number of matches: 0, recipients in wait list: 101,average time in waitlist INF, patients which leave the list 4
# 241.8929726965471 new_recipient None
# A new recipient has arrived. Day:  241.8929726965471
# Number of matches: 0, recipients in wait list: 102,average time in waitlist INF, patients which leave the list 4
# 246.09360976303356 new_recipient None
# A new recipient has arrived. Day:  246.09360976303356
# Number of matches: 0, recipients in wait list: 103,average time in waitlist INF, patients which leave the list 4
# 248.50106821057878 new_recipient None
# A new recipient has arrived. Day:  248.50106821057878
# Number of matches: 0, recipients in wait list: 104,average time in waitlist INF, patients which leave the list 4
# 262.1963074672285 new_recipient None
# A new recipient has arrived. Day:  262.1963074672285
# Number of matches: 0, recipients in wait list: 105,average time in waitlist INF, patients which leave the list 4
# 271.4569842914447 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  271.4569842914447
# Number of matches: 0, recipients in wait list: 104,average time in waitlist INF, patients which leave the list 4
# 274.0169164469177 new_recipient None
# A new recipient has arrived. Day:  274.0169164469177
# Number of matches: 0, recipients in wait list: 105,average time in waitlist INF, patients which leave the list 4
# 277.285337373507 new_recipient None
# A new recipient has arrived. Day:  277.285337373507
# Number of matches: 0, recipients in wait list: 106,average time in waitlist INF, patients which leave the list 4
# 279.7457108215559 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  279.7457108215559
# Number of matches: 0, recipients in wait list: 105,average time in waitlist INF, patients which leave the list 4
# 279.8683555656566 new_recipient None
# A new recipient has arrived. Day:  279.8683555656566
# Number of matches: 0, recipients in wait list: 106,average time in waitlist INF, patients which leave the list 4
# 287.68790343210014 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  287.68790343210014
# Number of matches: 0, recipients in wait list: 105,average time in waitlist INF, patients which leave the list 4
# 294.70544820948913 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  294.70544820948913
# Number of matches: 0, recipients in wait list: 104,average time in waitlist INF, patients which leave the list 4
# 309.40049387671604 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  309.40049387671604
# Number of matches: 0, recipients in wait list: 103,average time in waitlist INF, patients which leave the list 4
# 312.28197944682273 new_recipient None
# A new recipient has arrived. Day:  312.28197944682273
# Number of matches: 0, recipients in wait list: 104,average time in waitlist INF, patients which leave the list 4
# 318.11500508587176 new_recipient None
# A new recipient has arrived. Day:  318.11500508587176
# Number of matches: 0, recipients in wait list: 105,average time in waitlist INF, patients which leave the list 4
# 318.4425292037344 new_recipient None
# A new recipient has arrived. Day:  318.4425292037344
# Number of matches: 0, recipients in wait list: 106,average time in waitlist INF, patients which leave the list 4
# 321.30960909663406 new_recipient None
# A new recipient has arrived. Day:  321.30960909663406
# Number of matches: 0, recipients in wait list: 107,average time in waitlist INF, patients which leave the list 4
# 325.8071418098944 new_recipient None
# A new recipient has arrived. Day:  325.8071418098944
# Number of matches: 0, recipients in wait list: 108,average time in waitlist INF, patients which leave the list 4
# 326.65167654668664 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  326.65167654668664
# Number of matches: 0, recipients in wait list: 107,average time in waitlist INF, patients which leave the list 4
# 329.5512777427597 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.8004182699729505. Day:  329.5512777427597
# Number of matches: 0, recipients in wait list: 106,average time in waitlist INF, patients which leave the list 4
# 333.4273223719904 new_recipient None
# A new recipient has arrived. Day:  333.4273223719904
# Number of matches: 0, recipients in wait list: 107,average time in waitlist INF, patients which leave the list 4
# 334.2163050032682 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  334.2163050032682
# Number of matches: 0, recipients in wait list: 106,average time in waitlist INF, patients which leave the list 4
# 339.6837103946759 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  339.6837103946759
# Number of matches: 0, recipients in wait list: 105,average time in waitlist INF, patients which leave the list 4
# 340.3250174001936 new_donor None
# A donation was done with expected life 2354.0468992355763 and probabity 0.6213407169292465. Day:  340.3250174001936
# Number of matches: 0, recipients in wait list: 104,average time in waitlist INF, patients which leave the list 4
# 343.70182497989566 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  343.70182497989566
# Number of matches: 0, recipients in wait list: 103,average time in waitlist INF, patients which leave the list 4
# 345.1091367307376 new_recipient None
# A new recipient has arrived. Day:  345.1091367307376
# Number of matches: 0, recipients in wait list: 104,average time in waitlist INF, patients which leave the list 4
# 352.4424306258646 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  352.4424306258646
# Number of matches: 0, recipients in wait list: 103,average time in waitlist INF, patients which leave the list 4
# 352.6338966988094 new_recipient None
# A new recipient has arrived. Day:  352.6338966988094
# Number of matches: 0, recipients in wait list: 104,average time in waitlist INF, patients which leave the list 4
# 355.86347700888695 new_recipient None
# A new recipient has arrived. Day:  355.86347700888695
# Number of matches: 0, recipients in wait list: 105,average time in waitlist INF, patients which leave the list 4
# 363.8614768129563 new_donor None
# A donation was done with expected life 2354.0468992355763 and probabity 0.6213407169292465. Day:  363.8614768129563
# Number of matches: 0, recipients in wait list: 104,average time in waitlist INF, patients which leave the list 4
# 380.9543208459269 new_donor None
# A donation was done with expected life 2354.0468992355763 and probabity 0.6213407169292465. Day:  380.9543208459269
# Number of matches: 0, recipients in wait list: 103,average time in waitlist INF, patients which leave the list 4
# 395.43404605162675 new_recipient None
# A new recipient has arrived. Day:  395.43404605162675
# Number of matches: 0, recipients in wait list: 104,average time in waitlist INF, patients which leave the list 4
# 398.44611916255934 new_recipient None
# A new recipient has arrived. Day:  398.44611916255934
# Number of matches: 0, recipients in wait list: 105,average time in waitlist INF, patients which leave the list 4
# 407.98092363069486 new_recipient None
# A new recipient has arrived. Day:  407.98092363069486
# Number of matches: 0, recipients in wait list: 106,average time in waitlist INF, patients which leave the list 4
# 414.6532240032362 new_recipient None
# A new recipient has arrived. Day:  414.6532240032362
# Number of matches: 0, recipients in wait list: 107,average time in waitlist INF, patients which leave the list 4
# 428.4028829268693 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  428.4028829268693
# Number of matches: 0, recipients in wait list: 106,average time in waitlist INF, patients which leave the list 4
# 430.5224608610798 new_recipient None
# A new recipient has arrived. Day:  430.5224608610798
# Number of matches: 0, recipients in wait list: 107,average time in waitlist INF, patients which leave the list 4
# 452.8873273945094 new_recipient None
# A new recipient has arrived. Day:  452.8873273945094
# Number of matches: 0, recipients in wait list: 108,average time in waitlist INF, patients which leave the list 4
# 470.07383415783977 new_recipient None
# A new recipient has arrived. Day:  470.07383415783977
# Number of matches: 0, recipients in wait list: 109,average time in waitlist INF, patients which leave the list 4
# 485.8530591634323 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  485.8530591634323
# Number of matches: 0, recipients in wait list: 108,average time in waitlist INF, patients which leave the list 4
# 491.1407253855853 new_recipient None
# A new recipient has arrived. Day:  491.1407253855853
# Number of matches: 0, recipients in wait list: 109,average time in waitlist INF, patients which leave the list 4
# 503.5989785191988 new_recipient None
# A new recipient has arrived. Day:  503.5989785191988
# Number of matches: 0, recipients in wait list: 110,average time in waitlist INF, patients which leave the list 4
# 509.92900934092955 new_recipient None
# A new recipient has arrived. Day:  509.92900934092955
# Number of matches: 0, recipients in wait list: 111,average time in waitlist INF, patients which leave the list 4
# 512.4806466878159 new_recipient None
# A new recipient has arrived. Day:  512.4806466878159
# Number of matches: 0, recipients in wait list: 112,average time in waitlist INF, patients which leave the list 4
# 516.6546027788669 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  516.6546027788669
# Number of matches: 0, recipients in wait list: 111,average time in waitlist INF, patients which leave the list 4
# 521.231477181399 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  521.231477181399
# Number of matches: 0, recipients in wait list: 110,average time in waitlist INF, patients which leave the list 4
# 523.884498958255 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  523.884498958255
# Number of matches: 0, recipients in wait list: 109,average time in waitlist INF, patients which leave the list 4
# 552.2450287377217 new_recipient None
# A new recipient has arrived. Day:  552.2450287377217
# Number of matches: 0, recipients in wait list: 110,average time in waitlist INF, patients which leave the list 4
# 555.1080141067304 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7841656399742981. Day:  555.1080141067304
# Number of matches: 0, recipients in wait list: 109,average time in waitlist INF, patients which leave the list 4
# 567.5643124488843 new_recipient None
# A new recipient has arrived. Day:  567.5643124488843
# Number of matches: 0, recipients in wait list: 110,average time in waitlist INF, patients which leave the list 4
# 568.0223153200277 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  568.0223153200277
# Number of matches: 0, recipients in wait list: 109,average time in waitlist INF, patients which leave the list 4
# 569.5261607006181 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  569.5261607006181
# Number of matches: 0, recipients in wait list: 108,average time in waitlist INF, patients which leave the list 4
# 571.118123246195 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  571.118123246195
# Number of matches: 0, recipients in wait list: 107,average time in waitlist INF, patients which leave the list 4
# 572.953790689688 new_recipient None
# A new recipient has arrived. Day:  572.953790689688
# Number of matches: 0, recipients in wait list: 108,average time in waitlist INF, patients which leave the list 4
# 577.5941024572539 new_recipient None
# A new recipient has arrived. Day:  577.5941024572539
# Number of matches: 0, recipients in wait list: 109,average time in waitlist INF, patients which leave the list 4
# 578.4022059684319 new_recipient None
# A new recipient has arrived. Day:  578.4022059684319
# Number of matches: 0, recipients in wait list: 110,average time in waitlist INF, patients which leave the list 4
# 578.4022059684319 leave_list 2706
# Number of matches: 0, recipients in wait list: 109,average time in waitlist INF, patients which leave the list 5
# 591.5163118196031 new_recipient None
# A new recipient has arrived. Day:  591.5163118196031
# Number of matches: 0, recipients in wait list: 110,average time in waitlist INF, patients which leave the list 5
# 600.112649062098 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  600.112649062098
# Number of matches: 0, recipients in wait list: 109,average time in waitlist INF, patients which leave the list 5
# 613.7319297593206 new_recipient None
# A new recipient has arrived. Day:  613.7319297593206
# Number of matches: 0, recipients in wait list: 110,average time in waitlist INF, patients which leave the list 5
# 629.7450919266095 new_recipient None
# A new recipient has arrived. Day:  629.7450919266095
# Number of matches: 0, recipients in wait list: 111,average time in waitlist INF, patients which leave the list 5
# 630.4327052781418 new_recipient None
# A new recipient has arrived. Day:  630.4327052781418
# Number of matches: 0, recipients in wait list: 112,average time in waitlist INF, patients which leave the list 5
# 650.419032415896 new_recipient None
# A new recipient has arrived. Day:  650.419032415896
# Number of matches: 0, recipients in wait list: 113,average time in waitlist INF, patients which leave the list 5
# 650.419032415896 leave_list 5480
# Number of matches: 0, recipients in wait list: 112,average time in waitlist INF, patients which leave the list 6
# 657.6060654647805 new_recipient None
# A new recipient has arrived. Day:  657.6060654647805
# Number of matches: 0, recipients in wait list: 113,average time in waitlist INF, patients which leave the list 6
# 667.3958508476231 new_recipient None
# A new recipient has arrived. Day:  667.3958508476231
# Number of matches: 0, recipients in wait list: 114,average time in waitlist INF, patients which leave the list 6
# 673.8621991140693 new_donor None
# A donation was done with expected life 2354.0468992355763 and probabity 0.6213407169292465. Day:  673.8621991140693
# Number of matches: 0, recipients in wait list: 113,average time in waitlist INF, patients which leave the list 6
# 677.5003634683327 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  677.5003634683327
# Number of matches: 0, recipients in wait list: 112,average time in waitlist INF, patients which leave the list 6
# 684.1013066464582 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  684.1013066464582
# Number of matches: 0, recipients in wait list: 111,average time in waitlist INF, patients which leave the list 6
# 685.0493158667813 new_recipient None
# A new recipient has arrived. Day:  685.0493158667813
# Number of matches: 0, recipients in wait list: 112,average time in waitlist INF, patients which leave the list 6
# 685.1628499521588 new_recipient None
# A new recipient has arrived. Day:  685.1628499521588
# Number of matches: 0, recipients in wait list: 113,average time in waitlist INF, patients which leave the list 6
# 692.0992591622537 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  692.0992591622537
# Number of matches: 0, recipients in wait list: 112,average time in waitlist INF, patients which leave the list 6
# 703.3275807001186 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  703.3275807001186
# Number of matches: 0, recipients in wait list: 111,average time in waitlist INF, patients which leave the list 6
# 707.5641138588012 new_recipient None
# A new recipient has arrived. Day:  707.5641138588012
# Number of matches: 0, recipients in wait list: 112,average time in waitlist INF, patients which leave the list 6
# 710.6281123283896 new_recipient None
# A new recipient has arrived. Day:  710.6281123283896
# Number of matches: 0, recipients in wait list: 113,average time in waitlist INF, patients which leave the list 6
# 712.7041337059171 new_recipient None
# A new recipient has arrived. Day:  712.7041337059171
# Number of matches: 0, recipients in wait list: 114,average time in waitlist INF, patients which leave the list 6
# 724.2235350292425 new_recipient None
# A new recipient has arrived. Day:  724.2235350292425
# Number of matches: 0, recipients in wait list: 115,average time in waitlist INF, patients which leave the list 6
# 724.7678000194876 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  724.7678000194876
# Number of matches: 0, recipients in wait list: 114,average time in waitlist INF, patients which leave the list 6
# 725.1234652579856 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  725.1234652579856
# Number of matches: 0, recipients in wait list: 113,average time in waitlist INF, patients which leave the list 6
# 727.1944011331195 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  727.1944011331195
# Number of matches: 0, recipients in wait list: 112,average time in waitlist INF, patients which leave the list 6
# 730.440667798175 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  730.440667798175
# Number of matches: 0, recipients in wait list: 111,average time in waitlist INF, patients which leave the list 6
# 736.805663031162 new_recipient None
# A new recipient has arrived. Day:  736.805663031162
# Number of matches: 0, recipients in wait list: 112,average time in waitlist INF, patients which leave the list 6
# 746.5170369690321 new_recipient None
# A new recipient has arrived. Day:  746.5170369690321
# Number of matches: 0, recipients in wait list: 113,average time in waitlist INF, patients which leave the list 6
# 747.0723335258235 new_recipient None
# A new recipient has arrived. Day:  747.0723335258235
# Number of matches: 0, recipients in wait list: 114,average time in waitlist INF, patients which leave the list 6
# 754.4235426693991 new_recipient None
# A new recipient has arrived. Day:  754.4235426693991
# Number of matches: 0, recipients in wait list: 115,average time in waitlist INF, patients which leave the list 6
# 760.983579980832 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  760.983579980832
# Number of matches: 0, recipients in wait list: 114,average time in waitlist INF, patients which leave the list 6
# 773.9253844925113 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  773.9253844925113
# Number of matches: 0, recipients in wait list: 113,average time in waitlist INF, patients which leave the list 6
# 776.1841670590475 new_recipient None
# A new recipient has arrived. Day:  776.1841670590475
# Number of matches: 0, recipients in wait list: 114,average time in waitlist INF, patients which leave the list 6
# 776.5803858994642 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  776.5803858994642
# Number of matches: 0, recipients in wait list: 113,average time in waitlist INF, patients which leave the list 6
# 778.8417826411511 new_recipient None
# A new recipient has arrived. Day:  778.8417826411511
# Number of matches: 0, recipients in wait list: 114,average time in waitlist INF, patients which leave the list 6
# 789.175933436998 new_recipient None
# A new recipient has arrived. Day:  789.175933436998
# Number of matches: 0, recipients in wait list: 115,average time in waitlist INF, patients which leave the list 6
# 805.1206267576237 new_recipient None
# A new recipient has arrived. Day:  805.1206267576237
# Number of matches: 0, recipients in wait list: 116,average time in waitlist INF, patients which leave the list 6
# 805.1206267576237 leave_list 22079
# Number of matches: 0, recipients in wait list: 115,average time in waitlist INF, patients which leave the list 7
# 807.2522482588632 new_recipient None
# A new recipient has arrived. Day:  807.2522482588632
# Number of matches: 0, recipients in wait list: 116,average time in waitlist INF, patients which leave the list 7
# 817.6869072627261 new_recipient None
# A new recipient has arrived. Day:  817.6869072627261
# Number of matches: 0, recipients in wait list: 117,average time in waitlist INF, patients which leave the list 7
# 820.1552663444545 new_recipient None
# A new recipient has arrived. Day:  820.1552663444545
# Number of matches: 0, recipients in wait list: 118,average time in waitlist INF, patients which leave the list 7
# 824.879214178631 new_recipient None
# A new recipient has arrived. Day:  824.879214178631
# Number of matches: 0, recipients in wait list: 119,average time in waitlist INF, patients which leave the list 7
# 833.669048603637 new_recipient None
# A new recipient has arrived. Day:  833.669048603637
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 7
# 855.6465456607777 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  855.6465456607777
# Number of matches: 0, recipients in wait list: 119,average time in waitlist INF, patients which leave the list 7
# 857.1107432064065 new_recipient None
# A new recipient has arrived. Day:  857.1107432064065
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 7
# 866.9386900576499 new_recipient None
# A new recipient has arrived. Day:  866.9386900576499
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 7
# 872.9096526240612 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  872.9096526240612
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 7
# 873.4502489290343 new_recipient None
# A new recipient has arrived. Day:  873.4502489290343
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 7
# 879.6500122949082 new_recipient None
# A new recipient has arrived. Day:  879.6500122949082
# Number of matches: 0, recipients in wait list: 122,average time in waitlist INF, patients which leave the list 7
# 887.5163341655534 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  887.5163341655534
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 7
# 887.819327609071 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  887.819327609071
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 7
# 897.622705484355 new_recipient None
# A new recipient has arrived. Day:  897.622705484355
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 7
# 898.9513305407451 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  898.9513305407451
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 7
# 905.052256604766 new_recipient None
# A new recipient has arrived. Day:  905.052256604766
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 7
# 906.090867923358 new_recipient None
# A new recipient has arrived. Day:  906.090867923358
# Number of matches: 0, recipients in wait list: 122,average time in waitlist INF, patients which leave the list 7
# 922.3909934204831 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  922.3909934204831
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 7
# 924.4218450121465 new_recipient None
# A new recipient has arrived. Day:  924.4218450121465
# Number of matches: 0, recipients in wait list: 122,average time in waitlist INF, patients which leave the list 7
# 926.711789598263 new_recipient None
# A new recipient has arrived. Day:  926.711789598263
# Number of matches: 0, recipients in wait list: 123,average time in waitlist INF, patients which leave the list 7
# 928.8818186126908 new_recipient None
# A new recipient has arrived. Day:  928.8818186126908
# Number of matches: 0, recipients in wait list: 124,average time in waitlist INF, patients which leave the list 7
# 929.6053328112633 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  929.6053328112633
# Number of matches: 0, recipients in wait list: 123,average time in waitlist INF, patients which leave the list 7
# 947.1113650485647 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  947.1113650485647
# Number of matches: 0, recipients in wait list: 122,average time in waitlist INF, patients which leave the list 7
# 949.5237532587121 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.8004182699729505. Day:  949.5237532587121
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 7
# 955.6146660893264 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  955.6146660893264
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 7
# 960.6794593546847 new_recipient None
# A new recipient has arrived. Day:  960.6794593546847
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 7
# 962.7140569756274 new_recipient None
# A new recipient has arrived. Day:  962.7140569756274
# Number of matches: 0, recipients in wait list: 122,average time in waitlist INF, patients which leave the list 7
# 962.7140569756274 leave_list 16590
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 8
# 965.1883825997654 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  965.1883825997654
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 8
# 972.7561962700712 new_recipient None
# A new recipient has arrived. Day:  972.7561962700712
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 8
# 977.3181576593067 new_recipient None
# A new recipient has arrived. Day:  977.3181576593067
# Number of matches: 0, recipients in wait list: 122,average time in waitlist INF, patients which leave the list 8
# 982.9737904806091 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  982.9737904806091
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 8
# 986.9922769094113 new_recipient None
# A new recipient has arrived. Day:  986.9922769094113
# Number of matches: 0, recipients in wait list: 122,average time in waitlist INF, patients which leave the list 8
# 994.3167926520975 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  994.3167926520975
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 8
# 1000.640119880715 new_recipient None
# A new recipient has arrived. Day:  1000.640119880715
# Number of matches: 0, recipients in wait list: 122,average time in waitlist INF, patients which leave the list 8
# 1010.8298943141097 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  1010.8298943141097
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 8
# 1034.0756214701144 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  1034.0756214701144
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 8
# 1035.8215433894802 new_recipient None
# A new recipient has arrived. Day:  1035.8215433894802
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 8
# 1037.1641633350962 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  1037.1641633350962
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 8
# 1042.0898833979584 new_recipient None
# A new recipient has arrived. Day:  1042.0898833979584
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 8
# 1042.511548429779 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  1042.511548429779
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 8
# 1043.1519721623117 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  1043.1519721623117
# Number of matches: 0, recipients in wait list: 119,average time in waitlist INF, patients which leave the list 8
# 1044.0195336754796 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  1044.0195336754796
# Number of matches: 0, recipients in wait list: 118,average time in waitlist INF, patients which leave the list 8
# 1045.523977424218 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.8004182699729505. Day:  1045.523977424218
# Number of matches: 0, recipients in wait list: 117,average time in waitlist INF, patients which leave the list 8
# 1048.8316718883825 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  1048.8316718883825
# Number of matches: 0, recipients in wait list: 116,average time in waitlist INF, patients which leave the list 8
# 1050.3277540789136 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  1050.3277540789136
# Number of matches: 0, recipients in wait list: 115,average time in waitlist INF, patients which leave the list 8
# 1063.8033849724297 new_recipient None
# A new recipient has arrived. Day:  1063.8033849724297
# Number of matches: 0, recipients in wait list: 116,average time in waitlist INF, patients which leave the list 8
# 1068.2308059836203 new_recipient None
# A new recipient has arrived. Day:  1068.2308059836203
# Number of matches: 0, recipients in wait list: 117,average time in waitlist INF, patients which leave the list 8
# 1069.130339449011 new_recipient None
# A new recipient has arrived. Day:  1069.130339449011
# Number of matches: 0, recipients in wait list: 118,average time in waitlist INF, patients which leave the list 8
# 1071.6236249340554 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  1071.6236249340554
# Number of matches: 0, recipients in wait list: 117,average time in waitlist INF, patients which leave the list 8
# 1073.5384868448248 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  1073.5384868448248
# Number of matches: 0, recipients in wait list: 116,average time in waitlist INF, patients which leave the list 8
# 1074.1688362272362 new_recipient None
# A new recipient has arrived. Day:  1074.1688362272362
# Number of matches: 0, recipients in wait list: 117,average time in waitlist INF, patients which leave the list 8
# 1075.7794633444757 new_recipient None
# A new recipient has arrived. Day:  1075.7794633444757
# Number of matches: 0, recipients in wait list: 118,average time in waitlist INF, patients which leave the list 8
# 1075.77949613 leave_list 14318
# Number of matches: 0, recipients in wait list: 117,average time in waitlist INF, patients which leave the list 9
# 1081.8482553455108 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  1081.8482553455108
# Number of matches: 0, recipients in wait list: 116,average time in waitlist INF, patients which leave the list 9
# 1092.393332865324 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  1092.393332865324
# Number of matches: 0, recipients in wait list: 115,average time in waitlist INF, patients which leave the list 9
# 1095.8372860904142 new_recipient None
# A new recipient has arrived. Day:  1095.8372860904142
# Number of matches: 0, recipients in wait list: 116,average time in waitlist INF, patients which leave the list 9
# 1108.1561908669103 new_recipient None
# A new recipient has arrived. Day:  1108.1561908669103
# Number of matches: 0, recipients in wait list: 117,average time in waitlist INF, patients which leave the list 9
# 1110.8015708905061 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  1110.8015708905061
# Number of matches: 0, recipients in wait list: 116,average time in waitlist INF, patients which leave the list 9
# 1134.4311408800254 new_recipient None
# A new recipient has arrived. Day:  1134.4311408800254
# Number of matches: 0, recipients in wait list: 117,average time in waitlist INF, patients which leave the list 9
# 1142.6880190504507 new_recipient None
# A new recipient has arrived. Day:  1142.6880190504507
# Number of matches: 0, recipients in wait list: 118,average time in waitlist INF, patients which leave the list 9
# 1169.6118533910876 new_recipient None
# A new recipient has arrived. Day:  1169.6118533910876
# Number of matches: 0, recipients in wait list: 119,average time in waitlist INF, patients which leave the list 9
# 1171.7010786114558 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  1171.7010786114558
# Number of matches: 0, recipients in wait list: 118,average time in waitlist INF, patients which leave the list 9
# 1180.1031686027632 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  1180.1031686027632
# Number of matches: 0, recipients in wait list: 117,average time in waitlist INF, patients which leave the list 9
# 1209.28373621725 new_recipient None
# A new recipient has arrived. Day:  1209.28373621725
# Number of matches: 0, recipients in wait list: 118,average time in waitlist INF, patients which leave the list 9
# 1213.1661967336768 new_recipient None
# A new recipient has arrived. Day:  1213.1661967336768
# Number of matches: 0, recipients in wait list: 119,average time in waitlist INF, patients which leave the list 9
# 1215.187742663142 new_recipient None
# A new recipient has arrived. Day:  1215.187742663142
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 9
# 1216.775837352818 new_recipient None
# A new recipient has arrived. Day:  1216.775837352818
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 9
# 1220.558167829095 new_recipient None
# A new recipient has arrived. Day:  1220.558167829095
# Number of matches: 0, recipients in wait list: 122,average time in waitlist INF, patients which leave the list 9
# 1222.8507039873004 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  1222.8507039873004
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 9
# 1229.996477781216 new_recipient None
# A new recipient has arrived. Day:  1229.996477781216
# Number of matches: 0, recipients in wait list: 122,average time in waitlist INF, patients which leave the list 9
# 1232.067546242112 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  1232.067546242112
# Number of matches: 0, recipients in wait list: 121,average time in waitlist INF, patients which leave the list 9
# 1238.4352470848496 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  1238.4352470848496
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 9
# 1246.0065749083765 new_donor None
# A donation was done with expected life 2354.0468992355763 and probabity 0.6213407169292465. Day:  1246.0065749083765
# Number of matches: 0, recipients in wait list: 119,average time in waitlist INF, patients which leave the list 9
# 1258.555807470429 new_recipient None
# A new recipient has arrived. Day:  1258.555807470429
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 9
# 1269.4879547080275 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  1269.4879547080275
# Number of matches: 0, recipients in wait list: 119,average time in waitlist INF, patients which leave the list 9
# 1271.0335850681563 new_recipient None
# A new recipient has arrived. Day:  1271.0335850681563
# Number of matches: 0, recipients in wait list: 120,average time in waitlist INF, patients which leave the list 9
# 1273.9811298239504 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  1273.9811298239504
# Number of matches: 0, recipients in wait list: 119,average time in waitlist INF, patients which leave the list 9
# 1282.8881176488367 new_donor None
# ...
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  14255.953468402116
# Number of matches: 720, recipients in wait list: 139,average time in waitlist 1586.3802291961981, patients which leave the list 146
# 14263.44257190194 new_recipient None
# A new recipient has arrived. Day:  14263.44257190194
# Number of matches: 720, recipients in wait list: 140,average time in waitlist 1586.3802291961981, patients which leave the list 146
# 14269.531045195909 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  14269.531045195909
# Number of matches: 721, recipients in wait list: 139,average time in waitlist 1586.6616068133237, patients which leave the list 146
# 14286.24016045009 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  14286.24016045009
# Number of matches: 722, recipients in wait list: 138,average time in waitlist 1586.9461764192536, patients which leave the list 146
# 14287.142344429698 new_recipient None
# A new recipient has arrived. Day:  14287.142344429698
# Number of matches: 722, recipients in wait list: 139,average time in waitlist 1586.9461764192536, patients which leave the list 146
# 14301.262527714916 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.8004182699729505. Day:  14301.262527714916
# Number of matches: 723, recipients in wait list: 138,average time in waitlist 1587.211802354654, patients which leave the list 146
# 14304.46393241186 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  14304.46393241186
# Number of matches: 724, recipients in wait list: 137,average time in waitlist 1587.4761543526254, patients which leave the list 146
# 14305.56490949913 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  14305.56490949913
# Number of matches: 725, recipients in wait list: 136,average time in waitlist 1587.6748939480042, patients which leave the list 146
# 14314.402164184241 new_recipient None
# A new recipient has arrived. Day:  14314.402164184241
# Number of matches: 725, recipients in wait list: 137,average time in waitlist 1587.6748939480042, patients which leave the list 146
# 14325.687280986896 new_recipient None
# A new recipient has arrived. Day:  14325.687280986896
# Number of matches: 725, recipients in wait list: 138,average time in waitlist 1587.6748939480042, patients which leave the list 146
# 14325.687720164413 new_recipient None
# A new recipient has arrived. Day:  14325.687720164413
# Number of matches: 725, recipients in wait list: 139,average time in waitlist 1587.6748939480042, patients which leave the list 146
# 14344.29305972477 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  14344.29305972477
# Number of matches: 726, recipients in wait list: 138,average time in waitlist 1587.9172506604773, patients which leave the list 146
# 14344.361619345547 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  14344.361619345547
# Number of matches: 727, recipients in wait list: 137,average time in waitlist 1588.156225788539, patients which leave the list 146
# 14358.879593460872 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  14358.879593460872
# Number of matches: 728, recipients in wait list: 136,average time in waitlist 1588.4051600417408, patients which leave the list 146
# 14359.080208413032 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  14359.080208413032
# Number of matches: 729, recipients in wait list: 135,average time in waitlist 1588.642684795674, patients which leave the list 146
# 14368.433713373108 new_recipient None
# A new recipient has arrived. Day:  14368.433713373108
# Number of matches: 729, recipients in wait list: 136,average time in waitlist 1588.642684795674, patients which leave the list 146
# 14372.095350974205 new_recipient None
# A new recipient has arrived. Day:  14372.095350974205
# Number of matches: 729, recipients in wait list: 137,average time in waitlist 1588.642684795674, patients which leave the list 146
# 14375.670337324207 new_recipient None
# A new recipient has arrived. Day:  14375.670337324207
# Number of matches: 729, recipients in wait list: 138,average time in waitlist 1588.642684795674, patients which leave the list 146
# 14381.635212084002 new_recipient None
# A new recipient has arrived. Day:  14381.635212084002
# Number of matches: 729, recipients in wait list: 139,average time in waitlist 1588.642684795674, patients which leave the list 146
# 14381.635212084002 leave_list 21989
# ----------------------- One patient left the waitlist. Day:  14381.635212084002 21989
# Number of matches: 729, recipients in wait list: 138,average time in waitlist 1588.642684795674, patients which leave the list 147
# 14387.290884154458 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  14387.290884154458
# Number of matches: 730, recipients in wait list: 137,average time in waitlist 1588.8954125244986, patients which leave the list 147
# 14388.687195730521 new_recipient None
# A new recipient has arrived. Day:  14388.687195730521
# Number of matches: 730, recipients in wait list: 138,average time in waitlist 1588.8954125244986, patients which leave the list 147
# 14388.687195821689 leave_list 9429
# ----------------------- One patient left the waitlist. Day:  14388.687195821689 9429
# Number of matches: 730, recipients in wait list: 137,average time in waitlist 1588.8954125244986, patients which leave the list 148
# 14398.523597139058 new_recipient None
# A new recipient has arrived. Day:  14398.523597139058
# Number of matches: 730, recipients in wait list: 138,average time in waitlist 1588.8954125244986, patients which leave the list 148
# 14399.840276369612 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7069534320897705. Day:  14399.840276369612
# Number of matches: 731, recipients in wait list: 137,average time in waitlist 1589.142298223911, patients which leave the list 148
# 14406.286027132499 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  14406.286027132499
# Number of matches: 732, recipients in wait list: 136,average time in waitlist 1589.3861304726315, patients which leave the list 148
# 14406.74973014061 new_recipient None
# A new recipient has arrived. Day:  14406.74973014061
# Number of matches: 732, recipients in wait list: 137,average time in waitlist 1589.3861304726315, patients which leave the list 148
# 14411.595855673977 new_recipient None
# A new recipient has arrived. Day:  14411.595855673977
# Number of matches: 732, recipients in wait list: 138,average time in waitlist 1589.3861304726315, patients which leave the list 148
# 14411.595855673977 leave_list 19761
# ----------------------- One patient left the waitlist. Day:  14411.595855673977 19761
# Number of matches: 732, recipients in wait list: 137,average time in waitlist 1589.3861304726315, patients which leave the list 149
# 14421.409460323892 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  14421.409460323892
# Number of matches: 733, recipients in wait list: 136,average time in waitlist 1589.6296235738025, patients which leave the list 149
# 14429.219635923952 new_recipient None
# A new recipient has arrived. Day:  14429.219635923952
# Number of matches: 733, recipients in wait list: 137,average time in waitlist 1589.6296235738025, patients which leave the list 149
# 14431.984987144793 new_recipient None
# A new recipient has arrived. Day:  14431.984987144793
# Number of matches: 733, recipients in wait list: 138,average time in waitlist 1589.6296235738025, patients which leave the list 149
# 14436.019337109925 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  14436.019337109925
# Number of matches: 734, recipients in wait list: 137,average time in waitlist 1589.8781238726651, patients which leave the list 149
# 14456.141349991998 new_recipient None
# A new recipient has arrived. Day:  14456.141349991998
# Number of matches: 734, recipients in wait list: 138,average time in waitlist 1589.8781238726651, patients which leave the list 149
# 14464.530463819554 new_recipient None
# A new recipient has arrived. Day:  14464.530463819554
# Number of matches: 734, recipients in wait list: 139,average time in waitlist 1589.8781238726651, patients which leave the list 149
# 14466.645810100841 new_recipient None
# A new recipient has arrived. Day:  14466.645810100841
# Number of matches: 734, recipients in wait list: 140,average time in waitlist 1589.8781238726651, patients which leave the list 149
# 14480.462422168755 new_recipient None
# A new recipient has arrived. Day:  14480.462422168755
# Number of matches: 734, recipients in wait list: 141,average time in waitlist 1589.8781238726651, patients which leave the list 149
# 14480.571995916462 new_recipient None
# A new recipient has arrived. Day:  14480.571995916462
# Number of matches: 734, recipients in wait list: 142,average time in waitlist 1589.8781238726651, patients which leave the list 149
# 14481.26291394608 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  14481.26291394608
# Number of matches: 735, recipients in wait list: 141,average time in waitlist 1590.1781828203527, patients which leave the list 149
# 14481.524436736567 new_recipient None
# A new recipient has arrived. Day:  14481.524436736567
# Number of matches: 735, recipients in wait list: 142,average time in waitlist 1590.1781828203527, patients which leave the list 149
# 14485.605741040234 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  14485.605741040234
# Number of matches: 736, recipients in wait list: 141,average time in waitlist 1590.4746595031136, patients which leave the list 149
# 14489.26332188749 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7841656399742981. Day:  14489.26332188749
# Number of matches: 737, recipients in wait list: 140,average time in waitlist 1590.7003462187301, patients which leave the list 149
# 14502.006887309739 new_recipient None
# A new recipient has arrived. Day:  14502.006887309739
# Number of matches: 737, recipients in wait list: 141,average time in waitlist 1590.7003462187301, patients which leave the list 149
# 14503.762115930358 new_recipient None
# A new recipient has arrived. Day:  14503.762115930358
# Number of matches: 737, recipients in wait list: 142,average time in waitlist 1590.7003462187301, patients which leave the list 149
# 14508.806221398865 new_recipient None
# A new recipient has arrived. Day:  14508.806221398865
# Number of matches: 737, recipients in wait list: 143,average time in waitlist 1590.7003462187301, patients which leave the list 149
# 14512.42983040225 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  14512.42983040225
# Number of matches: 738, recipients in wait list: 142,average time in waitlist 1590.948635227756, patients which leave the list 149
# 14512.815444317857 new_recipient None
# A new recipient has arrived. Day:  14512.815444317857
# Number of matches: 738, recipients in wait list: 143,average time in waitlist 1590.948635227756, patients which leave the list 149
# 14518.413282889805 new_recipient None
# A new recipient has arrived. Day:  14518.413282889805
# Number of matches: 738, recipients in wait list: 144,average time in waitlist 1590.948635227756, patients which leave the list 149
# 14519.411415908435 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  14519.411415908435
# Number of matches: 739, recipients in wait list: 143,average time in waitlist 1591.1948261865048, patients which leave the list 149
# 14530.461113772571 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  14530.461113772571
# Number of matches: 740, recipients in wait list: 142,average time in waitlist 1591.4382756577081, patients which leave the list 149
# 14534.303421947978 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  14534.303421947978
# Number of matches: 741, recipients in wait list: 141,average time in waitlist 1591.682005130995, patients which leave the list 149
# 14535.024703168603 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  14535.024703168603
# Number of matches: 742, recipients in wait list: 140,average time in waitlist 1591.9169825215686, patients which leave the list 149
# 14549.590468076558 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.8004182699729505. Day:  14549.590468076558
# Number of matches: 743, recipients in wait list: 139,average time in waitlist 1592.1598583637735, patients which leave the list 149
# 14560.280048018758 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  14560.280048018758
# Number of matches: 744, recipients in wait list: 138,average time in waitlist 1592.390790519634, patients which leave the list 149
# 14563.277612829517 new_recipient None
# A new recipient has arrived. Day:  14563.277612829517
# Number of matches: 744, recipients in wait list: 139,average time in waitlist 1592.390790519634, patients which leave the list 149
# 14567.619447158391 new_recipient None
# A new recipient has arrived. Day:  14567.619447158391
# Number of matches: 744, recipients in wait list: 140,average time in waitlist 1592.390790519634, patients which leave the list 149
# 14572.204412916015 new_recipient None
# A new recipient has arrived. Day:  14572.204412916015
# Number of matches: 744, recipients in wait list: 141,average time in waitlist 1592.390790519634, patients which leave the list 149
# 14586.09338326808 new_recipient None
# A new recipient has arrived. Day:  14586.09338326808
# Number of matches: 744, recipients in wait list: 142,average time in waitlist 1592.390790519634, patients which leave the list 149
# 14590.080550082648 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  14590.080550082648
# Number of matches: 745, recipients in wait list: 141,average time in waitlist 1592.6597160154151, patients which leave the list 149
# 14591.183708215609 new_recipient None
# A new recipient has arrived. Day:  14591.183708215609
# Number of matches: 745, recipients in wait list: 142,average time in waitlist 1592.6597160154151, patients which leave the list 149
# 14592.320925647531 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  14592.320925647531
# Number of matches: 746, recipients in wait list: 141,average time in waitlist 1592.9018045899666, patients which leave the list 149
# 14595.433361254465 new_recipient None
# A new recipient has arrived. Day:  14595.433361254465
# Number of matches: 746, recipients in wait list: 142,average time in waitlist 1592.9018045899666, patients which leave the list 149
# 14595.433361254465 leave_list 17496
# ----------------------- One patient left the waitlist. Day:  14595.433361254465 17496
# Number of matches: 746, recipients in wait list: 141,average time in waitlist 1592.9018045899666, patients which leave the list 150
# 14603.361975281769 new_recipient None
# A new recipient has arrived. Day:  14603.361975281769
# Number of matches: 746, recipients in wait list: 142,average time in waitlist 1592.9018045899666, patients which leave the list 150
# ([1592.9018045899666], [746])

# %%
waiting_time_leaves=[]
for pa in leave_list_global[0]:
     waiting_time_leaves.append([pa.waiting_time])

# %%
# Create the DataFrame for the first plot
df_plot = pd.DataFrame(waiting_time_convergence[0], columns=['current_t', 'waiting_time'])
df_plot2 = pd.DataFrame(wait_list_length[0], columns=['current_t', 'waitlist_length'])

# Create the plot with two y-axes
fig, ax1 = plt.subplots()

# First y-axis
ax1.plot(df_plot['current_t'], df_plot['waiting_time'], label="Waiting Time", color='blue')
ax1.set_xlabel('Current Day')
ax1.set_ylabel('Waiting Time (days)', color='blue')
# Adding a horizontal line at the last waiting time
last_waiting_time = df_plot['waiting_time'].iloc[-1]
ax1.hlines(last_waiting_time, 0, df_plot['current_t'].max(), colors='black', alpha=0.3, linestyles='dashed')
ax1.annotate(str(np.round(last_waiting_time,2)), (0, last_waiting_time-100))
ax1.tick_params(axis='y', labelcolor='blue')
ax1.set_ylim(0)

# Second y-axis
ax2 = ax1.twinx()
ax2.plot(df_plot2['current_t'], df_plot2['waitlist_length'], label="Wait List Length (number of patients)", color='red')
ax2.set_ylabel('Wait List Length', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.set_ylim(0)

# Add titles and show the plot
fig.tight_layout()  # Adjust layout to avoid overlap
plt.title('Waiting Time and Wait List Length Over Time')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Create the DataFrame for the first plot
df_plot = pd.DataFrame(waiting_time_convergence[0], columns=['current_t', 'waiting_time'])
df_plot2 = pd.DataFrame(wait_list_length[0], columns=['current_t', 'waitlist_length'])

# Calculate moving averages
window_size = 200  # Set the rolling window size
df_plot['moving_avg_waiting_time'] = df_plot['waiting_time'].rolling(window=window_size).mean()
df_plot2['moving_avg_waitlist_length'] = df_plot2['waitlist_length'].rolling(window=window_size).mean()

# Create the plot with two y-axes
fig, ax1 = plt.subplots()

# First y-axis (Waiting Time)
ax1.plot(df_plot['current_t'], df_plot['waiting_time'], label="Waiting Time", color='blue', alpha=0.2)
ax1.plot(df_plot['current_t'], df_plot['moving_avg_waiting_time'], label="Moving Avg (Waiting Time)", color='cyan', linestyle='--')
ax1.set_xlabel('Current Day')
ax1.set_ylabel('Waiting Time (days)', color='blue')
ax1.set_ylim(0)
ax1.tick_params(axis='y', labelcolor='blue')

# Second y-axis (Wait List Length)
ax2 = ax1.twinx()
ax2.plot(df_plot2['current_t'], df_plot2['waitlist_length'], label="Wait List Length", color='red', alpha=0.2)
ax2.plot(df_plot2['current_t'], df_plot2['moving_avg_waitlist_length'], label="Moving Avg (Wait List Length)", color='orange', linestyle='--')
ax2.set_ylabel('Wait List Length', color='red')
ax2.set_ylim(0)
ax2.tick_params(axis='y', labelcolor='red')



# Add title and show the plot
fig.tight_layout()  # Adjust layout to avoid overlap
plt.title('Waiting Time and Wait List Length Over Time with Moving Averages')
plt.show()
