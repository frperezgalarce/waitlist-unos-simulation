# %%
import pandas as pd 

df_base = pd.read_csv('data/data_to_simulate.csv', index_col=0)
df_base.dropna(inplace=True)
print(df_base.columns)
columns = ['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON', 'AGE', 'DIAB',
                'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI', 'SERUM_CREAT',
                'CREAT_TRR', 'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC','CREAT_TRRg1.5', 'SERUM_CREATg1.2',
                'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
                'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE','TX_DATE', 'PT_CODE', 'ABO', 'ABO_DON']

predictors = ['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'WGT_KG_DON_CALC',
                    'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'COD_CAD_DON', 'ETHCAT_DON', 'ABO_MAT', 
                    'HLAMIS', 'DIALYSIS_DATE', 'AGE', 'DIAB', 'DIALYSIS_DATEle0.0', 'CREAT_TRRg1.5', 'SERUM_CREATg1.2']

donor = df_base[['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 
            'HIST_HYPERTENS_DON', 'ABO_DON', 'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2']]

print(donor.columns)
donor.to_csv('data/donors.csv')

recipient = df_base[[ 'DIALYSIS_DATE', 'AGE', 'DIAB', 'ETHCAT', 'GENDER', 'ABO', 'DIALYSIS_DATEle0.0']]
recipient.to_csv('data/recipients.csv')

ethcat_mapping = {
    1: "White, Non-Hispanic",
    2: "Black, Non-Hispanic",
    4: "Hispanic/Latino",
    5: "Asian, Non-Hispanic",
    6: "Amer Ind/Alaska Native, Non-Hispanic",
    7: "Native Hawaiian/Other Pacific Islander, Non-Hispanic",
    9: "Multiracial, Non-Hispanic",
}
# Out:
# Index(['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON',
#        'AGE', 'DIAB', 'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI',
#        'SERUM_CREAT', 'ABO_MAT', 'AMIS', 'BMIS', 'DRMIS', 'CREAT_TRR',
#        'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC', 'ABO_DON',
#        'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
#        'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE', 'TX_DATE',
#        'PT_CODE', 'COMPOSITE_DEATH_DATE', 'ABO', 'T', 'Tag_date', 'DIAB_1',
#        'DIAB_998', 'HIST_DIABETES_DON_1', 'HIST_DIABETES_DON_998',
#        'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2',
#        'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype='object')
# Index(['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC',
#        'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'ABO_DON',
#        'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2'],
#       dtype='object')

# %%
real_gender_df = df_base.GENDER.value_counts(normalize=True).reset_index()
real_gender_df.columns = ['gender', 'sample_proportion']
real_gender_df
# Out:
#   gender  sample_proportion
# 0      M            0.64827
# 1      F            0.35173

# %%
real_ethcat_df = df_base.ETHCAT.value_counts(normalize=True).reset_index()
real_ethcat_df.ETHCAT = real_ethcat_df.ETHCAT.map(ethcat_mapping)
real_ethcat_df.columns = ['ethcat', 'sample_proportion']
real_ethcat_df
# Out:
#                                               ethcat  sample_proportion
# 0                                White, Non-Hispanic           0.439416
# 1                                Black, Non-Hispanic           0.325258
# 2                                    Hispanic/Latino           0.159551
# 3                                Asian, Non-Hispanic           0.053213
# 4               Amer Ind/Alaska Native, Non-Hispanic           0.013618
# 5                          Multiracial, Non-Hispanic           0.004764
# 6  Native Hawaiian/Other Pacific Islander, Non-Hi...           0.004180

# %%
recipient.ABO.unique()
# Out:
# array(['B', 'A', 'O', 'AB', 'A2', 'A1', 'A1B', 'A2B'], dtype=object)

# %%
blood_type_compatibility = {
    "A": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A1": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A2": ["A", "A1", "A2", "AB", "A1B", "A2B", "B"],
    "B":  ["B", "AB", "A1B", "A2B"],
    "AB": ["AB", "A1B", "A2B"],
    "A1B": ["A1B"],
    "A2B": ["A2B", "AB"],
    "O": ["A", "A1", "A2", "B", "AB", "A1B", "A2B", "O"]
}

# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
path = Path("C:/Users/HP/Desktop/UNOS data/codes/simulation-waitline-unos").resolve()  # Get the absolute path
os.chdir(path)
import pandas as pd
import numpy as np
import scipy as sc
import recipient as rec
import prediction as pred 
import donor as don
from event import Event

# %%
def create_list_of_events(n_events = 5000):
    events = Event(number_of_events= n_events, 
                    time_between_arrivals_recipients=4, 
                    time_between_arrivals_donor= 6) #average time in days
    events.create_events()
    return events

# %%
TARGET_TIME  = 5 * 365
SIMULATION_TIME = 365*30  
predictor = pred.SurvivalPredictionModel(model_path='models\decision_tree_2511.pkl')
#9.1% leave the list
#theshold_leave_list = 0.091 
recipients_for_initialization = 300
time_before_starting_simulation = 0
released_recipients = []
# Out:
# models\decision_tree_2511.pkl
# ok
# Model loaded successfully from models\decision_tree_2511.pkl.
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\HP\AppData\Local\Temp\ipykernel_10064\4126554741.py:3: SyntaxWarning: invalid escape sequence '\d'
#   predictor = pred.SurvivalPredictionModel(model_path='models\decision_tree_2511.pkl')

# %%
predictor.model.feature_names_in_
# Out:
# array(['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS',
#        'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'DIALYSIS_DATE', 'AGE',
#        'DIAB', 'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80',
#        'COD_CAD_DON_2', 'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype=object)

# %%
def get_expected_life(predicted_survival_function): 
    return sum((predicted_survival_function[0].x[i + 1] - predicted_survival_function[0].x[i]) *
    predicted_survival_function[0].y[i] for i in range(len(predicted_survival_function[0].x) - 1))

# %%
df = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
df_leaves = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
waiting_time_convergence = []
wait_list_length = []
leave_list_global = []



def run_simulation(T=10, replicates=1, verbose=False):
    waiting_time_convergence_r = []
    wait_list_length_r = []
    average_waiting_times = []
    number_of_matches_list = []
    
    for r in range(replicates):
        events = create_list_of_events(n_events = 10000)
        print('Replicate #', str(r))
        wait_list = []  # Initialize an empty waitlist for each replicate
        leave_list = []
        next_in_leave_the_list = []
        total_waiting_time = 0  # Track the total waiting time for this replicate
        num_matched_patients = 0  # Track the number of matched patients
        current_t = 0  # Start time    
    
        for i in range(recipients_for_initialization):
                new_recipient = rec.Recipient(time_before_starting_simulation) 
                new_recipient.create_recipient(i)
                wait_list.append(new_recipient)
                next_in_leave_the_list.append((new_recipient.time_to_leave_list, 
                                               new_recipient.reason_to_leave_list, 
                                               new_recipient.ID))
                next_in_leave_the_list = sorted(next_in_leave_the_list)
                
        while current_t < T:  
            (time_aux, _, _)  = events.list_of_events[0]
            (time2_aux, _, _) = next_in_leave_the_list[0]
            
            if time_aux + current_t < time2_aux:
                (time, event_type, counter)  = events.list_of_events.pop(0)
                ID = None
                print(time+current_t, event_type, ID)
            else: 
                (time, event_type, ID) = next_in_leave_the_list.pop(0)
                print(time, event_type, ID)
                   
            #print(time, event_type)         
            match event_type:
                case "new_donor":
                    current_t += time
                    donor = don.Donor(current_t)
                    donor.create_donor(counter)
                    
                    if len(wait_list) < 1:
                        raise('The waitlist length is 0, check the setup please')            
                    
                    survival_probs = []
                    for recipient in wait_list: 
                        if donor.blood in blood_type_compatibility[recipient.blood]: 
                            survival_probs.append(predictor.predict_survival_prob(recipient, donor, TARGET_TIME))
                        else: 
                             survival_probs.append(0)
                             
                    total_times = []           
                    
                    for recipient in wait_list:
                        if donor.blood in blood_type_compatibility[recipient.blood]:
                            _, function_pred = predictor.predict_survival_prob(recipient, donor, TARGET_TIME, surv_function=True)
                            total_ind = current_t-recipient.arrival_time + get_expected_life(function_pred)
                            total_times.append(total_ind)
                        else: 
                            total_times.append(-1)
                    
                    if len(survival_probs)>0: 
                        best_match_index = np.argmax(total_times)
                        recipient_best = wait_list[best_match_index]
                        _, predicted_survival_function = predictor.predict_survival_prob(recipient_best, donor, TARGET_TIME, surv_function=True)
                        
                        mean_survival_time = sum(
                        (predicted_survival_function[0].x[i + 1] - predicted_survival_function[0].x[i]) *
                        predicted_survival_function[0].y[i]
                        for i in range(len(predicted_survival_function[0].x) - 1)
)
                        
                        best_patient = wait_list.pop(best_match_index)
                        next_leave_time = [(a, b, c) for (a, b, c) in next_in_leave_the_list if c==best_patient.ID]
                        _index = next_in_leave_the_list.index(next_leave_time[0])   
                        _ = next_in_leave_the_list.pop(_index)
                        
                        print(f'A donation was done with expected life {mean_survival_time} and probabity {survival_probs[best_match_index]}. Day: ', str(current_t))
                        waiting_time = current_t - best_patient.arrival_time
                        
                        if current_t > 8*365.25:
                            total_waiting_time += waiting_time
                            
                        best_patient.waiting_time = waiting_time
                        
                        
                        if current_t > 8*365.25:
                            df.loc[len(df)] = [r, best_patient.ethcat, best_patient.gender, best_patient.waiting_time, mean_survival_time, current_t]
                            released_recipients.append(best_patient)
                            num_matched_patients += 1
                
                case "new_recipient":            
                    current_t += time
                    new_recipient = rec.Recipient(current_t) 
                    new_recipient.create_recipient(counter)
                    wait_list.append(new_recipient)
                    next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                    next_in_leave_the_list = sorted(next_in_leave_the_list)
                    print('A new recipient has arrived. Day: ', str(current_t))
                
                case "leave_list":
                    current_t = time
                    next_leave_time = [p for p in wait_list if p.ID==ID]
                    _index = wait_list.index(next_leave_time[0])   
                    out_of_list = wait_list.pop(_index)
                    leave_list.append(out_of_list)
                    
                    if current_t > 8*365.25:
                        df_leaves.loc[len(df)] = [r, out_of_list.ethcat, out_of_list.gender, out_of_list.waiting_time, _, current_t]
                        print('----------------------- One patient left the waitlist. Day: ', str(current_t), out_of_list.ID) 
                    
                    

            if num_matched_patients>0:
                if current_t > 8*365.25:
                    average_time = total_waiting_time / num_matched_patients
                    #we collect data after 8 years
                    waiting_time_convergence_r.append([current_t, average_time])
                wait_list_length_r.append([current_t, len(wait_list)])
            else: 
                average_time = 'INF'
            if verbose:
                print(f'Number of matches: {num_matched_patients}, recipients in wait list: {len(wait_list)},'
                      f'average time in waitlist {average_time}, patients which leave the list {len(leave_list)}')        
        if num_matched_patients > 0:
            average_waiting_times.append(total_waiting_time / num_matched_patients)
            waiting_time_convergence.append(waiting_time_convergence_r)
            wait_list_length.append(wait_list_length_r)
            number_of_matches_list.append(num_matched_patients)
            leave_list_global.append(leave_list)
        else:
            average_waiting_times.append(0)
            
    return average_waiting_times, number_of_matches_list

# %%
run_simulation(T=SIMULATION_TIME, replicates=1, verbose=True)
# Out:
# Replicate # 0
# 0.315783575824629 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  0.315783575824629
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 2.6781606383611742 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  2.6781606383611742
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 0
# 5.148806890223798 new_recipient None
# A new recipient has arrived. Day:  5.148806890223798
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 5.40076825023247 new_recipient None
# A new recipient has arrived. Day:  5.40076825023247
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 5.932254493768754 new_recipient None
# A new recipient has arrived. Day:  5.932254493768754
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 9.964949915225068 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  9.964949915225068
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 10.615735770662004 new_recipient None
# A new recipient has arrived. Day:  10.615735770662004
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 11.823850376055367 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  11.823850376055367
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 15.799193346940807 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  15.799193346940807
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 18.087119532433626 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  18.087119532433626
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 0
# 18.10324228019367 new_recipient None
# A new recipient has arrived. Day:  18.10324228019367
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 18.39168491695495 new_recipient None
# A new recipient has arrived. Day:  18.39168491695495
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 19.812328377794827 leave_list 11006
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 1
# 24.078195196674955 new_recipient None
# A new recipient has arrived. Day:  24.078195196674955
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 1
# 29.55919692840815 new_recipient None
# A new recipient has arrived. Day:  29.55919692840815
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 1
# 31.396155392542617 leave_list 19162
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 2
# 33.50053402012532 new_recipient None
# A new recipient has arrived. Day:  33.50053402012532
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 2
# 33.57155097958101 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  33.57155097958101
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 2
# 35.78602269930311 new_recipient None
# A new recipient has arrived. Day:  35.78602269930311
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 2
# 36.48985444798881 new_recipient None
# A new recipient has arrived. Day:  36.48985444798881
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 2
# 36.65390853221894 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  36.65390853221894
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 2
# 38.06344284740266 leave_list 14368
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 3
# 39.90657770716723 new_recipient None
# A new recipient has arrived. Day:  39.90657770716723
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 3
# 40.80142283204723 new_recipient None
# A new recipient has arrived. Day:  40.80142283204723
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 3
# 41.02514507912777 new_recipient None
# A new recipient has arrived. Day:  41.02514507912777
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 3
# 41.96603053794002 new_recipient None
# A new recipient has arrived. Day:  41.96603053794002
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 3
# 43.82837193139745 new_recipient None
# A new recipient has arrived. Day:  43.82837193139745
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 3
# 44.18500811281468 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  44.18500811281468
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 3
# 49.586228191908006 leave_list 8104
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 4
# 57.006505406553195 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  57.006505406553195
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 4
# 60.01032478509645 new_recipient None
# A new recipient has arrived. Day:  60.01032478509645
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 4
# 60.62641851636715 new_recipient None
# A new recipient has arrived. Day:  60.62641851636715
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 4
# 61.13483945585232 new_recipient None
# A new recipient has arrived. Day:  61.13483945585232
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 4
# 61.67333492554173 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  61.67333492554173
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 4
# 64.40437018573563 leave_list 3442
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 5
# 67.33054328894708 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  67.33054328894708
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 5
# 67.51750066078993 new_recipient None
# A new recipient has arrived. Day:  67.51750066078993
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 5
# 69.44844931069333 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  69.44844931069333
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 5
# 72.13029764381872 new_recipient None
# A new recipient has arrived. Day:  72.13029764381872
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 5
# 75.4351358328553 new_recipient None
# A new recipient has arrived. Day:  75.4351358328553
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 5
# 78.89683896454287 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  78.89683896454287
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 5
# 80.08163122253805 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  80.08163122253805
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 5
# 80.58452028047878 new_recipient None
# A new recipient has arrived. Day:  80.58452028047878
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 5
# 82.82297148359237 new_recipient None
# A new recipient has arrived. Day:  82.82297148359237
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 5
# 87.28589683718722 new_recipient None
# A new recipient has arrived. Day:  87.28589683718722
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 5
# 90.04667372948653 new_recipient None
# A new recipient has arrived. Day:  90.04667372948653
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 5
# 94.18121230693573 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  94.18121230693573
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 5
# 98.73608763058824 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  98.73608763058824
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 5
# 98.95580721815568 new_recipient None
# A new recipient has arrived. Day:  98.95580721815568
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 5
# 99.28699377662002 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  99.28699377662002
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 5
# 100.11064239946717 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  100.11064239946717
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 5
# 101.52595954847415 new_recipient None
# A new recipient has arrived. Day:  101.52595954847415
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 5
# 101.81248338842092 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  101.81248338842092
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 5
# 110.97932934044758 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  110.97932934044758
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 5
# 111.20299381408694 new_recipient None
# A new recipient has arrived. Day:  111.20299381408694
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 5
# 113.79304736436629 new_recipient None
# A new recipient has arrived. Day:  113.79304736436629
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 5
# 114.81792732317126 leave_list 945
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 6
# 118.45010324659289 new_recipient None
# A new recipient has arrived. Day:  118.45010324659289
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 6
# 119.26964285795948 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  119.26964285795948
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 6
# 119.2708308147158 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  119.2708308147158
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 6
# 122.68899908070766 new_recipient None
# A new recipient has arrived. Day:  122.68899908070766
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 6
# 125.3320722651828 leave_list 15882
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 7
# 128.71952507385038 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  128.71952507385038
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 7
# 129.85751859834264 new_recipient None
# A new recipient has arrived. Day:  129.85751859834264
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 7
# 130.42671529083475 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  130.42671529083475
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 7
# 131.43586357692254 new_recipient None
# A new recipient has arrived. Day:  131.43586357692254
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 7
# 132.26783477333106 leave_list 15399
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 8
# 133.75983694615655 new_recipient None
# A new recipient has arrived. Day:  133.75983694615655
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 8
# 138.32733155340577 new_recipient None
# A new recipient has arrived. Day:  138.32733155340577
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 8
# 138.9640484726691 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  138.9640484726691
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 8
# 139.40648605038723 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  139.40648605038723
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 8
# 140.50948986978423 new_recipient None
# A new recipient has arrived. Day:  140.50948986978423
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 8
# 142.22237309727677 new_recipient None
# A new recipient has arrived. Day:  142.22237309727677
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 8
# 143.53576343214743 leave_list 3318
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 9
# 147.5091283772962 new_recipient None
# A new recipient has arrived. Day:  147.5091283772962
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 9
# 148.31458943047082 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  148.31458943047082
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 9
# 151.5976765826956 new_recipient None
# A new recipient has arrived. Day:  151.5976765826956
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 9
# 152.90942756149704 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  152.90942756149704
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 9
# 158.75042918198665 new_recipient None
# A new recipient has arrived. Day:  158.75042918198665
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 9
# 159.4599140011102 new_recipient None
# A new recipient has arrived. Day:  159.4599140011102
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 9
# 161.73870042531888 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  161.73870042531888
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 9
# 171.05728716746057 leave_list 7502
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 10
# 172.0412123305929 leave_list 12244
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 11
# 180.2392897681887 leave_list 5163
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 12
# 180.48012369633176 leave_list 16500
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 13
# 182.32466731060973 leave_list 1753
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 14
# 193.78069002648155 new_recipient None
# A new recipient has arrived. Day:  193.78069002648155
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 14
# 195.62410543134857 new_recipient None
# A new recipient has arrived. Day:  195.62410543134857
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 14
# 197.39867527077539 leave_list 4153
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 15
# 200.43902508001068 new_recipient None
# A new recipient has arrived. Day:  200.43902508001068
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 15
# 200.6864584518181 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  200.6864584518181
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 15
# 200.8136360532986 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  200.8136360532986
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 15
# 201.23344423349093 new_recipient None
# A new recipient has arrived. Day:  201.23344423349093
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 15
# 202.7055396220451 new_recipient None
# A new recipient has arrived. Day:  202.7055396220451
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 15
# 204.1059171079513 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  204.1059171079513
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 15
# 205.0974217954799 new_recipient None
# A new recipient has arrived. Day:  205.0974217954799
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 15
# 207.53681537498136 new_recipient None
# A new recipient has arrived. Day:  207.53681537498136
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 15
# 210.1480972410866 new_recipient None
# A new recipient has arrived. Day:  210.1480972410866
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 15
# 215.462770670397 new_recipient None
# A new recipient has arrived. Day:  215.462770670397
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 15
# 215.66606107596616 leave_list 3318
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 16
# 219.25112582174242 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  219.25112582174242
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 16
# 223.12609014265695 leave_list 1753
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 17
# 227.79391441745324 new_recipient None
# A new recipient has arrived. Day:  227.79391441745324
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 17
# 228.060338285797 new_recipient None
# A new recipient has arrived. Day:  228.060338285797
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 17
# 229.35567508364988 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  229.35567508364988
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 17
# 230.44596863320754 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  230.44596863320754
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 17
# 232.3630738043777 new_recipient None
# A new recipient has arrived. Day:  232.3630738043777
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 17
# 232.6525028672643 new_recipient None
# A new recipient has arrived. Day:  232.6525028672643
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 17
# 233.45106363982418 new_recipient None
# A new recipient has arrived. Day:  233.45106363982418
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 17
# 234.14717292302862 new_recipient None
# A new recipient has arrived. Day:  234.14717292302862
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 17
# 234.7532805109474 new_recipient None
# A new recipient has arrived. Day:  234.7532805109474
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 17
# 238.33405380017413 new_recipient None
# A new recipient has arrived. Day:  238.33405380017413
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 17
# 238.60910725623836 new_recipient None
# A new recipient has arrived. Day:  238.60910725623836
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 17
# 244.25201959131994 new_recipient None
# A new recipient has arrived. Day:  244.25201959131994
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 17
# 244.7539993838235 new_recipient None
# A new recipient has arrived. Day:  244.7539993838235
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 17
# 245.46932608589717 new_donor None
# A donation was done with expected life 2354.0468992355763 and probabity 0.6213407169292465. Day:  245.46932608589717
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 17
# 246.63360562729636 leave_list 21848
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 18
# 247.93437120877184 new_recipient None
# A new recipient has arrived. Day:  247.93437120877184
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 18
# 256.0695523432165 new_recipient None
# A new recipient has arrived. Day:  256.0695523432165
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 18
# 256.16084006474955 new_recipient None
# A new recipient has arrived. Day:  256.16084006474955
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 18
# 258.82839937075556 leave_list 2594
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 19
# 262.42365690945473 new_recipient None
# A new recipient has arrived. Day:  262.42365690945473
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 19
# 265.72967348259107 new_recipient None
# A new recipient has arrived. Day:  265.72967348259107
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 19
# 267.82911895206314 new_recipient None
# A new recipient has arrived. Day:  267.82911895206314
# Number of matches: 0, recipients in wait list: 312,average time in waitlist INF, patients which leave the list 19
# 271.4636501880847 new_recipient None
# A new recipient has arrived. Day:  271.4636501880847
# Number of matches: 0, recipients in wait list: 313,average time in waitlist INF, patients which leave the list 19
# 271.964221219087 new_recipient None
# A new recipient has arrived. Day:  271.964221219087
# Number of matches: 0, recipients in wait list: 314,average time in waitlist INF, patients which leave the list 19
# 272.5463820797254 new_recipient None
# A new recipient has arrived. Day:  272.5463820797254
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 19
# 273.22311049868296 new_recipient None
# A new recipient has arrived. Day:  273.22311049868296
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 19
# 274.8981901878996 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  274.8981901878996
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 19
# 275.60767062678093 leave_list 21553
# Number of matches: 0, recipients in wait list: 314,average time in waitlist INF, patients which leave the list 20
# 279.3601215094946 new_recipient None
# A new recipient has arrived. Day:  279.3601215094946
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 20
# 279.451362997287 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  279.451362997287
# Number of matches: 0, recipients in wait list: 314,average time in waitlist INF, patients which leave the list 20
# 280.51414605971905 new_recipient None
# A new recipient has arrived. Day:  280.51414605971905
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 20
# 281.7772746209527 new_recipient None
# A new recipient has arrived. Day:  281.7772746209527
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 20
# 282.0358891514249 new_recipient None
# A new recipient has arrived. Day:  282.0358891514249
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 20
# 282.5809975200743 new_recipient None
# A new recipient has arrived. Day:  282.5809975200743
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 20
# 287.99188632998914 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  287.99188632998914
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 20
# 290.41259954051003 new_recipient None
# A new recipient has arrived. Day:  290.41259954051003
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 20
# 291.3382518335578 new_recipient None
# A new recipient has arrived. Day:  291.3382518335578
# Number of matches: 0, recipients in wait list: 319,average time in waitlist INF, patients which leave the list 20
# 291.40575102725865 new_recipient None
# A new recipient has arrived. Day:  291.40575102725865
# Number of matches: 0, recipients in wait list: 320,average time in waitlist INF, patients which leave the list 20
# 291.6427874367315 new_recipient None
# A new recipient has arrived. Day:  291.6427874367315
# Number of matches: 0, recipients in wait list: 321,average time in waitlist INF, patients which leave the list 20
# 291.6453466730353 new_recipient None
# A new recipient has arrived. Day:  291.6453466730353
# Number of matches: 0, recipients in wait list: 322,average time in waitlist INF, patients which leave the list 20
# 295.8855315550492 leave_list 20014
# Number of matches: 0, recipients in wait list: 321,average time in waitlist INF, patients which leave the list 21
# 300.3414555239345 leave_list 1373
# Number of matches: 0, recipients in wait list: 320,average time in waitlist INF, patients which leave the list 22
# 302.8598055806273 leave_list 19162
# Number of matches: 0, recipients in wait list: 319,average time in waitlist INF, patients which leave the list 23
# 303.0103278186697 leave_list 8901
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 24
# 308.68562486045 new_recipient None
# A new recipient has arrived. Day:  308.68562486045
# Number of matches: 0, recipients in wait list: 319,average time in waitlist INF, patients which leave the list 24
# 310.02951608180626 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  310.02951608180626
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 24
# 310.13836538657637 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  310.13836538657637
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 24
# 314.1464442361198 new_recipient None
# A new recipient has arrived. Day:  314.1464442361198
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 24
# 314.6140115003044 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  314.6140115003044
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 24
# 317.4309731763119 new_recipient None
# A new recipient has arrived. Day:  317.4309731763119
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 24
# 317.7692981857597 new_recipient None
# A new recipient has arrived. Day:  317.7692981857597
# Number of matches: 0, recipients in wait list: 319,average time in waitlist INF, patients which leave the list 24
# 318.3231638286692 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  318.3231638286692
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 24
# 319.2108548645687 leave_list 16121
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 25
# 321.25997823055144 new_recipient None
# A new recipient has arrived. Day:  321.25997823055144
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 25
# 321.83641810342397 new_recipient None
# A new recipient has arrived. Day:  321.83641810342397
# Number of matches: 0, recipients in wait list: 319,average time in waitlist INF, patients which leave the list 25
# 322.55573698291744 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  322.55573698291744
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 25
# 322.7470929186437 leave_list 4970
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 26
# 325.33782051953915 new_recipient None
# A new recipient has arrived. Day:  325.33782051953915
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 26
# 329.97266660444274 new_recipient None
# A new recipient has arrived. Day:  329.97266660444274
# Number of matches: 0, recipients in wait list: 319,average time in waitlist INF, patients which leave the list 26
# 333.61887752145014 leave_list 20581
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 27
# 338.64563244005956 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  338.64563244005956
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 27
# 342.16717602116864 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  342.16717602116864
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 27
# 342.7967909974273 new_recipient None
# A new recipient has arrived. Day:  342.7967909974273
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 27
# 350.6678234130754 new_donor None
# A donation was done with expected life 2354.0468992355763 and probabity 0.6213407169292465. Day:  350.6678234130754
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 27
# 355.9493573797674 new_recipient None
# A new recipient has arrived. Day:  355.9493573797674
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 27
# 356.15577366455443 new_recipient None
# A new recipient has arrived. Day:  356.15577366455443
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 27
# 356.7226246461152 leave_list 2817
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 28
# 357.3231360454284 leave_list 21003
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 29
# 357.6716653587268 leave_list 880
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 30
# 369.46725828738147 leave_list 1090
# Number of matches: 0, recipients in wait list: 314,average time in waitlist INF, patients which leave the list 31
# 370.8504014415669 leave_list 13771
# Number of matches: 0, recipients in wait list: 313,average time in waitlist INF, patients which leave the list 32
# 372.5204997379822 leave_list 12295
# Number of matches: 0, recipients in wait list: 312,average time in waitlist INF, patients which leave the list 33
# 377.75704152235477 leave_list 12435
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 34
# 381.47273400167967 leave_list 5163
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 35
# 384.2585254280146 leave_list 18962
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 36
# 387.50398300098993 leave_list 12244
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 37
# 399.4463455769416 leave_list 13393
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 38
# 405.60223542677136 leave_list 5691
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 39
# 409.24569486915954 leave_list 7395
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 40
# 411.9958469365262 leave_list 13378
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 41
# 424.29061550572936 new_recipient None
# A new recipient has arrived. Day:  424.29061550572936
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 41
# 425.816483536051 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  425.816483536051
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 41
# 426.63771401664974 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  426.63771401664974
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 41
# 428.5233739279596 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  428.5233739279596
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 41
# 429.0678167124243 leave_list 2948
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 42
# 430.8104041658343 leave_list 19320
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 43
# 433.3536121334887 new_recipient None
# A new recipient has arrived. Day:  433.3536121334887
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 43
# 433.5787113888827 new_recipient None
# A new recipient has arrived. Day:  433.5787113888827
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 43
# 437.34474146886026 new_recipient None
# A new recipient has arrived. Day:  437.34474146886026
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 43
# 440.0669050305672 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  440.0669050305672
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 43
# 441.3969033902644 leave_list 9478
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 44
# 446.1369187662746 leave_list 1827
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 45
# 450.28153780991806 leave_list 4833
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 46
# 458.11600971361037 new_recipient None
# A new recipient has arrived. Day:  458.11600971361037
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 46
# 463.47639611979275 leave_list 20581
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 47
# 469.81472107821173 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  469.81472107821173
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 47
# 477.5888133120699 new_recipient None
# A new recipient has arrived. Day:  477.5888133120699
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 47
# 479.1345529157685 new_recipient None
# A new recipient has arrived. Day:  479.1345529157685
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 47
# 479.4116237268229 leave_list 2817
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 48
# 482.54552593934505 new_recipient None
# A new recipient has arrived. Day:  482.54552593934505
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 48
# 483.9942159915082 new_recipient None
# A new recipient has arrived. Day:  483.9942159915082
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 48
# 491.0203861567437 new_recipient None
# A new recipient has arrived. Day:  491.0203861567437
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 48
# 493.08676373385555 new_recipient None
# A new recipient has arrived. Day:  493.08676373385555
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 48
# 493.6872219092847 new_recipient None
# A new recipient has arrived. Day:  493.6872219092847
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 48
# 497.7136690482724 leave_list 21702
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 49
# 509.786235510003 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  509.786235510003
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 49
# 510.38858335302035 new_recipient None
# A new recipient has arrived. Day:  510.38858335302035
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 49
# 510.62964706362584 leave_list 8090
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 50
# 520.2696282106824 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  520.2696282106824
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 50
# 521.9930285944448 leave_list 9072
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 51
# 524.8783667719322 new_recipient None
# A new recipient has arrived. Day:  524.8783667719322
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 51
# 526.8842579213701 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  526.8842579213701
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 51
# 530.2383754987646 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  530.2383754987646
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 51
# 530.6086540409227 new_recipient None
# A new recipient has arrived. Day:  530.6086540409227
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 51
# 534.4385327442355 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  534.4385327442355
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 51
# 535.2459194103958 new_recipient None
# A new recipient has arrived. Day:  535.2459194103958
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 51
# 535.2561807747675 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  535.2561807747675
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 51
# 535.8185060276587 new_recipient None
# A new recipient has arrived. Day:  535.8185060276587
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 51
# 536.3875757718237 new_recipient None
# A new recipient has arrived. Day:  536.3875757718237
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 51
# 538.6944628881071 new_recipient None
# A new recipient has arrived. Day:  538.6944628881071
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 51
# 541.2091551663494 leave_list 2709
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 52
# 544.142734619944 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  544.142734619944
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 52
# 545.9899062211646 new_recipient None
# A new recipient has arrived. Day:  545.9899062211646
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 52
# 547.0581147395707 new_recipient None
# A new recipient has arrived. Day:  547.0581147395707
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 52
# 550.5552660601237 new_recipient None
# A new recipient has arrived. Day:  550.5552660601237
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 52
# 551.5747806639532 new_recipient None
# A new recipient has arrived. Day:  551.5747806639532
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 52
# 556.139363523234 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  556.139363523234
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 52
# 557.4292792970339 leave_list 21533
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 53
# 559.8903449694236 new_recipient None
# A new recipient has arrived. Day:  559.8903449694236
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 53
# 566.0182605386423 new_recipient None
# A new recipient has arrived. Day:  566.0182605386423
# ...
# Number of matches: 1125, recipients in wait list: 251,average time in waitlist 1310.196690932647, patients which leave the list 767
# 10803.94894715373 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  10803.94894715373
# Number of matches: 1126, recipients in wait list: 250,average time in waitlist 1309.9317857907163, patients which leave the list 767
# 10804.133644575948 new_recipient None
# A new recipient has arrived. Day:  10804.133644575948
# Number of matches: 1126, recipients in wait list: 251,average time in waitlist 1309.9317857907163, patients which leave the list 767
# 10804.27381711429 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  10804.27381711429
# Number of matches: 1127, recipients in wait list: 250,average time in waitlist 1309.6382624519713, patients which leave the list 767
# 10807.336791409345 leave_list 15639
# ----------------------- One patient left the waitlist. Day:  10807.336791409345 15639
# Number of matches: 1127, recipients in wait list: 249,average time in waitlist 1309.6382624519713, patients which leave the list 768
# 10808.536040936367 leave_list 19042
# ----------------------- One patient left the waitlist. Day:  10808.536040936367 19042
# Number of matches: 1127, recipients in wait list: 248,average time in waitlist 1309.6382624519713, patients which leave the list 769
# 10813.111165843906 new_recipient None
# A new recipient has arrived. Day:  10813.111165843906
# Number of matches: 1127, recipients in wait list: 249,average time in waitlist 1309.6382624519713, patients which leave the list 769
# 10813.640637031978 new_recipient None
# A new recipient has arrived. Day:  10813.640637031978
# Number of matches: 1127, recipients in wait list: 250,average time in waitlist 1309.6382624519713, patients which leave the list 769
# 10814.583329829058 leave_list 132
# ----------------------- One patient left the waitlist. Day:  10814.583329829058 132
# Number of matches: 1127, recipients in wait list: 249,average time in waitlist 1309.6382624519713, patients which leave the list 770
# 10817.67296397407 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  10817.67296397407
# Number of matches: 1128, recipients in wait list: 248,average time in waitlist 1309.647694387369, patients which leave the list 770
# 10818.670224362919 new_recipient None
# A new recipient has arrived. Day:  10818.670224362919
# Number of matches: 1128, recipients in wait list: 249,average time in waitlist 1309.647694387369, patients which leave the list 770
# 10820.150281644843 new_recipient None
# A new recipient has arrived. Day:  10820.150281644843
# Number of matches: 1128, recipients in wait list: 250,average time in waitlist 1309.647694387369, patients which leave the list 770
# 10822.77717378277 new_recipient None
# A new recipient has arrived. Day:  10822.77717378277
# Number of matches: 1128, recipients in wait list: 251,average time in waitlist 1309.647694387369, patients which leave the list 770
# 10823.361419188894 new_recipient None
# A new recipient has arrived. Day:  10823.361419188894
# Number of matches: 1128, recipients in wait list: 252,average time in waitlist 1309.647694387369, patients which leave the list 770
# 10824.525776175122 new_recipient None
# A new recipient has arrived. Day:  10824.525776175122
# Number of matches: 1128, recipients in wait list: 253,average time in waitlist 1309.647694387369, patients which leave the list 770
# 10826.58686776434 leave_list 15157
# ----------------------- One patient left the waitlist. Day:  10826.58686776434 15157
# Number of matches: 1128, recipients in wait list: 252,average time in waitlist 1309.647694387369, patients which leave the list 771
# 10834.160281089004 new_recipient None
# A new recipient has arrived. Day:  10834.160281089004
# Number of matches: 1128, recipients in wait list: 253,average time in waitlist 1309.647694387369, patients which leave the list 771
# 10836.474516625618 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  10836.474516625618
# Number of matches: 1129, recipients in wait list: 252,average time in waitlist 1309.6362351746288, patients which leave the list 771
# 10838.064855115674 new_recipient None
# A new recipient has arrived. Day:  10838.064855115674
# Number of matches: 1129, recipients in wait list: 253,average time in waitlist 1309.6362351746288, patients which leave the list 771
# 10838.920513679459 new_recipient None
# A new recipient has arrived. Day:  10838.920513679459
# Number of matches: 1129, recipients in wait list: 254,average time in waitlist 1309.6362351746288, patients which leave the list 771
# 10842.810625791797 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  10842.810625791797
# Number of matches: 1130, recipients in wait list: 253,average time in waitlist 1309.3610111436967, patients which leave the list 771
# 10843.724273930004 new_recipient None
# A new recipient has arrived. Day:  10843.724273930004
# Number of matches: 1130, recipients in wait list: 254,average time in waitlist 1309.3610111436967, patients which leave the list 771
# 10845.627087740997 leave_list 12127
# ----------------------- One patient left the waitlist. Day:  10845.627087740997 12127
# Number of matches: 1130, recipients in wait list: 253,average time in waitlist 1309.3610111436967, patients which leave the list 772
# 10848.652901958714 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  10848.652901958714
# Number of matches: 1131, recipients in wait list: 252,average time in waitlist 1309.1323097404472, patients which leave the list 772
# 10849.160763726943 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  10849.160763726943
# Number of matches: 1132, recipients in wait list: 251,average time in waitlist 1309.16603916509, patients which leave the list 772
# 10856.510512250687 new_recipient None
# A new recipient has arrived. Day:  10856.510512250687
# Number of matches: 1132, recipients in wait list: 252,average time in waitlist 1309.16603916509, patients which leave the list 772
# 10856.697783582966 new_recipient None
# A new recipient has arrived. Day:  10856.697783582966
# Number of matches: 1132, recipients in wait list: 253,average time in waitlist 1309.16603916509, patients which leave the list 772
# 10857.183727388827 new_recipient None
# A new recipient has arrived. Day:  10857.183727388827
# Number of matches: 1132, recipients in wait list: 254,average time in waitlist 1309.16603916509, patients which leave the list 772
# 10865.151112854865 new_recipient None
# A new recipient has arrived. Day:  10865.151112854865
# Number of matches: 1132, recipients in wait list: 255,average time in waitlist 1309.16603916509, patients which leave the list 772
# 10867.96787012623 new_recipient None
# A new recipient has arrived. Day:  10867.96787012623
# Number of matches: 1132, recipients in wait list: 256,average time in waitlist 1309.16603916509, patients which leave the list 772
# 10868.523236533378 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10868.523236533378
# Number of matches: 1133, recipients in wait list: 255,average time in waitlist 1309.1730186964876, patients which leave the list 772
# 10876.635490943441 new_recipient None
# A new recipient has arrived. Day:  10876.635490943441
# Number of matches: 1133, recipients in wait list: 256,average time in waitlist 1309.1730186964876, patients which leave the list 772
# 10877.512724744496 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  10877.512724744496
# Number of matches: 1134, recipients in wait list: 255,average time in waitlist 1308.9329240021852, patients which leave the list 772
# 10880.268390977275 leave_list 7795
# ----------------------- One patient left the waitlist. Day:  10880.268390977275 7795
# Number of matches: 1134, recipients in wait list: 254,average time in waitlist 1308.9329240021852, patients which leave the list 773
# 10884.698345507331 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  10884.698345507331
# Number of matches: 1135, recipients in wait list: 253,average time in waitlist 1308.9431423202025, patients which leave the list 773
# 10892.749408634962 new_recipient None
# A new recipient has arrived. Day:  10892.749408634962
# Number of matches: 1135, recipients in wait list: 254,average time in waitlist 1308.9431423202025, patients which leave the list 773
# 10893.708423616477 new_recipient None
# A new recipient has arrived. Day:  10893.708423616477
# Number of matches: 1135, recipients in wait list: 255,average time in waitlist 1308.9431423202025, patients which leave the list 773
# 10895.702522807453 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10895.702522807453
# Number of matches: 1136, recipients in wait list: 254,average time in waitlist 1308.947972907311, patients which leave the list 773
# 10900.113739915994 new_recipient None
# A new recipient has arrived. Day:  10900.113739915994
# Number of matches: 1136, recipients in wait list: 255,average time in waitlist 1308.947972907311, patients which leave the list 773
# 10900.343963228243 leave_list 3977
# ----------------------- One patient left the waitlist. Day:  10900.343963228243 3977
# Number of matches: 1136, recipients in wait list: 254,average time in waitlist 1308.947972907311, patients which leave the list 774
# 10905.516528574013 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10905.516528574013
# Number of matches: 1137, recipients in wait list: 253,average time in waitlist 1309.206079447062, patients which leave the list 774
# 10906.174444305987 leave_list 10962
# ----------------------- One patient left the waitlist. Day:  10906.174444305987 10962
# Number of matches: 1137, recipients in wait list: 252,average time in waitlist 1309.206079447062, patients which leave the list 775
# 10907.404490161858 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10907.404490161858
# Number of matches: 1138, recipients in wait list: 251,average time in waitlist 1310.970067168319, patients which leave the list 775
# 10908.115885880918 new_recipient None
# A new recipient has arrived. Day:  10908.115885880918
# Number of matches: 1138, recipients in wait list: 252,average time in waitlist 1310.970067168319, patients which leave the list 775
# 10909.173260841668 leave_list 6730
# ----------------------- One patient left the waitlist. Day:  10909.173260841668 6730
# Number of matches: 1138, recipients in wait list: 251,average time in waitlist 1310.970067168319, patients which leave the list 776
# 10910.546454971663 new_recipient None
# A new recipient has arrived. Day:  10910.546454971663
# Number of matches: 1138, recipients in wait list: 252,average time in waitlist 1310.970067168319, patients which leave the list 776
# 10910.85444761675 new_recipient None
# A new recipient has arrived. Day:  10910.85444761675
# Number of matches: 1138, recipients in wait list: 253,average time in waitlist 1310.970067168319, patients which leave the list 776
# 10911.203666579433 leave_list 4945
# ----------------------- One patient left the waitlist. Day:  10911.203666579433 4945
# Number of matches: 1138, recipients in wait list: 252,average time in waitlist 1310.970067168319, patients which leave the list 777
# 10912.417493913239 new_recipient None
# A new recipient has arrived. Day:  10912.417493913239
# Number of matches: 1138, recipients in wait list: 253,average time in waitlist 1310.970067168319, patients which leave the list 777
# 10912.968304808417 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10912.968304808417
# Number of matches: 1139, recipients in wait list: 252,average time in waitlist 1312.5887959418283, patients which leave the list 777
# 10914.751818745852 leave_list 12785
# ----------------------- One patient left the waitlist. Day:  10914.751818745852 12785
# Number of matches: 1139, recipients in wait list: 251,average time in waitlist 1312.5887959418283, patients which leave the list 778
# 10918.21863866214 new_recipient None
# A new recipient has arrived. Day:  10918.21863866214
# Number of matches: 1139, recipients in wait list: 252,average time in waitlist 1312.5887959418283, patients which leave the list 778
# 10919.090999435446 new_recipient None
# A new recipient has arrived. Day:  10919.090999435446
# Number of matches: 1139, recipients in wait list: 253,average time in waitlist 1312.5887959418283, patients which leave the list 778
# 10920.826108808287 leave_list 13815
# ----------------------- One patient left the waitlist. Day:  10920.826108808287 13815
# Number of matches: 1139, recipients in wait list: 252,average time in waitlist 1312.5887959418283, patients which leave the list 779
# 10923.531053451627 new_recipient None
# A new recipient has arrived. Day:  10923.531053451627
# Number of matches: 1139, recipients in wait list: 253,average time in waitlist 1312.5887959418283, patients which leave the list 779
# 10926.916012302385 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  10926.916012302385
# Number of matches: 1140, recipients in wait list: 252,average time in waitlist 1312.6256458722858, patients which leave the list 779
# 10931.202904414697 new_recipient None
# A new recipient has arrived. Day:  10931.202904414697
# Number of matches: 1140, recipients in wait list: 253,average time in waitlist 1312.6256458722858, patients which leave the list 779
# 10934.693592662397 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  10934.693592662397
# Number of matches: 1141, recipients in wait list: 252,average time in waitlist 1312.433326108788, patients which leave the list 779
# 10937.302277591969 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  10937.302277591969
# Number of matches: 1142, recipients in wait list: 251,average time in waitlist 1312.523548951835, patients which leave the list 779
# 10941.685805215799 leave_list 5796
# ----------------------- One patient left the waitlist. Day:  10941.685805215799 5796
# Number of matches: 1142, recipients in wait list: 250,average time in waitlist 1312.523548951835, patients which leave the list 780
# 10946.575746755994 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  10946.575746755994
# Number of matches: 1143, recipients in wait list: 249,average time in waitlist 1312.562598582198, patients which leave the list 780
# 10946.623019006624 new_recipient None
# A new recipient has arrived. Day:  10946.623019006624
# Number of matches: 1143, recipients in wait list: 250,average time in waitlist 1312.562598582198, patients which leave the list 780
# 10948.052177881356 new_recipient None
# A new recipient has arrived. Day:  10948.052177881356
# Number of matches: 1143, recipients in wait list: 251,average time in waitlist 1312.562598582198, patients which leave the list 780
# 10949.135716515826 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  10949.135716515826
# Number of matches: 1144, recipients in wait list: 250,average time in waitlist 1312.3527354999555, patients which leave the list 780
# 10951.174838999745 new_recipient None
# A new recipient has arrived. Day:  10951.174838999745
# Number of matches: 1144, recipients in wait list: 251,average time in waitlist 1312.3527354999555, patients which leave the list 780
# ([1312.3527354999555], [1144])

# %%
df['ethcat'] = df['ethcat'].replace(ethcat_mapping)

# %%
df_waiting_time = ((df.groupby(by=['replicate', 'ethcat'])
                   .agg(
                       waiting_time=('waiting_time', 'mean'), 
                       count=('waiting_time', 'size'), 
                       mean_survival_time=('mean_survival_time', 'mean'))
                   .reset_index())
)#.to_csv('simulation_results.csv')
df_waiting_time = df_waiting_time[['ethcat', 'waiting_time', 'count', 'mean_survival_time']].groupby('ethcat').agg(['mean', 'std'])
df_waiting_time.columns = [f"{col[0]}_{col[1]}" for col in df_waiting_time.columns] 
df_waiting_time['prop_simu'] = df_waiting_time['count_mean'] / df_waiting_time['count_mean'].sum()
df_waiting_time = df_waiting_time.merge(real_ethcat_df, on='ethcat').round(3)
df_waiting_time.columns = ['ethcat', 'wt_mean', 'wt_std', 'count_mean', 'count_std', 'st_mean', 'st_std', 'prop_simu', 'sample_proportion']
df_waiting_time
# Out:
#                                               ethcat   wt_mean  wt_std  \
# 0               Amer Ind/Alaska Native, Non-Hispanic  1284.512     NaN
# 1                                Asian, Non-Hispanic  1293.081     NaN
# 2                                Black, Non-Hispanic  1317.722     NaN
# 3                                    Hispanic/Latino  1299.906     NaN
# 4                          Multiracial, Non-Hispanic  1553.840     NaN
# 5  Native Hawaiian/Other Pacific Islander, Non-Hi...  1349.434     NaN
# 6                                White, Non-Hispanic  1312.321     NaN
#
#    count_mean  count_std   st_mean  st_std  prop_simu  sample_proportion
# 0         9.0        NaN  2868.835     NaN      0.008              0.014
# 1        55.0        NaN  2955.085     NaN      0.048              0.053
# 2       366.0        NaN  2961.069     NaN      0.320              0.325
# 3       205.0        NaN  2932.072     NaN      0.179              0.160
# 4         7.0        NaN  3038.760     NaN      0.006              0.005
# 5         6.0        NaN  2950.441     NaN      0.005              0.004
# 6       496.0        NaN  2963.696     NaN      0.434              0.439

# %%
df_gender = ((df.groupby(by=['replicate', 'gender'])
                .agg(
                    waiting_time=('waiting_time', 'mean'), 
                    count=('waiting_time', 'size'),
                    mean_survival_time=('mean_survival_time', 'mean'))
                .reset_index())
)#.to_csv('simulation_results.csv')
df_gender = df_gender[['gender', 'waiting_time', 'count', 'mean_survival_time']].groupby('gender').agg(['mean', 'std'])
df_gender.columns = [f"{col[0]}_{col[1]}" for col in df_gender.columns] 
df_gender['proportion_sim'] = df_gender['count_mean'] / df_gender['count_mean'].sum()
df_gender.reset_index(inplace=True)
df_gender = df_gender.merge(real_gender_df, on = 'gender')
df_gender.columns = ['gender', 'wt_mean', 'wt_std', 'count_mean',
       'count_std', 'st_mean', 'st_std',
       'prop_sim', 'sample_proportion']
df_gender.round(3)
# Out:
#   gender   wt_mean  wt_std  count_mean  count_std   st_mean  st_std  prop_sim  \
# 0      F  1302.294     NaN       421.0        NaN  2952.929     NaN     0.368
# 1      M  1318.210     NaN       723.0        NaN  2958.449     NaN     0.632
#
#    sample_proportion
# 0              0.352
# 1              0.648

# %%
#df.to_csv('results_decision_tree.csv')
