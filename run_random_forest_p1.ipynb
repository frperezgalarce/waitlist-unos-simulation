# %%
import pandas as pd 

df_base = pd.read_csv('data/data_to_simulate.csv', index_col=0)
df_base.dropna(inplace=True)
print(df_base.columns)
columns = ['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON', 'AGE', 'DIAB',
                'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI', 'SERUM_CREAT',
                'CREAT_TRR', 'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC','CREAT_TRRg1.5', 'SERUM_CREATg1.2',
                'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
                'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE','TX_DATE', 'PT_CODE', 'ABO', 'ABO_DON']

predictors = ['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'WGT_KG_DON_CALC',
                    'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'COD_CAD_DON', 'ETHCAT_DON', 'ABO_MAT', 
                    'HLAMIS', 'DIALYSIS_DATE', 'AGE', 'DIAB', 'DIALYSIS_DATEle0.0', 'CREAT_TRRg1.5', 'SERUM_CREATg1.2']

donor = df_base[['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 
            'HIST_HYPERTENS_DON', 'ABO_DON', 'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2']]

print(donor.columns)
donor.to_csv('data/donors.csv')

recipient = df_base[[ 'DIALYSIS_DATE', 'AGE', 'DIAB', 'ETHCAT', 'GENDER', 'ABO', 'DIALYSIS_DATEle0.0']]
recipient.to_csv('data/recipients.csv')

ethcat_mapping = {
    1: "White, Non-Hispanic",
    2: "Black, Non-Hispanic",
    4: "Hispanic/Latino",
    5: "Asian, Non-Hispanic",
    6: "Amer Ind/Alaska Native, Non-Hispanic",
    7: "Native Hawaiian/Other Pacific Islander, Non-Hispanic",
    9: "Multiracial, Non-Hispanic",
}
# Out:
# Index(['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON',
#        'AGE', 'DIAB', 'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI',
#        'SERUM_CREAT', 'ABO_MAT', 'AMIS', 'BMIS', 'DRMIS', 'CREAT_TRR',
#        'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC', 'ABO_DON',
#        'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
#        'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE', 'TX_DATE',
#        'PT_CODE', 'COMPOSITE_DEATH_DATE', 'ABO', 'T', 'Tag_date', 'DIAB_1',
#        'DIAB_998', 'HIST_DIABETES_DON_1', 'HIST_DIABETES_DON_998',
#        'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2',
#        'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype='object')
# Index(['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC',
#        'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'ABO_DON',
#        'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2'],
#       dtype='object')

# %%
real_gender_df = df_base.GENDER.value_counts(normalize=True).reset_index()
real_gender_df.columns = ['gender', 'sample_proportion']
real_gender_df
# Out:
#   gender  sample_proportion
# 0      M            0.64827
# 1      F            0.35173

# %%
real_ethcat_df = df_base.ETHCAT.value_counts(normalize=True).reset_index()
real_ethcat_df.ETHCAT = real_ethcat_df.ETHCAT.map(ethcat_mapping)
real_ethcat_df.columns = ['ethcat', 'sample_proportion']
real_ethcat_df
# Out:
#                                               ethcat  sample_proportion
# 0                                White, Non-Hispanic           0.439416
# 1                                Black, Non-Hispanic           0.325258
# 2                                    Hispanic/Latino           0.159551
# 3                                Asian, Non-Hispanic           0.053213
# 4               Amer Ind/Alaska Native, Non-Hispanic           0.013618
# 5                          Multiracial, Non-Hispanic           0.004764
# 6  Native Hawaiian/Other Pacific Islander, Non-Hi...           0.004180

# %%
recipient.ABO.unique()
# Out:
# array(['B', 'A', 'O', 'AB', 'A2', 'A1', 'A1B', 'A2B'], dtype=object)

# %%
blood_type_compatibility = {
    "A": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A1": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A2": ["A", "A1", "A2", "AB", "A1B", "A2B", "B"],
    "B":  ["B", "AB", "A1B", "A2B"],
    "AB": ["AB", "A1B", "A2B"],
    "A1B": ["A1B"],
    "A2B": ["A2B", "AB"],
    "O": ["A", "A1", "A2", "B", "AB", "A1B", "A2B", "O"]
}

# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
path = Path("C:/Users/HP/Desktop/UNOS data/codes/simulation-waitline-unos").resolve()  # Get the absolute path
os.chdir(path)
import pandas as pd
import numpy as np
import scipy as sc
import recipient as rec
import prediction as pred 
import donor as don
from event import Event

# %%
def create_list_of_events(n_events = 10000):
    events = Event(number_of_events= n_events, 
                    time_between_arrivals_recipients=4, 
                    time_between_arrivals_donor= 6) #average time in days
    events.create_events()
    return events

# %%
TARGET_TIME  = 5 * 365
SIMULATION_TIME = 365*30 
predictor = pred.SurvivalPredictionModel(model_path='models/random_forest_2511.pkl')
#9.1% leave the list
#theshold_leave_list = 0.091 
recipients_for_initialization = 300
time_before_starting_simulation = 0
released_recipients = []
# Out:
# models/random_forest_2511.pkl
# ok
# Model loaded successfully from models/random_forest_2511.pkl.

# %%
predictor.model.feature_names_in_
# Out:
# array(['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS',
#        'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'DIALYSIS_DATE', 'AGE',
#        'DIAB', 'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80',
#        'COD_CAD_DON_2', 'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype=object)

# %%
df = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
df_leaves = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
waiting_time_convergence = []
wait_list_length = []
leave_list_global = []



def run_simulation(T=10, replicates=1, verbose=False):
    waiting_time_convergence_r = []
    wait_list_length_r = []
    average_waiting_times = []
    number_of_matches_list = []
    
    for r in range(replicates):
        events = create_list_of_events(n_events = 10000)
        print('Replicate #', str(r))
        wait_list = []  # Initialize an empty waitlist for each replicate
        leave_list = []
        next_in_leave_the_list = []
        total_waiting_time = 0  # Track the total waiting time for this replicate
        num_matched_patients = 0  # Track the number of matched patients
        current_t = 0  # Start time    
    
        for i in range(recipients_for_initialization):
                new_recipient = rec.Recipient(time_before_starting_simulation) 
                new_recipient.create_recipient(i)
                wait_list.append(new_recipient)
                next_in_leave_the_list.append((new_recipient.time_to_leave_list, 
                                               new_recipient.reason_to_leave_list, 
                                               new_recipient.ID))
                next_in_leave_the_list = sorted(next_in_leave_the_list)
                
        while current_t < T:  
            (time_aux, _, _)  = events.list_of_events[0]
            (time2_aux, _, _) = next_in_leave_the_list[0]
            
            if time_aux + current_t < time2_aux:
                (time, event_type, counter)  = events.list_of_events.pop(0)
                ID = None
                print(time+current_t, event_type, ID)
            else: 
                (time, event_type, ID) = next_in_leave_the_list.pop(0)
                print(time, event_type, ID)
                   
            #print(time, event_type)         
            match event_type:
                case "new_donor":
                    current_t += time
                    donor = don.Donor(current_t)
                    donor.create_donor(counter)
                    
                    if len(wait_list) < 1:
                        raise('The waitlist length is 0, check the setup please')            
                    
                    survival_probs = []
                    for recipient in wait_list: 
                        if donor.blood in blood_type_compatibility[recipient.blood]: 
                            survival_probs.append(predictor.predict_survival_prob(recipient, donor, TARGET_TIME))
                        else: 
                             survival_probs.append(0)
                                    
                    if len(survival_probs)>0: 
                        best_match_index = np.argmax(survival_probs)
                        recipient_best = wait_list[best_match_index]
                        _, predicted_survival_function = predictor.predict_survival_prob(recipient_best, donor, TARGET_TIME, surv_function=True)
                        
                        mean_survival_time = sum(
                        (predicted_survival_function[0].x[i + 1] - predicted_survival_function[0].x[i]) *
                        predicted_survival_function[0].y[i]
                        for i in range(len(predicted_survival_function[0].x) - 1)
)
                        
                        best_patient = wait_list.pop(best_match_index)
                        next_leave_time = [(a, b, c) for (a, b, c) in next_in_leave_the_list if c==best_patient.ID]
                        _index = next_in_leave_the_list.index(next_leave_time[0])   
                        _ = next_in_leave_the_list.pop(_index)
                        
                        print(f'A donation was done with expected life {mean_survival_time} and probabity {survival_probs[best_match_index]}. Day: ', str(current_t))
                        waiting_time = current_t - best_patient.arrival_time
                        
                        if current_t > 8*365.25:
                            total_waiting_time += waiting_time
                            
                        best_patient.waiting_time = waiting_time
                        
                        
                        if current_t > 8*365.25:
                            df.loc[len(df)] = [r, best_patient.ethcat, best_patient.gender, best_patient.waiting_time, mean_survival_time, current_t]
                            released_recipients.append(best_patient)
                            num_matched_patients += 1
                
                case "new_recipient":            
                    current_t += time
                    new_recipient = rec.Recipient(current_t) 
                    new_recipient.create_recipient(counter)
                    wait_list.append(new_recipient)
                    next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                    next_in_leave_the_list = sorted(next_in_leave_the_list)
                    print('A new recipient has arrived. Day: ', str(current_t))
                
                case "leave_list":
                    current_t = time
                    next_leave_time = [p for p in wait_list if p.ID==ID]
                    _index = wait_list.index(next_leave_time[0])   
                    out_of_list = wait_list.pop(_index)
                    leave_list.append(out_of_list)
                    
                    if current_t > 8*365.25:
                        df_leaves.loc[len(df)] = [r, out_of_list.ethcat, out_of_list.gender, out_of_list.waiting_time, _, current_t]
                        print('----------------------- One patient left the waitlist. Day: ', str(current_t), out_of_list.ID) 
                    
                    

            if num_matched_patients>0:
                if current_t > 8*365.25:
                    average_time = total_waiting_time / num_matched_patients
                    #we collect data after 8 years
                    waiting_time_convergence_r.append([current_t, average_time])
                wait_list_length_r.append([current_t, len(wait_list)])
            else: 
                average_time = 'INF'
            if verbose:
                print(f'Number of matches: {num_matched_patients}, recipients in wait list: {len(wait_list)},'
                      f'average time in waitlist {average_time}, patients which leave the list {len(leave_list)}')        
        if num_matched_patients > 0:
            average_waiting_times.append(total_waiting_time / num_matched_patients)
            waiting_time_convergence.append(waiting_time_convergence_r)
            wait_list_length.append(wait_list_length_r)
            number_of_matches_list.append(num_matched_patients)
            leave_list_global.append(leave_list)
        else:
            average_waiting_times.append(0)
            
    return average_waiting_times, number_of_matches_list

# %%
run_simulation(T=SIMULATION_TIME, replicates=1, verbose=True)
# Out:
# Replicate # 0
# 4.876207089675746 new_donor None
# A donation was done with expected life 2720.111178208371 and probabity 0.7161873969527908. Day:  4.876207089675746
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 5.791089572476234 new_recipient None
# A new recipient has arrived. Day:  5.791089572476234
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 6.047182188712358 new_donor None
# A donation was done with expected life 2832.2597705351004 and probabity 0.7446588278015481. Day:  6.047182188712358
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 9.42408411604908 new_recipient None
# A new recipient has arrived. Day:  9.42408411604908
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 10.089299809939014 new_recipient None
# A new recipient has arrived. Day:  10.089299809939014
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 10.77158119150715 new_recipient None
# A new recipient has arrived. Day:  10.77158119150715
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 0
# 11.140292586252258 new_donor None
# A donation was done with expected life 3271.221657678562 and probabity 0.8362768430734131. Day:  11.140292586252258
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 13.33138079960913 new_donor None
# A donation was done with expected life 2907.938202712166 and probabity 0.7487266892599126. Day:  13.33138079960913
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 14.101681497986865 new_donor None
# A donation was done with expected life 2824.2422495878477 and probabity 0.7435475837337511. Day:  14.101681497986865
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 14.837610193158365 new_recipient None
# A new recipient has arrived. Day:  14.837610193158365
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 17.34093124119582 new_donor None
# A donation was done with expected life 2996.2689426089087 and probabity 0.7788565108666803. Day:  17.34093124119582
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 18.065507956448297 new_recipient None
# A new recipient has arrived. Day:  18.065507956448297
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 18.399314413746612 new_donor None
# A donation was done with expected life 2806.725897241481 and probabity 0.7195792915673482. Day:  18.399314413746612
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 18.967432163677667 new_recipient None
# A new recipient has arrived. Day:  18.967432163677667
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 19.121877791329872 new_donor None
# A donation was done with expected life 3217.3837452511434 and probabity 0.818290940685311. Day:  19.121877791329872
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 19.812328377794827 leave_list 11006
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 1
# 22.461314997768007 new_donor None
# A donation was done with expected life 3308.8226179760577 and probabity 0.846741086658588. Day:  22.461314997768007
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 1
# 24.870630055903607 new_recipient None
# A new recipient has arrived. Day:  24.870630055903607
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 1
# 26.261071786230836 new_recipient None
# A new recipient has arrived. Day:  26.261071786230836
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 1
# 31.396155392542617 leave_list 19162
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 2
# 38.06344284740266 leave_list 14368
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 3
# 45.83734629091654 new_recipient None
# A new recipient has arrived. Day:  45.83734629091654
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 3
# 46.20896795844633 new_recipient None
# A new recipient has arrived. Day:  46.20896795844633
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 3
# 48.29459151167449 new_recipient None
# A new recipient has arrived. Day:  48.29459151167449
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 3
# 48.4533572999893 new_donor None
# A donation was done with expected life 3175.0110800279544 and probabity 0.8098216358606867. Day:  48.4533572999893
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 3
# 48.73304827791228 new_donor None
# A donation was done with expected life 3013.1735238523484 and probabity 0.7831475593015783. Day:  48.73304827791228
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 3
# 48.94770883152832 new_donor None
# A donation was done with expected life 2998.0270286464406 and probabity 0.7756910890524682. Day:  48.94770883152832
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 3
# 49.586228191908006 leave_list 8104
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 4
# 51.51487636421791 new_donor None
# A donation was done with expected life 3300.8004570374255 and probabity 0.8454627578857453. Day:  51.51487636421791
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 4
# 57.03162476000425 new_donor None
# A donation was done with expected life 3034.6908708710944 and probabity 0.7756047504459823. Day:  57.03162476000425
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 4
# 62.35935374531375 new_recipient None
# A new recipient has arrived. Day:  62.35935374531375
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 4
# 62.984264238884634 new_recipient None
# A new recipient has arrived. Day:  62.984264238884634
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 4
# 63.409002443178295 new_recipient None
# A new recipient has arrived. Day:  63.409002443178295
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 4
# 64.13485626338185 new_recipient None
# A new recipient has arrived. Day:  64.13485626338185
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 4
# 64.40437018573563 leave_list 3442
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 67.20830448592191 new_recipient None
# A new recipient has arrived. Day:  67.20830448592191
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 68.79240588768815 new_donor None
# A donation was done with expected life 2990.626539815348 and probabity 0.7783242640113531. Day:  68.79240588768815
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 73.20294035932534 new_recipient None
# A new recipient has arrived. Day:  73.20294035932534
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 73.4544682546746 new_recipient None
# A new recipient has arrived. Day:  73.4544682546746
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 5
# 77.50921320616526 new_donor None
# A donation was done with expected life 3050.726709821795 and probabity 0.7750639251203224. Day:  77.50921320616526
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 77.8733231281432 new_donor None
# A donation was done with expected life 3268.547059069015 and probabity 0.8395242310682814. Day:  77.8733231281432
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 79.04685649485525 new_recipient None
# A new recipient has arrived. Day:  79.04685649485525
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 79.96822238565518 new_donor None
# A donation was done with expected life 2892.9484529826445 and probabity 0.7579673047739424. Day:  79.96822238565518
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 80.2099546450925 new_recipient None
# A new recipient has arrived. Day:  80.2099546450925
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 84.74719244434826 new_donor None
# A donation was done with expected life 2796.4877869439792 and probabity 0.7327788837718278. Day:  84.74719244434826
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 85.07505291677613 new_recipient None
# A new recipient has arrived. Day:  85.07505291677613
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 86.87265026870314 new_donor None
# A donation was done with expected life 2934.634576946884 and probabity 0.7594579439881334. Day:  86.87265026870314
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 87.39439297073908 new_recipient None
# A new recipient has arrived. Day:  87.39439297073908
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 87.42696820716577 new_recipient None
# A new recipient has arrived. Day:  87.42696820716577
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 5
# 87.82641071724805 new_recipient None
# A new recipient has arrived. Day:  87.82641071724805
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 5
# 93.77906024698542 new_donor None
# A donation was done with expected life 2976.858529019902 and probabity 0.7705228090490519. Day:  93.77906024698542
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 5
# 97.37865929762944 new_donor None
# A donation was done with expected life 3208.3831216225713 and probabity 0.8163430665744167. Day:  97.37865929762944
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 102.92447211063225 new_donor None
# A donation was done with expected life 2924.203498661784 and probabity 0.7527963351392718. Day:  102.92447211063225
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 106.50044293848084 new_recipient None
# A new recipient has arrived. Day:  106.50044293848084
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 108.83222241617129 new_recipient None
# A new recipient has arrived. Day:  108.83222241617129
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 5
# 113.96333771654051 new_donor None
# A donation was done with expected life 2858.079842509676 and probabity 0.7357733190677123. Day:  113.96333771654051
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 114.81792732317126 leave_list 945
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 6
# 119.93464555637621 new_donor None
# A donation was done with expected life 3254.1264986349784 and probabity 0.8301437366918712. Day:  119.93464555637621
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 6
# 120.22378350373256 new_donor None
# A donation was done with expected life 3085.5249880647525 and probabity 0.7866872228814447. Day:  120.22378350373256
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 6
# 125.3320722651828 leave_list 15882
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 7
# 130.5490335334789 new_recipient None
# A new recipient has arrived. Day:  130.5490335334789
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 7
# 132.26783477333106 leave_list 15399
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 8
# 134.64671275087025 new_recipient None
# A new recipient has arrived. Day:  134.64671275087025
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 8
# 135.99801605005536 new_recipient None
# A new recipient has arrived. Day:  135.99801605005536
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 8
# 137.33817166359793 new_donor None
# A donation was done with expected life 3120.498456773537 and probabity 0.7982991270631732. Day:  137.33817166359793
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 8
# 138.6509956158319 new_recipient None
# A new recipient has arrived. Day:  138.6509956158319
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 8
# 140.47208267609625 new_donor None
# A donation was done with expected life 2562.323348413397 and probabity 0.6788050671147251. Day:  140.47208267609625
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 8
# 141.3158785905137 new_recipient None
# A new recipient has arrived. Day:  141.3158785905137
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 8
# 141.68375177989626 new_donor None
# A donation was done with expected life 2829.5189853107017 and probabity 0.743987386275207. Day:  141.68375177989626
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 8
# 143.53576343214743 leave_list 3318
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 9
# 150.10067523053567 new_donor None
# A donation was done with expected life 2705.335787353086 and probabity 0.713062305689756. Day:  150.10067523053567
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 9
# 163.94466752953667 new_recipient None
# A new recipient has arrived. Day:  163.94466752953667
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 9
# 165.44035265492468 new_donor None
# A donation was done with expected life 3227.272473567591 and probabity 0.8244350533917004. Day:  165.44035265492468
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 9
# 165.88088060840332 new_donor None
# A donation was done with expected life 3166.367108406065 and probabity 0.8117365869736904. Day:  165.88088060840332
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 9
# 167.02322952402446 new_recipient None
# A new recipient has arrived. Day:  167.02322952402446
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 9
# 169.57655701465788 new_recipient None
# A new recipient has arrived. Day:  169.57655701465788
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 9
# 171.05728716746057 leave_list 7502
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 10
# 172.0412123305929 leave_list 12244
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 11
# 173.91031444735924 new_donor None
# A donation was done with expected life 2807.5895068154737 and probabity 0.7391986322612811. Day:  173.91031444735924
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 11
# 174.150943592102 new_donor None
# A donation was done with expected life 2651.141690985305 and probabity 0.699174716298249. Day:  174.150943592102
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 11
# 175.04269393184634 new_recipient None
# A new recipient has arrived. Day:  175.04269393184634
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 11
# 176.72434057166208 new_donor None
# A donation was done with expected life 2979.580518633429 and probabity 0.778667322649174. Day:  176.72434057166208
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 11
# 176.9264630929693 new_recipient None
# A new recipient has arrived. Day:  176.9264630929693
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 11
# 180.2392897681887 leave_list 5163
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 12
# 180.48012369633176 leave_list 16500
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 13
# 182.32466731060973 leave_list 1753
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 14
# 188.5574781793951 new_recipient None
# A new recipient has arrived. Day:  188.5574781793951
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 14
# 190.72017924593035 new_donor None
# A donation was done with expected life 2968.595518470839 and probabity 0.7763275496818367. Day:  190.72017924593035
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 14
# 190.9781803686324 new_donor None
# A donation was done with expected life 2827.141993981541 and probabity 0.7436069887513659. Day:  190.9781803686324
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 14
# 191.428676740584 new_recipient None
# A new recipient has arrived. Day:  191.428676740584
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 14
# 194.36091673384885 new_recipient None
# A new recipient has arrived. Day:  194.36091673384885
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 14
# 195.32858691201457 new_donor None
# A donation was done with expected life 2831.3683222676677 and probabity 0.7365503461038054. Day:  195.32858691201457
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 14
# 197.39867527077539 leave_list 4153
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 15
# 201.04471346463544 new_recipient None
# A new recipient has arrived. Day:  201.04471346463544
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 15
# 203.81551004392384 new_donor None
# A donation was done with expected life 2879.6342840820407 and probabity 0.7502903378701927. Day:  203.81551004392384
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 15
# 204.89681598184555 new_recipient None
# A new recipient has arrived. Day:  204.89681598184555
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 15
# 208.00016834825004 new_recipient None
# A new recipient has arrived. Day:  208.00016834825004
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 15
# 211.19484629457997 new_donor None
# A donation was done with expected life 2645.198676744759 and probabity 0.69860729147239. Day:  211.19484629457997
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 15
# 214.98025533829536 new_donor None
# A donation was done with expected life 2759.118044885267 and probabity 0.7238611342071883. Day:  214.98025533829536
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 15
# 216.38620573022774 new_recipient None
# A new recipient has arrived. Day:  216.38620573022774
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 15
# 216.99023168682203 leave_list 3318
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 16
# 220.0654122417122 new_recipient None
# A new recipient has arrived. Day:  220.0654122417122
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 16
# 220.93173996125594 new_donor None
# A donation was done with expected life 3259.2530446028013 and probabity 0.829337861180732. Day:  220.93173996125594
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 16
# 221.2063325856065 new_recipient None
# A new recipient has arrived. Day:  221.2063325856065
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 16
# 228.3106936503107 new_donor None
# A donation was done with expected life 2986.690026173438 and probabity 0.781389683511069. Day:  228.3106936503107
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 16
# 228.4791202505301 new_donor None
# A donation was done with expected life 2811.142907233938 and probabity 0.7415951918582144. Day:  228.4791202505301
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 16
# 228.9515736776829 new_donor None
# A donation was done with expected life 3226.568553450311 and probabity 0.8259880412078967. Day:  228.9515736776829
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 16
# 230.61925882228422 leave_list 1753
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 17
# 232.4316657021694 new_donor None
# A donation was done with expected life 3034.6012027274387 and probabity 0.780644875273418. Day:  232.4316657021694
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 17
# 234.12380204052243 new_recipient None
# A new recipient has arrived. Day:  234.12380204052243
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 17
# 235.69269561185587 new_donor None
# A donation was done with expected life 2804.2082899348457 and probabity 0.7429861440105243. Day:  235.69269561185587
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 17
# 236.95416284671995 new_recipient None
# A new recipient has arrived. Day:  236.95416284671995
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 17
# 240.73787868797277 new_donor None
# A donation was done with expected life 2999.810809527751 and probabity 0.77661593546158. Day:  240.73787868797277
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 17
# 241.83348100245658 new_donor None
# A donation was done with expected life 3021.3964336251224 and probabity 0.7800138318756066. Day:  241.83348100245658
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 17
# 243.2732298499192 new_recipient None
# A new recipient has arrived. Day:  243.2732298499192
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 17
# 246.63360562729636 leave_list 21848
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 18
# 251.83342205515152 new_donor None
# A donation was done with expected life 2632.1091737062975 and probabity 0.698581796988991. Day:  251.83342205515152
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 18
# 252.3111170019901 new_donor None
# A donation was done with expected life 2945.76517183042 and probabity 0.7687469520926675. Day:  252.3111170019901
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 18
# 253.9752408881081 new_recipient None
# A new recipient has arrived. Day:  253.9752408881081
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 18
# 254.24203712561732 new_recipient None
# A new recipient has arrived. Day:  254.24203712561732
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 18
# 254.2538945939328 new_recipient None
# A new recipient has arrived. Day:  254.2538945939328
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 18
# 256.7150005943811 new_donor None
# A donation was done with expected life 2877.49953659584 and probabity 0.7520961220264683. Day:  256.7150005943811
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 18
# 258.82839937075556 leave_list 2594
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 19
# 263.17917738021896 new_donor None
# A donation was done with expected life 2920.6395818986307 and probabity 0.7664841184478217. Day:  263.17917738021896
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 19
# 264.2409829705809 new_recipient None
# A new recipient has arrived. Day:  264.2409829705809
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 19
# 273.71371130668564 new_recipient None
# A new recipient has arrived. Day:  273.71371130668564
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 19
# 275.60767062678093 leave_list 21553
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 20
# 277.64706010457945 new_donor None
# A donation was done with expected life 3023.2336473507503 and probabity 0.7852515394252175. Day:  277.64706010457945
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 20
# 282.64578605268605 new_recipient None
# A new recipient has arrived. Day:  282.64578605268605
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 20
# 284.26223157126685 new_recipient None
# A new recipient has arrived. Day:  284.26223157126685
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 20
# 289.2482347259093 new_recipient None
# A new recipient has arrived. Day:  289.2482347259093
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 20
# 289.7257197532725 leave_list 1373
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 21
# 290.4258424138925 new_donor None
# A donation was done with expected life 2830.5249361786173 and probabity 0.7467554609696465. Day:  290.4258424138925
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 21
# 294.8886377301487 new_recipient None
# A new recipient has arrived. Day:  294.8886377301487
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 21
# 295.6371383631235 leave_list 19162
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 22
# 297.455028606552 new_recipient None
# A new recipient has arrived. Day:  297.455028606552
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 22
# 297.9753479019792 new_recipient None
# A new recipient has arrived. Day:  297.9753479019792
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 22
# 298.073708143936 new_donor None
# A donation was done with expected life 2915.5346295316917 and probabity 0.7528958463709595. Day:  298.073708143936
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 22
# 301.7544050536302 new_recipient None
# A new recipient has arrived. Day:  301.7544050536302
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 22
# 303.0103278186697 leave_list 8901
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 23
# 304.3808825124084 new_recipient None
# A new recipient has arrived. Day:  304.3808825124084
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 23
# 305.6142023088885 new_donor None
# A donation was done with expected life 2868.888576840916 and probabity 0.7447894110350727. Day:  305.6142023088885
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 23
# 309.3086454369893 new_donor None
# A donation was done with expected life 3006.831431880353 and probabity 0.7809237420340175. Day:  309.3086454369893
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 23
# 312.6901522258303 new_recipient None
# A new recipient has arrived. Day:  312.6901522258303
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 23
# 316.5171586639185 new_donor None
# A donation was done with expected life 2663.6502826267715 and probabity 0.6895598860076262. Day:  316.5171586639185
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 23
# 318.81341641776294 new_recipient None
# A new recipient has arrived. Day:  318.81341641776294
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 23
# 320.62061266076176 new_recipient None
# A new recipient has arrived. Day:  320.62061266076176
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 23
# 322.7470929186437 leave_list 4970
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 24
# 326.56316024332483 new_recipient None
# A new recipient has arrived. Day:  326.56316024332483
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 24
# 327.40244342444623 new_recipient None
# A new recipient has arrived. Day:  327.40244342444623
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 24
# 329.31893060080256 new_donor None
# A donation was done with expected life 2904.349111289993 and probabity 0.7537839038413958. Day:  329.31893060080256
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 24
# 329.3500870098991 new_recipient None
# A new recipient has arrived. Day:  329.3500870098991
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 24
# 332.2931750153323 new_donor None
# A donation was done with expected life 3069.441199414807 and probabity 0.7886056717788975. Day:  332.2931750153323
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 24
# 333.61887752145014 leave_list 20581
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 25
# 336.6298942023947 new_recipient None
# A new recipient has arrived. Day:  336.6298942023947
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 25
# 337.7089694175833 new_recipient None
# A new recipient has arrived. Day:  337.7089694175833
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 25
# 340.2142490884466 new_donor None
# A donation was done with expected life 2895.8913600974297 and probabity 0.7521400732342296. Day:  340.2142490884466
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 25
# 342.01273904760154 new_recipient None
# A new recipient has arrived. Day:  342.01273904760154
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 25
# 343.04060623713065 new_recipient None
# A new recipient has arrived. Day:  343.04060623713065
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 25
# 345.75481269794477 new_recipient None
# A new recipient has arrived. Day:  345.75481269794477
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 25
# 348.6547401505554 new_recipient None
# A new recipient has arrived. Day:  348.6547401505554
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 25
# 349.8426187293222 new_donor None
# A donation was done with expected life 3060.007294657227 and probabity 0.7873512701063331. Day:  349.8426187293222
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 25
# 351.1959418750033 new_donor None
# A donation was done with expected life 2958.773889891456 and probabity 0.7745326115781161. Day:  351.1959418750033
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 25
# 355.05575305760857 new_recipient None
# A new recipient has arrived. Day:  355.05575305760857
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 25
# 355.3669466613912 new_recipient None
# A new recipient has arrived. Day:  355.3669466613912
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 25
# 356.4067988430299 new_donor None
# A donation was done with expected life 2813.533276600642 and probabity 0.7278222242690149. Day:  356.4067988430299
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 25
# 356.5854486792914 new_donor None
# A donation was done with expected life 2953.7558935648276 and probabity 0.7727347536396997. Day:  356.5854486792914
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 25
# 356.7226246461152 leave_list 2817
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 26
# 357.3231360454284 leave_list 21003
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 27
# 357.6716653587268 leave_list 880
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 28
# 360.8967150248791 new_donor None
# A donation was done with expected life 3028.391011109986 and probabity 0.7783977140527878. Day:  360.8967150248791
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 28
# 366.01622091335634 new_donor None
# A donation was done with expected life 2790.07534911906 and probabity 0.7308152244017394. Day:  366.01622091335634
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 28
# 370.1062985024161 new_recipient None
# A new recipient has arrived. Day:  370.1062985024161
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 28
# 370.8504014415669 leave_list 13771
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 29
# 372.5204997379822 leave_list 12295
# Number of matches: 0, recipients in wait list: 279,average time in waitlist INF, patients which leave the list 30
# 374.5769478310371 leave_list 22119
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 31
# 377.0556504020496 new_donor None
# A donation was done with expected life 3153.59494105624 and probabity 0.8101596895867905. Day:  377.0556504020496
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 31
# 377.75704152235477 leave_list 12435
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 32
# 379.14601396118974 new_donor None
# A donation was done with expected life 2504.0182034075865 and probabity 0.6659487935967202. Day:  379.14601396118974
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 32
# 383.4729397579469 new_recipient None
# A new recipient has arrived. Day:  383.4729397579469
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 32
# 384.2585254280146 leave_list 18962
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 33
# 392.0943032794189 new_donor None
# A donation was done with expected life 3238.407978313962 and probabity 0.8326836931405566. Day:  392.0943032794189
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 33
# 393.2211883429659 new_donor None
# A donation was done with expected life 2997.160392020168 and probabity 0.7772688523815708. Day:  393.2211883429659
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 33
# 398.42948252494955 new_recipient None
# A new recipient has arrived. Day:  398.42948252494955
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 33
# 399.4463455769416 leave_list 13393
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 34
# 401.21593572491963 new_recipient None
# A new recipient has arrived. Day:  401.21593572491963
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 34
# 405.60223542677136 leave_list 5691
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 35
# 409.24569486915954 leave_list 7395
# Number of matches: 0, recipients in wait list: 272,average time in waitlist INF, patients which leave the list 36
# 411.9958469365262 leave_list 13378
# Number of matches: 0, recipients in wait list: 271,average time in waitlist INF, patients which leave the list 37
# 416.50945020317033 new_donor None
# A donation was done with expected life 2983.5825705999528 and probabity 0.7760003487014744. Day:  416.50945020317033
# Number of matches: 0, recipients in wait list: 270,average time in waitlist INF, patients which leave the list 37
# 417.9093411668141 new_donor None
# A donation was done with expected life 2732.171515794782 and probabity 0.7064498769559863. Day:  417.9093411668141
# Number of matches: 0, recipients in wait list: 269,average time in waitlist INF, patients which leave the list 37
# 420.0826401309952 new_donor None
# A donation was done with expected life 2718.220125158271 and probabity 0.7199052724988744. Day:  420.0826401309952
# Number of matches: 0, recipients in wait list: 268,average time in waitlist INF, patients which leave the list 37
# 420.4142941219536 leave_list 22119
# Number of matches: 0, recipients in wait list: 267,average time in waitlist INF, patients which leave the list 38
# 421.41207884979474 new_recipient None
# A new recipient has arrived. Day:  421.41207884979474
# Number of matches: 0, recipients in wait list: 268,average time in waitlist INF, patients which leave the list 38
# 423.5129011632047 new_recipient None
# A new recipient has arrived. Day:  423.5129011632047
# Number of matches: 0, recipients in wait list: 269,average time in waitlist INF, patients which leave the list 38
# 429.0678167124243 leave_list 2948
# Number of matches: 0, recipients in wait list: 268,average time in waitlist INF, patients which leave the list 39
# 430.8104041658343 leave_list 19320
# Number of matches: 0, recipients in wait list: 267,average time in waitlist INF, patients which leave the list 40
# 441.3969033902644 leave_list 9478
# Number of matches: 0, recipients in wait list: 266,average time in waitlist INF, patients which leave the list 41
# 446.1369187662746 leave_list 1827
# Number of matches: 0, recipients in wait list: 265,average time in waitlist INF, patients which leave the list 42
# 450.28153780991806 leave_list 4833
# Number of matches: 0, recipients in wait list: 264,average time in waitlist INF, patients which leave the list 43
# 462.7409017566023 new_donor None
# A donation was done with expected life 2972.071365432424 and probabity 0.7781513484634072. Day:  462.7409017566023
# Number of matches: 0, recipients in wait list: 263,average time in waitlist INF, patients which leave the list 43
# 463.38491811063375 new_recipient None
# A new recipient has arrived. Day:  463.38491811063375
# Number of matches: 0, recipients in wait list: 264,average time in waitlist INF, patients which leave the list 43
# 467.23108514968243 new_recipient None
# A new recipient has arrived. Day:  467.23108514968243
# Number of matches: 0, recipients in wait list: 265,average time in waitlist INF, patients which leave the list 43
# 468.2388295460784 new_donor None
# A donation was done with expected life 2548.0070111618516 and probabity 0.6830353027086524. Day:  468.2388295460784
# Number of matches: 0, recipients in wait list: 264,average time in waitlist INF, patients which leave the list 43
# 474.98153047896983 new_donor None
# A donation was done with expected life 2910.0593311830385 and probabity 0.7615821587490665. Day:  474.98153047896983
# Number of matches: 0, recipients in wait list: 263,average time in waitlist INF, patients which leave the list 43
# 479.93873184063926 new_recipient None
# A new recipient has arrived. Day:  479.93873184063926
# Number of matches: 0, recipients in wait list: 264,average time in waitlist INF, patients which leave the list 43
# 481.3233425901111 new_recipient None
# A new recipient has arrived. Day:  481.3233425901111
# Number of matches: 0, recipients in wait list: 265,average time in waitlist INF, patients which leave the list 43
# 484.68930048354963 new_recipient None
# A new recipient has arrived. Day:  484.68930048354963
# Number of matches: 0, recipients in wait list: 266,average time in waitlist INF, patients which leave the list 43
# 485.3330637983173 new_donor None
# A donation was done with expected life 2889.73921224285 and probabity 0.7451071143265326. Day:  485.3330637983173
# Number of matches: 0, recipients in wait list: 265,average time in waitlist INF, patients which leave the list 43
# 491.36933739698543 leave_list 2817
# Number of matches: 0, recipients in wait list: 264,average time in waitlist INF, patients which leave the list 44
# 497.7136690482724 leave_list 21702
# Number of matches: 0, recipients in wait list: 263,average time in waitlist INF, patients which leave the list 45
# 504.59075396049315 new_donor None
# A donation was done with expected life 2982.4047005440307 and probabity 0.7800663937404664. Day:  504.59075396049315
# Number of matches: 0, recipients in wait list: 262,average time in waitlist INF, patients which leave the list 45
# 505.4440474822586 new_donor None
# A donation was done with expected life 2561.492445379159 and probabity 0.6896189668427419. Day:  505.4440474822586
# Number of matches: 0, recipients in wait list: 261,average time in waitlist INF, patients which leave the list 45
# 507.2368294164269 new_recipient None
# A new recipient has arrived. Day:  507.2368294164269
# Number of matches: 0, recipients in wait list: 262,average time in waitlist INF, patients which leave the list 45
# 508.8437427490396 new_donor None
# A donation was done with expected life 3199.316176005934 and probabity 0.8202263797292291. Day:  508.8437427490396
# Number of matches: 0, recipients in wait list: 261,average time in waitlist INF, patients which leave the list 45
# 510.62964706362584 leave_list 8090
# Number of matches: 0, recipients in wait list: 260,average time in waitlist INF, patients which leave the list 46
# 519.8879267579822 new_recipient None
# A new recipient has arrived. Day:  519.8879267579822
# Number of matches: 0, recipients in wait list: 261,average time in waitlist INF, patients which leave the list 46
# 519.9819931986715 new_donor None
# A donation was done with expected life 2800.835304852562 and probabity 0.726360130488482. Day:  519.9819931986715
# Number of matches: 0, recipients in wait list: 260,average time in waitlist INF, patients which leave the list 46
# 520.5370859059059 new_recipient None
# A new recipient has arrived. Day:  520.5370859059059
# Number of matches: 0, recipients in wait list: 261,average time in waitlist INF, patients which leave the list 46
# 520.6143613012262 new_donor None
# A donation was done with expected life 2884.585145397648 and probabity 0.7556474312145255. Day:  520.6143613012262
# Number of matches: 0, recipients in wait list: 260,average time in waitlist INF, patients which leave the list 46
# 521.0957473645018 new_donor None
# A donation was done with expected life 3124.5061260569196 and probabity 0.8045493189610124. Day:  521.0957473645018
# Number of matches: 0, recipients in wait list: 259,average time in waitlist INF, patients which leave the list 46
# 523.819148120779 new_recipient None
# A new recipient has arrived. Day:  523.819148120779
# Number of matches: 0, recipients in wait list: 260,average time in waitlist INF, patients which leave the list 46
# 527.35021583671 new_donor None
# A donation was done with expected life 2985.978035887275 and probabity 0.7740728731585458. Day:  527.35021583671
# ...
# A donation was done with expected life 2935.443187309656 and probabity 0.7672733556498227. Day:  10796.30467893114
# Number of matches: 1147, recipients in wait list: 216,average time in waitlist 640.3370104014598, patients which leave the list 719
# 10799.428184711029 new_donor None
# A donation was done with expected life 2701.9615136622815 and probabity 0.7110673846796445. Day:  10799.428184711029
# Number of matches: 1148, recipients in wait list: 215,average time in waitlist 641.0027477062865, patients which leave the list 719
# 10800.375521729828 new_donor None
# A donation was done with expected life 2929.9779249239205 and probabity 0.767518783741698. Day:  10800.375521729828
# Number of matches: 1149, recipients in wait list: 214,average time in waitlist 640.4897948584105, patients which leave the list 719
# 10800.773457179308 new_donor None
# A donation was done with expected life 3078.1535304842455 and probabity 0.7836208843240803. Day:  10800.773457179308
# Number of matches: 1150, recipients in wait list: 213,average time in waitlist 645.9067431240804, patients which leave the list 719
# 10809.269370817803 new_recipient None
# A new recipient has arrived. Day:  10809.269370817803
# Number of matches: 1150, recipients in wait list: 214,average time in waitlist 645.9067431240804, patients which leave the list 719
# 10809.713035966113 new_recipient None
# A new recipient has arrived. Day:  10809.713035966113
# Number of matches: 1150, recipients in wait list: 215,average time in waitlist 645.9067431240804, patients which leave the list 719
# 10810.734406490215 new_recipient None
# A new recipient has arrived. Day:  10810.734406490215
# Number of matches: 1150, recipients in wait list: 216,average time in waitlist 645.9067431240804, patients which leave the list 719
# 10812.042856803027 new_recipient None
# A new recipient has arrived. Day:  10812.042856803027
# Number of matches: 1150, recipients in wait list: 217,average time in waitlist 645.9067431240804, patients which leave the list 719
# 10812.802878752178 new_donor None
# A donation was done with expected life 2847.7574021585574 and probabity 0.7354072870746726. Day:  10812.802878752178
# Number of matches: 1151, recipients in wait list: 216,average time in waitlist 646.5399430957394, patients which leave the list 719
# 10814.44867093692 new_donor None
# A donation was done with expected life 2917.957196155297 and probabity 0.7529594376753559. Day:  10814.44867093692
# Number of matches: 1152, recipients in wait list: 215,average time in waitlist 646.0410113061739, patients which leave the list 719
# 10817.752048433924 new_donor None
# A donation was done with expected life 3196.7388204131075 and probabity 0.8171593417545127. Day:  10817.752048433924
# Number of matches: 1153, recipients in wait list: 214,average time in waitlist 646.6771686020253, patients which leave the list 719
# 10823.570686364315 new_recipient None
# A new recipient has arrived. Day:  10823.570686364315
# Number of matches: 1153, recipients in wait list: 215,average time in waitlist 646.6771686020253, patients which leave the list 719
# 10824.82355178757 new_donor None
# A donation was done with expected life 2974.667844008885 and probabity 0.7815865645501815. Day:  10824.82355178757
# Number of matches: 1154, recipients in wait list: 214,average time in waitlist 646.1289987378098, patients which leave the list 719
# 10826.301417032271 new_recipient None
# A new recipient has arrived. Day:  10826.301417032271
# Number of matches: 1154, recipients in wait list: 215,average time in waitlist 646.1289987378098, patients which leave the list 719
# 10828.368855515762 new_recipient None
# A new recipient has arrived. Day:  10828.368855515762
# Number of matches: 1154, recipients in wait list: 216,average time in waitlist 646.1289987378098, patients which leave the list 719
# 10830.066171814266 new_recipient None
# A new recipient has arrived. Day:  10830.066171814266
# Number of matches: 1154, recipients in wait list: 217,average time in waitlist 646.1289987378098, patients which leave the list 719
# 10830.580570224693 new_donor None
# A donation was done with expected life 3007.6530039938243 and probabity 0.7762915101154657. Day:  10830.580570224693
# Number of matches: 1155, recipients in wait list: 216,average time in waitlist 645.5714945957934, patients which leave the list 719
# 10831.611634148117 new_donor None
# A donation was done with expected life 2913.080456990504 and probabity 0.7624740769477207. Day:  10831.611634148117
# Number of matches: 1156, recipients in wait list: 215,average time in waitlist 646.1775765541565, patients which leave the list 719
# 10831.896675913677 new_donor None
# A donation was done with expected life 2844.325407160879 and probabity 0.7373247143686238. Day:  10831.896675913677
# Number of matches: 1157, recipients in wait list: 214,average time in waitlist 646.7637711163652, patients which leave the list 719
# 10832.584831777083 new_donor None
# A donation was done with expected life 2684.034552366472 and probabity 0.7141305652420941. Day:  10832.584831777083
# Number of matches: 1158, recipients in wait list: 213,average time in waitlist 646.2106792714848, patients which leave the list 719
# 10836.077137136283 new_recipient None
# A new recipient has arrived. Day:  10836.077137136283
# Number of matches: 1158, recipients in wait list: 214,average time in waitlist 646.2106792714848, patients which leave the list 719
# 10837.132171088788 new_recipient None
# A new recipient has arrived. Day:  10837.132171088788
# Number of matches: 1158, recipients in wait list: 215,average time in waitlist 646.2106792714848, patients which leave the list 719
# 10839.275483543204 new_donor None
# A donation was done with expected life 3201.908717123582 and probabity 0.8194089420554246. Day:  10839.275483543204
# Number of matches: 1159, recipients in wait list: 214,average time in waitlist 645.6549697228936, patients which leave the list 719
# 10840.595723683551 new_donor None
# A donation was done with expected life 2542.695849179048 and probabity 0.6771115748767434. Day:  10840.595723683551
# Number of matches: 1160, recipients in wait list: 213,average time in waitlist 645.1421684748814, patients which leave the list 719
# 10844.13019836908 new_donor None
# A donation was done with expected life 2972.310818621179 and probabity 0.7811842922992526. Day:  10844.13019836908
# Number of matches: 1161, recipients in wait list: 212,average time in waitlist 644.598604183822, patients which leave the list 719
# 10846.007286893178 new_donor None
# A donation was done with expected life 2649.791546161014 and probabity 0.6899305495098359. Day:  10846.007286893178
# Number of matches: 1162, recipients in wait list: 211,average time in waitlist 649.9947094984651, patients which leave the list 719
# 10852.098305616964 leave_list 3947
# ----------------------- One patient left the waitlist. Day:  10852.098305616964 3947
# Number of matches: 1162, recipients in wait list: 210,average time in waitlist 649.9947094984651, patients which leave the list 720
# 10860.82547336107 new_donor None
# A donation was done with expected life 2729.671720259573 and probabity 0.7151080100003585. Day:  10860.82547336107
# Number of matches: 1163, recipients in wait list: 209,average time in waitlist 655.2890910460657, patients which leave the list 720
# 10862.213371373437 new_donor None
# A donation was done with expected life 3089.620440364577 and probabity 0.7954040226658512. Day:  10862.213371373437
# Number of matches: 1164, recipients in wait list: 208,average time in waitlist 660.5486987248953, patients which leave the list 720
# 10863.897805358585 leave_list 5686
# ----------------------- One patient left the waitlist. Day:  10863.897805358585 5686
# Number of matches: 1164, recipients in wait list: 207,average time in waitlist 660.5486987248953, patients which leave the list 721
# 10870.463607627968 new_donor None
# A donation was done with expected life 2488.629045940857 and probabity 0.6634398058479853. Day:  10870.463607627968
# Number of matches: 1165, recipients in wait list: 206,average time in waitlist 665.709162682249, patients which leave the list 721
# 10875.672833325614 new_donor None
# A donation was done with expected life 2928.9590115274946 and probabity 0.7649817759279043. Day:  10875.672833325614
# Number of matches: 1166, recipients in wait list: 205,average time in waitlist 666.272660284389, patients which leave the list 721
# 10876.432000469393 leave_list 7519
# ----------------------- One patient left the waitlist. Day:  10876.432000469393 7519
# Number of matches: 1166, recipients in wait list: 204,average time in waitlist 666.272660284389, patients which leave the list 722
# 10878.344219234075 new_recipient None
# A new recipient has arrived. Day:  10878.344219234075
# Number of matches: 1166, recipients in wait list: 205,average time in waitlist 666.272660284389, patients which leave the list 722
# 10882.658526500416 new_recipient None
# A new recipient has arrived. Day:  10882.658526500416
# Number of matches: 1166, recipients in wait list: 206,average time in waitlist 666.272660284389, patients which leave the list 722
# 10883.444892488626 new_donor None
# A donation was done with expected life 2977.3891697359522 and probabity 0.7660608295957809. Day:  10883.444892488626
# Number of matches: 1167, recipients in wait list: 205,average time in waitlist 665.7629168185803, patients which leave the list 722
# 10887.248285471984 new_donor None
# A donation was done with expected life 2557.0575190870477 and probabity 0.685747691906378. Day:  10887.248285471984
# Number of matches: 1168, recipients in wait list: 204,average time in waitlist 666.3311027035073, patients which leave the list 722
# 10887.97782095619 new_donor None
# A donation was done with expected life 2945.272649433104 and probabity 0.7709751878564199. Day:  10887.97782095619
# Number of matches: 1169, recipients in wait list: 203,average time in waitlist 671.4596612531182, patients which leave the list 722
# 10890.258983711552 new_recipient None
# A new recipient has arrived. Day:  10890.258983711552
# Number of matches: 1169, recipients in wait list: 204,average time in waitlist 671.4596612531182, patients which leave the list 722
# 10890.99810622782 leave_list 12455
# ----------------------- One patient left the waitlist. Day:  10890.99810622782 12455
# Number of matches: 1169, recipients in wait list: 203,average time in waitlist 671.4596612531182, patients which leave the list 723
# 10892.591493346548 new_recipient None
# A new recipient has arrived. Day:  10892.591493346548
# Number of matches: 1169, recipients in wait list: 204,average time in waitlist 671.4596612531182, patients which leave the list 723
# 10896.941122114742 new_recipient None
# A new recipient has arrived. Day:  10896.941122114742
# Number of matches: 1169, recipients in wait list: 205,average time in waitlist 671.4596612531182, patients which leave the list 723
# 10897.037245134767 new_donor None
# A donation was done with expected life 2941.915741295591 and probabity 0.7745901680621315. Day:  10897.037245134767
# Number of matches: 1170, recipients in wait list: 204,average time in waitlist 670.8915574925798, patients which leave the list 723
# 10902.185057572206 new_recipient None
# A new recipient has arrived. Day:  10902.185057572206
# Number of matches: 1170, recipients in wait list: 205,average time in waitlist 670.8915574925798, patients which leave the list 723
# 10903.033436462098 new_recipient None
# A new recipient has arrived. Day:  10903.033436462098
# Number of matches: 1170, recipients in wait list: 206,average time in waitlist 670.8915574925798, patients which leave the list 723
# 10903.593685512233 leave_list 4366
# ----------------------- One patient left the waitlist. Day:  10903.593685512233 4366
# Number of matches: 1170, recipients in wait list: 205,average time in waitlist 670.8915574925798, patients which leave the list 724
# 10906.925492157496 new_recipient None
# A new recipient has arrived. Day:  10906.925492157496
# Number of matches: 1170, recipients in wait list: 206,average time in waitlist 670.8915574925798, patients which leave the list 724
# 10908.40167732782 new_recipient None
# A new recipient has arrived. Day:  10908.40167732782
# Number of matches: 1170, recipients in wait list: 207,average time in waitlist 670.8915574925798, patients which leave the list 724
# 10909.877495264403 new_donor None
# A donation was done with expected life 2945.272649433104 and probabity 0.7709751878564199. Day:  10909.877495264403
# Number of matches: 1171, recipients in wait list: 206,average time in waitlist 671.4531428535186, patients which leave the list 724
# 10910.114973698895 new_donor None
# A donation was done with expected life 3222.783652496391 and probabity 0.8240569329751731. Day:  10910.114973698895
# Number of matches: 1172, recipients in wait list: 205,average time in waitlist 670.8951823906336, patients which leave the list 724
# 10911.838655438989 new_recipient None
# A new recipient has arrived. Day:  10911.838655438989
# Number of matches: 1172, recipients in wait list: 206,average time in waitlist 670.8951823906336, patients which leave the list 724
# 10913.848929357546 new_recipient None
# A new recipient has arrived. Day:  10913.848929357546
# Number of matches: 1172, recipients in wait list: 207,average time in waitlist 670.8951823906336, patients which leave the list 724
# 10916.49112715435 new_recipient None
# A new recipient has arrived. Day:  10916.49112715435
# Number of matches: 1172, recipients in wait list: 208,average time in waitlist 670.8951823906336, patients which leave the list 724
# 10917.994820653048 new_recipient None
# A new recipient has arrived. Day:  10917.994820653048
# Number of matches: 1172, recipients in wait list: 209,average time in waitlist 670.8951823906336, patients which leave the list 724
# 10917.998809215876 new_recipient None
# A new recipient has arrived. Day:  10917.998809215876
# Number of matches: 1172, recipients in wait list: 210,average time in waitlist 670.8951823906336, patients which leave the list 724
# 10920.175515021525 new_recipient None
# A new recipient has arrived. Day:  10920.175515021525
# Number of matches: 1172, recipients in wait list: 211,average time in waitlist 670.8951823906336, patients which leave the list 724
# 10924.314109699182 new_donor None
# A donation was done with expected life 3122.1217916633273 and probabity 0.8017387864231358. Day:  10924.314109699182
# Number of matches: 1173, recipients in wait list: 210,average time in waitlist 675.957457947406, patients which leave the list 724
# 10928.312610196721 new_recipient None
# A new recipient has arrived. Day:  10928.312610196721
# Number of matches: 1173, recipients in wait list: 211,average time in waitlist 675.957457947406, patients which leave the list 724
# 10942.680071865541 new_donor None
# A donation was done with expected life 3004.275286632353 and probabity 0.7773625907148675. Day:  10942.680071865541
# Number of matches: 1174, recipients in wait list: 210,average time in waitlist 675.4039924335763, patients which leave the list 724
# 10943.816943342435 new_donor None
# A donation was done with expected life 2641.9428448344297 and probabity 0.7042954319552588. Day:  10943.816943342435
# Number of matches: 1175, recipients in wait list: 209,average time in waitlist 675.9735680082846, patients which leave the list 724
# 10945.724816804528 new_recipient None
# A new recipient has arrived. Day:  10945.724816804528
# Number of matches: 1175, recipients in wait list: 210,average time in waitlist 675.9735680082846, patients which leave the list 724
# 10947.061042134112 leave_list 686
# ----------------------- One patient left the waitlist. Day:  10947.061042134112 686
# Number of matches: 1175, recipients in wait list: 209,average time in waitlist 675.9735680082846, patients which leave the list 725
# 10953.276018330223 leave_list 17438
# ----------------------- One patient left the waitlist. Day:  10953.276018330223 17438
# Number of matches: 1175, recipients in wait list: 208,average time in waitlist 675.9735680082846, patients which leave the list 726
# ([675.9735680082846], [1175])

# %%
df['ethcat'] = df['ethcat'].replace(ethcat_mapping)

# %%
df_waiting_time = ((df.groupby(by=['replicate', 'ethcat'])
                   .agg(
                       waiting_time=('waiting_time', 'mean'), 
                       count=('waiting_time', 'size'), 
                       mean_survival_time=('mean_survival_time', 'mean'))
                   .reset_index())
)#.to_csv('simulation_results.csv')
df_waiting_time = df_waiting_time[['ethcat', 'waiting_time', 'count', 'mean_survival_time']].groupby('ethcat').agg(['mean', 'std'])
df_waiting_time.columns = [f"{col[0]}_{col[1]}" for col in df_waiting_time.columns] 
df_waiting_time['prop_simu'] = df_waiting_time['count_mean'] / df_waiting_time['count_mean'].sum()
df_waiting_time = df_waiting_time.merge(real_ethcat_df, on='ethcat').round(3)
df_waiting_time.columns = ['ethcat', 'wt_mean', 'wt_std', 'count_mean', 'count_std', 'st_mean', 'st_std', 'prop_simu', 'sample_proportion']
df_waiting_time
# Out:
#                                               ethcat   wt_mean  wt_std  \
# 0               Amer Ind/Alaska Native, Non-Hispanic   822.157     NaN
# 1                                Asian, Non-Hispanic   683.137     NaN
# 2                                Black, Non-Hispanic   640.075     NaN
# 3                                    Hispanic/Latino   873.883     NaN
# 4                          Multiracial, Non-Hispanic   288.412     NaN
# 5  Native Hawaiian/Other Pacific Islander, Non-Hi...  1592.607     NaN
# 6                                White, Non-Hispanic   629.319     NaN
#
#    count_mean  count_std   st_mean  st_std  prop_simu  sample_proportion
# 0        16.0        NaN  2836.639     NaN      0.014              0.014
# 1        49.0        NaN  2872.022     NaN      0.042              0.053
# 2       361.0        NaN  2906.086     NaN      0.307              0.325
# 3       171.0        NaN  2899.944     NaN      0.146              0.160
# 4         7.0        NaN  2957.459     NaN      0.006              0.005
# 5         6.0        NaN  2918.827     NaN      0.005              0.004
# 6       565.0        NaN  2904.380     NaN      0.481              0.439

# %%
df_gender = ((df.groupby(by=['replicate', 'gender'])
                .agg(
                    waiting_time=('waiting_time', 'mean'), 
                    count=('waiting_time', 'size'),
                    mean_survival_time=('mean_survival_time', 'mean'))
                .reset_index())
)#.to_csv('simulation_results.csv')
df_gender = df_gender[['gender', 'waiting_time', 'count', 'mean_survival_time']].groupby('gender').agg(['mean', 'std'])
df_gender.columns = [f"{col[0]}_{col[1]}" for col in df_gender.columns] 
df_gender['proportion_sim'] = df_gender['count_mean'] / df_gender['count_mean'].sum()
df_gender.reset_index(inplace=True)
df_gender = df_gender.merge(real_gender_df, on = 'gender')
df_gender.columns = ['gender', 'wt_mean', 'wt_std', 'count_mean',
       'count_std', 'st_mean', 'st_std',
       'prop_sim', 'sample_proportion']
df_gender.round(3)
# Out:
#   gender  wt_mean  wt_std  count_mean  count_std   st_mean  st_std  prop_sim  \
# 0      F  690.203     NaN       415.0        NaN  2909.151     NaN     0.353
# 1      M  668.204     NaN       760.0        NaN  2898.677     NaN     0.647
#
#    sample_proportion
# 0              0.352
# 1              0.648

# %%
#df.to_csv('results_decision_tree.csv')

# %%
import numpy as np 

np.quantile(np.mean(np.random.exponential(scale=(1)*365, size=100)), 0.2)
# Out:
# 344.09182861412404
