# %%
import pandas as pd 

df_base = pd.read_csv('data/data_to_simulate.csv', index_col=0)
df_base.dropna(inplace=True)
print(df_base.columns)
columns = ['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON', 'AGE', 'DIAB',
                'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI', 'SERUM_CREAT',
                'CREAT_TRR', 'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC','CREAT_TRRg1.5', 'SERUM_CREATg1.2',
                'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
                'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE','TX_DATE', 'PT_CODE', 'ABO', 'ABO_DON']

predictors = ['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'WGT_KG_DON_CALC',
                    'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'COD_CAD_DON', 'ETHCAT_DON', 'ABO_MAT', 
                    'HLAMIS', 'DIALYSIS_DATE', 'AGE', 'DIAB', 'DIALYSIS_DATEle0.0', 'CREAT_TRRg1.5', 'SERUM_CREATg1.2']

donor = df_base[['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 
            'HIST_HYPERTENS_DON', 'ABO_DON', 'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2']]

print(donor.columns)
donor.to_csv('data/donors.csv')

recipient = df_base[[ 'DIALYSIS_DATE', 'AGE', 'DIAB', 'ETHCAT', 'GENDER', 'ABO', 'DIALYSIS_DATEle0.0']]
recipient.to_csv('data/recipients.csv')

ethcat_mapping = {
    1: "White, Non-Hispanic",
    2: "Black, Non-Hispanic",
    4: "Hispanic/Latino",
    5: "Asian, Non-Hispanic",
    6: "Amer Ind/Alaska Native, Non-Hispanic",
    7: "Native Hawaiian/Other Pacific Islander, Non-Hispanic",
    9: "Multiracial, Non-Hispanic",
}
# Out:
# Index(['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON',
#        'AGE', 'DIAB', 'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI',
#        'SERUM_CREAT', 'ABO_MAT', 'AMIS', 'BMIS', 'DRMIS', 'CREAT_TRR',
#        'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC', 'ABO_DON',
#        'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
#        'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE', 'TX_DATE',
#        'PT_CODE', 'COMPOSITE_DEATH_DATE', 'ABO', 'T', 'Tag_date', 'DIAB_1',
#        'DIAB_998', 'HIST_DIABETES_DON_1', 'HIST_DIABETES_DON_998',
#        'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2',
#        'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype='object')
# Index(['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC',
#        'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'ABO_DON',
#        'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2'],
#       dtype='object')

# %%
real_gender_df = df_base.GENDER.value_counts(normalize=True).reset_index()
real_gender_df.columns = ['gender', 'sample_proportion']
real_gender_df
# Out:
#   gender  sample_proportion
# 0      M            0.64827
# 1      F            0.35173

# %%
real_ethcat_df = df_base.ETHCAT.value_counts(normalize=True).reset_index()
real_ethcat_df.ETHCAT = real_ethcat_df.ETHCAT.map(ethcat_mapping)
real_ethcat_df.columns = ['ethcat', 'sample_proportion']
real_ethcat_df
# Out:
#                                               ethcat  sample_proportion
# 0                                White, Non-Hispanic           0.439416
# 1                                Black, Non-Hispanic           0.325258
# 2                                    Hispanic/Latino           0.159551
# 3                                Asian, Non-Hispanic           0.053213
# 4               Amer Ind/Alaska Native, Non-Hispanic           0.013618
# 5                          Multiracial, Non-Hispanic           0.004764
# 6  Native Hawaiian/Other Pacific Islander, Non-Hi...           0.004180

# %%
recipient.ABO.unique()
# Out:
# array(['B', 'A', 'O', 'AB', 'A2', 'A1', 'A1B', 'A2B'], dtype=object)

# %%
blood_type_compatibility = {
    "A": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A1": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A2": ["A", "A1", "A2", "AB", "A1B", "A2B", "B"],
    "B":  ["B", "AB", "A1B", "A2B"],
    "AB": ["AB", "A1B", "A2B"],
    "A1B": ["A1B"],
    "A2B": ["A2B", "AB"],
    "O": ["A", "A1", "A2", "B", "AB", "A1B", "A2B", "O"]
}

# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
path = Path("C:/Users/HP/Desktop/UNOS data/codes/simulation-waitline-unos").resolve()  # Get the absolute path
os.chdir(path)
import pandas as pd
import numpy as np
import scipy as sc
import recipient as rec
import prediction as pred 
import donor as don
from event import Event

# %%
def create_list_of_events(n_events = 10000):
    events = Event(number_of_events= n_events, 
                    time_between_arrivals_recipients=4, 
                    time_between_arrivals_donor= 6) #average time in days
    events.create_events()
    return events

# %%
TARGET_TIME  = 5 * 365
SIMULATION_TIME = 365*30  
predictor = pred.SurvivalPredictionModel(model_path='models\decision_tree_2511.pkl')
#9.1% leave the list
#theshold_leave_list = 0.091 
recipients_for_initialization = 300
time_before_starting_simulation = 0
released_recipients = []
# Out:
# models\decision_tree_2511.pkl
# ok
# Model loaded successfully from models\decision_tree_2511.pkl.
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\HP\AppData\Local\Temp\ipykernel_6736\4126554741.py:3: SyntaxWarning: invalid escape sequence '\d'
#   predictor = pred.SurvivalPredictionModel(model_path='models\decision_tree_2511.pkl')

# %%
predictor.model.feature_names_in_
# Out:
# array(['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS',
#        'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'DIALYSIS_DATE', 'AGE',
#        'DIAB', 'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80',
#        'COD_CAD_DON_2', 'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype=object)

# %%
df = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
df_leaves = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
waiting_time_convergence = []
wait_list_length = []
leave_list_global = []



def run_simulation(T=10, replicates=1, verbose=False):
    waiting_time_convergence_r = []
    wait_list_length_r = []
    average_waiting_times = []
    number_of_matches_list = []
    
    for r in range(replicates):
        events = create_list_of_events(n_events = 10000)
        print('Replicate #', str(r))
        wait_list = []  # Initialize an empty waitlist for each replicate
        leave_list = []
        next_in_leave_the_list = []
        total_waiting_time = 0  # Track the total waiting time for this replicate
        num_matched_patients = 0  # Track the number of matched patients
        current_t = 0  # Start time    
    
        for i in range(recipients_for_initialization):
                new_recipient = rec.Recipient(time_before_starting_simulation) 
                new_recipient.create_recipient(i)
                wait_list.append(new_recipient)
                next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                next_in_leave_the_list = sorted(next_in_leave_the_list)
                
        while current_t < T:  
            (time_aux, _, _)  = events.list_of_events[0]
            (time2_aux, _, _) = next_in_leave_the_list[0]
            
            if time_aux + current_t < time2_aux:
                (time, event_type, counter)  = events.list_of_events.pop(0)
                ID = None
                print(time+current_t, event_type, ID)
            else: 
                (time, event_type, ID) = next_in_leave_the_list.pop(0)
                print(time, event_type, ID)
                   
            #print(time, event_type)         
            match event_type:
                case "new_donor":
                    current_t += time
                    donor = don.Donor(current_t)
                    donor.create_donor(counter)
                    
                    if len(wait_list) < 1:
                        raise('The waitlist length is 0, check the setup please')            
                    
                    survival_probs = []
                    for recipient in wait_list: 
                        if donor.blood in blood_type_compatibility[recipient.blood]: 
                            survival_probs.append(predictor.predict_survival_prob(recipient, donor, TARGET_TIME))
                        else: 
                             survival_probs.append(0)
                                    
                    if len(survival_probs)>0: 
                        best_match_index = np.argmax(survival_probs)
                        recipient_best = wait_list[best_match_index]
                        _, predicted_survival_function = predictor.predict_survival_prob(recipient_best, donor, 
                                                                                         TARGET_TIME, surv_function=True)
                        
                        mean_survival_time = sum(
                        (predicted_survival_function[0].x[i + 1] - predicted_survival_function[0].x[i]) *
                        predicted_survival_function[0].y[i]
                        for i in range(len(predicted_survival_function[0].x) - 1)
)
                        
                        best_patient = wait_list.pop(best_match_index)
                        next_leave_time = [(a, b, c) for (a, b, c) in next_in_leave_the_list if c==best_patient.ID]
                        _index = next_in_leave_the_list.index(next_leave_time[0])   
                        _ = next_in_leave_the_list.pop(_index)
                        
                        print(f'A donation was done with expected life {mean_survival_time} and probabity {survival_probs[best_match_index]}. Day: ', str(current_t))
                        waiting_time = current_t - best_patient.arrival_time
                        
                        if current_t > 8*365.25:
                            total_waiting_time += waiting_time
                            
                        best_patient.waiting_time = waiting_time
                        
                        
                        if current_t > 8*365.25:
                            df.loc[len(df)] = [r, best_patient.ethcat, best_patient.gender, best_patient.waiting_time, mean_survival_time, current_t]
                            released_recipients.append(best_patient)
                            num_matched_patients += 1
                
                case "new_recipient":            
                    current_t += time
                    new_recipient = rec.Recipient(current_t) 
                    new_recipient.create_recipient(counter)
                    wait_list.append(new_recipient)
                    next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                    next_in_leave_the_list = sorted(next_in_leave_the_list)
                    print('A new recipient has arrived. Day: ', str(current_t))
                
                case "leave_list":
                    current_t = time
                    next_leave_time = [p for p in wait_list if p.ID==ID]
                    _index = wait_list.index(next_leave_time[0])   
                    out_of_list = wait_list.pop(_index)
                    leave_list.append(out_of_list)
                    
                    if current_t > 8*365.25:
                        df_leaves.loc[len(df)] = [r, out_of_list.ethcat, out_of_list.gender, out_of_list.waiting_time, _, current_t]
                        print('----------------------- One patient left the waitlist. Day: ', str(current_t), out_of_list.ID) 
                    
                    

            if num_matched_patients>0:
                if current_t > 8*365.25:
                    average_time = total_waiting_time / num_matched_patients
                    #we collect data after 8 years
                    waiting_time_convergence_r.append([current_t, average_time])
                wait_list_length_r.append([current_t, len(wait_list)])
            else: 
                average_time = 'INF'
            if verbose:
                print(f'Number of matches: {num_matched_patients}, recipients in wait list: {len(wait_list)},'
                      f'average time in waitlist {average_time}, patients which leave the list {len(leave_list)}')        
        if num_matched_patients > 0:
            average_waiting_times.append(total_waiting_time / num_matched_patients)
            waiting_time_convergence.append(waiting_time_convergence_r)
            wait_list_length.append(wait_list_length_r)
            number_of_matches_list.append(num_matched_patients)
            leave_list_global.append(leave_list)
        else:
            average_waiting_times.append(0)
            
    return average_waiting_times, number_of_matches_list

# %%
run_simulation(T=SIMULATION_TIME, replicates=1, verbose=True)
# Out:
# Replicate # 0
# 11.078105095968827 new_recipient None
# A new recipient has arrived. Day:  11.078105095968827
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 14.436255467630918 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  14.436255467630918
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 15.947049418537452 new_recipient None
# A new recipient has arrived. Day:  15.947049418537452
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 16.723131556520016 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  16.723131556520016
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 19.812328377794827 leave_list 11006
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 1
# 23.70857363017426 new_recipient None
# A new recipient has arrived. Day:  23.70857363017426
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 1
# 25.043890245495447 new_recipient None
# A new recipient has arrived. Day:  25.043890245495447
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 1
# 26.363349286754328 new_recipient None
# A new recipient has arrived. Day:  26.363349286754328
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 1
# 29.447168709992916 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  29.447168709992916
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 1
# 31.030909024318753 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  31.030909024318753
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 1
# 31.396155392542617 leave_list 19162
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 2
# 34.62714336040651 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  34.62714336040651
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 2
# 37.85169082329075 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  37.85169082329075
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 2
# 38.06344284740266 leave_list 14368
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 3
# 38.57729939996297 new_recipient None
# A new recipient has arrived. Day:  38.57729939996297
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 3
# 39.38813206280089 new_recipient None
# A new recipient has arrived. Day:  39.38813206280089
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 3
# 40.389427616270616 new_recipient None
# A new recipient has arrived. Day:  40.389427616270616
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 3
# 46.97380196050936 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  46.97380196050936
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 3
# 47.25058481912979 new_recipient None
# A new recipient has arrived. Day:  47.25058481912979
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 3
# 47.50534911107358 new_recipient None
# A new recipient has arrived. Day:  47.50534911107358
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 3
# 49.586228191908006 leave_list 8104
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 4
# 53.405357719456944 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  53.405357719456944
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 4
# 54.0994443312776 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  54.0994443312776
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 4
# 61.417959970746864 new_recipient None
# A new recipient has arrived. Day:  61.417959970746864
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 4
# 63.43486872823014 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  63.43486872823014
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 4
# 64.40437018573563 leave_list 3442
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 5
# 70.29468030926421 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  70.29468030926421
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 5
# 71.42495638530991 new_recipient None
# A new recipient has arrived. Day:  71.42495638530991
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 5
# 72.27768986421219 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  72.27768986421219
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 5
# 74.00301073601366 new_recipient None
# A new recipient has arrived. Day:  74.00301073601366
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 5
# 77.49791429971108 new_recipient None
# A new recipient has arrived. Day:  77.49791429971108
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 78.81266873785397 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  78.81266873785397
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 5
# 82.01118354167225 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  82.01118354167225
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 5
# 85.98035410115715 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  85.98035410115715
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 5
# 86.04515286525383 new_recipient None
# A new recipient has arrived. Day:  86.04515286525383
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 5
# 88.66639228640172 new_recipient None
# A new recipient has arrived. Day:  88.66639228640172
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 5
# 89.41605283062432 new_recipient None
# A new recipient has arrived. Day:  89.41605283062432
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 94.8021412613147 new_recipient None
# A new recipient has arrived. Day:  94.8021412613147
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 101.15821663170428 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  101.15821663170428
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 101.43027741290378 new_recipient None
# A new recipient has arrived. Day:  101.43027741290378
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 102.90723079566598 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  102.90723079566598
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 106.69436214488677 new_recipient None
# A new recipient has arrived. Day:  106.69436214488677
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 109.95903738218513 new_recipient None
# A new recipient has arrived. Day:  109.95903738218513
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 5
# 113.38267618699163 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  113.38267618699163
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 113.40039276947526 new_recipient None
# A new recipient has arrived. Day:  113.40039276947526
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 5
# 113.89705805789974 new_recipient None
# A new recipient has arrived. Day:  113.89705805789974
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 5
# 114.81792732317126 leave_list 945
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 6
# 119.52503718330131 new_recipient None
# A new recipient has arrived. Day:  119.52503718330131
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 6
# 120.14111628381738 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  120.14111628381738
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 6
# 122.18927961248288 new_recipient None
# A new recipient has arrived. Day:  122.18927961248288
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 6
# 122.7185819814811 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  122.7185819814811
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 6
# 123.72386103038264 new_recipient None
# A new recipient has arrived. Day:  123.72386103038264
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 6
# 125.19704615620286 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  125.19704615620286
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 6
# 125.3320722651828 leave_list 15882
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 7
# 127.09477637154305 new_recipient None
# A new recipient has arrived. Day:  127.09477637154305
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 7
# 129.64026098998494 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  129.64026098998494
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 7
# 132.26783477333106 leave_list 15399
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 8
# 135.13215772475485 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  135.13215772475485
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 8
# 135.6642492279431 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  135.6642492279431
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 8
# 137.07937362127723 new_recipient None
# A new recipient has arrived. Day:  137.07937362127723
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 8
# 137.7257643975418 new_recipient None
# A new recipient has arrived. Day:  137.7257643975418
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 8
# 140.43030999856128 new_recipient None
# A new recipient has arrived. Day:  140.43030999856128
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 8
# 141.07900048445939 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  141.07900048445939
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 8
# 143.53576343214743 leave_list 3318
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 9
# 146.41979865408905 new_recipient None
# A new recipient has arrived. Day:  146.41979865408905
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 9
# 147.97081154941037 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  147.97081154941037
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 9
# 154.53586557749912 new_recipient None
# A new recipient has arrived. Day:  154.53586557749912
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 9
# 157.04765152958248 new_donor None
# A donation was done with expected life 2354.0468992355763 and probabity 0.6213407169292465. Day:  157.04765152958248
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 9
# 158.38212872447272 new_recipient None
# A new recipient has arrived. Day:  158.38212872447272
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 9
# 164.7537122657452 new_recipient None
# A new recipient has arrived. Day:  164.7537122657452
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 9
# 168.3906092528558 new_recipient None
# A new recipient has arrived. Day:  168.3906092528558
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 9
# 168.58585036659218 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  168.58585036659218
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 9
# 171.05728716746057 leave_list 7502
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 10
# 172.0412123305929 leave_list 12244
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 11
# 177.40729202084677 new_recipient None
# A new recipient has arrived. Day:  177.40729202084677
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 11
# 178.1440116170415 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  178.1440116170415
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 11
# 180.2392897681887 leave_list 5163
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 12
# 180.48012369633176 leave_list 16500
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 13
# 182.32466731060973 leave_list 1753
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 14
# 186.60803350454214 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  186.60803350454214
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 14
# 186.65896238807323 new_recipient None
# A new recipient has arrived. Day:  186.65896238807323
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 14
# 191.49914655727866 leave_list 3442
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 15
# 197.39867527077539 leave_list 4153
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 16
# 206.17686901532272 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  206.17686901532272
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 16
# 207.9624850403748 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  207.9624850403748
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 16
# 209.1975579762735 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  209.1975579762735
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 16
# 211.24913180416885 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  211.24913180416885
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 16
# 212.1019460866398 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  212.1019460866398
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 16
# 213.05978041963021 new_recipient None
# A new recipient has arrived. Day:  213.05978041963021
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 16
# 214.927215462816 new_recipient None
# A new recipient has arrived. Day:  214.927215462816
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 16
# 215.6583210337656 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  215.6583210337656
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 16
# 216.28897394012813 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  216.28897394012813
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 16
# 216.8092877818926 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  216.8092877818926
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 16
# 217.3542102870808 new_recipient None
# A new recipient has arrived. Day:  217.3542102870808
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 16
# 219.73447753414655 new_recipient None
# A new recipient has arrived. Day:  219.73447753414655
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 16
# 220.97913462865657 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  220.97913462865657
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 16
# 222.94034876250882 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  222.94034876250882
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 16
# 223.04859024701096 new_recipient None
# A new recipient has arrived. Day:  223.04859024701096
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 16
# 229.35786498273384 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  229.35786498273384
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 16
# 232.0058968456853 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  232.0058968456853
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 16
# 234.68701404497367 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  234.68701404497367
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 16
# 235.69903585957303 new_recipient None
# A new recipient has arrived. Day:  235.69903585957303
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 16
# 236.47155504535826 new_recipient None
# A new recipient has arrived. Day:  236.47155504535826
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 16
# 237.56370381829475 new_recipient None
# A new recipient has arrived. Day:  237.56370381829475
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 16
# 240.06127254486927 new_recipient None
# A new recipient has arrived. Day:  240.06127254486927
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 16
# 244.75675927383853 new_recipient None
# A new recipient has arrived. Day:  244.75675927383853
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 16
# 246.63360562729636 leave_list 21848
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 17
# 250.08854093666054 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  250.08854093666054
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 17
# 250.15098564505763 new_recipient None
# A new recipient has arrived. Day:  250.15098564505763
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 17
# 251.74736612528952 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  251.74736612528952
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 17
# 252.43433969541962 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  252.43433969541962
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 17
# 253.67581690332696 new_recipient None
# A new recipient has arrived. Day:  253.67581690332696
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 17
# 255.71700242880743 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  255.71700242880743
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 17
# 257.30439391650924 new_recipient None
# A new recipient has arrived. Day:  257.30439391650924
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 17
# 258.82839937075556 leave_list 2594
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 18
# 261.23516828060764 new_recipient None
# A new recipient has arrived. Day:  261.23516828060764
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 18
# 265.1390259351135 new_donor None
# A donation was done with expected life 2354.0468992355763 and probabity 0.6213407169292465. Day:  265.1390259351135
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 18
# 265.6092449330845 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  265.6092449330845
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 18
# 267.1960024511944 new_recipient None
# A new recipient has arrived. Day:  267.1960024511944
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 18
# 270.3911844506246 new_recipient None
# A new recipient has arrived. Day:  270.3911844506246
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 18
# 271.1941867735163 new_recipient None
# A new recipient has arrived. Day:  271.1941867735163
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 18
# 271.7158074382863 new_recipient None
# A new recipient has arrived. Day:  271.7158074382863
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 18
# 271.93571888165894 new_recipient None
# A new recipient has arrived. Day:  271.93571888165894
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 18
# 273.65484884202544 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  273.65484884202544
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 18
# 274.6099453317556 new_recipient None
# A new recipient has arrived. Day:  274.6099453317556
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 18
# 275.60767062678093 leave_list 21553
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 19
# 278.46157533579367 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  278.46157533579367
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 19
# 282.35314702419464 new_recipient None
# A new recipient has arrived. Day:  282.35314702419464
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 19
# 283.3477652895465 new_recipient None
# A new recipient has arrived. Day:  283.3477652895465
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 19
# 287.3013748889328 new_recipient None
# A new recipient has arrived. Day:  287.3013748889328
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 19
# 292.37217802439227 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  292.37217802439227
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 19
# 293.16921150669685 new_recipient None
# A new recipient has arrived. Day:  293.16921150669685
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 19
# 293.7226815180386 leave_list 15882
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 20
# 294.3833543679286 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  294.3833543679286
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 20
# 294.5222327507036 new_recipient None
# A new recipient has arrived. Day:  294.5222327507036
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 20
# 295.8855315550492 leave_list 20014
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 21
# 299.5529583326541 new_recipient None
# A new recipient has arrived. Day:  299.5529583326541
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 21
# 302.5174974824447 new_recipient None
# A new recipient has arrived. Day:  302.5174974824447
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 21
# 303.0103278186697 leave_list 8901
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 22
# 304.1576782559629 new_recipient None
# A new recipient has arrived. Day:  304.1576782559629
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 22
# 305.34832462904444 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  305.34832462904444
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 22
# 307.56681085724637 new_recipient None
# A new recipient has arrived. Day:  307.56681085724637
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 22
# 310.6042385693392 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  310.6042385693392
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 22
# 311.0626843969503 new_recipient None
# A new recipient has arrived. Day:  311.0626843969503
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 22
# 313.08468379370265 new_recipient None
# A new recipient has arrived. Day:  313.08468379370265
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 22
# 314.928723141657 new_recipient None
# A new recipient has arrived. Day:  314.928723141657
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 22
# 316.0890690400268 leave_list 1373
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 23
# 317.30225723265926 new_recipient None
# A new recipient has arrived. Day:  317.30225723265926
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 23
# 318.57830621073816 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  318.57830621073816
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 23
# 319.2108548645687 leave_list 16121
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 24
# 322.7470929186437 leave_list 4970
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 25
# 329.23945623530483 new_recipient None
# A new recipient has arrived. Day:  329.23945623530483
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 25
# 333.61887752145014 leave_list 20581
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 26
# 340.8067073285197 new_recipient None
# A new recipient has arrived. Day:  340.8067073285197
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 26
# 341.2689073482027 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  341.2689073482027
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 26
# 348.08692890550185 new_recipient None
# A new recipient has arrived. Day:  348.08692890550185
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 26
# 351.26433186555937 new_recipient None
# A new recipient has arrived. Day:  351.26433186555937
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 26
# 352.7437153835084 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  352.7437153835084
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 26
# 352.9960185386883 new_recipient None
# A new recipient has arrived. Day:  352.9960185386883
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 26
# 353.0288394480404 new_recipient None
# A new recipient has arrived. Day:  353.0288394480404
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 26
# 355.9142840402145 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  355.9142840402145
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 26
# 356.7226246461152 leave_list 2817
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 27
# 357.3231360454284 leave_list 21003
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 28
# 357.6716653587268 leave_list 880
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 29
# 361.13216895865116 new_recipient None
# A new recipient has arrived. Day:  361.13216895865116
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 29
# 361.7711866636544 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  361.7711866636544
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 29
# 368.4691905368514 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  368.4691905368514
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 29
# 369.46725828738147 leave_list 1090
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 30
# 370.8504014415669 leave_list 13771
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 31
# 372.5204997379822 leave_list 12295
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 32
# 377.75704152235477 leave_list 12435
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 33
# 383.5789126302265 new_recipient None
# A new recipient has arrived. Day:  383.5789126302265
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 33
# 384.2585254280146 leave_list 18962
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 34
# 391.46330559869364 new_recipient None
# A new recipient has arrived. Day:  391.46330559869364
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 34
# 394.9811266404126 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  394.9811266404126
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 34
# 395.2694182078166 new_recipient None
# A new recipient has arrived. Day:  395.2694182078166
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 34
# 397.5935000552695 leave_list 5163
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 35
# 399.4463455769416 leave_list 13393
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 36
# 405.60223542677136 leave_list 5691
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 37
# 409.24569486915954 leave_list 7395
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 38
# 411.9958469365262 leave_list 13378
# Number of matches: 0, recipients in wait list: 279,average time in waitlist INF, patients which leave the list 39
# 418.6733427897561 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  418.6733427897561
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 39
# 419.2626056661793 new_recipient None
# A new recipient has arrived. Day:  419.2626056661793
# Number of matches: 0, recipients in wait list: 279,average time in waitlist INF, patients which leave the list 39
# 419.48255004642886 new_recipient None
# A new recipient has arrived. Day:  419.48255004642886
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 39
# 423.37423861130594 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  423.37423861130594
# Number of matches: 0, recipients in wait list: 279,average time in waitlist INF, patients which leave the list 39
# 428.3697392747627 new_recipient None
# A new recipient has arrived. Day:  428.3697392747627
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 39
# 429.0678167124243 leave_list 2948
# Number of matches: 0, recipients in wait list: 279,average time in waitlist INF, patients which leave the list 40
# 430.8104041658343 leave_list 19320
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 41
# 433.13038595648146 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  433.13038595648146
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 41
# 435.89600319337745 new_recipient None
# A new recipient has arrived. Day:  435.89600319337745
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 41
# 435.94130190688327 new_recipient None
# A new recipient has arrived. Day:  435.94130190688327
# Number of matches: 0, recipients in wait list: 279,average time in waitlist INF, patients which leave the list 41
# 440.5429320526219 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  440.5429320526219
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 41
# 441.3969033902644 leave_list 9478
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 42
# 445.86869867616866 new_recipient None
# A new recipient has arrived. Day:  445.86869867616866
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 42
# 446.42492861633616 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  446.42492861633616
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 42
# 448.5666141825502 new_recipient None
# A new recipient has arrived. Day:  448.5666141825502
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 42
# 451.0907872747811 new_recipient None
# A new recipient has arrived. Day:  451.0907872747811
# Number of matches: 0, recipients in wait list: 279,average time in waitlist INF, patients which leave the list 42
# 452.57930285115924 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  452.57930285115924
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 42
# 460.27409407368435 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  460.27409407368435
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 42
# 462.4338952339693 new_recipient None
# A new recipient has arrived. Day:  462.4338952339693
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 42
# 462.4633211265221 new_recipient None
# A new recipient has arrived. Day:  462.4633211265221
# Number of matches: 0, recipients in wait list: 279,average time in waitlist INF, patients which leave the list 42
# 463.8814319752316 new_recipient None
# A new recipient has arrived. Day:  463.8814319752316
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 42
# 466.63467293553606 new_recipient None
# A new recipient has arrived. Day:  466.63467293553606
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 42
# 467.0959143061618 new_recipient None
# A new recipient has arrived. Day:  467.0959143061618
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 42
# 469.923192237622 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  469.923192237622
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 42
# 470.3688826581754 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  470.3688826581754
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 42
# 470.3894363389735 new_recipient None
# A new recipient has arrived. Day:  470.3894363389735
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 42
# 476.5034600619236 new_recipient None
# A new recipient has arrived. Day:  476.5034600619236
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 42
# 477.4124570662793 new_recipient None
# A new recipient has arrived. Day:  477.4124570662793
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 42
# 481.61443626025675 new_recipient None
# A new recipient has arrived. Day:  481.61443626025675
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 42
# 484.8881358278277 new_recipient None
# A new recipient has arrived. Day:  484.8881358278277
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 42
# 491.697474531051 new_recipient None
# A new recipient has arrived. Day:  491.697474531051
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 42
# 493.80558004206125 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  493.80558004206125
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 42
# 495.3394173475373 new_recipient None
# A new recipient has arrived. Day:  495.3394173475373
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 42
# 497.04215330341106 new_recipient None
# A new recipient has arrived. Day:  497.04215330341106
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 42
# 497.3889333853384 new_recipient None
# A new recipient has arrived. Day:  497.3889333853384
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 42
# 497.7136690482724 leave_list 21702
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 43
# 499.00136213862464 new_recipient None
# A new recipient has arrived. Day:  499.00136213862464
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 43
# 500.0048301377979 new_recipient None
# A new recipient has arrived. Day:  500.0048301377979
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 43
# 500.5743755988764 new_recipient None
# A new recipient has arrived. Day:  500.5743755988764
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 43
# 501.1279634089358 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  501.1279634089358
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 43
# 503.1977004384545 new_recipient None
# A new recipient has arrived. Day:  503.1977004384545
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 43
# 505.2018754229177 new_recipient None
# A new recipient has arrived. Day:  505.2018754229177
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 43
# 505.7675566230808 new_recipient None
# A new recipient has arrived. Day:  505.7675566230808
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 43
# 510.1286281089756 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  510.1286281089756
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 43
# ...
# 10804.419295074471 leave_list 4366
# ----------------------- One patient left the waitlist. Day:  10804.419295074471 4366
# Number of matches: 1168, recipients in wait list: 219,average time in waitlist 1240.3108757896061, patients which leave the list 796
# 10807.098696699986 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10807.098696699986
# Number of matches: 1169, recipients in wait list: 218,average time in waitlist 1240.3727216407483, patients which leave the list 796
# 10807.843210690658 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10807.843210690658
# Number of matches: 1170, recipients in wait list: 217,average time in waitlist 1240.4302949408386, patients which leave the list 796
# 10809.755147347667 leave_list 7976
# ----------------------- One patient left the waitlist. Day:  10809.755147347667 7976
# Number of matches: 1170, recipients in wait list: 216,average time in waitlist 1240.4302949408386, patients which leave the list 797
# 10815.602830773461 new_recipient None
# A new recipient has arrived. Day:  10815.602830773461
# Number of matches: 1170, recipients in wait list: 217,average time in waitlist 1240.4302949408386, patients which leave the list 797
# 10816.385238387333 new_recipient None
# A new recipient has arrived. Day:  10816.385238387333
# Number of matches: 1170, recipients in wait list: 218,average time in waitlist 1240.4302949408386, patients which leave the list 797
# 10816.812157648423 new_recipient None
# A new recipient has arrived. Day:  10816.812157648423
# Number of matches: 1170, recipients in wait list: 219,average time in waitlist 1240.4302949408386, patients which leave the list 797
# 10821.338281265449 new_recipient None
# A new recipient has arrived. Day:  10821.338281265449
# Number of matches: 1170, recipients in wait list: 220,average time in waitlist 1240.4302949408386, patients which leave the list 797
# 10822.642776487879 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  10822.642776487879
# Number of matches: 1171, recipients in wait list: 219,average time in waitlist 1240.4749592569633, patients which leave the list 797
# 10826.17530199753 leave_list 7519
# ----------------------- One patient left the waitlist. Day:  10826.17530199753 7519
# Number of matches: 1171, recipients in wait list: 218,average time in waitlist 1240.4749592569633, patients which leave the list 798
# 10830.732694489168 new_recipient None
# A new recipient has arrived. Day:  10830.732694489168
# Number of matches: 1171, recipients in wait list: 219,average time in waitlist 1240.4749592569633, patients which leave the list 798
# 10832.34484907961 new_recipient None
# A new recipient has arrived. Day:  10832.34484907961
# Number of matches: 1171, recipients in wait list: 220,average time in waitlist 1240.4749592569633, patients which leave the list 798
# 10833.13274311738 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  10833.13274311738
# Number of matches: 1172, recipients in wait list: 219,average time in waitlist 1240.3886242239, patients which leave the list 798
# 10835.700474072837 new_recipient None
# A new recipient has arrived. Day:  10835.700474072837
# Number of matches: 1172, recipients in wait list: 220,average time in waitlist 1240.3886242239, patients which leave the list 798
# 10837.464012029346 new_recipient None
# A new recipient has arrived. Day:  10837.464012029346
# Number of matches: 1172, recipients in wait list: 221,average time in waitlist 1240.3886242239, patients which leave the list 798
# 10839.471530159755 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  10839.471530159755
# Number of matches: 1173, recipients in wait list: 220,average time in waitlist 1240.3032885535374, patients which leave the list 798
# 10840.039061158428 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10840.039061158428
# Number of matches: 1174, recipients in wait list: 219,average time in waitlist 1240.3605167870674, patients which leave the list 798
# 10840.272257608169 new_recipient None
# A new recipient has arrived. Day:  10840.272257608169
# Number of matches: 1174, recipients in wait list: 220,average time in waitlist 1240.3605167870674, patients which leave the list 798
# 10841.987312081466 new_donor None
# A donation was done with expected life 2354.0468992355763 and probabity 0.6213407169292465. Day:  10841.987312081466
# Number of matches: 1175, recipients in wait list: 219,average time in waitlist 1240.4158829850214, patients which leave the list 798
# 10842.264517038015 new_recipient None
# A new recipient has arrived. Day:  10842.264517038015
# Number of matches: 1175, recipients in wait list: 220,average time in waitlist 1240.4158829850214, patients which leave the list 798
# 10842.805511956622 new_recipient None
# A new recipient has arrived. Day:  10842.805511956622
# Number of matches: 1175, recipients in wait list: 221,average time in waitlist 1240.4158829850214, patients which leave the list 798
# 10853.433930825156 new_recipient None
# A new recipient has arrived. Day:  10853.433930825156
# Number of matches: 1175, recipients in wait list: 222,average time in waitlist 1240.4158829850214, patients which leave the list 798
# 10857.783086767478 new_recipient None
# A new recipient has arrived. Day:  10857.783086767478
# Number of matches: 1175, recipients in wait list: 223,average time in waitlist 1240.4158829850214, patients which leave the list 798
# 10864.043941384693 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  10864.043941384693
# Number of matches: 1176, recipients in wait list: 222,average time in waitlist 1240.487422603635, patients which leave the list 798
# 10868.678030181276 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10868.678030181276
# Number of matches: 1177, recipients in wait list: 221,average time in waitlist 1240.5571600840165, patients which leave the list 798
# 10870.490147640865 new_recipient None
# A new recipient has arrived. Day:  10870.490147640865
# Number of matches: 1177, recipients in wait list: 222,average time in waitlist 1240.5571600840165, patients which leave the list 798
# 10871.45190419528 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  10871.45190419528
# Number of matches: 1178, recipients in wait list: 221,average time in waitlist 1240.4615634850154, patients which leave the list 798
# 10873.533369796944 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  10873.533369796944
# Number of matches: 1179, recipients in wait list: 220,average time in waitlist 1240.3651461936718, patients which leave the list 798
# 10875.30661483502 new_recipient None
# A new recipient has arrived. Day:  10875.30661483502
# Number of matches: 1179, recipients in wait list: 221,average time in waitlist 1240.3651461936718, patients which leave the list 798
# 10877.219378108639 leave_list 5023
# ----------------------- One patient left the waitlist. Day:  10877.219378108639 5023
# Number of matches: 1179, recipients in wait list: 220,average time in waitlist 1240.3651461936718, patients which leave the list 799
# 10881.423245986767 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  10881.423245986767
# Number of matches: 1180, recipients in wait list: 219,average time in waitlist 1239.9605927759947, patients which leave the list 799
# 10881.59173393411 new_recipient None
# A new recipient has arrived. Day:  10881.59173393411
# Number of matches: 1180, recipients in wait list: 220,average time in waitlist 1239.9605927759947, patients which leave the list 799
# 10882.990716607615 new_recipient None
# A new recipient has arrived. Day:  10882.990716607615
# Number of matches: 1180, recipients in wait list: 221,average time in waitlist 1239.9605927759947, patients which leave the list 799
# 10884.547448881223 new_recipient None
# A new recipient has arrived. Day:  10884.547448881223
# Number of matches: 1180, recipients in wait list: 222,average time in waitlist 1239.9605927759947, patients which leave the list 799
# 10886.88014402638 new_recipient None
# A new recipient has arrived. Day:  10886.88014402638
# Number of matches: 1180, recipients in wait list: 223,average time in waitlist 1239.9605927759947, patients which leave the list 799
# 10887.049206845337 leave_list 8890
# ----------------------- One patient left the waitlist. Day:  10887.049206845337 8890
# Number of matches: 1180, recipients in wait list: 222,average time in waitlist 1239.9605927759947, patients which leave the list 800
# 10891.249235062356 new_recipient None
# A new recipient has arrived. Day:  10891.249235062356
# Number of matches: 1180, recipients in wait list: 223,average time in waitlist 1239.9605927759947, patients which leave the list 800
# 10891.460103696721 leave_list 12455
# ----------------------- One patient left the waitlist. Day:  10891.460103696721 12455
# Number of matches: 1180, recipients in wait list: 222,average time in waitlist 1239.9605927759947, patients which leave the list 801
# 10892.155233275907 new_recipient None
# A new recipient has arrived. Day:  10892.155233275907
# Number of matches: 1180, recipients in wait list: 223,average time in waitlist 1239.9605927759947, patients which leave the list 801
# 10893.651478707636 new_recipient None
# A new recipient has arrived. Day:  10893.651478707636
# Number of matches: 1180, recipients in wait list: 224,average time in waitlist 1239.9605927759947, patients which leave the list 801
# 10896.961662713129 new_recipient None
# A new recipient has arrived. Day:  10896.961662713129
# Number of matches: 1180, recipients in wait list: 225,average time in waitlist 1239.9605927759947, patients which leave the list 801
# 10900.298302438505 new_recipient None
# A new recipient has arrived. Day:  10900.298302438505
# Number of matches: 1180, recipients in wait list: 226,average time in waitlist 1239.9605927759947, patients which leave the list 801
# 10900.412053501503 new_recipient None
# A new recipient has arrived. Day:  10900.412053501503
# Number of matches: 1180, recipients in wait list: 227,average time in waitlist 1239.9605927759947, patients which leave the list 801
# 10901.138749343501 new_recipient None
# A new recipient has arrived. Day:  10901.138749343501
# Number of matches: 1180, recipients in wait list: 228,average time in waitlist 1239.9605927759947, patients which leave the list 801
# 10902.336622232924 leave_list 1765
# ----------------------- One patient left the waitlist. Day:  10902.336622232924 1765
# Number of matches: 1180, recipients in wait list: 227,average time in waitlist 1239.9605927759947, patients which leave the list 802
# 10906.959982337292 new_recipient None
# A new recipient has arrived. Day:  10906.959982337292
# Number of matches: 1180, recipients in wait list: 228,average time in waitlist 1239.9605927759947, patients which leave the list 802
# 10909.621548123197 new_recipient None
# A new recipient has arrived. Day:  10909.621548123197
# Number of matches: 1180, recipients in wait list: 229,average time in waitlist 1239.9605927759947, patients which leave the list 802
# 10911.46123409338 new_recipient None
# A new recipient has arrived. Day:  10911.46123409338
# Number of matches: 1180, recipients in wait list: 230,average time in waitlist 1239.9605927759947, patients which leave the list 802
# 10914.615233855247 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  10914.615233855247
# Number of matches: 1181, recipients in wait list: 229,average time in waitlist 1240.0622490684052, patients which leave the list 802
# 10915.990920139478 new_recipient None
# A new recipient has arrived. Day:  10915.990920139478
# Number of matches: 1181, recipients in wait list: 230,average time in waitlist 1240.0622490684052, patients which leave the list 802
# 10917.168626888653 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  10917.168626888653
# Number of matches: 1182, recipients in wait list: 229,average time in waitlist 1239.6335368146827, patients which leave the list 802
# 10917.34750416713 new_recipient None
# A new recipient has arrived. Day:  10917.34750416713
# Number of matches: 1182, recipients in wait list: 230,average time in waitlist 1239.6335368146827, patients which leave the list 802
# 10918.981511966445 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10918.981511966445
# Number of matches: 1183, recipients in wait list: 229,average time in waitlist 1240.3661996267945, patients which leave the list 802
# 10919.68933568953 new_recipient None
# A new recipient has arrived. Day:  10919.68933568953
# Number of matches: 1183, recipients in wait list: 230,average time in waitlist 1240.3661996267945, patients which leave the list 802
# 10921.001604167783 new_recipient None
# A new recipient has arrived. Day:  10921.001604167783
# Number of matches: 1183, recipients in wait list: 231,average time in waitlist 1240.3661996267945, patients which leave the list 802
# 10924.606851199449 new_recipient None
# A new recipient has arrived. Day:  10924.606851199449
# Number of matches: 1183, recipients in wait list: 232,average time in waitlist 1240.3661996267945, patients which leave the list 802
# 10926.251722153613 new_recipient None
# A new recipient has arrived. Day:  10926.251722153613
# Number of matches: 1183, recipients in wait list: 233,average time in waitlist 1240.3661996267945, patients which leave the list 802
# 10926.588904198657 new_recipient None
# A new recipient has arrived. Day:  10926.588904198657
# Number of matches: 1183, recipients in wait list: 234,average time in waitlist 1240.3661996267945, patients which leave the list 802
# 10926.836357537355 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10926.836357537355
# Number of matches: 1184, recipients in wait list: 233,average time in waitlist 1240.464664744327, patients which leave the list 802
# 10934.165185586535 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  10934.165185586535
# Number of matches: 1185, recipients in wait list: 232,average time in waitlist 1240.5662234719923, patients which leave the list 802
# 10936.26833754218 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  10936.26833754218
# Number of matches: 1186, recipients in wait list: 231,average time in waitlist 1240.3277027155639, patients which leave the list 802
# 10939.465328946553 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  10939.465328946553
# Number of matches: 1187, recipients in wait list: 230,average time in waitlist 1240.0733072076016, patients which leave the list 802
# 10941.33330441343 new_recipient None
# A new recipient has arrived. Day:  10941.33330441343
# Number of matches: 1187, recipients in wait list: 231,average time in waitlist 1240.0733072076016, patients which leave the list 802
# 10947.35437716429 leave_list 10184
# ----------------------- One patient left the waitlist. Day:  10947.35437716429 10184
# Number of matches: 1187, recipients in wait list: 230,average time in waitlist 1240.0733072076016, patients which leave the list 803
# 10953.628371501862 new_recipient None
# A new recipient has arrived. Day:  10953.628371501862
# Number of matches: 1187, recipients in wait list: 231,average time in waitlist 1240.0733072076016, patients which leave the list 803
# ([1240.0733072076016], [1187])

# %%
df['ethcat'] = df['ethcat'].replace(ethcat_mapping)

# %%
df_waiting_time = ((df.groupby(by=['replicate', 'ethcat'])
                   .agg(
                       waiting_time=('waiting_time', 'mean'), 
                       count=('waiting_time', 'size'), 
                       mean_survival_time=('mean_survival_time', 'mean'))
                   .reset_index())
)#.to_csv('simulation_results.csv')
df_waiting_time = df_waiting_time[['ethcat', 'waiting_time', 'count', 'mean_survival_time']].groupby('ethcat').agg(['mean', 'std'])
df_waiting_time.columns = [f"{col[0]}_{col[1]}" for col in df_waiting_time.columns] 
df_waiting_time['prop_simu'] = df_waiting_time['count_mean'] / df_waiting_time['count_mean'].sum()
df_waiting_time = df_waiting_time.merge(real_ethcat_df, on='ethcat').round(3)
df_waiting_time.columns = ['ethcat', 'wt_mean', 'wt_std', 'count_mean', 'count_std', 'st_mean', 'st_std', 'prop_simu', 'sample_proportion']
df_waiting_time
# Out:
#                                               ethcat   wt_mean  wt_std  \
# 0               Amer Ind/Alaska Native, Non-Hispanic  1219.751     NaN
# 1                                Asian, Non-Hispanic  1350.784     NaN
# 2                                Black, Non-Hispanic  1273.814     NaN
# 3                                    Hispanic/Latino  1242.503     NaN
# 4                          Multiracial, Non-Hispanic  1286.350     NaN
# 5  Native Hawaiian/Other Pacific Islander, Non-Hi...  1381.159     NaN
# 6                                White, Non-Hispanic  1201.443     NaN
#
#    count_mean  count_std   st_mean  st_std  prop_simu  sample_proportion
# 0        17.0        NaN  2936.347     NaN      0.014              0.014
# 1        62.0        NaN  2924.109     NaN      0.052              0.053
# 2       379.0        NaN  2974.649     NaN      0.319              0.325
# 3       186.0        NaN  2938.824     NaN      0.157              0.160
# 4         8.0        NaN  2877.121     NaN      0.007              0.005
# 5         3.0        NaN  2798.340     NaN      0.003              0.004
# 6       532.0        NaN  2987.858     NaN      0.448              0.439

# %%
df_gender = ((df.groupby(by=['replicate', 'gender'])
                .agg(
                    waiting_time=('waiting_time', 'mean'), 
                    count=('waiting_time', 'size'),
                    mean_survival_time=('mean_survival_time', 'mean'))
                .reset_index())
)#.to_csv('simulation_results.csv')
df_gender = df_gender[['gender', 'waiting_time', 'count', 'mean_survival_time']].groupby('gender').agg(['mean', 'std'])
df_gender.columns = [f"{col[0]}_{col[1]}" for col in df_gender.columns] 
df_gender['proportion_sim'] = df_gender['count_mean'] / df_gender['count_mean'].sum()
df_gender.reset_index(inplace=True)
df_gender = df_gender.merge(real_gender_df, on = 'gender')
df_gender.columns = ['gender', 'wt_mean', 'wt_std', 'count_mean',
       'count_std', 'st_mean', 'st_std',
       'prop_sim', 'sample_proportion']
df_gender.round(3)
# Out:
#   gender   wt_mean  wt_std  count_mean  count_std   st_mean  st_std  prop_sim  \
# 0      F  1223.988     NaN       417.0        NaN  2967.620     NaN     0.351
# 1      M  1248.785     NaN       770.0        NaN  2972.313     NaN     0.649
#
#    sample_proportion
# 0              0.352
# 1              0.648

# %%
#df.to_csv('results_decision_tree.csv')

# %%
import numpy as np 

np.quantile(np.mean(np.random.exponential(scale=(1)*365, size=100)), 0.2)
# Out:
# 377.514622368911
