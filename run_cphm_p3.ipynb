# %%
import pandas as pd 

df_base = pd.read_csv('data/data_to_simulate.csv', index_col=0)
df_base.dropna(inplace=True)
print(df_base.columns)
columns = ['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON', 'AGE', 'DIAB',
                'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI', 'SERUM_CREAT',
                'CREAT_TRR', 'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC','CREAT_TRRg1.5', 'SERUM_CREATg1.2',
                'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
                'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE','TX_DATE', 'PT_CODE', 'ABO', 'ABO_DON']

predictors = ['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'WGT_KG_DON_CALC',
                    'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'COD_CAD_DON', 'ETHCAT_DON', 'ABO_MAT', 
                    'HLAMIS', 'DIALYSIS_DATE', 'AGE', 'DIAB', 'DIALYSIS_DATEle0.0', 'CREAT_TRRg1.5', 'SERUM_CREATg1.2']

donor = df_base[['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 
            'HIST_HYPERTENS_DON', 'ABO_DON', 'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2']]

print(donor.columns)
donor.to_csv('data/donors.csv')

recipient = df_base[[ 'DIALYSIS_DATE', 'AGE', 'DIAB', 'ETHCAT', 'GENDER', 'ABO', 'DIALYSIS_DATEle0.0']]
recipient.to_csv('data/recipients.csv')

ethcat_mapping = {
    1: "White, Non-Hispanic",
    2: "Black, Non-Hispanic",
    4: "Hispanic/Latino",
    5: "Asian, Non-Hispanic",
    6: "Amer Ind/Alaska Native, Non-Hispanic",
    7: "Native Hawaiian/Other Pacific Islander, Non-Hispanic",
    9: "Multiracial, Non-Hispanic",
}
# Out:
# Index(['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON',
#        'AGE', 'DIAB', 'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI',
#        'SERUM_CREAT', 'ABO_MAT', 'AMIS', 'BMIS', 'DRMIS', 'CREAT_TRR',
#        'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC', 'ABO_DON',
#        'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
#        'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE', 'TX_DATE',
#        'PT_CODE', 'COMPOSITE_DEATH_DATE', 'ABO', 'T', 'Tag_date', 'DIAB_1',
#        'DIAB_998', 'HIST_DIABETES_DON_1', 'HIST_DIABETES_DON_998',
#        'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2',
#        'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype='object')
# Index(['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC',
#        'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'ABO_DON',
#        'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2'],
#       dtype='object')

# %%
real_gender_df = df_base.GENDER.value_counts(normalize=True).reset_index()
real_gender_df.columns = ['gender', 'sample_proportion']
real_gender_df
# Out:
#   gender  sample_proportion
# 0      M            0.64827
# 1      F            0.35173

# %%
real_ethcat_df = df_base.ETHCAT.value_counts(normalize=True).reset_index()
real_ethcat_df.ETHCAT = real_ethcat_df.ETHCAT.map(ethcat_mapping)
real_ethcat_df.columns = ['ethcat', 'sample_proportion']
real_ethcat_df
# Out:
#                                               ethcat  sample_proportion
# 0                                White, Non-Hispanic           0.439416
# 1                                Black, Non-Hispanic           0.325258
# 2                                    Hispanic/Latino           0.159551
# 3                                Asian, Non-Hispanic           0.053213
# 4               Amer Ind/Alaska Native, Non-Hispanic           0.013618
# 5                          Multiracial, Non-Hispanic           0.004764
# 6  Native Hawaiian/Other Pacific Islander, Non-Hi...           0.004180

# %%
recipient.ABO.unique()
# Out:
# array(['B', 'A', 'O', 'AB', 'A2', 'A1', 'A1B', 'A2B'], dtype=object)

# %%
blood_type_compatibility = {
    "A": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A1": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A2": ["A", "A1", "A2", "AB", "A1B", "A2B", "B"],
    "B":  ["B", "AB", "A1B", "A2B"],
    "AB": ["AB", "A1B", "A2B"],
    "A1B": ["A1B"],
    "A2B": ["A2B", "AB"],
    "O": ["A", "A1", "A2", "B", "AB", "A1B", "A2B", "O"]
}

# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
path = Path("C:/Users/HP/Desktop/UNOS data/codes/simulation-waitline-unos").resolve()  # Get the absolute path
os.chdir(path)
import pandas as pd
import numpy as np
import scipy as sc
import recipient as rec
import prediction as pred 
import donor as don
from event import Event

# %%
def create_list_of_events(n_events = 10000):
    events = Event(number_of_events= n_events, 
                    time_between_arrivals_recipients=4, 
                    time_between_arrivals_donor= 6) #average time in days
    events.create_events()
    return events

# %%
TARGET_TIME  = 5 * 365
SIMULATION_TIME = 365*30 
predictor = pred.SurvivalPredictionModel(model_path='models\cox_prop_2511.pkl')
#9.1% leave the list
#theshold_leave_list = 0.091 
recipients_for_initialization = 300
time_before_starting_simulation = 0
released_recipients = []
# Out:
# models\cox_prop_2511.pkl
# ok
# Model loaded successfully from models\cox_prop_2511.pkl.
# <>:3: SyntaxWarning: invalid escape sequence '\c'
# <>:3: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\HP\AppData\Local\Temp\ipykernel_23752\1261647170.py:3: SyntaxWarning: invalid escape sequence '\c'
#   predictor = pred.SurvivalPredictionModel(model_path='models\cox_prop_2511.pkl')

# %%
predictor.model.feature_names_in_
# Out:
# array(['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS',
#        'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'DIALYSIS_DATE', 'AGE',
#        'DIAB', 'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80',
#        'COD_CAD_DON_2', 'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype=object)

# %%
def get_expected_life(predicted_survival_function): 
    return sum((predicted_survival_function[0].x[i + 1] - predicted_survival_function[0].x[i]) *
    predicted_survival_function[0].y[i] for i in range(len(predicted_survival_function[0].x) - 1))

# %%
df = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
df_leaves = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
waiting_time_convergence = []
wait_list_length = []
leave_list_global = []



def run_simulation(T=10, replicates=1, verbose=False):
    waiting_time_convergence_r = []
    wait_list_length_r = []
    average_waiting_times = []
    number_of_matches_list = []
    
    for r in range(replicates):
        events = create_list_of_events(n_events = 10000)
        print('Replicate #', str(r))
        wait_list = []  # Initialize an empty waitlist for each replicate
        leave_list = []
        next_in_leave_the_list = []
        total_waiting_time = 0  # Track the total waiting time for this replicate
        num_matched_patients = 0  # Track the number of matched patients
        current_t = 0  # Start time    
    
        for i in range(recipients_for_initialization):
                new_recipient = rec.Recipient(time_before_starting_simulation) 
                new_recipient.create_recipient(i)
                wait_list.append(new_recipient)
                next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                next_in_leave_the_list = sorted(next_in_leave_the_list)
                
        while current_t < T:  
            (time_aux, _, _)  = events.list_of_events[0]
            (time2_aux, _, _) = next_in_leave_the_list[0]
            
            if time_aux + current_t < time2_aux:
                (time, event_type, counter)  = events.list_of_events.pop(0)
                ID = None
                print(time+current_t, event_type, ID)
            else: 
                (time, event_type, ID) = next_in_leave_the_list.pop(0)
                print(time, event_type, ID)
                   
            #print(time, event_type)         
            match event_type:
                case "new_donor":
                    current_t += time
                    donor = don.Donor(current_t)
                    donor.create_donor(counter)
                    
                    if len(wait_list) < 1:
                        raise('The waitlist length is 0, check the setup please')            
                    
                    survival_probs = []
                    for recipient in wait_list: 
                        if donor.blood in blood_type_compatibility[recipient.blood]: 
                            survival_probs.append(predictor.predict_survival_prob(recipient, donor, TARGET_TIME))
                        else: 
                             survival_probs.append(0)
                             
                    total_times = []           
                    
                    for recipient in wait_list:
                        if donor.blood in blood_type_compatibility[recipient.blood]:
                            _, function_pred = predictor.predict_survival_prob(recipient, donor, TARGET_TIME, surv_function=True)
                            total_ind = current_t-recipient.arrival_time + get_expected_life(function_pred)
                            total_times.append(total_ind)
                        else: 
                            total_times.append(-1)

                    if len(survival_probs)>0: 
                        best_match_index = np.argmax(total_times)
                        recipient_best = wait_list[best_match_index]
                        _, predicted_survival_function = predictor.predict_survival_prob(recipient_best, donor, TARGET_TIME, surv_function=True)
                        mean_survival_time = get_expected_life(predicted_survival_function)                        
                        best_patient = wait_list.pop(best_match_index)
                        next_leave_time = [(a, b, c) for (a, b, c) in next_in_leave_the_list if c==best_patient.ID]
                        _index = next_in_leave_the_list.index(next_leave_time[0])   
                        _ = next_in_leave_the_list.pop(_index)
                        
                        print(f'A donation was done with expected life {mean_survival_time} and probabity {survival_probs[best_match_index]}. Day: ', str(current_t))
                        waiting_time = current_t - best_patient.arrival_time
                        
                        if current_t > 8*365.25:
                            total_waiting_time += waiting_time
                            
                        best_patient.waiting_time = waiting_time
                        
                        
                        if current_t > 8*365.25:
                            df.loc[len(df)] = [r, best_patient.ethcat, best_patient.gender, best_patient.waiting_time, mean_survival_time, current_t]
                            released_recipients.append(best_patient)
                            num_matched_patients += 1
                
                case "new_recipient":            
                    current_t += time
                    new_recipient = rec.Recipient(current_t) 
                    new_recipient.create_recipient(counter)
                    wait_list.append(new_recipient)
                    next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                    next_in_leave_the_list = sorted(next_in_leave_the_list)
                    print('A new recipient has arrived. Day: ', str(current_t))
                
                case "leave_list":
                    current_t = time
                    next_leave_time = [p for p in wait_list if p.ID==ID]
                    _index = wait_list.index(next_leave_time[0])   
                    out_of_list = wait_list.pop(_index)
                    leave_list.append(out_of_list)
                    
                    if current_t > 8*365.25:
                        df_leaves.loc[len(df)] = [r, out_of_list.ethcat, out_of_list.gender, out_of_list.waiting_time, _, current_t]
                        print('----------------------- One patient left the waitlist. Day: ', str(current_t), out_of_list.ID) 
                    
                    

            if num_matched_patients>0:
                if current_t > 8*365.25:
                    average_time = total_waiting_time / num_matched_patients
                    #we collect data after 8 years
                    waiting_time_convergence_r.append([current_t, average_time])
                wait_list_length_r.append([current_t, len(wait_list)])
            else: 
                average_time = 'INF'
            if verbose:
                print(f'Number of matches: {num_matched_patients}, recipients in wait list: {len(wait_list)},'
                      f'average time in waitlist {average_time}, patients which leave the list {len(leave_list)}')        
        if num_matched_patients > 0:
            average_waiting_times.append(total_waiting_time / num_matched_patients)
            waiting_time_convergence.append(waiting_time_convergence_r)
            wait_list_length.append(wait_list_length_r)
            number_of_matches_list.append(num_matched_patients)
            leave_list_global.append(leave_list)
        else:
            average_waiting_times.append(0)
            
    return average_waiting_times, number_of_matches_list

# %%
run_simulation(T=SIMULATION_TIME, replicates=1, verbose=True)
# Out:
# Replicate # 0
# 4.410786820784188 new_recipient None
# A new recipient has arrived. Day:  4.410786820784188
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 4.997011252113413 new_recipient None
# A new recipient has arrived. Day:  4.997011252113413
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 0
# 8.846325666463757 new_recipient None
# A new recipient has arrived. Day:  8.846325666463757
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 0
# 9.123795085102028 new_recipient None
# A new recipient has arrived. Day:  9.123795085102028
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 0
# 12.980102290226505 new_donor None
# A donation was done with expected life 2643.464911160396 and probabity 0.7065336604159629. Day:  12.980102290226505
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 0
# 14.001169891183311 new_donor None
# A donation was done with expected life 3107.9857806328705 and probabity 0.8116534310900373. Day:  14.001169891183311
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 0
# 15.718546065002611 new_recipient None
# A new recipient has arrived. Day:  15.718546065002611
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 0
# 19.812328377794827 leave_list 11006
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 1
# 27.20908151257592 new_recipient None
# A new recipient has arrived. Day:  27.20908151257592
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 1
# 27.873394313275227 new_recipient None
# A new recipient has arrived. Day:  27.873394313275227
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 1
# 28.629501602914246 new_recipient None
# A new recipient has arrived. Day:  28.629501602914246
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 1
# 31.396155392542617 leave_list 19162
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 2
# 37.66939960932733 new_recipient None
# A new recipient has arrived. Day:  37.66939960932733
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 2
# 38.06344284740266 leave_list 14368
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 3
# 40.5421030602497 new_donor None
# A donation was done with expected life 2992.9276040922314 and probabity 0.7869396457395337. Day:  40.5421030602497
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 3
# 42.8821476590619 new_recipient None
# A new recipient has arrived. Day:  42.8821476590619
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 3
# 47.95971052833685 new_donor None
# A donation was done with expected life 3096.669463137501 and probabity 0.8092583981775103. Day:  47.95971052833685
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 3
# 49.586228191908006 leave_list 8104
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 4
# 54.73106989767462 new_recipient None
# A new recipient has arrived. Day:  54.73106989767462
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 4
# 56.6586421617206 new_donor None
# A donation was done with expected life 3083.049242669165 and probabity 0.8063656077070676. Day:  56.6586421617206
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 4
# 57.966498021189906 new_recipient None
# A new recipient has arrived. Day:  57.966498021189906
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 4
# 62.063134428358936 new_donor None
# A donation was done with expected life 2338.9528410936878 and probabity 0.6289598658416576. Day:  62.063134428358936
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 4
# 63.94322497898452 new_recipient None
# A new recipient has arrived. Day:  63.94322497898452
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 4
# 64.40437018573563 leave_list 3442
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 5
# 65.02502162060011 new_donor None
# A donation was done with expected life 2288.366510100686 and probabity 0.6153099416139298. Day:  65.02502162060011
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 5
# 65.92749416519092 new_donor None
# A donation was done with expected life 2386.5133415297123 and probabity 0.6415865575839709. Day:  65.92749416519092
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 5
# 65.9368371606779 leave_list 14368
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 6
# 67.40671103461402 new_recipient None
# A new recipient has arrived. Day:  67.40671103461402
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 6
# 68.82093639509498 new_recipient None
# A new recipient has arrived. Day:  68.82093639509498
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 6
# 70.13191745956513 new_recipient None
# A new recipient has arrived. Day:  70.13191745956513
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 6
# 72.31473591861983 new_donor None
# A donation was done with expected life 3264.326515010665 and probabity 0.843982802870706. Day:  72.31473591861983
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 6
# 75.42358502432067 new_recipient None
# A new recipient has arrived. Day:  75.42358502432067
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 6
# 76.84585432603247 new_recipient None
# A new recipient has arrived. Day:  76.84585432603247
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 6
# 77.36695475122151 new_donor None
# A donation was done with expected life 3213.548550975173 and probabity 0.8336346881700584. Day:  77.36695475122151
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 6
# 77.54294527728896 new_recipient None
# A new recipient has arrived. Day:  77.54294527728896
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 6
# 78.04237021207337 new_recipient None
# A new recipient has arrived. Day:  78.04237021207337
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 6
# 81.55356769948855 new_recipient None
# A new recipient has arrived. Day:  81.55356769948855
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 6
# 83.37611126504163 new_recipient None
# A new recipient has arrived. Day:  83.37611126504163
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 6
# 86.97396144684137 new_donor None
# A donation was done with expected life 2488.953246524073 and probabity 0.66812418670207. Day:  86.97396144684137
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 6
# 89.57303225301267 new_donor None
# A donation was done with expected life 2836.9729629787853 and probabity 0.7520981633925721. Day:  89.57303225301267
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 6
# 89.91315763353197 new_recipient None
# A new recipient has arrived. Day:  89.91315763353197
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 6
# 93.25063574819062 new_recipient None
# A new recipient has arrived. Day:  93.25063574819062
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 6
# 95.89535227516474 new_recipient None
# A new recipient has arrived. Day:  95.89535227516474
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 6
# 96.83204632618785 new_recipient None
# A new recipient has arrived. Day:  96.83204632618785
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 6
# 98.45943952093332 new_donor None
# A donation was done with expected life 2572.105402000352 and probabity 0.6890288226181182. Day:  98.45943952093332
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 6
# 103.8540636449764 new_recipient None
# A new recipient has arrived. Day:  103.8540636449764
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 6
# 104.28335681420228 new_recipient None
# A new recipient has arrived. Day:  104.28335681420228
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 6
# 105.12426721279434 new_recipient None
# A new recipient has arrived. Day:  105.12426721279434
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 6
# 105.71075843344758 new_recipient None
# A new recipient has arrived. Day:  105.71075843344758
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 6
# 108.62182073795394 new_recipient None
# A new recipient has arrived. Day:  108.62182073795394
# Number of matches: 0, recipients in wait list: 312,average time in waitlist INF, patients which leave the list 6
# 111.2626022807056 new_recipient None
# A new recipient has arrived. Day:  111.2626022807056
# Number of matches: 0, recipients in wait list: 313,average time in waitlist INF, patients which leave the list 6
# 114.14101929933085 new_recipient None
# A new recipient has arrived. Day:  114.14101929933085
# Number of matches: 0, recipients in wait list: 314,average time in waitlist INF, patients which leave the list 6
# 114.81792732317126 leave_list 945
# Number of matches: 0, recipients in wait list: 313,average time in waitlist INF, patients which leave the list 7
# 120.2658332076473 new_donor None
# A donation was done with expected life 2636.105848715463 and probabity 0.704746562087736. Day:  120.2658332076473
# Number of matches: 0, recipients in wait list: 312,average time in waitlist INF, patients which leave the list 7
# 121.06584218413461 new_donor None
# A donation was done with expected life 2279.477840862717 and probabity 0.6128876589774548. Day:  121.06584218413461
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 7
# 121.28988989269456 new_recipient None
# A new recipient has arrived. Day:  121.28988989269456
# Number of matches: 0, recipients in wait list: 312,average time in waitlist INF, patients which leave the list 7
# 121.8753949404609 new_recipient None
# A new recipient has arrived. Day:  121.8753949404609
# Number of matches: 0, recipients in wait list: 313,average time in waitlist INF, patients which leave the list 7
# 124.63211826889993 new_recipient None
# A new recipient has arrived. Day:  124.63211826889993
# Number of matches: 0, recipients in wait list: 314,average time in waitlist INF, patients which leave the list 7
# 125.3320722651828 leave_list 15882
# Number of matches: 0, recipients in wait list: 313,average time in waitlist INF, patients which leave the list 8
# 126.83869960229907 new_recipient None
# A new recipient has arrived. Day:  126.83869960229907
# Number of matches: 0, recipients in wait list: 314,average time in waitlist INF, patients which leave the list 8
# 126.93820926118376 new_donor None
# A donation was done with expected life 2843.8957780391347 and probabity 0.7536791175197575. Day:  126.93820926118376
# Number of matches: 0, recipients in wait list: 313,average time in waitlist INF, patients which leave the list 8
# 128.84940585487456 new_recipient None
# A new recipient has arrived. Day:  128.84940585487456
# Number of matches: 0, recipients in wait list: 314,average time in waitlist INF, patients which leave the list 8
# 129.86025422702784 new_recipient None
# A new recipient has arrived. Day:  129.86025422702784
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 8
# 130.37346768587201 new_recipient None
# A new recipient has arrived. Day:  130.37346768587201
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 8
# 131.24319989576472 new_donor None
# A donation was done with expected life 2614.9489710669322 and probabity 0.6995857258673656. Day:  131.24319989576472
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 8
# 132.26783477333106 leave_list 15399
# Number of matches: 0, recipients in wait list: 314,average time in waitlist INF, patients which leave the list 9
# 133.93317508576237 new_recipient None
# A new recipient has arrived. Day:  133.93317508576237
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 9
# 136.26530423636916 new_recipient None
# A new recipient has arrived. Day:  136.26530423636916
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 9
# 137.97907564669484 new_recipient None
# A new recipient has arrived. Day:  137.97907564669484
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 9
# 143.2146321101817 new_recipient None
# A new recipient has arrived. Day:  143.2146321101817
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 9
# 143.53576343214743 leave_list 3318
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 10
# 144.52131577369354 new_recipient None
# A new recipient has arrived. Day:  144.52131577369354
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 10
# 148.69081602951962 new_recipient None
# A new recipient has arrived. Day:  148.69081602951962
# Number of matches: 0, recipients in wait list: 319,average time in waitlist INF, patients which leave the list 10
# 148.71276641842303 new_recipient None
# A new recipient has arrived. Day:  148.71276641842303
# Number of matches: 0, recipients in wait list: 320,average time in waitlist INF, patients which leave the list 10
# 150.52371226527652 new_recipient None
# A new recipient has arrived. Day:  150.52371226527652
# Number of matches: 0, recipients in wait list: 321,average time in waitlist INF, patients which leave the list 10
# 153.1919407402808 new_donor None
# A donation was done with expected life 2781.102427702306 and probabity 0.7392178720209795. Day:  153.1919407402808
# Number of matches: 0, recipients in wait list: 320,average time in waitlist INF, patients which leave the list 10
# 155.47190870474304 new_donor None
# A donation was done with expected life 2845.6624274583246 and probabity 0.7540820405560968. Day:  155.47190870474304
# Number of matches: 0, recipients in wait list: 319,average time in waitlist INF, patients which leave the list 10
# 155.9818988608993 new_recipient None
# A new recipient has arrived. Day:  155.9818988608993
# Number of matches: 0, recipients in wait list: 320,average time in waitlist INF, patients which leave the list 10
# 161.997013053568 new_recipient None
# A new recipient has arrived. Day:  161.997013053568
# Number of matches: 0, recipients in wait list: 321,average time in waitlist INF, patients which leave the list 10
# 162.86933847213345 new_recipient None
# A new recipient has arrived. Day:  162.86933847213345
# Number of matches: 0, recipients in wait list: 322,average time in waitlist INF, patients which leave the list 10
# 163.36822902120932 new_recipient None
# A new recipient has arrived. Day:  163.36822902120932
# Number of matches: 0, recipients in wait list: 323,average time in waitlist INF, patients which leave the list 10
# 165.31128557333335 new_donor None
# A donation was done with expected life 2332.7310850556587 and probabity 0.6272933541651441. Day:  165.31128557333335
# Number of matches: 0, recipients in wait list: 322,average time in waitlist INF, patients which leave the list 10
# 166.1545967988765 new_donor None
# A donation was done with expected life 2750.819803221751 and probabity 0.7321449376071042. Day:  166.1545967988765
# Number of matches: 0, recipients in wait list: 321,average time in waitlist INF, patients which leave the list 10
# 171.05728716746057 leave_list 7502
# Number of matches: 0, recipients in wait list: 320,average time in waitlist INF, patients which leave the list 11
# 172.0412123305929 leave_list 12244
# Number of matches: 0, recipients in wait list: 319,average time in waitlist INF, patients which leave the list 12
# 177.04826833250928 new_donor None
# A donation was done with expected life 2281.2778045006603 and probabity 0.6133787533932263. Day:  177.04826833250928
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 12
# 180.08679678541958 new_recipient None
# A new recipient has arrived. Day:  180.08679678541958
# Number of matches: 0, recipients in wait list: 319,average time in waitlist INF, patients which leave the list 12
# 180.2392897681887 leave_list 5163
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 13
# 180.48012369633176 leave_list 16500
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 14
# 182.32466731060973 leave_list 1753
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 15
# 192.5593787178135 new_donor None
# A donation was done with expected life 2427.0749380655593 and probabity 0.6522003161961066. Day:  192.5593787178135
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 15
# 194.6816885760247 new_recipient None
# A new recipient has arrived. Day:  194.6816885760247
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 15
# 197.2763621462762 new_recipient None
# A new recipient has arrived. Day:  197.2763621462762
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 15
# 197.39867527077539 leave_list 4153
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 16
# 199.01779713306826 new_donor None
# A donation was done with expected life 2309.8313585750093 and probabity 0.6211299187981937. Day:  199.01779713306826
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 16
# 207.87792725330587 new_recipient None
# A new recipient has arrived. Day:  207.87792725330587
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 16
# 210.89858624710854 new_donor None
# A donation was done with expected life 1884.7876918357726 and probabity 0.4976735408669015. Day:  210.89858624710854
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 16
# 213.58768465585325 new_recipient None
# A new recipient has arrived. Day:  213.58768465585325
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 16
# 220.47833820716733 new_recipient None
# A new recipient has arrived. Day:  220.47833820716733
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 16
# 227.4480302669545 new_donor None
# A donation was done with expected life 1959.2173743830858 and probabity 0.520593277717265. Day:  227.4480302669545
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 16
# 230.3915197715556 new_recipient None
# A new recipient has arrived. Day:  230.3915197715556
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 16
# 230.83662167168595 new_recipient None
# A new recipient has arrived. Day:  230.83662167168595
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 16
# 232.3365439294315 new_donor None
# A donation was done with expected life 3031.4788462559236 and probabity 0.7953107837473301. Day:  232.3365439294315
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 16
# 236.2277919839137 new_donor None
# A donation was done with expected life 2432.908803296707 and probabity 0.6537153211612279. Day:  236.2277919839137
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 16
# 239.62220234847177 new_recipient None
# A new recipient has arrived. Day:  239.62220234847177
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 16
# 241.91078445795256 new_donor None
# A donation was done with expected life 1930.5503136342306 and probabity 0.5118335951498356. Day:  241.91078445795256
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 16
# 246.63360562729636 leave_list 21848
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 17
# 251.65726673275134 new_recipient None
# A new recipient has arrived. Day:  251.65726673275134
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 17
# 255.05007312838242 new_donor None
# A donation was done with expected life 2238.384320697082 and probabity 0.6015951429766564. Day:  255.05007312838242
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 17
# 255.24738505265375 new_recipient None
# A new recipient has arrived. Day:  255.24738505265375
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 17
# 257.0812624481078 new_recipient None
# A new recipient has arrived. Day:  257.0812624481078
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 17
# 257.46476833168003 new_recipient None
# A new recipient has arrived. Day:  257.46476833168003
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 17
# 260.2953015050332 new_recipient None
# A new recipient has arrived. Day:  260.2953015050332
# Number of matches: 0, recipients in wait list: 319,average time in waitlist INF, patients which leave the list 17
# 263.09342687795163 new_donor None
# A donation was done with expected life 2490.2702135243944 and probabity 0.6684596414075388. Day:  263.09342687795163
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 17
# 263.4331107256474 new_donor None
# A donation was done with expected life 2210.5375977788176 and probabity 0.5938539789159932. Day:  263.4331107256474
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 17
# 263.8875131576017 new_recipient None
# A new recipient has arrived. Day:  263.8875131576017
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 17
# 268.7383294600482 new_donor None
# A donation was done with expected life 2353.160117278475 and probabity 0.6327524840809344. Day:  268.7383294600482
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 17
# 269.85338803887635 leave_list 15882
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 18
# 275.60767062678093 leave_list 21553
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 19
# 282.94816865010085 new_donor None
# A donation was done with expected life 1664.227463002066 and probabity 0.4263435351676286. Day:  282.94816865010085
# Number of matches: 0, recipients in wait list: 314,average time in waitlist INF, patients which leave the list 19
# 283.269316407284 new_recipient None
# A new recipient has arrived. Day:  283.269316407284
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 19
# 285.41771280493936 new_recipient None
# A new recipient has arrived. Day:  285.41771280493936
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 19
# 285.9814227971362 new_recipient None
# A new recipient has arrived. Day:  285.9814227971362
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 19
# 287.0644672797793 new_recipient None
# A new recipient has arrived. Day:  287.0644672797793
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 19
# 287.18922023617966 new_recipient None
# A new recipient has arrived. Day:  287.18922023617966
# Number of matches: 0, recipients in wait list: 319,average time in waitlist INF, patients which leave the list 19
# 288.2067883813324 new_donor None
# A donation was done with expected life 2118.613001458851 and probabity 0.5677779476452007. Day:  288.2067883813324
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 19
# 289.7257197532725 leave_list 1373
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 20
# 293.2217509103804 new_recipient None
# A new recipient has arrived. Day:  293.2217509103804
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 20
# 294.8123256540792 new_donor None
# A donation was done with expected life 1500.8992435328732 and probabity 0.37028053930875937. Day:  294.8123256540792
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 20
# 295.0197683754592 new_recipient None
# A new recipient has arrived. Day:  295.0197683754592
# Number of matches: 0, recipients in wait list: 318,average time in waitlist INF, patients which leave the list 20
# 295.8855315550492 leave_list 20014
# Number of matches: 0, recipients in wait list: 317,average time in waitlist INF, patients which leave the list 21
# 303.0103278186697 leave_list 8901
# Number of matches: 0, recipients in wait list: 316,average time in waitlist INF, patients which leave the list 22
# 305.4442658182751 leave_list 1373
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 23
# 312.69215083979833 new_donor None
# A donation was done with expected life 2195.184890509555 and probabity 0.5895549625331716. Day:  312.69215083979833
# Number of matches: 0, recipients in wait list: 314,average time in waitlist INF, patients which leave the list 23
# 314.2033902583775 new_recipient None
# A new recipient has arrived. Day:  314.2033902583775
# Number of matches: 0, recipients in wait list: 315,average time in waitlist INF, patients which leave the list 23
# 315.28085977617593 new_donor None
# A donation was done with expected life 1521.5084469122082 and probabity 0.3774994911715532. Day:  315.28085977617593
# Number of matches: 0, recipients in wait list: 314,average time in waitlist INF, patients which leave the list 23
# 318.58537562872226 leave_list 19162
# Number of matches: 0, recipients in wait list: 313,average time in waitlist INF, patients which leave the list 24
# 319.2108548645687 leave_list 16121
# Number of matches: 0, recipients in wait list: 312,average time in waitlist INF, patients which leave the list 25
# 322.7470929186437 leave_list 4970
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 26
# 327.9732231218731 new_donor None
# A donation was done with expected life 2290.9953845621503 and probabity 0.616024971264636. Day:  327.9732231218731
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 26
# 333.61887752145014 leave_list 20581
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 27
# 339.29487588766176 new_donor None
# A donation was done with expected life 2583.9086305306855 and probabity 0.6919514976500938. Day:  339.29487588766176
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 27
# 345.08796692479456 new_recipient None
# A new recipient has arrived. Day:  345.08796692479456
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 27
# 345.9072378634667 new_recipient None
# A new recipient has arrived. Day:  345.9072378634667
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 27
# 346.53440378305817 new_donor None
# A donation was done with expected life 2277.02723431842 and probabity 0.6122185716207434. Day:  346.53440378305817
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 27
# 346.8322856298106 new_recipient None
# A new recipient has arrived. Day:  346.8322856298106
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 27
# 349.42928261278485 new_recipient None
# A new recipient has arrived. Day:  349.42928261278485
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 27
# 350.8563059035955 new_donor None
# A donation was done with expected life 2175.8423738696306 and probabity 0.584106991298147. Day:  350.8563059035955
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 27
# 354.7950906520073 new_recipient None
# A new recipient has arrived. Day:  354.7950906520073
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 27
# 355.49775764772176 new_donor None
# A donation was done with expected life 2501.8744693870563 and probabity 0.6714093022459949. Day:  355.49775764772176
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 27
# 356.7226246461152 leave_list 2817
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 28
# 357.3231360454284 leave_list 21003
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 29
# 357.6716653587268 leave_list 880
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 30
# 359.0318149293733 new_recipient None
# A new recipient has arrived. Day:  359.0318149293733
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 30
# 367.7875910799738 new_recipient None
# A new recipient has arrived. Day:  367.7875910799738
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 30
# 368.7224208095837 new_recipient None
# A new recipient has arrived. Day:  368.7224208095837
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 30
# 370.1460382367454 new_recipient None
# A new recipient has arrived. Day:  370.1460382367454
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 30
# 370.1613931524677 new_recipient None
# A new recipient has arrived. Day:  370.1613931524677
# Number of matches: 0, recipients in wait list: 312,average time in waitlist INF, patients which leave the list 30
# 370.2046890294692 new_recipient None
# A new recipient has arrived. Day:  370.2046890294692
# Number of matches: 0, recipients in wait list: 313,average time in waitlist INF, patients which leave the list 30
# 370.8504014415669 leave_list 13771
# Number of matches: 0, recipients in wait list: 312,average time in waitlist INF, patients which leave the list 31
# 373.6744872641931 new_recipient None
# A new recipient has arrived. Day:  373.6744872641931
# Number of matches: 0, recipients in wait list: 313,average time in waitlist INF, patients which leave the list 31
# 374.5769478310371 leave_list 22119
# Number of matches: 0, recipients in wait list: 312,average time in waitlist INF, patients which leave the list 32
# 377.5156519144649 leave_list 5163
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 33
# 377.75704152235477 leave_list 12435
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 34
# 382.2072869061842 new_donor None
# A donation was done with expected life 1593.8272064689215 and probabity 0.4025057576306682. Day:  382.2072869061842
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 34
# 384.2585254280146 leave_list 18962
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 35
# 391.26899279216946 new_recipient None
# A new recipient has arrived. Day:  391.26899279216946
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 35
# 395.63822706230627 new_donor None
# A donation was done with expected life 2401.1253398740423 and probabity 0.6454263375184136. Day:  395.63822706230627
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 35
# 396.70628585482825 new_donor None
# A donation was done with expected life 2902.3716170198836 and probabity 0.7669038389518076. Day:  396.70628585482825
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 35
# 397.03871457485747 new_donor None
# A donation was done with expected life 2115.8751352897343 and probabity 0.5669888119004892. Day:  397.03871457485747
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 35
# 398.2883068748698 new_donor None
# A donation was done with expected life 2543.2739525858074 and probabity 0.6818434079214376. Day:  398.2883068748698
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 35
# 398.53161459109896 new_donor None
# A donation was done with expected life 2479.1558923114985 and probabity 0.6656241460844219. Day:  398.53161459109896
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 35
# 399.8152768483104 new_recipient None
# A new recipient has arrived. Day:  399.8152768483104
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 35
# 402.49736179223066 new_recipient None
# A new recipient has arrived. Day:  402.49736179223066
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 35
# 403.3767519260337 new_donor None
# A donation was done with expected life 2145.2849379685504 and probabity 0.5754274654522481. Day:  403.3767519260337
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 35
# 404.0618927353094 new_donor None
# A donation was done with expected life 2063.8432412862676 and probabity 0.5518516361197918. Day:  404.0618927353094
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 35
# 405.60223542677136 leave_list 5691
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 36
# 409.24569486915954 leave_list 7395
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 37
# 411.9958469365262 leave_list 13378
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 38
# 415.6735526203405 new_recipient None
# A new recipient has arrived. Day:  415.6735526203405
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 38
# 416.7536478539591 new_recipient None
# A new recipient has arrived. Day:  416.7536478539591
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 38
# 416.87269790798973 new_recipient None
# A new recipient has arrived. Day:  416.87269790798973
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 38
# 418.3180119307829 new_donor None
# A donation was done with expected life 3174.52547288835 and probabity 0.8255837902598111. Day:  418.3180119307829
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 38
# 421.87678279730017 new_recipient None
# A new recipient has arrived. Day:  421.87678279730017
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 38
# 424.72439154695434 new_recipient None
# A new recipient has arrived. Day:  424.72439154695434
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 38
# 429.0678167124243 leave_list 2948
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 39
# 430.8104041658343 leave_list 19320
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 40
# 435.8172003875827 new_recipient None
# A new recipient has arrived. Day:  435.8172003875827
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 40
# 436.87066855141063 new_recipient None
# A new recipient has arrived. Day:  436.87066855141063
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 40
# 438.36092279256144 new_recipient None
# A new recipient has arrived. Day:  438.36092279256144
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 40
# 438.5201728100216 leave_list 22119
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 41
# 439.68319561787524 leave_list 2709
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 42
# 441.3969033902644 leave_list 9478
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 43
# 445.89535559177585 new_donor None
# A donation was done with expected life 2365.9249444515917 and probabity 0.636144899412436. Day:  445.89535559177585
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 43
# 446.1369187662746 leave_list 1827
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 44
# 446.72045740412517 new_donor None
# A donation was done with expected life 1415.2067475212334 and probabity 0.3398502218684523. Day:  446.72045740412517
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 44
# 450.28153780991806 leave_list 4833
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 45
# 456.3518992955912 new_donor None
# A donation was done with expected life 2156.1286710535655 and probabity 0.5785177756929324. Day:  456.3518992955912
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 45
# 456.6333562514368 new_donor None
# A donation was done with expected life 1790.0846717534826 and probabity 0.46767366743896. Day:  456.6333562514368
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 45
# 458.723721396935 new_recipient None
# A new recipient has arrived. Day:  458.723721396935
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 45
# 459.6931915099974 new_recipient None
# A new recipient has arrived. Day:  459.6931915099974
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 45
# 460.1365738455405 new_recipient None
# A new recipient has arrived. Day:  460.1365738455405
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 45
# 460.8580400625731 new_recipient None
# A new recipient has arrived. Day:  460.8580400625731
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 45
# 461.12578950067194 new_donor None
# A donation was done with expected life 2490.0439257263274 and probabity 0.6684020120567873. Day:  461.12578950067194
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 45
# 461.2039082135555 new_donor None
# A donation was done with expected life 2158.204545210388 and probabity 0.5791080801849658. Day:  461.2039082135555
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 45
# 464.45474539916296 new_recipient None
# A new recipient has arrived. Day:  464.45474539916296
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 45
# 466.07450958626816 new_donor None
# A donation was done with expected life 2045.5255407534535 and probabity 0.546458749472501. Day:  466.07450958626816
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 45
# 467.25529834675825 new_recipient None
# A new recipient has arrived. Day:  467.25529834675825
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 45
# 467.66963243825734 new_donor None
# A donation was done with expected life 2093.4622665619822 and probabity 0.5605011535121399. Day:  467.66963243825734
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 45
# 469.3349476772736 new_recipient None
# A new recipient has arrived. Day:  469.3349476772736
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 45
# 471.89390849227317 new_recipient None
# A new recipient has arrived. Day:  471.89390849227317
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 45
# 472.44079278174684 new_recipient None
# A new recipient has arrived. Day:  472.44079278174684
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 45
# 476.9910456367297 new_recipient None
# A new recipient has arrived. Day:  476.9910456367297
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 45
# 478.1990802325969 new_recipient None
# A new recipient has arrived. Day:  478.1990802325969
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 45
# 479.9786260634404 new_recipient None
# A new recipient has arrived. Day:  479.9786260634404
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 45
# 482.6977398796241 new_donor None
# A donation was done with expected life 1611.9584552076044 and probabity 0.4086935034348773. Day:  482.6977398796241
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 45
# 484.5834527931472 new_recipient None
# A new recipient has arrived. Day:  484.5834527931472
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 45
# 486.58287887314304 leave_list 2817
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 46
# 493.27544061150786 new_donor None
# A donation was done with expected life 1527.0295626620841 and probabity 0.3794265663078752. Day:  493.27544061150786
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 46
# 495.67124559014616 new_donor None
# A donation was done with expected life 1970.9660226565622 and probabity 0.5241588209006219. Day:  495.67124559014616
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 46
# 497.7136690482724 leave_list 21702
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 47
# 500.10605841913156 new_donor None
# A donation was done with expected life 2410.0050329131814 and probabity 0.6477507985772432. Day:  500.10605841913156
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 47
# 502.22055902982027 new_recipient None
# A new recipient has arrived. Day:  502.22055902982027
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 47
# 502.5820900176202 new_donor None
# A donation was done with expected life 2068.595682151355 and probabity 0.553245329263858. Day:  502.5820900176202
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 47
# 506.5600625219005 new_donor None
# A donation was done with expected life 1787.3555826773095 and probabity 0.4667951514120461. Day:  506.5600625219005
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 47
# 509.89328342237155 new_donor None
# A donation was done with expected life 2040.8471315443549 and probabity 0.5450760054991813. Day:  509.89328342237155
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 47
# 510.626466735893 new_donor None
# A donation was done with expected life 1902.3217462627952 and probabity 0.5031247586825073. Day:  510.626466735893
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 47
# 510.62964706362584 leave_list 8090
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 48
# 513.8455604538334 new_donor None
# ...
# 10789.56369312702 leave_list 2121
# ----------------------- One patient left the waitlist. Day:  10789.56369312702 2121
# Number of matches: 1089, recipients in wait list: 255,average time in waitlist 1345.356451006812, patients which leave the list 778
# 10797.550773074126 new_donor None
# A donation was done with expected life 2145.098985998966 and probabity 0.5753743729328318. Day:  10797.550773074126
# Number of matches: 1090, recipients in wait list: 254,average time in waitlist 1345.180384992599, patients which leave the list 778
# 10798.546717468907 new_donor None
# A donation was done with expected life 2167.2327991181924 and probabity 0.5816705848320471. Day:  10798.546717468907
# Number of matches: 1091, recipients in wait list: 253,average time in waitlist 1344.3334197235765, patients which leave the list 778
# 10805.670667688493 leave_list 17380
# ----------------------- One patient left the waitlist. Day:  10805.670667688493 17380
# Number of matches: 1091, recipients in wait list: 252,average time in waitlist 1344.3334197235765, patients which leave the list 779
# 10809.998788311788 leave_list 4064
# ----------------------- One patient left the waitlist. Day:  10809.998788311788 4064
# Number of matches: 1091, recipients in wait list: 251,average time in waitlist 1344.3334197235765, patients which leave the list 780
# 10817.295199161952 new_donor None
# A donation was done with expected life 799.8937570243204 and probabity 0.11600833454039301. Day:  10817.295199161952
# Number of matches: 1092, recipients in wait list: 250,average time in waitlist 1344.5969130290748, patients which leave the list 780
# 10818.691027803527 new_recipient None
# A new recipient has arrived. Day:  10818.691027803527
# Number of matches: 1092, recipients in wait list: 251,average time in waitlist 1344.5969130290748, patients which leave the list 780
# 10820.009794332238 new_donor None
# A donation was done with expected life 2496.75203385271 and probabity 0.6701086008941592. Day:  10820.009794332238
# Number of matches: 1093, recipients in wait list: 250,average time in waitlist 1344.3118168136164, patients which leave the list 780
# 10822.704672632242 new_recipient None
# A new recipient has arrived. Day:  10822.704672632242
# Number of matches: 1093, recipients in wait list: 251,average time in waitlist 1344.3118168136164, patients which leave the list 780
# 10831.365968214326 new_recipient None
# A new recipient has arrived. Day:  10831.365968214326
# Number of matches: 1093, recipients in wait list: 252,average time in waitlist 1344.3118168136164, patients which leave the list 780
# 10831.736473551699 new_recipient None
# A new recipient has arrived. Day:  10831.736473551699
# Number of matches: 1093, recipients in wait list: 253,average time in waitlist 1344.3118168136164, patients which leave the list 780
# 10833.904973774583 new_recipient None
# A new recipient has arrived. Day:  10833.904973774583
# Number of matches: 1093, recipients in wait list: 254,average time in waitlist 1344.3118168136164, patients which leave the list 780
# 10834.495124002879 new_donor None
# A donation was done with expected life 1983.551640053914 and probabity 0.5279626776782789. Day:  10834.495124002879
# Number of matches: 1094, recipients in wait list: 253,average time in waitlist 1344.0777698420748, patients which leave the list 780
# 10834.931673281015 new_donor None
# A donation was done with expected life 1464.9659798270527 and probabity 0.3575995537201948. Day:  10834.931673281015
# Number of matches: 1095, recipients in wait list: 252,average time in waitlist 1346.872266188562, patients which leave the list 780
# 10835.61173620278 new_recipient None
# A new recipient has arrived. Day:  10835.61173620278
# Number of matches: 1095, recipients in wait list: 253,average time in waitlist 1346.872266188562, patients which leave the list 780
# 10836.465251528425 leave_list 9198
# ----------------------- One patient left the waitlist. Day:  10836.465251528425 9198
# Number of matches: 1095, recipients in wait list: 252,average time in waitlist 1346.872266188562, patients which leave the list 781
# 10839.00235600586 new_recipient None
# A new recipient has arrived. Day:  10839.00235600586
# Number of matches: 1095, recipients in wait list: 253,average time in waitlist 1346.872266188562, patients which leave the list 781
# 10840.954687555799 leave_list 17992
# ----------------------- One patient left the waitlist. Day:  10840.954687555799 17992
# Number of matches: 1095, recipients in wait list: 252,average time in waitlist 1346.872266188562, patients which leave the list 782
# 10845.492028803794 new_donor None
# A donation was done with expected life 1782.932916728915 and probabity 0.4653697907187292. Day:  10845.492028803794
# Number of matches: 1096, recipients in wait list: 251,average time in waitlist 1346.8313585151482, patients which leave the list 782
# 10845.617712582052 leave_list 13224
# ----------------------- One patient left the waitlist. Day:  10845.617712582052 13224
# Number of matches: 1096, recipients in wait list: 250,average time in waitlist 1346.8313585151482, patients which leave the list 783
# 10846.908374953144 new_recipient None
# A new recipient has arrived. Day:  10846.908374953144
# Number of matches: 1096, recipients in wait list: 251,average time in waitlist 1346.8313585151482, patients which leave the list 783
# 10852.095257364159 leave_list 3014
# ----------------------- One patient left the waitlist. Day:  10852.095257364159 3014
# Number of matches: 1096, recipients in wait list: 250,average time in waitlist 1346.8313585151482, patients which leave the list 784
# 10859.291502335973 new_donor None
# A donation was done with expected life 1729.3710235045965 and probabity 0.44794380571831927. Day:  10859.291502335973
# Number of matches: 1097, recipients in wait list: 249,average time in waitlist 1346.9158368340368, patients which leave the list 784
# 10859.483579437167 new_recipient None
# A new recipient has arrived. Day:  10859.483579437167
# Number of matches: 1097, recipients in wait list: 250,average time in waitlist 1346.9158368340368, patients which leave the list 784
# 10860.601279471113 new_donor None
# A donation was done with expected life 2022.23597186687 and probabity 0.5395535387334967. Day:  10860.601279471113
# Number of matches: 1098, recipients in wait list: 249,average time in waitlist 1346.7392028660686, patients which leave the list 784
# 10861.798852795933 new_recipient None
# A new recipient has arrived. Day:  10861.798852795933
# Number of matches: 1098, recipients in wait list: 250,average time in waitlist 1346.7392028660686, patients which leave the list 784
# 10866.08648434326 leave_list 21418
# ----------------------- One patient left the waitlist. Day:  10866.08648434326 21418
# Number of matches: 1098, recipients in wait list: 249,average time in waitlist 1346.7392028660686, patients which leave the list 785
# 10870.553186458656 new_recipient None
# A new recipient has arrived. Day:  10870.553186458656
# Number of matches: 1098, recipients in wait list: 250,average time in waitlist 1346.7392028660686, patients which leave the list 785
# 10874.384446658949 new_donor None
# A donation was done with expected life 2214.5423370780063 and probabity 0.5949717270054328. Day:  10874.384446658949
# Number of matches: 1099, recipients in wait list: 249,average time in waitlist 1346.335673610449, patients which leave the list 785
# 10874.477782497112 new_recipient None
# A new recipient has arrived. Day:  10874.477782497112
# Number of matches: 1099, recipients in wait list: 250,average time in waitlist 1346.335673610449, patients which leave the list 785
# 10875.534990470498 new_recipient None
# A new recipient has arrived. Day:  10875.534990470498
# Number of matches: 1099, recipients in wait list: 251,average time in waitlist 1346.335673610449, patients which leave the list 785
# 10876.629356892958 new_recipient None
# A new recipient has arrived. Day:  10876.629356892958
# Number of matches: 1099, recipients in wait list: 252,average time in waitlist 1346.335673610449, patients which leave the list 785
# 10880.117821983902 new_donor None
# A donation was done with expected life 1527.269572281192 and probabity 0.3795102723875012. Day:  10880.117821983902
# Number of matches: 1100, recipients in wait list: 251,average time in waitlist 1346.5308319610226, patients which leave the list 785
# 10883.577817939098 new_donor None
# A donation was done with expected life 2092.188619766982 and probabity 0.56013100039191. Day:  10883.577817939098
# Number of matches: 1101, recipients in wait list: 250,average time in waitlist 1348.6116470368788, patients which leave the list 785
# 10886.867737501314 new_donor None
# A donation was done with expected life 1696.4840887183723 and probabity 0.43709467323057055. Day:  10886.867737501314
# Number of matches: 1102, recipients in wait list: 249,average time in waitlist 1348.5228192181626, patients which leave the list 785
# 10890.208686661645 new_donor None
# A donation was done with expected life 2001.630868714141 and probabity 0.5333986171425406. Day:  10890.208686661645
# Number of matches: 1103, recipients in wait list: 248,average time in waitlist 1348.1576025702468, patients which leave the list 785
# 10892.443176740357 new_donor None
# A donation was done with expected life 2078.1103305728493 and probabity 0.5560288382314438. Day:  10892.443176740357
# Number of matches: 1104, recipients in wait list: 247,average time in waitlist 1347.8508209274378, patients which leave the list 785
# 10892.901627960211 new_recipient None
# A new recipient has arrived. Day:  10892.901627960211
# Number of matches: 1104, recipients in wait list: 248,average time in waitlist 1347.8508209274378, patients which leave the list 785
# 10894.638378195381 new_recipient None
# A new recipient has arrived. Day:  10894.638378195381
# Number of matches: 1104, recipients in wait list: 249,average time in waitlist 1347.8508209274378, patients which leave the list 785
# 10894.717349777762 new_recipient None
# A new recipient has arrived. Day:  10894.717349777762
# Number of matches: 1104, recipients in wait list: 250,average time in waitlist 1347.8508209274378, patients which leave the list 785
# 10899.702346800726 new_recipient None
# A new recipient has arrived. Day:  10899.702346800726
# Number of matches: 1104, recipients in wait list: 251,average time in waitlist 1347.8508209274378, patients which leave the list 785
# 10902.29155585502 leave_list 19743
# ----------------------- One patient left the waitlist. Day:  10902.29155585502 19743
# Number of matches: 1104, recipients in wait list: 250,average time in waitlist 1347.8508209274378, patients which leave the list 786
# 10906.452229514205 leave_list 13274
# ----------------------- One patient left the waitlist. Day:  10906.452229514205 13274
# Number of matches: 1104, recipients in wait list: 249,average time in waitlist 1347.8508209274378, patients which leave the list 787
# 10906.708760786316 leave_list 12083
# ----------------------- One patient left the waitlist. Day:  10906.708760786316 12083
# Number of matches: 1104, recipients in wait list: 248,average time in waitlist 1347.8508209274378, patients which leave the list 788
# 10911.725044003586 new_recipient None
# A new recipient has arrived. Day:  10911.725044003586
# Number of matches: 1104, recipients in wait list: 249,average time in waitlist 1347.8508209274378, patients which leave the list 788
# 10913.627038522305 new_recipient None
# A new recipient has arrived. Day:  10913.627038522305
# Number of matches: 1104, recipients in wait list: 250,average time in waitlist 1347.8508209274378, patients which leave the list 788
# 10917.326223810502 new_recipient None
# A new recipient has arrived. Day:  10917.326223810502
# Number of matches: 1104, recipients in wait list: 251,average time in waitlist 1347.8508209274378, patients which leave the list 788
# 10918.094831476703 new_donor None
# A donation was done with expected life 2120.9164037505225 and probabity 0.5684412913720588. Day:  10918.094831476703
# Number of matches: 1105, recipients in wait list: 250,average time in waitlist 1347.3360429361553, patients which leave the list 788
# 10918.670735060361 leave_list 17713
# ----------------------- One patient left the waitlist. Day:  10918.670735060361 17713
# Number of matches: 1105, recipients in wait list: 249,average time in waitlist 1347.3360429361553, patients which leave the list 789
# 10922.14285698099 new_recipient None
# A new recipient has arrived. Day:  10922.14285698099
# Number of matches: 1105, recipients in wait list: 250,average time in waitlist 1347.3360429361553, patients which leave the list 789
# 10923.061779037118 new_recipient None
# A new recipient has arrived. Day:  10923.061779037118
# Number of matches: 1105, recipients in wait list: 251,average time in waitlist 1347.3360429361553, patients which leave the list 789
# 10925.26327115332 new_recipient None
# A new recipient has arrived. Day:  10925.26327115332
# Number of matches: 1105, recipients in wait list: 252,average time in waitlist 1347.3360429361553, patients which leave the list 789
# 10927.043628072513 new_recipient None
# A new recipient has arrived. Day:  10927.043628072513
# Number of matches: 1105, recipients in wait list: 253,average time in waitlist 1347.3360429361553, patients which leave the list 789
# 10927.52000845461 new_recipient None
# A new recipient has arrived. Day:  10927.52000845461
# Number of matches: 1105, recipients in wait list: 254,average time in waitlist 1347.3360429361553, patients which leave the list 789
# 10928.898718007546 new_recipient None
# A new recipient has arrived. Day:  10928.898718007546
# Number of matches: 1105, recipients in wait list: 255,average time in waitlist 1347.3360429361553, patients which leave the list 789
# 10928.93367249002 new_recipient None
# A new recipient has arrived. Day:  10928.93367249002
# Number of matches: 1105, recipients in wait list: 256,average time in waitlist 1347.3360429361553, patients which leave the list 789
# 10933.405171354374 new_recipient None
# A new recipient has arrived. Day:  10933.405171354374
# Number of matches: 1105, recipients in wait list: 257,average time in waitlist 1347.3360429361553, patients which leave the list 789
# 10937.975119799328 new_donor None
# A donation was done with expected life 1824.6039669923373 and probabity 0.47871791299943073. Day:  10937.975119799328
# Number of matches: 1106, recipients in wait list: 256,average time in waitlist 1349.576684723947, patients which leave the list 789
# 10939.163190655958 new_donor None
# A donation was done with expected life 1830.9825734761923 and probabity 0.48074496572117303. Day:  10939.163190655958
# Number of matches: 1107, recipients in wait list: 255,average time in waitlist 1349.6112482508279, patients which leave the list 789
# 10940.930108008255 leave_list 9644
# ----------------------- One patient left the waitlist. Day:  10940.930108008255 9644
# Number of matches: 1107, recipients in wait list: 254,average time in waitlist 1349.6112482508279, patients which leave the list 790
# 10944.899976928566 new_donor None
# A donation was done with expected life 1209.2284301908944 and probabity 0.26448860067962743. Day:  10944.899976928566
# Number of matches: 1108, recipients in wait list: 253,average time in waitlist 1350.0142278005244, patients which leave the list 790
# 10947.430066314997 new_recipient None
# A new recipient has arrived. Day:  10947.430066314997
# Number of matches: 1108, recipients in wait list: 254,average time in waitlist 1350.0142278005244, patients which leave the list 790
# 10948.326142244523 new_recipient None
# A new recipient has arrived. Day:  10948.326142244523
# Number of matches: 1108, recipients in wait list: 255,average time in waitlist 1350.0142278005244, patients which leave the list 790
# 10950.10610060197 new_recipient None
# A new recipient has arrived. Day:  10950.10610060197
# Number of matches: 1108, recipients in wait list: 256,average time in waitlist 1350.0142278005244, patients which leave the list 790
# ([1350.0142278005244], [1108])

# %%
df['ethcat'] = df['ethcat'].replace(ethcat_mapping)

# %%
df_waiting_time = ((df.groupby(by=['replicate', 'ethcat'])
                   .agg(
                       waiting_time=('waiting_time', 'mean'), 
                       count=('waiting_time', 'size'), 
                       mean_survival_time=('mean_survival_time', 'mean'))
                   .reset_index())
)#.to_csv('simulation_results.csv')
df_waiting_time = df_waiting_time[['ethcat', 'waiting_time', 'count', 'mean_survival_time']].groupby('ethcat').agg(['mean', 'std'])
df_waiting_time.columns = [f"{col[0]}_{col[1]}" for col in df_waiting_time.columns] 
df_waiting_time['prop_simu'] = df_waiting_time['count_mean'] / df_waiting_time['count_mean'].sum()
df_waiting_time = df_waiting_time.merge(real_ethcat_df, on='ethcat').round(3)
df_waiting_time.columns = ['ethcat', 'wt_mean', 'wt_std', 'count_mean', 'count_std', 'st_mean', 'st_std', 'prop_simu', 'sample_proportion']
df_waiting_time
# Out:
#                                               ethcat   wt_mean  wt_std  \
# 0               Amer Ind/Alaska Native, Non-Hispanic  1248.182     NaN
# 1                                Asian, Non-Hispanic  1493.835     NaN
# 2                                Black, Non-Hispanic  1310.450     NaN
# 3                                    Hispanic/Latino  1269.479     NaN
# 4                          Multiracial, Non-Hispanic  1279.196     NaN
# 5  Native Hawaiian/Other Pacific Islander, Non-Hi...  1382.875     NaN
# 6                                White, Non-Hispanic  1398.816     NaN
#
#    count_mean  count_std   st_mean  st_std  prop_simu  sample_proportion
# 0        13.0        NaN  2076.870     NaN      0.012              0.014
# 1        47.0        NaN  1800.363     NaN      0.042              0.053
# 2       346.0        NaN  2002.912     NaN      0.312              0.325
# 3       197.0        NaN  1888.859     NaN      0.178              0.160
# 4         4.0        NaN  2044.255     NaN      0.004              0.005
# 5         3.0        NaN  1769.026     NaN      0.003              0.004
# 6       498.0        NaN  1845.896     NaN      0.449              0.439

# %%
df_gender = ((df.groupby(by=['replicate', 'gender'])
                .agg(
                    waiting_time=('waiting_time', 'mean'), 
                    count=('waiting_time', 'size'),
                    mean_survival_time=('mean_survival_time', 'mean'))
                .reset_index())
)#.to_csv('simulation_results.csv')
df_gender = df_gender[['gender', 'waiting_time', 'count', 'mean_survival_time']].groupby('gender').agg(['mean', 'std'])
df_gender.columns = [f"{col[0]}_{col[1]}" for col in df_gender.columns] 
df_gender['proportion_sim'] = df_gender['count_mean'] / df_gender['count_mean'].sum()
df_gender.reset_index(inplace=True)
df_gender = df_gender.merge(real_gender_df, on = 'gender')
df_gender.columns = ['gender', 'wt_mean', 'wt_std', 'count_mean',
       'count_std', 'st_mean', 'st_std',
       'prop_sim', 'sample_proportion']
df_gender.round(3)
# Out:
#   gender   wt_mean  wt_std  count_mean  count_std   st_mean  st_std  prop_sim  \
# 0      F  1332.412     NaN       399.0        NaN  1932.990     NaN      0.36
# 1      M  1359.920     NaN       709.0        NaN  1887.456     NaN      0.64
#
#    sample_proportion
# 0              0.352
# 1              0.648

# %%
#df.to_csv('results_decision_tree.csv')

# %%
import numpy as np 

np.quantile(np.mean(np.random.exponential(scale=(1)*365, size=100)), 0.2)
# Out:
# 344.24967892996773
