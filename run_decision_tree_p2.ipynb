# %%
import pandas as pd 

df_base = pd.read_csv('data/data_to_simulate.csv', index_col=0)
df_base.dropna(inplace=True)
print(df_base.columns)
columns = ['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON', 'AGE', 'DIAB',
                'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI', 'SERUM_CREAT',
                'CREAT_TRR', 'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC','CREAT_TRRg1.5', 'SERUM_CREATg1.2',
                'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
                'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE','TX_DATE', 'PT_CODE', 'ABO', 'ABO_DON']

predictors = ['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'WGT_KG_DON_CALC',
                    'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'COD_CAD_DON', 'ETHCAT_DON', 'ABO_MAT', 
                    'HLAMIS', 'DIALYSIS_DATE', 'AGE', 'DIAB', 'DIALYSIS_DATEle0.0', 'CREAT_TRRg1.5', 'SERUM_CREATg1.2']

donor = df_base[['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 
            'HIST_HYPERTENS_DON', 'ABO_DON', 'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2']]

print(donor.columns)
donor.to_csv('data/donors.csv')

recipient = df_base[[ 'DIALYSIS_DATE', 'AGE', 'DIAB', 'ETHCAT', 'GENDER', 'ABO', 'DIALYSIS_DATEle0.0']]
recipient.to_csv('data/recipients.csv')

ethcat_mapping = {
    1: "White, Non-Hispanic",
    2: "Black, Non-Hispanic",
    4: "Hispanic/Latino",
    5: "Asian, Non-Hispanic",
    6: "Amer Ind/Alaska Native, Non-Hispanic",
    7: "Native Hawaiian/Other Pacific Islander, Non-Hispanic",
    9: "Multiracial, Non-Hispanic",
}
# Out:
# Index(['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON',
#        'AGE', 'DIAB', 'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI',
#        'SERUM_CREAT', 'ABO_MAT', 'AMIS', 'BMIS', 'DRMIS', 'CREAT_TRR',
#        'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC', 'ABO_DON',
#        'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
#        'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE', 'TX_DATE',
#        'PT_CODE', 'COMPOSITE_DEATH_DATE', 'ABO', 'T', 'Tag_date', 'DIAB_1',
#        'DIAB_998', 'HIST_DIABETES_DON_1', 'HIST_DIABETES_DON_998',
#        'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2',
#        'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype='object')
# Index(['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC',
#        'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'ABO_DON',
#        'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2'],
#       dtype='object')

# %%
real_gender_df = df_base.GENDER.value_counts(normalize=True).reset_index()
real_gender_df.columns = ['gender', 'sample_proportion']
real_gender_df
# Out:
#   gender  sample_proportion
# 0      M            0.64827
# 1      F            0.35173

# %%
real_ethcat_df = df_base.ETHCAT.value_counts(normalize=True).reset_index()
real_ethcat_df.ETHCAT = real_ethcat_df.ETHCAT.map(ethcat_mapping)
real_ethcat_df.columns = ['ethcat', 'sample_proportion']
real_ethcat_df
# Out:
#                                               ethcat  sample_proportion
# 0                                White, Non-Hispanic           0.439416
# 1                                Black, Non-Hispanic           0.325258
# 2                                    Hispanic/Latino           0.159551
# 3                                Asian, Non-Hispanic           0.053213
# 4               Amer Ind/Alaska Native, Non-Hispanic           0.013618
# 5                          Multiracial, Non-Hispanic           0.004764
# 6  Native Hawaiian/Other Pacific Islander, Non-Hi...           0.004180

# %%
recipient.ABO.unique()
# Out:
# array(['B', 'A', 'O', 'AB', 'A2', 'A1', 'A1B', 'A2B'], dtype=object)

# %%
blood_type_compatibility = {
    "A": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A1": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A2": ["A", "A1", "A2", "AB", "A1B", "A2B", "B"],
    "B":  ["B", "AB", "A1B", "A2B"],
    "AB": ["AB", "A1B", "A2B"],
    "A1B": ["A1B"],
    "A2B": ["A2B", "AB"],
    "O": ["A", "A1", "A2", "B", "AB", "A1B", "A2B", "O"]
}

# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
path = Path("C:/Users/HP/Desktop/UNOS data/codes/simulation-waitline-unos").resolve()  # Get the absolute path
os.chdir(path)
import pandas as pd
import numpy as np
import scipy as sc
import recipient as rec
import prediction as pred 
import donor as don
from event import Event

# %%
def create_list_of_events(n_events = 5000):
    events = Event(number_of_events= n_events, 
                    time_between_arrivals_recipients=4, 
                    time_between_arrivals_donor= 6) #average time in days
    events.create_events()
    return events

# %%
TARGET_TIME  = 5 * 365
SIMULATION_TIME = 365*30  
predictor = pred.SurvivalPredictionModel(model_path='models\decision_tree_2511.pkl')
#9.1% leave the list
#theshold_leave_list = 0.091 
recipients_for_initialization = 300
time_before_starting_simulation = 0
released_recipients = []
# Out:
# models\decision_tree_2511.pkl
# ok
# Model loaded successfully from models\decision_tree_2511.pkl.
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\HP\AppData\Local\Temp\ipykernel_15324\4126554741.py:3: SyntaxWarning: invalid escape sequence '\d'
#   predictor = pred.SurvivalPredictionModel(model_path='models\decision_tree_2511.pkl')

# %%
predictor.model.feature_names_in_
# Out:
# array(['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS',
#        'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'DIALYSIS_DATE', 'AGE',
#        'DIAB', 'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80',
#        'COD_CAD_DON_2', 'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype=object)

# %%
df = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
df_leaves = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
waiting_time_convergence = []
wait_list_length = []
leave_list_global = []



def run_simulation(T=10, replicates=1, verbose=False):
    waiting_time_convergence_r = []
    wait_list_length_r = []
    average_waiting_times = []
    number_of_matches_list = []
    
    for r in range(replicates):
        events = create_list_of_events(n_events = 10000)
        print('Replicate #', str(r))
        wait_list = []  # Initialize an empty waitlist for each replicate
        leave_list = []
        next_in_leave_the_list = []
        total_waiting_time = 0  # Track the total waiting time for this replicate
        num_matched_patients = 0  # Track the number of matched patients
        current_t = 0  # Start time    
    
        for i in range(recipients_for_initialization):
                new_recipient = rec.Recipient(time_before_starting_simulation) 
                new_recipient.create_recipient(i)
                wait_list.append(new_recipient)
                next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                next_in_leave_the_list = sorted(next_in_leave_the_list)
                
        while current_t < T:  
            (time_aux, _, _)  = events.list_of_events[0]
            (time2_aux, _, _) = next_in_leave_the_list[0]
            
            if time_aux + current_t < time2_aux:
                (time, event_type, counter)  = events.list_of_events.pop(0)
                ID = None
                print(time+current_t, event_type, ID)
            else: 
                (time, event_type, ID) = next_in_leave_the_list.pop(0)
                print(time, event_type, ID)
                   
            #print(time, event_type)         
            match event_type:
                case "new_donor":
                    current_t += time
                    donor = don.Donor(current_t)
                    donor.create_donor(counter)
                    
                    if len(wait_list) < 1:
                        raise('The waitlist length is 0, check the setup please')            
                    
                    survival_probs = []
                    for recipient in wait_list: 
                        if donor.blood in blood_type_compatibility[recipient.blood]: 
                            survival_probs.append(predictor.predict_survival_prob(recipient, donor, TARGET_TIME))
                        else: 
                             survival_probs.append(0)
                                    
                    arrival_times = []
                    for recipient in wait_list: 
                        if donor.blood in blood_type_compatibility[recipient.blood]:
                            arrival_times.append(recipient.arrival_time)
                        else: 
                            arrival_times.append(current_t)
                    
                    if len(survival_probs)>0: 
                        best_match_index = np.argmin(arrival_times)
                        recipient_best = wait_list[best_match_index]
                        _, predicted_survival_function = predictor.predict_survival_prob(recipient_best, donor, TARGET_TIME, surv_function=True)
                        
                        mean_survival_time = sum(
                        (predicted_survival_function[0].x[i + 1] - predicted_survival_function[0].x[i]) *
                        predicted_survival_function[0].y[i]
                        for i in range(len(predicted_survival_function[0].x) - 1)
)
                        
                        best_patient = wait_list.pop(best_match_index)
                        next_leave_time = [(a, b, c) for (a, b, c) in next_in_leave_the_list if c==best_patient.ID]
                        _index = next_in_leave_the_list.index(next_leave_time[0])   
                        _ = next_in_leave_the_list.pop(_index)
                        
                        print(f'A donation was done with expected life {mean_survival_time} and probabity {survival_probs[best_match_index]}. Day: ', str(current_t))
                        waiting_time = current_t - best_patient.arrival_time
                        
                        if current_t > 8*365.25:
                            total_waiting_time += waiting_time
                            
                        best_patient.waiting_time = waiting_time
                        
                        
                        if current_t > 8*365.25:
                            df.loc[len(df)] = [r, best_patient.ethcat, best_patient.gender, best_patient.waiting_time, mean_survival_time, current_t]
                            released_recipients.append(best_patient)
                            num_matched_patients += 1
                
                case "new_recipient":            
                    current_t += time
                    new_recipient = rec.Recipient(current_t) 
                    new_recipient.create_recipient(counter)
                    wait_list.append(new_recipient)
                    next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                    next_in_leave_the_list = sorted(next_in_leave_the_list)
                    print('A new recipient has arrived. Day: ', str(current_t))
                
                case "leave_list":
                    current_t = time
                    next_leave_time = [p for p in wait_list if p.ID==ID]
                    _index = wait_list.index(next_leave_time[0])   
                    out_of_list = wait_list.pop(_index)
                    leave_list.append(out_of_list)
                    
                    if current_t > 8*365.25:
                        df_leaves.loc[len(df)] = [r, out_of_list.ethcat, out_of_list.gender, out_of_list.waiting_time, _, current_t]
                        print('----------------------- One patient left the waitlist. Day: ', str(current_t), out_of_list.ID) 
                    
                    

            if num_matched_patients>0:
                if current_t > 8*365.25:
                    average_time = total_waiting_time / num_matched_patients
                    #we collect data after 8 years
                    waiting_time_convergence_r.append([current_t, average_time])
                wait_list_length_r.append([current_t, len(wait_list)])
            else: 
                average_time = 'INF'
            if verbose:
                print(f'Number of matches: {num_matched_patients}, recipients in wait list: {len(wait_list)},'
                      f'average time in waitlist {average_time}, patients which leave the list {len(leave_list)}')        
        if num_matched_patients > 0:
            average_waiting_times.append(total_waiting_time / num_matched_patients)
            waiting_time_convergence.append(waiting_time_convergence_r)
            wait_list_length.append(wait_list_length_r)
            number_of_matches_list.append(num_matched_patients)
            leave_list_global.append(leave_list)
        else:
            average_waiting_times.append(0)
            
    return average_waiting_times, number_of_matches_list

# %%
run_simulation(T=SIMULATION_TIME, replicates=1, verbose=True)
# Out:
# Replicate # 0
# 0.3052814984430975 new_recipient None
# A new recipient has arrived. Day:  0.3052814984430975
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 0.6234353643959316 new_recipient None
# A new recipient has arrived. Day:  0.6234353643959316
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 0
# 2.9150930513552176 new_recipient None
# A new recipient has arrived. Day:  2.9150930513552176
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 0
# 5.030079611407455 new_recipient None
# A new recipient has arrived. Day:  5.030079611407455
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 0
# 9.433437762878812 new_recipient None
# A new recipient has arrived. Day:  9.433437762878812
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 0
# 10.711957022702993 new_recipient None
# A new recipient has arrived. Day:  10.711957022702993
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 0
# 14.1953659498925 new_recipient None
# A new recipient has arrived. Day:  14.1953659498925
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 0
# 14.446272238626323 new_recipient None
# A new recipient has arrived. Day:  14.446272238626323
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 0
# 18.930876768688968 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  18.930876768688968
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 0
# 19.812328377794827 leave_list 11006
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 1
# 26.122806590203453 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  26.122806590203453
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 1
# 26.679975159256163 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  26.679975159256163
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 1
# 28.797432235210707 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  28.797432235210707
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 1
# 29.219397555540002 new_recipient None
# A new recipient has arrived. Day:  29.219397555540002
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 1
# 31.396155392542617 leave_list 19162
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 2
# 36.19418573079824 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  36.19418573079824
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 2
# 36.81665299232572 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  36.81665299232572
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 2
# 37.71991414286501 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  37.71991414286501
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 2
# 38.06344284740266 leave_list 14368
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 3
# 41.062584533585216 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  41.062584533585216
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 3
# 41.41435113764125 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  41.41435113764125
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 3
# 44.47801903586809 new_recipient None
# A new recipient has arrived. Day:  44.47801903586809
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 3
# 45.63796105799057 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  45.63796105799057
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 3
# 47.62194275415336 new_recipient None
# A new recipient has arrived. Day:  47.62194275415336
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 3
# 49.586228191908006 leave_list 8104
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 4
# 54.601753521205694 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  54.601753521205694
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 4
# 60.992604404030764 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  60.992604404030764
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 4
# 61.81266092458225 new_recipient None
# A new recipient has arrived. Day:  61.81266092458225
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 4
# 64.03293051230591 new_recipient None
# A new recipient has arrived. Day:  64.03293051230591
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 4
# 64.40437018573563 leave_list 3442
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 5
# 70.73162168256893 new_recipient None
# A new recipient has arrived. Day:  70.73162168256893
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 77.27383508975143 new_recipient None
# A new recipient has arrived. Day:  77.27383508975143
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 79.53582315445207 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  79.53582315445207
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 80.68646651155383 new_recipient None
# A new recipient has arrived. Day:  80.68646651155383
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 82.27840589769296 new_recipient None
# A new recipient has arrived. Day:  82.27840589769296
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 5
# 82.68005120146088 new_recipient None
# A new recipient has arrived. Day:  82.68005120146088
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 5
# 83.14965557358789 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  83.14965557358789
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 5
# 88.32048283066052 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  88.32048283066052
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 91.1356085077826 new_recipient None
# A new recipient has arrived. Day:  91.1356085077826
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 5
# 99.22707162675071 new_recipient None
# A new recipient has arrived. Day:  99.22707162675071
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 5
# 99.78553330826468 new_recipient None
# A new recipient has arrived. Day:  99.78553330826468
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 5
# 99.79370130348755 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  99.79370130348755
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 5
# 102.93043407969388 new_recipient None
# A new recipient has arrived. Day:  102.93043407969388
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 5
# 103.52852014287292 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  103.52852014287292
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 5
# 109.11787386451837 new_recipient None
# A new recipient has arrived. Day:  109.11787386451837
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 5
# 114.14495602775851 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  114.14495602775851
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 5
# 114.73968603290633 new_recipient None
# A new recipient has arrived. Day:  114.73968603290633
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 5
# 114.81792732317126 leave_list 945
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 6
# 121.10195421559054 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  121.10195421559054
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 6
# 122.04238953770194 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  122.04238953770194
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 6
# 122.10374389051816 new_recipient None
# A new recipient has arrived. Day:  122.10374389051816
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 6
# 122.65821582067838 new_recipient None
# A new recipient has arrived. Day:  122.65821582067838
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 6
# 125.1780410880197 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  125.1780410880197
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 6
# 125.3320722651828 leave_list 15882
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 7
# 127.6043844713459 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  127.6043844713459
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 7
# 127.79516202260287 new_recipient None
# A new recipient has arrived. Day:  127.79516202260287
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 7
# 132.26783477333106 leave_list 15399
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 8
# 138.26554445940224 new_recipient None
# A new recipient has arrived. Day:  138.26554445940224
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 8
# 141.36651955799942 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  141.36651955799942
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 8
# 143.53576343214743 leave_list 3318
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 9
# 146.74330408149558 new_recipient None
# A new recipient has arrived. Day:  146.74330408149558
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 9
# 147.1966239582209 new_recipient None
# A new recipient has arrived. Day:  147.1966239582209
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 9
# 147.81188280977472 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  147.81188280977472
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 9
# 147.8592466277928 new_recipient None
# A new recipient has arrived. Day:  147.8592466277928
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 9
# 151.30678342034594 new_recipient None
# A new recipient has arrived. Day:  151.30678342034594
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 9
# 152.89096490036974 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  152.89096490036974
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 9
# 156.0098625211588 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  156.0098625211588
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 9
# 156.17738227121242 new_recipient None
# A new recipient has arrived. Day:  156.17738227121242
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 9
# 157.67555735074833 new_recipient None
# A new recipient has arrived. Day:  157.67555735074833
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 9
# 158.54690176877475 new_recipient None
# A new recipient has arrived. Day:  158.54690176877475
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 9
# 163.146530580831 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  163.146530580831
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 9
# 163.8193253239222 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  163.8193253239222
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 9
# 166.65637051915897 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  166.65637051915897
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 9
# 167.0336536993774 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  167.0336536993774
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 9
# 169.38990026803205 new_recipient None
# A new recipient has arrived. Day:  169.38990026803205
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 9
# 171.05728716746057 leave_list 7502
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 10
# 172.0412123305929 leave_list 12244
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 11
# 178.42380990251755 new_recipient None
# A new recipient has arrived. Day:  178.42380990251755
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 11
# 180.2392897681887 leave_list 5163
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 12
# 180.48012369633176 leave_list 16500
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 13
# 182.38592943847468 new_recipient None
# A new recipient has arrived. Day:  182.38592943847468
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 13
# 197.39867527077539 leave_list 4153
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 14
# 212.90545117696362 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  212.90545117696362
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 14
# 214.58695971270853 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  214.58695971270853
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 14
# 215.13704431043462 new_recipient None
# A new recipient has arrived. Day:  215.13704431043462
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 14
# 222.3661038309238 new_recipient None
# A new recipient has arrived. Day:  222.3661038309238
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 14
# 224.18885601439112 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  224.18885601439112
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 14
# 225.31444551758932 new_recipient None
# A new recipient has arrived. Day:  225.31444551758932
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 14
# 226.9804114777282 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  226.9804114777282
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 14
# 229.9466100647631 leave_list 1753
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 15
# 233.82483270606545 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  233.82483270606545
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 15
# 234.67137193993005 leave_list 3318
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 16
# 236.30541809689666 new_recipient None
# A new recipient has arrived. Day:  236.30541809689666
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 16
# 236.4024067412835 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  236.4024067412835
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 16
# 239.01059747719006 new_recipient None
# A new recipient has arrived. Day:  239.01059747719006
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 16
# 242.03662647297708 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  242.03662647297708
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 16
# 242.38903812758014 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  242.38903812758014
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 16
# 243.61594366474657 new_recipient None
# A new recipient has arrived. Day:  243.61594366474657
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 16
# 244.58497190364184 new_recipient None
# A new recipient has arrived. Day:  244.58497190364184
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 16
# 246.43126741698288 new_recipient None
# A new recipient has arrived. Day:  246.43126741698288
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 16
# 246.63360562729636 leave_list 21848
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 17
# 247.62792278023912 new_recipient None
# A new recipient has arrived. Day:  247.62792278023912
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 17
# 250.5049570957867 new_recipient None
# A new recipient has arrived. Day:  250.5049570957867
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 17
# 253.32229442023313 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  253.32229442023313
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 17
# 258.82839937075556 leave_list 2594
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 18
# 266.94992565051984 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  266.94992565051984
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 18
# 269.3350924303169 new_recipient None
# A new recipient has arrived. Day:  269.3350924303169
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 18
# 273.3385339396568 new_recipient None
# A new recipient has arrived. Day:  273.3385339396568
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 18
# 273.59292928686506 new_recipient None
# A new recipient has arrived. Day:  273.59292928686506
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 18
# 275.60767062678093 leave_list 21553
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 19
# 277.7389072770083 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  277.7389072770083
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 19
# 279.81310020998063 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  279.81310020998063
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 19
# 280.4937904621741 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  280.4937904621741
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 19
# 291.4843277126266 new_recipient None
# A new recipient has arrived. Day:  291.4843277126266
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 19
# 291.793162264171 new_recipient None
# A new recipient has arrived. Day:  291.793162264171
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 19
# 294.07924909406796 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  294.07924909406796
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 19
# 295.8855315550492 leave_list 20014
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 20
# 300.3883821848346 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  300.3883821848346
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 20
# 301.86769629232793 new_recipient None
# A new recipient has arrived. Day:  301.86769629232793
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 20
# 303.0103278186697 leave_list 8901
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 21
# 303.921085703165 leave_list 1373
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 22
# 305.23907033701994 new_recipient None
# A new recipient has arrived. Day:  305.23907033701994
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 22
# 306.6704941664356 new_recipient None
# A new recipient has arrived. Day:  306.6704941664356
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 22
# 309.20484803449637 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  309.20484803449637
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 22
# 310.48067676612453 new_recipient None
# A new recipient has arrived. Day:  310.48067676612453
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 22
# 311.8212594617649 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  311.8212594617649
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 22
# 312.27432885334434 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  312.27432885334434
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 22
# 315.24625674442126 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  315.24625674442126
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 22
# 318.0654494588997 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  318.0654494588997
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 22
# 318.9596722965836 new_recipient None
# A new recipient has arrived. Day:  318.9596722965836
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 22
# 319.2108548645687 leave_list 16121
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 23
# 319.5205163072394 new_recipient None
# A new recipient has arrived. Day:  319.5205163072394
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 23
# 319.7157242448947 new_recipient None
# A new recipient has arrived. Day:  319.7157242448947
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 23
# 320.08719454905173 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  320.08719454905173
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 23
# 320.5373553853199 new_recipient None
# A new recipient has arrived. Day:  320.5373553853199
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 23
# 320.7237331658859 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  320.7237331658859
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 23
# 322.4594779751824 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  322.4594779751824
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 23
# 322.7470929186437 leave_list 4970
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 24
# 323.3384432235927 new_recipient None
# A new recipient has arrived. Day:  323.3384432235927
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 24
# 324.15391950047984 new_recipient None
# A new recipient has arrived. Day:  324.15391950047984
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 24
# 326.28459815035757 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  326.28459815035757
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 24
# 326.3821901331341 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  326.3821901331341
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 24
# 328.64451013401475 new_recipient None
# A new recipient has arrived. Day:  328.64451013401475
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 24
# 329.35344784274764 new_recipient None
# A new recipient has arrived. Day:  329.35344784274764
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 24
# 333.61887752145014 leave_list 20581
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 25
# 337.9437290304853 new_recipient None
# A new recipient has arrived. Day:  337.9437290304853
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 25
# 338.8815831089116 new_recipient None
# A new recipient has arrived. Day:  338.8815831089116
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 25
# 339.9984053010562 new_recipient None
# A new recipient has arrived. Day:  339.9984053010562
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 25
# 343.0777100119362 new_recipient None
# A new recipient has arrived. Day:  343.0777100119362
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 25
# 352.3284385602195 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  352.3284385602195
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 25
# 356.4075033454425 new_recipient None
# A new recipient has arrived. Day:  356.4075033454425
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 25
# 356.7226246461152 leave_list 2817
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 26
# 357.3231360454284 leave_list 21003
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 27
# 357.6716653587268 leave_list 880
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 28
# 358.8587666091744 new_recipient None
# A new recipient has arrived. Day:  358.8587666091744
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 28
# 360.63141054034816 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  360.63141054034816
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 28
# 363.3502597384035 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  363.3502597384035
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 28
# 367.79246486017655 new_recipient None
# A new recipient has arrived. Day:  367.79246486017655
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 28
# 368.5330552902833 new_recipient None
# A new recipient has arrived. Day:  368.5330552902833
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 28
# 368.82347496564057 new_recipient None
# A new recipient has arrived. Day:  368.82347496564057
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 28
# 369.46725828738147 leave_list 1090
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 29
# 370.29315669297426 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  370.29315669297426
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 29
# 370.8504014415669 leave_list 13771
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 30
# 372.5204997379822 leave_list 12295
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 31
# 375.78445221112565 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  375.78445221112565
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 31
# 377.75704152235477 leave_list 12435
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 32
# 382.99408738493804 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  382.99408738493804
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 32
# 383.2604255186209 new_recipient None
# A new recipient has arrived. Day:  383.2604255186209
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 32
# 383.3554636418237 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  383.3554636418237
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 32
# 384.2585254280146 leave_list 18962
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 33
# 386.1216513125723 new_recipient None
# A new recipient has arrived. Day:  386.1216513125723
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 33
# 390.2854722315922 new_donor None
# A donation was done with expected life 2354.0468992355763 and probabity 0.6213407169292465. Day:  390.2854722315922
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 33
# 390.47361024691696 new_recipient None
# A new recipient has arrived. Day:  390.47361024691696
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 33
# 391.2248953972774 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  391.2248953972774
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 33
# 393.2999715947806 new_recipient None
# A new recipient has arrived. Day:  393.2999715947806
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 33
# 394.66192916423796 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  394.66192916423796
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 33
# 394.8666506797504 new_recipient None
# A new recipient has arrived. Day:  394.8666506797504
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 33
# 396.8557246333492 new_recipient None
# A new recipient has arrived. Day:  396.8557246333492
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 33
# 399.4463455769416 leave_list 13393
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 34
# 405.60223542677136 leave_list 5691
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 35
# 409.24569486915954 leave_list 7395
# Number of matches: 0, recipients in wait list: 279,average time in waitlist INF, patients which leave the list 36
# 418.4724797475758 leave_list 12244
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 37
# 419.0549668669052 leave_list 22119
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 38
# 428.3073996683701 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  428.3073996683701
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 38
# 428.51825565245656 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  428.51825565245656
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 38
# 429.0678167124243 leave_list 2948
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 39
# 430.0271606652693 new_recipient None
# A new recipient has arrived. Day:  430.0271606652693
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 39
# 430.8104041658343 leave_list 19320
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 40
# 432.5971578829419 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  432.5971578829419
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 40
# 434.864554716676 new_recipient None
# A new recipient has arrived. Day:  434.864554716676
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 40
# 437.4368358922206 new_recipient None
# A new recipient has arrived. Day:  437.4368358922206
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 40
# 437.67309438740847 new_recipient None
# A new recipient has arrived. Day:  437.67309438740847
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 40
# 437.8703204273032 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  437.8703204273032
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 40
# 438.6210645157689 new_donor None
# A donation was done with expected life 1260.2857142856165 and probabity 0.14285714285714288. Day:  438.6210645157689
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 40
# 441.2215770925123 new_recipient None
# A new recipient has arrived. Day:  441.2215770925123
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 40
# 441.3969033902644 leave_list 9478
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 41
# 443.0818654406177 new_recipient None
# A new recipient has arrived. Day:  443.0818654406177
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 41
# 446.2087698663867 new_recipient None
# A new recipient has arrived. Day:  446.2087698663867
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 41
# 450.26564001512696 new_recipient None
# A new recipient has arrived. Day:  450.26564001512696
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 41
# 450.28153780991806 leave_list 4833
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 42
# 451.3292810361849 new_recipient None
# A new recipient has arrived. Day:  451.3292810361849
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 42
# 453.7329019306279 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  453.7329019306279
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 42
# 455.08072359103005 new_recipient None
# A new recipient has arrived. Day:  455.08072359103005
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 42
# 455.0966521272104 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  455.0966521272104
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 42
# 457.4918481604237 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  457.4918481604237
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 42
# 468.1419706692108 new_recipient None
# A new recipient has arrived. Day:  468.1419706692108
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 42
# 471.480056488918 new_recipient None
# A new recipient has arrived. Day:  471.480056488918
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 42
# 473.53145003361095 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  473.53145003361095
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 42
# 474.29553077845486 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  474.29553077845486
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 42
# 476.737732106315 new_recipient None
# A new recipient has arrived. Day:  476.737732106315
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 42
# 482.5693578635721 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  482.5693578635721
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 42
# 483.3934991377615 new_recipient None
# A new recipient has arrived. Day:  483.3934991377615
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 42
# 483.99340080113666 new_recipient None
# A new recipient has arrived. Day:  483.99340080113666
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 42
# 484.072097524678 new_recipient None
# A new recipient has arrived. Day:  484.072097524678
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 42
# 486.00474311224764 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  486.00474311224764
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 42
# 486.57679497721256 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  486.57679497721256
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 42
# 487.87227372113256 new_recipient None
# A new recipient has arrived. Day:  487.87227372113256
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 42
# 489.72240122134735 new_recipient None
# A new recipient has arrived. Day:  489.72240122134735
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 42
# 491.2102864797188 new_recipient None
# A new recipient has arrived. Day:  491.2102864797188
# Number of matches: 0, recipients in wait list: 279,average time in waitlist INF, patients which leave the list 42
# 493.1173021519453 new_recipient None
# A new recipient has arrived. Day:  493.1173021519453
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 42
# 495.9235289367957 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  495.9235289367957
# Number of matches: 0, recipients in wait list: 279,average time in waitlist INF, patients which leave the list 42
# 496.96194459017755 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  496.96194459017755
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 42
# 497.09544562940687 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  497.09544562940687
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 42
# ...
# Number of matches: 1055, recipients in wait list: 269,average time in waitlist 1405.315638565135, patients which leave the list 789
# 10778.310832860643 new_recipient None
# A new recipient has arrived. Day:  10778.310832860643
# Number of matches: 1055, recipients in wait list: 270,average time in waitlist 1405.315638565135, patients which leave the list 789
# 10779.672099738073 new_recipient None
# A new recipient has arrived. Day:  10779.672099738073
# Number of matches: 1055, recipients in wait list: 271,average time in waitlist 1405.315638565135, patients which leave the list 789
# 10780.925929830619 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10780.925929830619
# Number of matches: 1056, recipients in wait list: 270,average time in waitlist 1405.2891780211642, patients which leave the list 789
# 10783.452258108926 new_recipient None
# A new recipient has arrived. Day:  10783.452258108926
# Number of matches: 1056, recipients in wait list: 271,average time in waitlist 1405.2891780211642, patients which leave the list 789
# 10786.235333882565 leave_list 10108
# ----------------------- One patient left the waitlist. Day:  10786.235333882565 10108
# Number of matches: 1056, recipients in wait list: 270,average time in waitlist 1405.2891780211642, patients which leave the list 790
# 10789.091374273043 new_recipient None
# A new recipient has arrived. Day:  10789.091374273043
# Number of matches: 1056, recipients in wait list: 271,average time in waitlist 1405.2891780211642, patients which leave the list 790
# 10796.599368169704 new_recipient None
# A new recipient has arrived. Day:  10796.599368169704
# Number of matches: 1056, recipients in wait list: 272,average time in waitlist 1405.2891780211642, patients which leave the list 790
# 10798.16956239262 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10798.16956239262
# Number of matches: 1057, recipients in wait list: 271,average time in waitlist 1408.9868978072527, patients which leave the list 790
# 10798.191639944856 new_recipient None
# A new recipient has arrived. Day:  10798.191639944856
# Number of matches: 1057, recipients in wait list: 272,average time in waitlist 1408.9868978072527, patients which leave the list 790
# 10801.046496756624 new_recipient None
# A new recipient has arrived. Day:  10801.046496756624
# Number of matches: 1057, recipients in wait list: 273,average time in waitlist 1408.9868978072527, patients which leave the list 790
# 10802.157706684018 new_donor None
# A donation was done with expected life 3095.0365793054657 and probabity 0.7841656399742981. Day:  10802.157706684018
# Number of matches: 1058, recipients in wait list: 272,average time in waitlist 1408.9778785954948, patients which leave the list 790
# 10803.733397354488 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10803.733397354488
# Number of matches: 1059, recipients in wait list: 271,average time in waitlist 1408.943946929739, patients which leave the list 790
# 10806.564874805528 leave_list 19845
# ----------------------- One patient left the waitlist. Day:  10806.564874805528 19845
# Number of matches: 1059, recipients in wait list: 270,average time in waitlist 1408.943946929739, patients which leave the list 791
# 10809.17156331651 leave_list 9327
# ----------------------- One patient left the waitlist. Day:  10809.17156331651 9327
# Number of matches: 1059, recipients in wait list: 269,average time in waitlist 1408.943946929739, patients which leave the list 792
# 10812.865198713376 leave_list 6730
# ----------------------- One patient left the waitlist. Day:  10812.865198713376 6730
# Number of matches: 1059, recipients in wait list: 268,average time in waitlist 1408.943946929739, patients which leave the list 793
# 10818.790581765727 new_recipient None
# A new recipient has arrived. Day:  10818.790581765727
# Number of matches: 1059, recipients in wait list: 269,average time in waitlist 1408.943946929739, patients which leave the list 793
# 10821.502996127021 new_recipient None
# A new recipient has arrived. Day:  10821.502996127021
# Number of matches: 1059, recipients in wait list: 270,average time in waitlist 1408.943946929739, patients which leave the list 793
# 10827.719145666199 new_recipient None
# A new recipient has arrived. Day:  10827.719145666199
# Number of matches: 1059, recipients in wait list: 271,average time in waitlist 1408.943946929739, patients which leave the list 793
# 10828.411182283824 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  10828.411182283824
# Number of matches: 1060, recipients in wait list: 270,average time in waitlist 1409.373873256987, patients which leave the list 793
# 10834.079830025003 leave_list 7217
# ----------------------- One patient left the waitlist. Day:  10834.079830025003 7217
# Number of matches: 1060, recipients in wait list: 269,average time in waitlist 1409.373873256987, patients which leave the list 794
# 10838.585102960866 leave_list 19042
# ----------------------- One patient left the waitlist. Day:  10838.585102960866 19042
# Number of matches: 1060, recipients in wait list: 268,average time in waitlist 1409.373873256987, patients which leave the list 795
# 10844.269672224214 leave_list 15244
# ----------------------- One patient left the waitlist. Day:  10844.269672224214 15244
# Number of matches: 1060, recipients in wait list: 267,average time in waitlist 1409.373873256987, patients which leave the list 796
# 10845.73936898511 leave_list 15157
# ----------------------- One patient left the waitlist. Day:  10845.73936898511 15157
# Number of matches: 1060, recipients in wait list: 266,average time in waitlist 1409.373873256987, patients which leave the list 797
# 10856.706245078987 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10856.706245078987
# Number of matches: 1061, recipients in wait list: 265,average time in waitlist 1409.3528240070627, patients which leave the list 797
# 10859.995686435977 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  10859.995686435977
# Number of matches: 1062, recipients in wait list: 264,average time in waitlist 1409.3236337139888, patients which leave the list 797
# 10865.202569309959 new_recipient None
# A new recipient has arrived. Day:  10865.202569309959
# Number of matches: 1062, recipients in wait list: 265,average time in waitlist 1409.3236337139888, patients which leave the list 797
# 10866.072099912988 new_recipient None
# A new recipient has arrived. Day:  10866.072099912988
# Number of matches: 1062, recipients in wait list: 266,average time in waitlist 1409.3236337139888, patients which leave the list 797
# 10868.170959572004 new_recipient None
# A new recipient has arrived. Day:  10868.170959572004
# Number of matches: 1062, recipients in wait list: 267,average time in waitlist 1409.3236337139888, patients which leave the list 797
# 10870.803238130378 leave_list 12127
# ----------------------- One patient left the waitlist. Day:  10870.803238130378 12127
# Number of matches: 1062, recipients in wait list: 266,average time in waitlist 1409.3236337139888, patients which leave the list 798
# 10874.39149895862 leave_list 4945
# ----------------------- One patient left the waitlist. Day:  10874.39149895862 4945
# Number of matches: 1062, recipients in wait list: 265,average time in waitlist 1409.3236337139888, patients which leave the list 799
# 10879.071136806753 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  10879.071136806753
# Number of matches: 1063, recipients in wait list: 264,average time in waitlist 1409.3013485269387, patients which leave the list 799
# 10883.230316710538 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  10883.230316710538
# Number of matches: 1064, recipients in wait list: 263,average time in waitlist 1409.2738122299236, patients which leave the list 799
# 10887.026207983543 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  10887.026207983543
# Number of matches: 1065, recipients in wait list: 262,average time in waitlist 1409.2218413638275, patients which leave the list 799
# 10888.7308451637 new_recipient None
# A new recipient has arrived. Day:  10888.7308451637
# Number of matches: 1065, recipients in wait list: 263,average time in waitlist 1409.2218413638275, patients which leave the list 799
# 10889.174543915995 new_recipient None
# A new recipient has arrived. Day:  10889.174543915995
# Number of matches: 1065, recipients in wait list: 264,average time in waitlist 1409.2218413638275, patients which leave the list 799
# 10890.059962010826 new_recipient None
# A new recipient has arrived. Day:  10890.059962010826
# Number of matches: 1065, recipients in wait list: 265,average time in waitlist 1409.2218413638275, patients which leave the list 799
# 10890.572667288558 new_recipient None
# A new recipient has arrived. Day:  10890.572667288558
# Number of matches: 1065, recipients in wait list: 266,average time in waitlist 1409.2218413638275, patients which leave the list 799
# 10893.560791201744 leave_list 7795
# ----------------------- One patient left the waitlist. Day:  10893.560791201744 7795
# Number of matches: 1065, recipients in wait list: 265,average time in waitlist 1409.2218413638275, patients which leave the list 800
# 10895.535532257585 leave_list 13224
# ----------------------- One patient left the waitlist. Day:  10895.535532257585 13224
# Number of matches: 1065, recipients in wait list: 264,average time in waitlist 1409.2218413638275, patients which leave the list 801
# 10900.152275440283 new_recipient None
# A new recipient has arrived. Day:  10900.152275440283
# Number of matches: 1065, recipients in wait list: 265,average time in waitlist 1409.2218413638275, patients which leave the list 801
# 10900.178490273836 new_recipient None
# A new recipient has arrived. Day:  10900.178490273836
# Number of matches: 1065, recipients in wait list: 266,average time in waitlist 1409.2218413638275, patients which leave the list 801
# 10900.530101463404 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  10900.530101463404
# Number of matches: 1066, recipients in wait list: 265,average time in waitlist 1412.2906674834048, patients which leave the list 801
# 10902.201464617441 new_recipient None
# A new recipient has arrived. Day:  10902.201464617441
# Number of matches: 1066, recipients in wait list: 266,average time in waitlist 1412.2906674834048, patients which leave the list 801
# 10902.938689994653 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  10902.938689994653
# Number of matches: 1067, recipients in wait list: 265,average time in waitlist 1412.2506519116985, patients which leave the list 801
# 10906.565089973588 new_recipient None
# A new recipient has arrived. Day:  10906.565089973588
# Number of matches: 1067, recipients in wait list: 266,average time in waitlist 1412.2506519116985, patients which leave the list 801
# 10907.099655829443 new_recipient None
# A new recipient has arrived. Day:  10907.099655829443
# Number of matches: 1067, recipients in wait list: 267,average time in waitlist 1412.2506519116985, patients which leave the list 801
# 10907.737157993313 leave_list 16751
# ----------------------- One patient left the waitlist. Day:  10907.737157993313 16751
# Number of matches: 1067, recipients in wait list: 266,average time in waitlist 1412.2506519116985, patients which leave the list 802
# 10910.834571276284 new_donor None
# A donation was done with expected life 3122.5749226965404 and probabity 0.8004182699729505. Day:  10910.834571276284
# Number of matches: 1068, recipients in wait list: 265,average time in waitlist 1412.331562812162, patients which leave the list 802
# 10911.709701694714 new_recipient None
# A new recipient has arrived. Day:  10911.709701694714
# Number of matches: 1068, recipients in wait list: 266,average time in waitlist 1412.331562812162, patients which leave the list 802
# 10914.361439696497 new_recipient None
# A new recipient has arrived. Day:  10914.361439696497
# Number of matches: 1068, recipients in wait list: 267,average time in waitlist 1412.331562812162, patients which leave the list 802
# 10915.018084460422 new_donor None
# A donation was done with expected life 2927.7158741612952 and probabity 0.7546977469156004. Day:  10915.018084460422
# Number of matches: 1069, recipients in wait list: 266,average time in waitlist 1412.7653862148438, patients which leave the list 802
# 10915.812339388169 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  10915.812339388169
# Number of matches: 1070, recipients in wait list: 265,average time in waitlist 1412.848918869074, patients which leave the list 802
# 10916.65578760159 new_recipient None
# A new recipient has arrived. Day:  10916.65578760159
# Number of matches: 1070, recipients in wait list: 266,average time in waitlist 1412.848918869074, patients which leave the list 802
# 10920.403342419317 new_donor None
# A donation was done with expected life 2733.652782381718 and probabity 0.7322714695987325. Day:  10920.403342419317
# Number of matches: 1071, recipients in wait list: 265,average time in waitlist 1412.8245392351198, patients which leave the list 802
# 10925.793228863293 leave_list 5796
# ----------------------- One patient left the waitlist. Day:  10925.793228863293 5796
# Number of matches: 1071, recipients in wait list: 264,average time in waitlist 1412.8245392351198, patients which leave the list 803
# 10933.172265013543 leave_list 3977
# ----------------------- One patient left the waitlist. Day:  10933.172265013543 3977
# Number of matches: 1071, recipients in wait list: 263,average time in waitlist 1412.8245392351198, patients which leave the list 804
# 10933.907716089114 leave_list 3578
# ----------------------- One patient left the waitlist. Day:  10933.907716089114 3578
# Number of matches: 1071, recipients in wait list: 262,average time in waitlist 1412.8245392351198, patients which leave the list 805
# 10943.874953071923 new_recipient None
# A new recipient has arrived. Day:  10943.874953071923
# Number of matches: 1071, recipients in wait list: 263,average time in waitlist 1412.8245392351198, patients which leave the list 805
# 10945.004438257585 new_donor None
# A donation was done with expected life 3010.319193262576 and probabity 0.7911197600210826. Day:  10945.004438257585
# Number of matches: 1072, recipients in wait list: 262,average time in waitlist 1412.9209731085098, patients which leave the list 805
# 10945.767716587012 new_donor None
# A donation was done with expected life 2749.5892749861 and probabity 0.7069534320897705. Day:  10945.767716587012
# Number of matches: 1073, recipients in wait list: 261,average time in waitlist 1413.0047232539, patients which leave the list 805
# 10948.476978873785 new_recipient None
# A new recipient has arrived. Day:  10948.476978873785
# Number of matches: 1073, recipients in wait list: 262,average time in waitlist 1413.0047232539, patients which leave the list 805
# 10949.36612474291 new_donor None
# A donation was done with expected life 2757.5459971227137 and probabity 0.7136076078610929. Day:  10949.36612474291
# Number of matches: 1074, recipients in wait list: 261,average time in waitlist 1412.9970438229745, patients which leave the list 805
# 10956.951222756132 leave_list 21586
# ----------------------- One patient left the waitlist. Day:  10956.951222756132 21586
# Number of matches: 1074, recipients in wait list: 260,average time in waitlist 1412.9970438229745, patients which leave the list 806
# ([1412.9970438229745], [1074])

# %%
df['ethcat'] = df['ethcat'].replace(ethcat_mapping)

# %%
df_waiting_time = ((df.groupby(by=['replicate', 'ethcat'])
                   .agg(
                       waiting_time=('waiting_time', 'mean'), 
                       count=('waiting_time', 'size'), 
                       mean_survival_time=('mean_survival_time', 'mean'))
                   .reset_index())
)#.to_csv('simulation_results.csv')
df_waiting_time = df_waiting_time[['ethcat', 'waiting_time', 'count', 'mean_survival_time']].groupby('ethcat').agg(['mean', 'std'])
df_waiting_time.columns = [f"{col[0]}_{col[1]}" for col in df_waiting_time.columns] 
df_waiting_time['prop_simu'] = df_waiting_time['count_mean'] / df_waiting_time['count_mean'].sum()
df_waiting_time = df_waiting_time.merge(real_ethcat_df, on='ethcat').round(3)
df_waiting_time.columns = ['ethcat', 'wt_mean', 'wt_std', 'count_mean', 'count_std', 'st_mean', 'st_std', 'prop_simu', 'sample_proportion']
df_waiting_time
# Out:
#                                               ethcat   wt_mean  wt_std  \
# 0               Amer Ind/Alaska Native, Non-Hispanic  1279.209     NaN
# 1                                Asian, Non-Hispanic  1654.909     NaN
# 2                                Black, Non-Hispanic  1434.989     NaN
# 3                                    Hispanic/Latino  1374.806     NaN
# 4                          Multiracial, Non-Hispanic  1489.971     NaN
# 5  Native Hawaiian/Other Pacific Islander, Non-Hi...  1311.961     NaN
# 6                                White, Non-Hispanic  1393.054     NaN
#
#    count_mean  count_std   st_mean  st_std  prop_simu  sample_proportion
# 0        11.0        NaN  2857.627     NaN      0.010              0.014
# 1        50.0        NaN  2890.084     NaN      0.047              0.053
# 2       307.0        NaN  2879.570     NaN      0.286              0.325
# 3       200.0        NaN  2880.244     NaN      0.186              0.160
# 4         7.0        NaN  2925.577     NaN      0.007              0.005
# 5         4.0        NaN  2816.761     NaN      0.004              0.004
# 6       495.0        NaN  2883.289     NaN      0.461              0.439

# %%
df_gender = ((df.groupby(by=['replicate', 'gender'])
                .agg(
                    waiting_time=('waiting_time', 'mean'), 
                    count=('waiting_time', 'size'),
                    mean_survival_time=('mean_survival_time', 'mean'))
                .reset_index())
)#.to_csv('simulation_results.csv')
df_gender = df_gender[['gender', 'waiting_time', 'count', 'mean_survival_time']].groupby('gender').agg(['mean', 'std'])
df_gender.columns = [f"{col[0]}_{col[1]}" for col in df_gender.columns] 
df_gender['proportion_sim'] = df_gender['count_mean'] / df_gender['count_mean'].sum()
df_gender.reset_index(inplace=True)
df_gender = df_gender.merge(real_gender_df, on = 'gender')
df_gender.columns = ['gender', 'wt_mean', 'wt_std', 'count_mean',
       'count_std', 'st_mean', 'st_std',
       'prop_sim', 'sample_proportion']
df_gender.round(3)
# Out:
#   gender   wt_mean  wt_std  count_mean  count_std   st_mean  st_std  prop_sim  \
# 0      F  1424.357     NaN       368.0        NaN  2892.821     NaN     0.343
# 1      M  1407.076     NaN       706.0        NaN  2875.965     NaN     0.657
#
#    sample_proportion
# 0              0.352
# 1              0.648

# %%
#df.to_csv('results_decision_tree.csv')
