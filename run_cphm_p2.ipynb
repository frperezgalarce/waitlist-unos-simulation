# %%
import pandas as pd 

df_base = pd.read_csv('data/data_to_simulate.csv', index_col=0)
df_base.dropna(inplace=True)
print(df_base.columns)
columns = ['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON', 'AGE', 'DIAB',
                'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI', 'SERUM_CREAT',
                'CREAT_TRR', 'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC','CREAT_TRRg1.5', 'SERUM_CREATg1.2',
                'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
                'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE','TX_DATE', 'PT_CODE', 'ABO', 'ABO_DON']

predictors = ['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'WGT_KG_DON_CALC',
                    'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'COD_CAD_DON', 'ETHCAT_DON', 'ABO_MAT', 
                    'HLAMIS', 'DIALYSIS_DATE', 'AGE', 'DIAB', 'DIALYSIS_DATEle0.0', 'CREAT_TRRg1.5', 'SERUM_CREATg1.2']

donor = df_base[['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 
            'HIST_HYPERTENS_DON', 'ABO_DON', 'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2']]

print(donor.columns)
donor.to_csv('data/donors.csv')

recipient = df_base[[ 'DIALYSIS_DATE', 'AGE', 'DIAB', 'ETHCAT', 'GENDER', 'ABO', 'DIALYSIS_DATEle0.0']]
recipient.to_csv('data/recipients.csv')

ethcat_mapping = {
    1: "White, Non-Hispanic",
    2: "Black, Non-Hispanic",
    4: "Hispanic/Latino",
    5: "Asian, Non-Hispanic",
    6: "Amer Ind/Alaska Native, Non-Hispanic",
    7: "Native Hawaiian/Other Pacific Islander, Non-Hispanic",
    9: "Multiracial, Non-Hispanic",
}
# Out:
# Index(['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON',
#        'AGE', 'DIAB', 'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI',
#        'SERUM_CREAT', 'ABO_MAT', 'AMIS', 'BMIS', 'DRMIS', 'CREAT_TRR',
#        'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC', 'ABO_DON',
#        'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
#        'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE', 'TX_DATE',
#        'PT_CODE', 'COMPOSITE_DEATH_DATE', 'ABO', 'T', 'Tag_date', 'DIAB_1',
#        'DIAB_998', 'HIST_DIABETES_DON_1', 'HIST_DIABETES_DON_998',
#        'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2',
#        'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype='object')
# Index(['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC',
#        'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'ABO_DON',
#        'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2'],
#       dtype='object')

# %%
real_gender_df = df_base.GENDER.value_counts(normalize=True).reset_index()
real_gender_df.columns = ['gender', 'sample_proportion']
real_gender_df
# Out:
#   gender  sample_proportion
# 0      M            0.64827
# 1      F            0.35173

# %%
real_ethcat_df = df_base.ETHCAT.value_counts(normalize=True).reset_index()
real_ethcat_df.ETHCAT = real_ethcat_df.ETHCAT.map(ethcat_mapping)
real_ethcat_df.columns = ['ethcat', 'sample_proportion']
real_ethcat_df
# Out:
#                                               ethcat  sample_proportion
# 0                                White, Non-Hispanic           0.439416
# 1                                Black, Non-Hispanic           0.325258
# 2                                    Hispanic/Latino           0.159551
# 3                                Asian, Non-Hispanic           0.053213
# 4               Amer Ind/Alaska Native, Non-Hispanic           0.013618
# 5                          Multiracial, Non-Hispanic           0.004764
# 6  Native Hawaiian/Other Pacific Islander, Non-Hi...           0.004180

# %%
recipient.ABO.unique()
# Out:
# array(['B', 'A', 'O', 'AB', 'A2', 'A1', 'A1B', 'A2B'], dtype=object)

# %%
blood_type_compatibility = {
    "A": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A1": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A2": ["A", "A1", "A2", "AB", "A1B", "A2B", "B"],
    "B":  ["B", "AB", "A1B", "A2B"],
    "AB": ["AB", "A1B", "A2B"],
    "A1B": ["A1B"],
    "A2B": ["A2B", "AB"],
    "O": ["A", "A1", "A2", "B", "AB", "A1B", "A2B", "O"]
}

# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
path = Path("C:/Users/HP/Desktop/UNOS data/codes/simulation-waitline-unos").resolve()  # Get the absolute path
os.chdir(path)
import pandas as pd
import numpy as np
import scipy as sc
import recipient as rec
import prediction as pred 
import donor as don
from event import Event

# %%
def create_list_of_events(n_events = 10000):
    events = Event(number_of_events= n_events, 
                    time_between_arrivals_recipients=4, 
                    time_between_arrivals_donor= 6) #average time in days
    events.create_events()
    return events

# %%
TARGET_TIME  = 5 * 365
SIMULATION_TIME = 365*30 
predictor = pred.SurvivalPredictionModel(model_path='models\cox_prop_2511.pkl')
#9.1% leave the list
#theshold_leave_list = 0.091 
recipients_for_initialization = 300
time_before_starting_simulation = 0
released_recipients = []
# Out:
# models\cox_prop_2511.pkl
# ok
# Model loaded successfully from models\cox_prop_2511.pkl.
# <>:3: SyntaxWarning: invalid escape sequence '\c'
# <>:3: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\HP\AppData\Local\Temp\ipykernel_17128\1261647170.py:3: SyntaxWarning: invalid escape sequence '\c'
#   predictor = pred.SurvivalPredictionModel(model_path='models\cox_prop_2511.pkl')

# %%
predictor.model.feature_names_in_
# Out:
# array(['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS',
#        'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'DIALYSIS_DATE', 'AGE',
#        'DIAB', 'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80',
#        'COD_CAD_DON_2', 'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype=object)

# %%
df = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
df_leaves = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
waiting_time_convergence = []
wait_list_length = []
leave_list_global = []



def run_simulation(T=10, replicates=1, verbose=False):
    waiting_time_convergence_r = []
    wait_list_length_r = []
    average_waiting_times = []
    number_of_matches_list = []
    
    for r in range(replicates):
        events = create_list_of_events(n_events = 10000)
        print('Replicate #', str(r))
        wait_list = []  # Initialize an empty waitlist for each replicate
        leave_list = []
        next_in_leave_the_list = []
        total_waiting_time = 0  # Track the total waiting time for this replicate
        num_matched_patients = 0  # Track the number of matched patients
        current_t = 0  # Start time    
    
        for i in range(recipients_for_initialization):
                new_recipient = rec.Recipient(time_before_starting_simulation) 
                new_recipient.create_recipient(i)
                wait_list.append(new_recipient)
                next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                next_in_leave_the_list = sorted(next_in_leave_the_list)
                
        while current_t < T:  
            (time_aux, _, _)  = events.list_of_events[0]
            (time2_aux, _, _) = next_in_leave_the_list[0]
            
            if time_aux + current_t < time2_aux:
                (time, event_type, counter)  = events.list_of_events.pop(0)
                ID = None
                print(time+current_t, event_type, ID)
            else: 
                (time, event_type, ID) = next_in_leave_the_list.pop(0)
                print(time, event_type, ID)
                   
            #print(time, event_type)         
            match event_type:
                case "new_donor":
                    current_t += time
                    donor = don.Donor(current_t)
                    donor.create_donor(counter)
                    
                    if len(wait_list) < 1:
                        raise('The waitlist length is 0, check the setup please')            
                    
                    survival_probs = []
                    for recipient in wait_list: 
                        if donor.blood in blood_type_compatibility[recipient.blood]: 
                            survival_probs.append(predictor.predict_survival_prob(recipient, donor, TARGET_TIME))
                        else: 
                             survival_probs.append(0)
                    
                            
                    arrival_times = []
                    for recipient in wait_list: 
                        if donor.blood in blood_type_compatibility[recipient.blood]:
                            arrival_times.append(recipient.arrival_time)
                        else: 
                            arrival_times.append(current_t)
                                               
                    if len(survival_probs)>0: 
                        best_match_index = np.argmin(arrival_times)
                        recipient_best = wait_list[best_match_index]
                        _, predicted_survival_function = predictor.predict_survival_prob(recipient_best, donor, TARGET_TIME, surv_function=True)
                        
                        mean_survival_time = sum(
                        (predicted_survival_function[0].x[i + 1] - predicted_survival_function[0].x[i]) *
                        predicted_survival_function[0].y[i]
                        for i in range(len(predicted_survival_function[0].x) - 1)
)
                        
                        best_patient = wait_list.pop(best_match_index)
                        next_leave_time = [(a, b, c) for (a, b, c) in next_in_leave_the_list if c==best_patient.ID]
                        _index = next_in_leave_the_list.index(next_leave_time[0])   
                        _ = next_in_leave_the_list.pop(_index)
                        
                        print(f'A donation was done with expected life {mean_survival_time} and probabity {survival_probs[best_match_index]}. Day: ', str(current_t))
                        waiting_time = current_t - best_patient.arrival_time
                        
                        if current_t > 8*365.25:
                            total_waiting_time += waiting_time
                            
                        best_patient.waiting_time = waiting_time
                        
                        
                        if current_t > 8*365.25:
                            df.loc[len(df)] = [r, best_patient.ethcat, best_patient.gender, best_patient.waiting_time, mean_survival_time, current_t]
                            released_recipients.append(best_patient)
                            num_matched_patients += 1
                
                case "new_recipient":            
                    current_t += time
                    new_recipient = rec.Recipient(current_t) 
                    new_recipient.create_recipient(counter)
                    wait_list.append(new_recipient)
                    next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                    next_in_leave_the_list = sorted(next_in_leave_the_list)
                    print('A new recipient has arrived. Day: ', str(current_t))
                
                case "leave_list":
                    current_t = time
                    next_leave_time = [p for p in wait_list if p.ID==ID]
                    _index = wait_list.index(next_leave_time[0])   
                    out_of_list = wait_list.pop(_index)
                    leave_list.append(out_of_list)
                    
                    if current_t > 8*365.25:
                        df_leaves.loc[len(df)] = [r, out_of_list.ethcat, out_of_list.gender, out_of_list.waiting_time, _, current_t]
                        print('----------------------- One patient left the waitlist. Day: ', str(current_t), out_of_list.ID) 
                    
                    

            if num_matched_patients>0:
                if current_t > 8*365.25:
                    average_time = total_waiting_time / num_matched_patients
                    #we collect data after 8 years
                    waiting_time_convergence_r.append([current_t, average_time])
                wait_list_length_r.append([current_t, len(wait_list)])
            else: 
                average_time = 'INF'
            if verbose:
                print(f'Number of matches: {num_matched_patients}, recipients in wait list: {len(wait_list)},'
                      f'average time in waitlist {average_time}, patients which leave the list {len(leave_list)}')        
        if num_matched_patients > 0:
            average_waiting_times.append(total_waiting_time / num_matched_patients)
            waiting_time_convergence.append(waiting_time_convergence_r)
            wait_list_length.append(wait_list_length_r)
            number_of_matches_list.append(num_matched_patients)
            leave_list_global.append(leave_list)
        else:
            average_waiting_times.append(0)
            
    return average_waiting_times, number_of_matches_list

# %%
run_simulation(T=SIMULATION_TIME, replicates=1, verbose=True)
# Out:
# Replicate # 0
# 0.5332531584474225 new_donor None
# A donation was done with expected life 1314.05704974528 and probabity 0.30316557342093237. Day:  0.5332531584474225
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 1.800935132453325 new_recipient None
# A new recipient has arrived. Day:  1.800935132453325
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 2.333305448876743 new_recipient None
# A new recipient has arrived. Day:  2.333305448876743
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 3.8939257136686796 new_recipient None
# A new recipient has arrived. Day:  3.8939257136686796
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 0
# 6.576929304002158 new_donor None
# A donation was done with expected life 1846.3590238239922 and probabity 0.4856138372145657. Day:  6.576929304002158
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 6.892274042623452 new_recipient None
# A new recipient has arrived. Day:  6.892274042623452
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 0
# 6.9553508329633615 new_donor None
# A donation was done with expected life 2895.706460224377 and probabity 0.765408024762641. Day:  6.9553508329633615
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 7.7222577947882085 new_recipient None
# A new recipient has arrived. Day:  7.7222577947882085
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 0
# 9.959473852319539 new_recipient None
# A new recipient has arrived. Day:  9.959473852319539
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 0
# 12.17824340882937 new_donor None
# A donation was done with expected life 2552.300087611505 and probabity 0.6841000129468433. Day:  12.17824340882937
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 0
# 13.721835635479577 new_recipient None
# A new recipient has arrived. Day:  13.721835635479577
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 0
# 13.741698252419395 new_donor None
# A donation was done with expected life 1697.7095991147276 and probabity 0.43750099376117874. Day:  13.741698252419395
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 0
# 16.43744725343901 new_recipient None
# A new recipient has arrived. Day:  16.43744725343901
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 0
# 19.812328377794827 leave_list 11006
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 1
# 25.77546095665271 new_recipient None
# A new recipient has arrived. Day:  25.77546095665271
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 1
# 26.01382871084886 new_recipient None
# A new recipient has arrived. Day:  26.01382871084886
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 1
# 26.16876042129413 new_recipient None
# A new recipient has arrived. Day:  26.16876042129413
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 1
# 26.217711738227102 new_recipient None
# A new recipient has arrived. Day:  26.217711738227102
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 1
# 28.6372608484633 new_recipient None
# A new recipient has arrived. Day:  28.6372608484633
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 1
# 30.69389195180184 new_recipient None
# A new recipient has arrived. Day:  30.69389195180184
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 1
# 30.934704327807395 new_recipient None
# A new recipient has arrived. Day:  30.934704327807395
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 1
# 31.396155392542617 leave_list 19162
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 2
# 32.02566860497302 new_donor None
# A donation was done with expected life 1534.3023408985318 and probabity 0.3819605711217931. Day:  32.02566860497302
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 2
# 32.966137329438126 new_donor None
# A donation was done with expected life 2253.0367270490397 and probabity 0.6056394517590986. Day:  32.966137329438126
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 2
# 38.06344284740266 leave_list 14368
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 3
# 44.06952838396061 new_recipient None
# A new recipient has arrived. Day:  44.06952838396061
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 3
# 48.0229166997222 leave_list 14368
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 4
# 49.586228191908006 leave_list 8104
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 5
# 55.50954593925738 new_donor None
# A donation was done with expected life 2359.333565153706 and probabity 0.6343949402544947. Day:  55.50954593925738
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 5
# 56.899908831142575 new_donor None
# A donation was done with expected life 2500.0117619692423 and probabity 0.6709365672343997. Day:  56.899908831142575
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 5
# 57.237587510961106 new_recipient None
# A new recipient has arrived. Day:  57.237587510961106
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 5
# 57.68735874173577 new_donor None
# A donation was done with expected life 2330.91197339505 and probabity 0.6268054518557421. Day:  57.68735874173577
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 5
# 61.6626471220232 new_donor None
# A donation was done with expected life 2319.6469344624124 and probabity 0.623777505363648. Day:  61.6626471220232
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 5
# 63.499233804548645 new_recipient None
# A new recipient has arrived. Day:  63.499233804548645
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 5
# 64.40437018573563 leave_list 3442
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 6
# 67.53245389805437 new_recipient None
# A new recipient has arrived. Day:  67.53245389805437
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 6
# 71.19817974199066 new_recipient None
# A new recipient has arrived. Day:  71.19817974199066
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 6
# 71.52661069898255 new_donor None
# A donation was done with expected life 1516.6644445874595 and probabity 0.37580635729515466. Day:  71.52661069898255
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 6
# 72.63649894028077 new_recipient None
# A new recipient has arrived. Day:  72.63649894028077
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 6
# 73.31464104683894 new_recipient None
# A new recipient has arrived. Day:  73.31464104683894
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 6
# 76.04033150190641 new_donor None
# A donation was done with expected life 2227.466147885705 and probabity 0.5985686019096936. Day:  76.04033150190641
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 6
# 76.17242718817126 new_recipient None
# A new recipient has arrived. Day:  76.17242718817126
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 6
# 79.65269853756796 new_recipient None
# A new recipient has arrived. Day:  79.65269853756796
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 6
# 83.141807235991 new_donor None
# A donation was done with expected life 1384.4750236741916 and probabity 0.3287851086787688. Day:  83.141807235991
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 6
# 84.96903565135885 new_recipient None
# A new recipient has arrived. Day:  84.96903565135885
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 6
# 87.56645505393912 new_donor None
# A donation was done with expected life 2161.319514502287 and probabity 0.5799930900622454. Day:  87.56645505393912
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 6
# 87.76459722496922 new_recipient None
# A new recipient has arrived. Day:  87.76459722496922
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 6
# 89.57631445136936 new_recipient None
# A new recipient has arrived. Day:  89.57631445136936
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 6
# 91.10017735213295 new_donor None
# A donation was done with expected life 2247.7028305470467 and probabity 0.6041695046195098. Day:  91.10017735213295
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 6
# 94.85616451677662 new_recipient None
# A new recipient has arrived. Day:  94.85616451677662
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 6
# 106.27327755794981 new_recipient None
# A new recipient has arrived. Day:  106.27327755794981
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 6
# 113.5029475058759 new_recipient None
# A new recipient has arrived. Day:  113.5029475058759
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 6
# 114.81792732317126 leave_list 945
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 7
# 116.41756411287007 new_recipient None
# A new recipient has arrived. Day:  116.41756411287007
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 7
# 117.73786940856377 new_donor None
# A donation was done with expected life 2270.9309613008477 and probabity 0.6105517342847373. Day:  117.73786940856377
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 7
# 118.39592756852196 new_recipient None
# A new recipient has arrived. Day:  118.39592756852196
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 7
# 121.10479848099575 new_donor None
# A donation was done with expected life 1567.4301822630323 and probabity 0.39343799404881147. Day:  121.10479848099575
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 7
# 121.36200801943306 new_recipient None
# A new recipient has arrived. Day:  121.36200801943306
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 7
# 122.55588295108288 new_recipient None
# A new recipient has arrived. Day:  122.55588295108288
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 7
# 125.3320722651828 leave_list 15882
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 8
# 128.62173726627108 new_donor None
# A donation was done with expected life 1888.6553832273673 and probabity 0.49887873813102684. Day:  128.62173726627108
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 8
# 131.7982580545784 new_donor None
# A donation was done with expected life 1640.7551014529909 and probabity 0.418452243722367. Day:  131.7982580545784
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 8
# 132.26783477333106 leave_list 15399
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 9
# 137.65107373672498 new_recipient None
# A new recipient has arrived. Day:  137.65107373672498
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 9
# 143.53576343214743 leave_list 3318
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 10
# 151.4915842878168 new_donor None
# A donation was done with expected life 2133.062168474088 and probabity 0.571930539993682. Day:  151.4915842878168
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 10
# 153.49306737181152 new_donor None
# A donation was done with expected life 2246.531921557314 and probabity 0.6038464668970284. Day:  153.49306737181152
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 10
# 162.19470251875512 new_recipient None
# A new recipient has arrived. Day:  162.19470251875512
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 10
# 165.6034454505395 new_recipient None
# A new recipient has arrived. Day:  165.6034454505395
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 10
# 166.57137490052855 new_recipient None
# A new recipient has arrived. Day:  166.57137490052855
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 10
# 168.72454908086837 new_recipient None
# A new recipient has arrived. Day:  168.72454908086837
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 10
# 171.05728716746057 leave_list 7502
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 11
# 172.0412123305929 leave_list 12244
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 12
# 174.7588223246072 new_recipient None
# A new recipient has arrived. Day:  174.7588223246072
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 12
# 177.26179166438448 new_recipient None
# A new recipient has arrived. Day:  177.26179166438448
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 12
# 179.26476018152593 new_donor None
# A donation was done with expected life 1943.0705241633789 and probabity 0.5156697796351563. Day:  179.26476018152593
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 12
# 180.2392897681887 leave_list 5163
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 13
# 180.48012369633176 leave_list 16500
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 14
# 182.4462249285214 new_donor None
# A donation was done with expected life 1723.6196620146493 and probabity 0.4460546731921296. Day:  182.4462249285214
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 14
# 183.20427453547205 new_recipient None
# A new recipient has arrived. Day:  183.20427453547205
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 14
# 186.75677491350936 new_donor None
# A donation was done with expected life 2242.0456067087293 and probabity 0.6026075806105987. Day:  186.75677491350936
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 14
# 191.1369042215527 new_recipient None
# A new recipient has arrived. Day:  191.1369042215527
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 14
# 195.65302018065682 new_recipient None
# A new recipient has arrived. Day:  195.65302018065682
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 14
# 197.39867527077539 leave_list 4153
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 15
# 200.44700268498474 new_recipient None
# A new recipient has arrived. Day:  200.44700268498474
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 15
# 201.80329884324138 new_recipient None
# A new recipient has arrived. Day:  201.80329884324138
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 15
# 204.06591315465224 new_recipient None
# A new recipient has arrived. Day:  204.06591315465224
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 15
# 204.6530925432232 new_recipient None
# A new recipient has arrived. Day:  204.6530925432232
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 15
# 204.81229874449718 new_recipient None
# A new recipient has arrived. Day:  204.81229874449718
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 15
# 205.82042037367168 new_recipient None
# A new recipient has arrived. Day:  205.82042037367168
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 15
# 208.28822904553175 new_recipient None
# A new recipient has arrived. Day:  208.28822904553175
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 15
# 214.18936990367249 new_donor None
# A donation was done with expected life 1627.9804427549689 and probabity 0.41413359004745165. Day:  214.18936990367249
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 15
# 215.77209365882925 new_recipient None
# A new recipient has arrived. Day:  215.77209365882925
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 15
# 216.85040447898638 leave_list 3318
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 16
# 219.2025281601261 new_donor None
# A donation was done with expected life 1652.457364917803 and probabity 0.42239360983292423. Day:  219.2025281601261
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 16
# 220.10739051048725 new_recipient None
# A new recipient has arrived. Day:  220.10739051048725
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 16
# 220.56536420980518 new_recipient None
# A new recipient has arrived. Day:  220.56536420980518
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 16
# 224.15993155074455 new_donor None
# A donation was done with expected life 2936.7449122903977 and probabity 0.7745715502148321. Day:  224.15993155074455
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 16
# 226.29839843067776 new_donor None
# A donation was done with expected life 859.6002368846331 and probabity 0.1364131823395709. Day:  226.29839843067776
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 16
# 229.4155231289365 new_donor None
# A donation was done with expected life 1575.9744262013385 and probabity 0.39638068332724385. Day:  229.4155231289365
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 16
# 234.7439183824221 new_donor None
# A donation was done with expected life 2212.171244782433 and probabity 0.59431012188425. Day:  234.7439183824221
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 16
# 235.01480905143754 new_recipient None
# A new recipient has arrived. Day:  235.01480905143754
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 16
# 235.14777527989023 new_recipient None
# A new recipient has arrived. Day:  235.14777527989023
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 16
# 246.5915984331433 new_recipient None
# A new recipient has arrived. Day:  246.5915984331433
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 16
# 246.63360562729636 leave_list 21848
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 17
# 247.92977960389766 new_donor None
# A donation was done with expected life 2060.1198778389034 and probabity 0.5507581579537523. Day:  247.92977960389766
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 17
# 252.3428697418576 new_recipient None
# A new recipient has arrived. Day:  252.3428697418576
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 17
# 252.6693579230989 new_donor None
# A donation was done with expected life 2051.226397102216 and probabity 0.5481407229645524. Day:  252.6693579230989
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 17
# 253.18047786710449 new_recipient None
# A new recipient has arrived. Day:  253.18047786710449
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 17
# 257.7852838503632 new_donor None
# A donation was done with expected life 1471.4837548381697 and probabity 0.35990843017396806. Day:  257.7852838503632
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 17
# 258.82839937075556 leave_list 2594
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 18
# 260.3337453109273 new_recipient None
# A new recipient has arrived. Day:  260.3337453109273
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 18
# 266.0838145954791 new_donor None
# A donation was done with expected life 1800.9711585833702 and probabity 0.4711702983272927. Day:  266.0838145954791
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 18
# 266.5374207417133 new_donor None
# A donation was done with expected life 1893.366272089265 and probabity 0.5003445709662622. Day:  266.5374207417133
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 18
# 266.59211163734847 new_donor None
# A donation was done with expected life 1656.1337067498478 and probabity 0.42362889427736783. Day:  266.59211163734847
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 18
# 266.6507965324766 new_donor None
# A donation was done with expected life 1562.5200368194808 and probabity 0.39174363407542073. Day:  266.6507965324766
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 18
# 267.0809763325453 new_recipient None
# A new recipient has arrived. Day:  267.0809763325453
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 18
# 267.1034265071616 new_recipient None
# A new recipient has arrived. Day:  267.1034265071616
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 18
# 269.29352814587133 new_recipient None
# A new recipient has arrived. Day:  269.29352814587133
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 18
# 270.0712272774187 new_donor None
# A donation was done with expected life 1596.7652655782902 and probabity 0.40351070191594623. Day:  270.0712272774187
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 18
# 271.6933515562021 new_recipient None
# A new recipient has arrived. Day:  271.6933515562021
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 18
# 273.8593882814144 new_recipient None
# A new recipient has arrived. Day:  273.8593882814144
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 18
# 275.60767062678093 leave_list 21553
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 19
# 277.7789350035988 new_recipient None
# A new recipient has arrived. Day:  277.7789350035988
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 19
# 277.996421684473 new_recipient None
# A new recipient has arrived. Day:  277.996421684473
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 19
# 288.1172069458089 new_recipient None
# A new recipient has arrived. Day:  288.1172069458089
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 19
# 288.8583032362455 new_recipient None
# A new recipient has arrived. Day:  288.8583032362455
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 19
# 289.10297025011613 new_recipient None
# A new recipient has arrived. Day:  289.10297025011613
# Number of matches: 0, recipients in wait list: 312,average time in waitlist INF, patients which leave the list 19
# 289.4530312442675 new_donor None
# A donation was done with expected life 2002.5035563975048 and probabity 0.533660169324451. Day:  289.4530312442675
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 19
# 291.3044582171525 new_donor None
# A donation was done with expected life 2426.2083359504613 and probabity 0.651975021014776. Day:  291.3044582171525
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 19
# 295.8855315550492 leave_list 20014
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 20
# 300.09089458978997 leave_list 15882
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 21
# 303.0103278186697 leave_list 8901
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 22
# 308.3624094508335 new_recipient None
# A new recipient has arrived. Day:  308.3624094508335
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 22
# 309.3925770770156 leave_list 19162
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 23
# 310.4991789899701 new_recipient None
# A new recipient has arrived. Day:  310.4991789899701
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 23
# 312.0821045112439 new_donor None
# A donation was done with expected life 1458.7731493363483 and probabity 0.35540226840472683. Day:  312.0821045112439
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 23
# 312.27763291536724 new_recipient None
# A new recipient has arrived. Day:  312.27763291536724
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 23
# 313.1798132474216 new_donor None
# A donation was done with expected life 1544.4037798666884 and probabity 0.3854716661317859. Day:  313.1798132474216
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 23
# 313.8254327221287 new_donor None
# A donation was done with expected life 1574.4356554004364 and probabity 0.39585125739381266. Day:  313.8254327221287
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 23
# 314.2724956464058 new_donor None
# A donation was done with expected life 1446.566852347246 and probabity 0.3510614187301147. Day:  314.2724956464058
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 23
# 319.2108548645687 leave_list 16121
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 24
# 322.7470929186437 leave_list 4970
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 25
# 327.7493186725804 new_recipient None
# A new recipient has arrived. Day:  327.7493186725804
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 25
# 333.5034645779904 new_donor None
# A donation was done with expected life 2540.7643957424807 and probabity 0.6812148430748562. Day:  333.5034645779904
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 25
# 333.61887752145014 leave_list 20581
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 26
# 335.6920649710416 new_recipient None
# A new recipient has arrived. Day:  335.6920649710416
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 26
# 337.50583263466854 new_donor None
# A donation was done with expected life 1434.0847546627917 and probabity 0.3466090883444681. Day:  337.50583263466854
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 26
# 339.89749797418006 new_donor None
# A donation was done with expected life 1949.8588039199583 and probabity 0.517742935233266. Day:  339.89749797418006
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 26
# 345.7867389291804 new_recipient None
# A new recipient has arrived. Day:  345.7867389291804
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 26
# 347.04146264379654 new_recipient None
# A new recipient has arrived. Day:  347.04146264379654
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 26
# 348.2441341213771 new_recipient None
# A new recipient has arrived. Day:  348.2441341213771
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 26
# 348.3073886088572 new_recipient None
# A new recipient has arrived. Day:  348.3073886088572
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 26
# 348.9558670149393 new_recipient None
# A new recipient has arrived. Day:  348.9558670149393
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 26
# 350.15564728542705 new_recipient None
# A new recipient has arrived. Day:  350.15564728542705
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 26
# 351.3887460803011 new_recipient None
# A new recipient has arrived. Day:  351.3887460803011
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 26
# 351.81529347255133 new_recipient None
# A new recipient has arrived. Day:  351.81529347255133
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 26
# 356.59541875988253 new_recipient None
# A new recipient has arrived. Day:  356.59541875988253
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 26
# 356.7226246461152 leave_list 2817
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 27
# 357.3231360454284 leave_list 21003
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 28
# 357.6716653587268 leave_list 880
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 29
# 358.42783350275846 new_recipient None
# A new recipient has arrived. Day:  358.42783350275846
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 29
# 358.5285591805423 new_recipient None
# A new recipient has arrived. Day:  358.5285591805423
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 29
# 358.9754375468719 new_recipient None
# A new recipient has arrived. Day:  358.9754375468719
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 29
# 359.1226628870832 new_recipient None
# A new recipient has arrived. Day:  359.1226628870832
# Number of matches: 0, recipients in wait list: 311,average time in waitlist INF, patients which leave the list 29
# 360.7303910569534 new_donor None
# A donation was done with expected life 1532.7230706449602 and probabity 0.3814107497150551. Day:  360.7303910569534
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 29
# 361.7371808892358 new_donor None
# A donation was done with expected life 1994.7054107327185 and probabity 0.5313202512913466. Day:  361.7371808892358
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 29
# 364.9620144686203 new_recipient None
# A new recipient has arrived. Day:  364.9620144686203
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 29
# 369.46725828738147 leave_list 1090
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 30
# 370.8504014415669 leave_list 13771
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 31
# 372.5204997379822 leave_list 12295
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 32
# 377.75704152235477 leave_list 12435
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 33
# 384.2585254280146 leave_list 18962
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 34
# 392.6120810433377 new_recipient None
# A new recipient has arrived. Day:  392.6120810433377
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 34
# 392.88201957645396 new_donor None
# A donation was done with expected life 1373.0553238155246 and probabity 0.3246545517438773. Day:  392.88201957645396
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 34
# 394.1332981544177 new_donor None
# A donation was done with expected life 1859.5708815471946 and probabity 0.4897774547963362. Day:  394.1332981544177
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 34
# 396.01138342701796 leave_list 5163
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 35
# 399.4463455769416 leave_list 13393
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 36
# 405.27083978283895 leave_list 22119
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 37
# 405.60223542677136 leave_list 5691
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 38
# 409.24569486915954 leave_list 7395
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 39
# 411.9958469365262 leave_list 13378
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 40
# 418.71957978005645 new_donor None
# A donation was done with expected life 2346.828756534681 and probabity 0.6310645335184255. Day:  418.71957978005645
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 40
# 422.06976865198743 new_recipient None
# A new recipient has arrived. Day:  422.06976865198743
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 40
# 427.7191038417611 new_donor None
# A donation was done with expected life 1856.4807742352448 and probabity 0.48880527257769874. Day:  427.7191038417611
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 40
# 429.0678167124243 leave_list 2948
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 41
# 430.8104041658343 leave_list 19320
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 42
# 437.0746001251193 new_recipient None
# A new recipient has arrived. Day:  437.0746001251193
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 42
# 441.35259111358107 new_donor None
# A donation was done with expected life 1465.6859545626555 and probabity 0.35785478692961875. Day:  441.35259111358107
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 42
# 441.3969033902644 leave_list 9478
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 43
# 444.0070461585043 new_recipient None
# A new recipient has arrived. Day:  444.0070461585043
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 43
# 445.5221755623892 new_recipient None
# A new recipient has arrived. Day:  445.5221755623892
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 43
# 446.8434234600069 new_recipient None
# A new recipient has arrived. Day:  446.8434234600069
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 43
# 448.8540897756846 new_recipient None
# A new recipient has arrived. Day:  448.8540897756846
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 43
# 450.28153780991806 leave_list 4833
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 44
# 453.72416203623925 new_recipient None
# A new recipient has arrived. Day:  453.72416203623925
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 44
# 455.36654973343286 new_recipient None
# A new recipient has arrived. Day:  455.36654973343286
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 44
# 455.8035413814024 new_recipient None
# A new recipient has arrived. Day:  455.8035413814024
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 44
# 459.0863262589474 new_recipient None
# A new recipient has arrived. Day:  459.0863262589474
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 44
# 459.4527200899193 new_recipient None
# A new recipient has arrived. Day:  459.4527200899193
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 44
# 459.70911600442577 new_donor None
# A donation was done with expected life 2183.2370831677285 and probabity 0.5861939640546675. Day:  459.70911600442577
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 44
# 464.10238759757095 new_recipient None
# A new recipient has arrived. Day:  464.10238759757095
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 44
# 465.58695169406656 new_recipient None
# A new recipient has arrived. Day:  465.58695169406656
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 44
# 465.9498781269712 new_donor None
# A donation was done with expected life 2441.148626448627 and probabity 0.6558502318837477. Day:  465.9498781269712
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 44
# 468.3216797125198 new_recipient None
# A new recipient has arrived. Day:  468.3216797125198
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 44
# 469.1846402016715 new_recipient None
# A new recipient has arrived. Day:  469.1846402016715
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 44
# 473.99341590719445 new_recipient None
# A new recipient has arrived. Day:  473.99341590719445
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 44
# 474.44011313776565 new_donor None
# A donation was done with expected life 1837.0960568007158 and probabity 0.48268374595918245. Day:  474.44011313776565
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 44
# 479.38287495229986 new_recipient None
# A new recipient has arrived. Day:  479.38287495229986
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 44
# 483.84847372549694 new_recipient None
# A new recipient has arrived. Day:  483.84847372549694
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 44
# 487.737993203196 new_recipient None
# A new recipient has arrived. Day:  487.737993203196
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 44
# 487.9999460645946 new_donor None
# A donation was done with expected life 1110.8456235063766 and probabity 0.22788947137076607. Day:  487.9999460645946
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 44
# 488.6742832603067 new_donor None
# A donation was done with expected life 1562.5321004135303 and probabity 0.39174779982054325. Day:  488.6742832603067
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 44
# 488.8089619490005 new_donor None
# A donation was done with expected life 2055.3537101107927 and probabity 0.5493564119448665. Day:  488.8089619490005
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 44
# 488.87580268505445 new_donor None
# A donation was done with expected life 1594.6880347217998 and probabity 0.4028002885671567. Day:  488.87580268505445
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 44
# 488.97089697197 new_recipient None
# A new recipient has arrived. Day:  488.97089697197
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 44
# 490.1202727024591 new_recipient None
# A new recipient has arrived. Day:  490.1202727024591
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 44
# 490.8444896286157 new_recipient None
# A new recipient has arrived. Day:  490.8444896286157
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 44
# 494.3736983828402 leave_list 2817
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 45
# 497.7136690482724 leave_list 21702
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 46
# 501.2780095983028 new_recipient None
# A new recipient has arrived. Day:  501.2780095983028
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 46
# 501.53277147919727 new_recipient None
# A new recipient has arrived. Day:  501.53277147919727
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 46
# 503.47448228351124 new_donor None
# A donation was done with expected life 1761.3648416063274 and probabity 0.4583891453200131. Day:  503.47448228351124
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 46
# 510.39178197665757 new_recipient None
# A new recipient has arrived. Day:  510.39178197665757
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 46
# 510.62964706362584 leave_list 8090
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 47
# 514.2041284408826 new_recipient None
# A new recipient has arrived. Day:  514.2041284408826
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 47
# 519.7092956089732 new_donor None
# A donation was done with expected life 1882.6889723218262 and probabity 0.49701891227451156. Day:  519.7092956089732
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 47
# 519.926858525906 new_recipient None
# A new recipient has arrived. Day:  519.926858525906
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 47
# 521.9930285944448 leave_list 9072
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 48
# 525.1660112141519 new_recipient None
# ...
# 10781.930927971767 new_recipient None
# A new recipient has arrived. Day:  10781.930927971767
# Number of matches: 1058, recipients in wait list: 259,average time in waitlist 1540.4548468926657, patients which leave the list 835
# 10783.315556466556 new_recipient None
# A new recipient has arrived. Day:  10783.315556466556
# Number of matches: 1058, recipients in wait list: 260,average time in waitlist 1540.4548468926657, patients which leave the list 835
# 10784.63898504812 leave_list 13300
# ----------------------- One patient left the waitlist. Day:  10784.63898504812 13300
# Number of matches: 1058, recipients in wait list: 259,average time in waitlist 1540.4548468926657, patients which leave the list 836
# 10787.882760314755 new_donor None
# A donation was done with expected life 1782.1732580160754 and probabity 0.4651247561318813. Day:  10787.882760314755
# Number of matches: 1059, recipients in wait list: 258,average time in waitlist 1540.2786689522582, patients which leave the list 836
# 10788.908380558982 new_donor None
# A donation was done with expected life 1690.7487023368096 and probabity 0.4351910053509797. Day:  10788.908380558982
# Number of matches: 1060, recipients in wait list: 257,average time in waitlist 1540.1625648026095, patients which leave the list 836
# 10790.81878781498 new_recipient None
# A new recipient has arrived. Day:  10790.81878781498
# Number of matches: 1060, recipients in wait list: 258,average time in waitlist 1540.1625648026095, patients which leave the list 836
# 10793.43510748649 new_recipient None
# A new recipient has arrived. Day:  10793.43510748649
# Number of matches: 1060, recipients in wait list: 259,average time in waitlist 1540.1625648026095, patients which leave the list 836
# 10793.62123730527 new_recipient None
# A new recipient has arrived. Day:  10793.62123730527
# Number of matches: 1060, recipients in wait list: 260,average time in waitlist 1540.1625648026095, patients which leave the list 836
# 10794.602067470449 new_donor None
# A donation was done with expected life 2226.745502192425 and probabity 0.5983684470016978. Day:  10794.602067470449
# Number of matches: 1061, recipients in wait list: 259,average time in waitlist 1539.9712955393118, patients which leave the list 836
# 10795.279618813967 new_recipient None
# A new recipient has arrived. Day:  10795.279618813967
# Number of matches: 1061, recipients in wait list: 260,average time in waitlist 1539.9712955393118, patients which leave the list 836
# 10797.919819767303 leave_list 8733
# ----------------------- One patient left the waitlist. Day:  10797.919819767303 8733
# Number of matches: 1061, recipients in wait list: 259,average time in waitlist 1539.9712955393118, patients which leave the list 837
# 10805.41157392792 new_donor None
# A donation was done with expected life 1297.1832764451033 and probabity 0.29697778569754135. Day:  10805.41157392792
# Number of matches: 1062, recipients in wait list: 258,average time in waitlist 1539.7882397044277, patients which leave the list 837
# 10807.621720917587 new_donor None
# A donation was done with expected life 1798.1027366307571 and probabity 0.4702502027853654. Day:  10807.621720917587
# Number of matches: 1063, recipients in wait list: 257,average time in waitlist 1539.6814323270123, patients which leave the list 837
# 10808.400580106329 new_recipient None
# A new recipient has arrived. Day:  10808.400580106329
# Number of matches: 1063, recipients in wait list: 258,average time in waitlist 1539.6814323270123, patients which leave the list 837
# 10809.284674777946 new_recipient None
# A new recipient has arrived. Day:  10809.284674777946
# Number of matches: 1063, recipients in wait list: 259,average time in waitlist 1539.6814323270123, patients which leave the list 837
# 10811.915354501645 new_donor None
# A donation was done with expected life 1446.5810595474134 and probabity 0.3510664787294454. Day:  10811.915354501645
# Number of matches: 1064, recipients in wait list: 258,average time in waitlist 1539.478191322222, patients which leave the list 837
# 10816.382324608583 new_recipient None
# A new recipient has arrived. Day:  10816.382324608583
# Number of matches: 1064, recipients in wait list: 259,average time in waitlist 1539.478191322222, patients which leave the list 837
# 10819.343324916936 new_recipient None
# A new recipient has arrived. Day:  10819.343324916936
# Number of matches: 1064, recipients in wait list: 260,average time in waitlist 1539.478191322222, patients which leave the list 837
# 10819.627956068156 leave_list 1137
# ----------------------- One patient left the waitlist. Day:  10819.627956068156 1137
# Number of matches: 1064, recipients in wait list: 259,average time in waitlist 1539.478191322222, patients which leave the list 838
# 10827.607843541937 new_donor None
# A donation was done with expected life 1917.9687880021374 and probabity 0.5079622730855189. Day:  10827.607843541937
# Number of matches: 1065, recipients in wait list: 258,average time in waitlist 1539.372348426998, patients which leave the list 838
# 10829.514279584713 new_donor None
# A donation was done with expected life 1829.4146239282913 and probabity 0.48024708522886267. Day:  10829.514279584713
# Number of matches: 1066, recipients in wait list: 257,average time in waitlist 1539.1808698814166, patients which leave the list 838
# 10830.18481849652 new_donor None
# A donation was done with expected life 1456.7378964025845 and probabity 0.3546793946505714. Day:  10830.18481849652
# Number of matches: 1067, recipients in wait list: 256,average time in waitlist 1539.0770006870819, patients which leave the list 838
# 10834.029247844064 new_recipient None
# A new recipient has arrived. Day:  10834.029247844064
# Number of matches: 1067, recipients in wait list: 257,average time in waitlist 1539.0770006870819, patients which leave the list 838
# 10839.938518622306 leave_list 20097
# ----------------------- One patient left the waitlist. Day:  10839.938518622306 20097
# Number of matches: 1067, recipients in wait list: 256,average time in waitlist 1539.0770006870819, patients which leave the list 839
# 10841.663891132719 leave_list 862
# ----------------------- One patient left the waitlist. Day:  10841.663891132719 862
# Number of matches: 1067, recipients in wait list: 255,average time in waitlist 1539.0770006870819, patients which leave the list 840
# 10852.231344078726 new_donor None
# A donation was done with expected life 2025.2313687481446 and probabity 0.5404447147088549. Day:  10852.231344078726
# Number of matches: 1068, recipients in wait list: 254,average time in waitlist 1538.8833104825317, patients which leave the list 840
# 10854.458165397615 leave_list 15639
# ----------------------- One patient left the waitlist. Day:  10854.458165397615 15639
# Number of matches: 1068, recipients in wait list: 253,average time in waitlist 1538.8833104825317, patients which leave the list 841
# 10859.576759291855 new_recipient None
# A new recipient has arrived. Day:  10859.576759291855
# Number of matches: 1068, recipients in wait list: 254,average time in waitlist 1538.8833104825317, patients which leave the list 841
# 10862.340635677481 new_recipient None
# A new recipient has arrived. Day:  10862.340635677481
# Number of matches: 1068, recipients in wait list: 255,average time in waitlist 1538.8833104825317, patients which leave the list 841
# 10866.785811208834 new_donor None
# A donation was done with expected life 1327.4806158872382 and probabity 0.3080755602309875. Day:  10866.785811208834
# Number of matches: 1069, recipients in wait list: 254,average time in waitlist 1538.8108142210908, patients which leave the list 841
# 10866.840923258906 new_recipient None
# A new recipient has arrived. Day:  10866.840923258906
# Number of matches: 1069, recipients in wait list: 255,average time in waitlist 1538.8108142210908, patients which leave the list 841
# 10874.002582475801 leave_list 10108
# ----------------------- One patient left the waitlist. Day:  10874.002582475801 10108
# Number of matches: 1069, recipients in wait list: 254,average time in waitlist 1538.8108142210908, patients which leave the list 842
# 10883.467069275019 new_donor None
# A donation was done with expected life 1691.1913401934262 and probabity 0.43533804654781233. Day:  10883.467069275019
# Number of matches: 1070, recipients in wait list: 253,average time in waitlist 1538.746144238651, patients which leave the list 842
# 10883.95078896929 new_recipient None
# A new recipient has arrived. Day:  10883.95078896929
# Number of matches: 1070, recipients in wait list: 254,average time in waitlist 1538.746144238651, patients which leave the list 842
# 10885.179780000866 leave_list 9327
# ----------------------- One patient left the waitlist. Day:  10885.179780000866 9327
# Number of matches: 1070, recipients in wait list: 253,average time in waitlist 1538.746144238651, patients which leave the list 843
# 10887.508576332026 new_donor None
# A donation was done with expected life 1486.4895831220583 and probabity 0.3652095244505249. Day:  10887.508576332026
# Number of matches: 1071, recipients in wait list: 252,average time in waitlist 1538.66871915933, patients which leave the list 843
# 10887.50991235914 new_recipient None
# A new recipient has arrived. Day:  10887.50991235914
# Number of matches: 1071, recipients in wait list: 253,average time in waitlist 1538.66871915933, patients which leave the list 843
# 10890.658784895759 new_donor None
# A donation was done with expected life 1445.4783991757129 and probabity 0.3506737059194803. Day:  10890.658784895759
# Number of matches: 1072, recipients in wait list: 252,average time in waitlist 1538.506517049205, patients which leave the list 843
# 10892.933313463933 new_recipient None
# A new recipient has arrived. Day:  10892.933313463933
# Number of matches: 1072, recipients in wait list: 253,average time in waitlist 1538.506517049205, patients which leave the list 843
# 10896.350433413074 leave_list 6730
# ----------------------- One patient left the waitlist. Day:  10896.350433413074 6730
# Number of matches: 1072, recipients in wait list: 252,average time in waitlist 1538.506517049205, patients which leave the list 844
# 10898.28727260009 leave_list 9252
# ----------------------- One patient left the waitlist. Day:  10898.28727260009 9252
# Number of matches: 1072, recipients in wait list: 251,average time in waitlist 1538.506517049205, patients which leave the list 845
# 10902.183019560509 new_donor None
# A donation was done with expected life 2240.539607403048 and probabity 0.6021912843720274. Day:  10902.183019560509
# Number of matches: 1073, recipients in wait list: 250,average time in waitlist 1538.3458074559699, patients which leave the list 845
# 10905.129261349583 new_donor None
# A donation was done with expected life 2070.145818336477 and probabity 0.5536994340485368. Day:  10905.129261349583
# Number of matches: 1074, recipients in wait list: 249,average time in waitlist 1538.2753038740304, patients which leave the list 845
# 10905.703885163315 new_recipient None
# A new recipient has arrived. Day:  10905.703885163315
# Number of matches: 1074, recipients in wait list: 250,average time in waitlist 1538.2753038740304, patients which leave the list 845
# 10907.677821457155 new_recipient None
# A new recipient has arrived. Day:  10907.677821457155
# Number of matches: 1074, recipients in wait list: 251,average time in waitlist 1538.2753038740304, patients which leave the list 845
# 10909.997689849086 new_recipient None
# A new recipient has arrived. Day:  10909.997689849086
# Number of matches: 1074, recipients in wait list: 252,average time in waitlist 1538.2753038740304, patients which leave the list 845
# 10912.65944779409 new_recipient None
# A new recipient has arrived. Day:  10912.65944779409
# Number of matches: 1074, recipients in wait list: 253,average time in waitlist 1538.2753038740304, patients which leave the list 845
# 10914.39309426898 new_donor None
# A donation was done with expected life 2402.2791034632455 and probabity 0.6457287435520099. Day:  10914.39309426898
# Number of matches: 1075, recipients in wait list: 252,average time in waitlist 1538.1260244143039, patients which leave the list 845
# 10917.578530462946 new_donor None
# A donation was done with expected life 1823.9542952102554 and probabity 0.47851121388084966. Day:  10917.578530462946
# Number of matches: 1076, recipients in wait list: 251,average time in waitlist 1537.9713870433136, patients which leave the list 845
# 10918.419525261508 leave_list 11225
# ----------------------- One patient left the waitlist. Day:  10918.419525261508 11225
# Number of matches: 1076, recipients in wait list: 250,average time in waitlist 1537.9713870433136, patients which leave the list 846
# 10919.538671052893 new_donor None
# A donation was done with expected life 2525.9472959948434 and probabity 0.6774933302029899. Day:  10919.538671052893
# Number of matches: 1077, recipients in wait list: 249,average time in waitlist 1537.7962853748277, patients which leave the list 846
# 10921.570485954964 new_donor None
# A donation was done with expected life 1236.9840347199602 and probabity 0.27477730876616674. Day:  10921.570485954964
# Number of matches: 1078, recipients in wait list: 248,average time in waitlist 1537.7265127729179, patients which leave the list 846
# 10924.561467148973 new_recipient None
# A new recipient has arrived. Day:  10924.561467148973
# Number of matches: 1078, recipients in wait list: 249,average time in waitlist 1537.7265127729179, patients which leave the list 846
# 10928.414146705929 new_recipient None
# A new recipient has arrived. Day:  10928.414146705929
# Number of matches: 1078, recipients in wait list: 250,average time in waitlist 1537.7265127729179, patients which leave the list 846
# 10928.483671142561 new_recipient None
# A new recipient has arrived. Day:  10928.483671142561
# Number of matches: 1078, recipients in wait list: 251,average time in waitlist 1537.7265127729179, patients which leave the list 846
# 10928.950368545586 new_donor None
# A donation was done with expected life 1106.954437032913 and probabity 0.22644143474113387. Day:  10928.950368545586
# Number of matches: 1079, recipients in wait list: 250,average time in waitlist 1537.6558538300924, patients which leave the list 846
# 10931.462734883824 new_recipient None
# A new recipient has arrived. Day:  10931.462734883824
# Number of matches: 1079, recipients in wait list: 251,average time in waitlist 1537.6558538300924, patients which leave the list 846
# 10931.63705102258 leave_list 132
# ----------------------- One patient left the waitlist. Day:  10931.63705102258 132
# Number of matches: 1079, recipients in wait list: 250,average time in waitlist 1537.6558538300924, patients which leave the list 847
# 10933.091768884284 new_recipient None
# A new recipient has arrived. Day:  10933.091768884284
# Number of matches: 1079, recipients in wait list: 251,average time in waitlist 1537.6558538300924, patients which leave the list 847
# 10935.102450975955 new_donor None
# A donation was done with expected life 1419.6873322855424 and probabity 0.3414570949848792. Day:  10935.102450975955
# Number of matches: 1080, recipients in wait list: 250,average time in waitlist 1537.4708719598905, patients which leave the list 847
# 10935.221314531098 new_donor None
# A donation was done with expected life 1709.6415746236614 and probabity 0.44144884203795126. Day:  10935.221314531098
# Number of matches: 1081, recipients in wait list: 249,average time in waitlist 1537.2861780612043, patients which leave the list 847
# 10949.250740785796 new_donor None
# A donation was done with expected life 2373.1103183160994 and probabity 0.6380482339170992. Day:  10949.250740785796
# Number of matches: 1082, recipients in wait list: 248,average time in waitlist 1537.2172142979693, patients which leave the list 847
# 10952.283402815732 new_donor None
# A donation was done with expected life 1358.7452801531297 and probabity 0.31946477325852174. Day:  10952.283402815732
# Number of matches: 1083, recipients in wait list: 247,average time in waitlist 1537.0470345353235, patients which leave the list 847
# ([1537.0470345353235], [1083])

# %%
df['ethcat'] = df['ethcat'].replace(ethcat_mapping)

# %%
df_waiting_time = ((df.groupby(by=['replicate', 'ethcat'])
                   .agg(
                       waiting_time=('waiting_time', 'mean'), 
                       count=('waiting_time', 'size'), 
                       mean_survival_time=('mean_survival_time', 'mean'))
                   .reset_index())
)#.to_csv('simulation_results.csv')
df_waiting_time = df_waiting_time[['ethcat', 'waiting_time', 'count', 'mean_survival_time']].groupby('ethcat').agg(['mean', 'std'])
df_waiting_time.columns = [f"{col[0]}_{col[1]}" for col in df_waiting_time.columns] 
df_waiting_time['prop_simu'] = df_waiting_time['count_mean'] / df_waiting_time['count_mean'].sum()
df_waiting_time = df_waiting_time.merge(real_ethcat_df, on='ethcat').round(3)
df_waiting_time.columns = ['ethcat', 'wt_mean', 'wt_std', 'count_mean', 'count_std', 'st_mean', 'st_std', 'prop_simu', 'sample_proportion']
df_waiting_time
# Out:
#                                               ethcat   wt_mean  wt_std  \
# 0               Amer Ind/Alaska Native, Non-Hispanic  1425.422     NaN
# 1                                Asian, Non-Hispanic  1581.198     NaN
# 2                                Black, Non-Hispanic  1544.790     NaN
# 3                                    Hispanic/Latino  1501.808     NaN
# 4                          Multiracial, Non-Hispanic  1753.507     NaN
# 5  Native Hawaiian/Other Pacific Islander, Non-Hi...  1544.551     NaN
# 6                                White, Non-Hispanic  1538.854     NaN
#
#    count_mean  count_std   st_mean  st_std  prop_simu  sample_proportion
# 0         8.0        NaN  1839.885     NaN      0.007              0.014
# 1        57.0        NaN  1831.227     NaN      0.053              0.053
# 2       328.0        NaN  1972.104     NaN      0.303              0.325
# 3       193.0        NaN  1857.647     NaN      0.178              0.160
# 4         8.0        NaN  2112.824     NaN      0.007              0.005
# 5         4.0        NaN  1713.166     NaN      0.004              0.004
# 6       485.0        NaN  1826.700     NaN      0.448              0.439

# %%
df_gender = ((df.groupby(by=['replicate', 'gender'])
                .agg(
                    waiting_time=('waiting_time', 'mean'), 
                    count=('waiting_time', 'size'),
                    mean_survival_time=('mean_survival_time', 'mean'))
                .reset_index())
)#.to_csv('simulation_results.csv')
df_gender = df_gender[['gender', 'waiting_time', 'count', 'mean_survival_time']].groupby('gender').agg(['mean', 'std'])
df_gender.columns = [f"{col[0]}_{col[1]}" for col in df_gender.columns] 
df_gender['proportion_sim'] = df_gender['count_mean'] / df_gender['count_mean'].sum()
df_gender.reset_index(inplace=True)
df_gender = df_gender.merge(real_gender_df, on = 'gender')
df_gender.columns = ['gender', 'wt_mean', 'wt_std', 'count_mean',
       'count_std', 'st_mean', 'st_std',
       'prop_sim', 'sample_proportion']
df_gender.round(3)
# Out:
#   gender   wt_mean  wt_std  count_mean  count_std   st_mean  st_std  prop_sim  \
# 0      F  1550.643     NaN       387.0        NaN  1908.919     NaN     0.357
# 1      M  1529.487     NaN       696.0        NaN  1861.248     NaN     0.643
#
#    sample_proportion
# 0              0.352
# 1              0.648

# %%
#df.to_csv('results_decision_tree.csv')

# %%
import numpy as np 

np.quantile(np.mean(np.random.exponential(scale=(1)*365, size=100)), 0.2)
# Out:
# 416.1335463280518
