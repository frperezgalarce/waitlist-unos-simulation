# %%
import pandas as pd 

df_base = pd.read_csv('data/data_to_simulate.csv', index_col=0)
df_base.dropna(inplace=True)
print(df_base.columns)
columns = ['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON', 'AGE', 'DIAB',
                'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI', 'SERUM_CREAT',
                'CREAT_TRR', 'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC','CREAT_TRRg1.5', 'SERUM_CREATg1.2',
                'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
                'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE','TX_DATE', 'PT_CODE', 'ABO', 'ABO_DON']

predictors = ['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'WGT_KG_DON_CALC',
                    'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'COD_CAD_DON', 'ETHCAT_DON', 'ABO_MAT', 
                    'HLAMIS', 'DIALYSIS_DATE', 'AGE', 'DIAB', 'DIALYSIS_DATEle0.0', 'CREAT_TRRg1.5', 'SERUM_CREATg1.2']

donor = df_base[['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 
            'HIST_HYPERTENS_DON', 'ABO_DON', 'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2']]

print(donor.columns)
donor.to_csv('data/donors.csv')

recipient = df_base[[ 'DIALYSIS_DATE', 'AGE', 'DIAB', 'ETHCAT', 'GENDER', 'ABO', 'DIALYSIS_DATEle0.0']]
recipient.to_csv('data/recipients.csv')

ethcat_mapping = {
    1: "White, Non-Hispanic",
    2: "Black, Non-Hispanic",
    4: "Hispanic/Latino",
    5: "Asian, Non-Hispanic",
    6: "Amer Ind/Alaska Native, Non-Hispanic",
    7: "Native Hawaiian/Other Pacific Islander, Non-Hispanic",
    9: "Multiracial, Non-Hispanic",
}
# Out:
# Index(['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON',
#        'AGE', 'DIAB', 'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI',
#        'SERUM_CREAT', 'ABO_MAT', 'AMIS', 'BMIS', 'DRMIS', 'CREAT_TRR',
#        'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC', 'ABO_DON',
#        'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
#        'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE', 'TX_DATE',
#        'PT_CODE', 'COMPOSITE_DEATH_DATE', 'ABO', 'T', 'Tag_date', 'DIAB_1',
#        'DIAB_998', 'HIST_DIABETES_DON_1', 'HIST_DIABETES_DON_998',
#        'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2',
#        'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype='object')
# Index(['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC',
#        'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'ABO_DON',
#        'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2'],
#       dtype='object')

# %%
real_gender_df = df_base.GENDER.value_counts(normalize=True).reset_index()
real_gender_df.columns = ['gender', 'sample_proportion']
real_gender_df
# Out:
#   gender  sample_proportion
# 0      M            0.64827
# 1      F            0.35173

# %%
real_ethcat_df = df_base.ETHCAT.value_counts(normalize=True).reset_index()
real_ethcat_df.ETHCAT = real_ethcat_df.ETHCAT.map(ethcat_mapping)
real_ethcat_df.columns = ['ethcat', 'sample_proportion']
real_ethcat_df
# Out:
#                                               ethcat  sample_proportion
# 0                                White, Non-Hispanic           0.439416
# 1                                Black, Non-Hispanic           0.325258
# 2                                    Hispanic/Latino           0.159551
# 3                                Asian, Non-Hispanic           0.053213
# 4               Amer Ind/Alaska Native, Non-Hispanic           0.013618
# 5                          Multiracial, Non-Hispanic           0.004764
# 6  Native Hawaiian/Other Pacific Islander, Non-Hi...           0.004180

# %%
recipient.ABO.unique()
# Out:
# array(['B', 'A', 'O', 'AB', 'A2', 'A1', 'A1B', 'A2B'], dtype=object)

# %%
blood_type_compatibility = {
    "A": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A1": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A2": ["A", "A1", "A2", "AB", "A1B", "A2B", "B"],
    "B":  ["B", "AB", "A1B", "A2B"],
    "AB": ["AB", "A1B", "A2B"],
    "A1B": ["A1B"],
    "A2B": ["A2B", "AB"],
    "O": ["A", "A1", "A2", "B", "AB", "A1B", "A2B", "O"]
}

# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
path = Path("C:/Users/HP/Desktop/UNOS data/codes/simulation-waitline-unos").resolve()  # Get the absolute path
os.chdir(path)
import pandas as pd
import numpy as np
import scipy as sc
import recipient as rec
import prediction as pred 
import donor as don
from event import Event

# %%
def create_list_of_events(n_events = 10000):
    events = Event(number_of_events= n_events, 
                    time_between_arrivals_recipients=4, 
                    time_between_arrivals_donor= 6) #average time in days
    events.create_events()
    return events

# %%
TARGET_TIME  = 5 * 365
SIMULATION_TIME = 365*30  
predictor = pred.SurvivalPredictionModel(model_path='models/random_forest_2511.pkl')
#9.1% leave the list
#theshold_leave_list = 0.091 
recipients_for_initialization = 300
time_before_starting_simulation = 0
released_recipients = []
# Out:
# models/random_forest_2511.pkl
# ok
# Model loaded successfully from models/random_forest_2511.pkl.

# %%
predictor.model.feature_names_in_
# Out:
# array(['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS',
#        'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'DIALYSIS_DATE', 'AGE',
#        'DIAB', 'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80',
#        'COD_CAD_DON_2', 'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype=object)

# %%
df = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
df_leaves = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
waiting_time_convergence = []
wait_list_length = []
leave_list_global = []



def run_simulation(T=10, replicates=1, verbose=False):
    waiting_time_convergence_r = []
    wait_list_length_r = []
    average_waiting_times = []
    number_of_matches_list = []
    
    for r in range(replicates):
        events = create_list_of_events(n_events = 10000)
        print('Replicate #', str(r))
        wait_list = []  # Initialize an empty waitlist for each replicate
        leave_list = []
        next_in_leave_the_list = []
        total_waiting_time = 0  # Track the total waiting time for this replicate
        num_matched_patients = 0  # Track the number of matched patients
        current_t = 0  # Start time    
    
        for i in range(recipients_for_initialization):
                new_recipient = rec.Recipient(time_before_starting_simulation) 
                new_recipient.create_recipient(i)
                wait_list.append(new_recipient)
                next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                next_in_leave_the_list = sorted(next_in_leave_the_list)
                
        while current_t < T:  
            (time_aux, _, _)  = events.list_of_events[0]
            (time2_aux, _, _) = next_in_leave_the_list[0]
            
            if time_aux + current_t < time2_aux:
                (time, event_type, counter)  = events.list_of_events.pop(0)
                ID = None
                print(time+current_t, event_type, ID)
            else: 
                (time, event_type, ID) = next_in_leave_the_list.pop(0)
                print(time, event_type, ID)
                   
            #print(time, event_type)         
            match event_type:
                case "new_donor":
                    current_t += time
                    donor = don.Donor(current_t)
                    donor.create_donor(counter)
                    
                    if len(wait_list) < 1:
                        raise('The waitlist length is 0, check the setup please')            
                    
                    survival_probs = []
                    for recipient in wait_list: 
                        if donor.blood in blood_type_compatibility[recipient.blood]: 
                            survival_probs.append(predictor.predict_survival_prob(recipient, donor, TARGET_TIME))
                        else: 
                             survival_probs.append(0)
                                    
                    arrival_times = []
                    for recipient in wait_list: 
                        if donor.blood in blood_type_compatibility[recipient.blood]:
                            arrival_times.append(recipient.arrival_time)
                        else: 
                            arrival_times.append(current_t)
                    
                    if len(survival_probs)>0: 
                        best_match_index = np.argmin(arrival_times)
                        
                        recipient_best = wait_list[best_match_index]
                        _, predicted_survival_function = predictor.predict_survival_prob(recipient_best, donor, TARGET_TIME, surv_function=True)
                        
                        mean_survival_time = sum(
                        (predicted_survival_function[0].x[i + 1] - predicted_survival_function[0].x[i]) *
                        predicted_survival_function[0].y[i]
                        for i in range(len(predicted_survival_function[0].x) - 1)
)
                        
                        best_patient = wait_list.pop(best_match_index)
                        next_leave_time = [(a, b, c) for (a, b, c) in next_in_leave_the_list if c==best_patient.ID]
                        _index = next_in_leave_the_list.index(next_leave_time[0])   
                        _ = next_in_leave_the_list.pop(_index)
                        
                        print(f'A donation was done with expected life {mean_survival_time} and probabity {survival_probs[best_match_index]}. Day: ', str(current_t))
                        waiting_time = current_t - best_patient.arrival_time
                        
                        if current_t > 8*365.25:
                            total_waiting_time += waiting_time
                            
                        best_patient.waiting_time = waiting_time
                        
                        
                        if current_t > 8*365.25:
                            df.loc[len(df)] = [r, best_patient.ethcat, best_patient.gender, best_patient.waiting_time, mean_survival_time, current_t]
                            released_recipients.append(best_patient)
                            num_matched_patients += 1
                
                case "new_recipient":            
                    current_t += time
                    new_recipient = rec.Recipient(current_t) 
                    new_recipient.create_recipient(counter)
                    wait_list.append(new_recipient)
                    next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                    next_in_leave_the_list = sorted(next_in_leave_the_list)
                    print('A new recipient has arrived. Day: ', str(current_t))
                
                case "leave_list":
                    current_t = time
                    next_leave_time = [p for p in wait_list if p.ID==ID]
                    _index = wait_list.index(next_leave_time[0])   
                    out_of_list = wait_list.pop(_index)
                    leave_list.append(out_of_list)
                    
                    if current_t > 8*365.25:
                        df_leaves.loc[len(df)] = [r, out_of_list.ethcat, out_of_list.gender, out_of_list.waiting_time, _, current_t]
                        print('----------------------- One patient left the waitlist. Day: ', str(current_t), out_of_list.ID) 
                    
                    

            if num_matched_patients>0:
                if current_t > 8*365.25:
                    average_time = total_waiting_time / num_matched_patients
                    #we collect data after 8 years
                    waiting_time_convergence_r.append([current_t, average_time])
                wait_list_length_r.append([current_t, len(wait_list)])
            else: 
                average_time = 'INF'
            if verbose:
                print(f'Number of matches: {num_matched_patients}, recipients in wait list: {len(wait_list)},'
                      f'average time in waitlist {average_time}, patients which leave the list {len(leave_list)}')        
        if num_matched_patients > 0:
            average_waiting_times.append(total_waiting_time / num_matched_patients)
            waiting_time_convergence.append(waiting_time_convergence_r)
            wait_list_length.append(wait_list_length_r)
            number_of_matches_list.append(num_matched_patients)
            leave_list_global.append(leave_list)
        else:
            average_waiting_times.append(0)
            
    return average_waiting_times, number_of_matches_list

# %%
run_simulation(T=SIMULATION_TIME, replicates=1, verbose=True)
# Out:
# Replicate # 0
# 2.73278930048392 new_donor None
# A donation was done with expected life 2556.6046886301997 and probabity 0.6837296215606051. Day:  2.73278930048392
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 4.524562159484566 new_recipient None
# A new recipient has arrived. Day:  4.524562159484566
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 4.793504515852812 new_donor None
# A donation was done with expected life 2832.2597705351004 and probabity 0.7446588278015481. Day:  4.793504515852812
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 5.78256236940346 new_recipient None
# A new recipient has arrived. Day:  5.78256236940346
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 6.301117601419251 new_recipient None
# A new recipient has arrived. Day:  6.301117601419251
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 11.936321309060045 new_recipient None
# A new recipient has arrived. Day:  11.936321309060045
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 0
# 12.029077783965965 new_donor None
# A donation was done with expected life 3164.1931343324068 and probabity 0.8106640241964287. Day:  12.029077783965965
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 14.220216843098811 new_donor None
# A donation was done with expected life 2860.461390077521 and probabity 0.7419720693558485. Day:  14.220216843098811
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 0
# 15.251808532401576 new_recipient None
# A new recipient has arrived. Day:  15.251808532401576
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 0
# 19.812328377794827 leave_list 11006
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 1
# 26.68938474435656 new_recipient None
# A new recipient has arrived. Day:  26.68938474435656
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 1
# 28.450477627212226 new_recipient None
# A new recipient has arrived. Day:  28.450477627212226
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 1
# 28.76421461942988 new_donor None
# A donation was done with expected life 2976.432509109151 and probabity 0.7776581792159049. Day:  28.76421461942988
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 1
# 30.53180594171568 new_donor None
# A donation was done with expected life 2646.4190463917 and probabity 0.6812240903634617. Day:  30.53180594171568
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 1
# 31.396155392542617 leave_list 19162
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 2
# 38.06344284740266 leave_list 14368
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 3
# 49.586228191908006 leave_list 8104
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 4
# 53.31525137980424 leave_list 14368
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 5
# 64.40437018573563 leave_list 3442
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 6
# 79.35604101638943 new_donor None
# A donation was done with expected life 3223.3051105415375 and probabity 0.8246730603152208. Day:  79.35604101638943
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 6
# 79.42514703047546 new_recipient None
# A new recipient has arrived. Day:  79.42514703047546
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 6
# 82.41674439145098 new_recipient None
# A new recipient has arrived. Day:  82.41674439145098
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 6
# 83.14787841857327 new_recipient None
# A new recipient has arrived. Day:  83.14787841857327
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 6
# 83.35562233222184 new_recipient None
# A new recipient has arrived. Day:  83.35562233222184
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 6
# 90.63648576408784 new_recipient None
# A new recipient has arrived. Day:  90.63648576408784
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 6
# 91.21474092426585 new_recipient None
# A new recipient has arrived. Day:  91.21474092426585
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 6
# 91.96118084523818 new_recipient None
# A new recipient has arrived. Day:  91.96118084523818
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 6
# 93.31510768894788 new_recipient None
# A new recipient has arrived. Day:  93.31510768894788
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 6
# 94.20394990960537 new_donor None
# A donation was done with expected life 2945.065200151326 and probabity 0.7696781699882623. Day:  94.20394990960537
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 6
# 95.24428821870177 new_recipient None
# A new recipient has arrived. Day:  95.24428821870177
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 6
# 97.17538297151049 new_donor None
# A donation was done with expected life 3268.8578150492417 and probabity 0.8397480854031452. Day:  97.17538297151049
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 6
# 97.29143164461722 new_recipient None
# A new recipient has arrived. Day:  97.29143164461722
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 6
# 97.79662717104196 new_donor None
# A donation was done with expected life 3170.039942896625 and probabity 0.8118039990936979. Day:  97.79662717104196
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 6
# 98.66375112431584 new_recipient None
# A new recipient has arrived. Day:  98.66375112431584
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 6
# 100.83218315732384 new_recipient None
# A new recipient has arrived. Day:  100.83218315732384
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 6
# 106.3626889854942 new_recipient None
# A new recipient has arrived. Day:  106.3626889854942
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 6
# 112.92131445116677 new_donor None
# A donation was done with expected life 2803.716519345747 and probabity 0.7402586103747083. Day:  112.92131445116677
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 6
# 113.40902090606001 new_donor None
# A donation was done with expected life 2924.635832198916 and probabity 0.7668622922935319. Day:  113.40902090606001
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 6
# 113.83279993656234 new_donor None
# A donation was done with expected life 2791.105288089542 and probabity 0.7249901801684269. Day:  113.83279993656234
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 6
# 114.81792732317126 leave_list 945
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 7
# 122.61496703143433 new_donor None
# A donation was done with expected life 3248.893033966185 and probabity 0.8277051293565879. Day:  122.61496703143433
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 7
# 124.07728078568093 new_donor None
# A donation was done with expected life 2953.65377671468 and probabity 0.7545675003963794. Day:  124.07728078568093
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 7
# 125.3320722651828 leave_list 15882
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 8
# 126.90703225748473 new_donor None
# A donation was done with expected life 3209.1588470316124 and probabity 0.8240801485706339. Day:  126.90703225748473
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 8
# 127.42971513930831 new_recipient None
# A new recipient has arrived. Day:  127.42971513930831
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 8
# 130.99793106830057 new_recipient None
# A new recipient has arrived. Day:  130.99793106830057
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 8
# 132.26783477333106 leave_list 15399
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 9
# 137.5689172029291 new_donor None
# A donation was done with expected life 2945.816241732105 and probabity 0.775379664673691. Day:  137.5689172029291
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 9
# 137.63569197086156 new_recipient None
# A new recipient has arrived. Day:  137.63569197086156
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 9
# 138.79219603894046 new_recipient None
# A new recipient has arrived. Day:  138.79219603894046
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 9
# 140.9583720337641 new_donor None
# A donation was done with expected life 2851.8320361424267 and probabity 0.7445549988555011. Day:  140.9583720337641
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 9
# 143.53576343214743 leave_list 3318
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 10
# 146.12760605125789 new_recipient None
# A new recipient has arrived. Day:  146.12760605125789
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 10
# 150.9442461415698 new_recipient None
# A new recipient has arrived. Day:  150.9442461415698
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 10
# 152.40908544137233 new_donor None
# A donation was done with expected life 3180.3635378246545 and probabity 0.811925967731007. Day:  152.40908544137233
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 10
# 157.79323019755364 new_recipient None
# A new recipient has arrived. Day:  157.79323019755364
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 10
# 160.87573709500597 new_donor None
# A donation was done with expected life 3147.1325590921697 and probabity 0.8049570949447875. Day:  160.87573709500597
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 10
# 163.87553391198654 new_recipient None
# A new recipient has arrived. Day:  163.87553391198654
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 10
# 166.7184778366458 new_recipient None
# A new recipient has arrived. Day:  166.7184778366458
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 10
# 166.8178965544031 new_recipient None
# A new recipient has arrived. Day:  166.8178965544031
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 10
# 167.41522170487687 new_donor None
# A donation was done with expected life 2718.975184355706 and probabity 0.7062952919168229. Day:  167.41522170487687
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 10
# 171.05728716746057 leave_list 7502
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 11
# 172.0412123305929 leave_list 12244
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 12
# 179.05345639503878 new_recipient None
# A new recipient has arrived. Day:  179.05345639503878
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 12
# 179.79469285981304 new_donor None
# A donation was done with expected life 3034.53433682638 and probabity 0.7778823063685827. Day:  179.79469285981304
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 12
# 180.2392897681887 leave_list 5163
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 13
# 180.48012369633176 leave_list 16500
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 14
# 185.98752338590762 new_recipient None
# A new recipient has arrived. Day:  185.98752338590762
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 14
# 187.99806684038148 new_donor None
# A donation was done with expected life 3069.716507265212 and probabity 0.788896306046359. Day:  187.99806684038148
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 14
# 191.56193967103184 new_recipient None
# A new recipient has arrived. Day:  191.56193967103184
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 14
# 197.33364329163376 new_donor None
# A donation was done with expected life 3016.7721354446153 and probabity 0.7735252157776903. Day:  197.33364329163376
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 14
# 197.39867527077539 leave_list 4153
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 15
# 198.18761391039072 new_donor None
# A donation was done with expected life 2865.7779902623283 and probabity 0.741698536484807. Day:  198.18761391039072
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 15
# 199.24519219687505 new_donor None
# A donation was done with expected life 2562.323348413397 and probabity 0.6788050671147251. Day:  199.24519219687505
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 15
# 199.98227133931263 new_recipient None
# A new recipient has arrived. Day:  199.98227133931263
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 15
# 201.24901074666826 new_recipient None
# A new recipient has arrived. Day:  201.24901074666826
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 15
# 201.64084004089128 new_recipient None
# A new recipient has arrived. Day:  201.64084004089128
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 15
# 204.35382577922385 new_donor None
# A donation was done with expected life 2943.9593597676467 and probabity 0.7742718867948188. Day:  204.35382577922385
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 15
# 205.68295870239473 new_donor None
# A donation was done with expected life 3167.4902814118195 and probabity 0.8109636447125633. Day:  205.68295870239473
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 15
# 205.82848907626934 new_recipient None
# A new recipient has arrived. Day:  205.82848907626934
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 15
# 211.53169938574538 new_donor None
# A donation was done with expected life 2521.159764570345 and probabity 0.6760789226992159. Day:  211.53169938574538
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 15
# 212.12047641208346 new_donor None
# A donation was done with expected life 3221.307216406538 and probabity 0.827247368824773. Day:  212.12047641208346
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 15
# 217.6453397466106 new_donor None
# A donation was done with expected life 2807.5895068154737 and probabity 0.7391986322612811. Day:  217.6453397466106
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 15
# 220.31697947190557 new_recipient None
# A new recipient has arrived. Day:  220.31697947190557
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 15
# 224.42752498035406 new_recipient None
# A new recipient has arrived. Day:  224.42752498035406
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 15
# 226.13255955253592 new_recipient None
# A new recipient has arrived. Day:  226.13255955253592
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 15
# 228.27990409772218 leave_list 3442
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 16
# 230.46343768887772 new_recipient None
# A new recipient has arrived. Day:  230.46343768887772
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 16
# 232.73005042983027 new_recipient None
# A new recipient has arrived. Day:  232.73005042983027
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 16
# 234.7551043242927 new_recipient None
# A new recipient has arrived. Day:  234.7551043242927
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 16
# 236.68630412577878 new_donor None
# A donation was done with expected life 2713.4847091696765 and probabity 0.7222293968353612. Day:  236.68630412577878
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 16
# 237.13135003013468 new_recipient None
# A new recipient has arrived. Day:  237.13135003013468
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 16
# 237.51703275778675 new_recipient None
# A new recipient has arrived. Day:  237.51703275778675
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 16
# 239.89652888181186 new_recipient None
# A new recipient has arrived. Day:  239.89652888181186
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 16
# 240.25130611696025 new_donor None
# A donation was done with expected life 2907.414674468625 and probabity 0.753434341271555. Day:  240.25130611696025
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 16
# 246.63360562729636 leave_list 21848
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 17
# 255.246727130572 new_recipient None
# A new recipient has arrived. Day:  255.246727130572
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 17
# 256.087072191534 new_recipient None
# A new recipient has arrived. Day:  256.087072191534
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 17
# 258.82839937075556 leave_list 2594
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 18
# 264.0776928533977 new_recipient None
# A new recipient has arrived. Day:  264.0776928533977
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 18
# 264.7698198643196 new_donor None
# A donation was done with expected life 2532.1753402063227 and probabity 0.6766884429943985. Day:  264.7698198643196
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 18
# 266.34579082818533 new_recipient None
# A new recipient has arrived. Day:  266.34579082818533
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 18
# 269.70585042622184 new_recipient None
# A new recipient has arrived. Day:  269.70585042622184
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 18
# 269.9206405219953 new_donor None
# A donation was done with expected life 2725.701865070688 and probabity 0.7228895054292687. Day:  269.9206405219953
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 18
# 274.1723708261075 new_donor None
# A donation was done with expected life 3196.0403560723744 and probabity 0.8150737655383925. Day:  274.1723708261075
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 18
# 274.28584815584793 leave_list 1753
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 19
# 275.60767062678093 leave_list 21553
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 20
# 282.4454398578917 new_recipient None
# A new recipient has arrived. Day:  282.4454398578917
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 20
# 284.24432753039855 new_recipient None
# A new recipient has arrived. Day:  284.24432753039855
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 20
# 285.10034358583493 new_donor None
# A donation was done with expected life 2722.7417945053826 and probabity 0.7246289769247507. Day:  285.10034358583493
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 20
# 285.6923520567278 new_recipient None
# A new recipient has arrived. Day:  285.6923520567278
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 20
# 286.92625641063455 new_recipient None
# A new recipient has arrived. Day:  286.92625641063455
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 20
# 288.4947317017954 new_donor None
# A donation was done with expected life 2883.224321306825 and probabity 0.7481122625203547. Day:  288.4947317017954
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 20
# 293.9990753315627 new_donor None
# A donation was done with expected life 2714.7189529801126 and probabity 0.7231235994551107. Day:  293.9990753315627
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 20
# 295.3563461105888 new_recipient None
# A new recipient has arrived. Day:  295.3563461105888
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 20
# 295.40006236888206 new_recipient None
# A new recipient has arrived. Day:  295.40006236888206
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 20
# 295.8855315550492 leave_list 20014
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 21
# 298.6891334212311 new_donor None
# A donation was done with expected life 2958.5279131466086 and probabity 0.766131191655023. Day:  298.6891334212311
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 21
# 302.7277950893688 new_donor None
# A donation was done with expected life 3041.9480607605196 and probabity 0.7837373687261606. Day:  302.7277950893688
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 21
# 303.0103278186697 leave_list 8901
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 22
# 304.62655999702446 new_donor None
# A donation was done with expected life 2543.974379414053 and probabity 0.6784332308220427. Day:  304.62655999702446
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 22
# 305.0773896335641 new_donor None
# A donation was done with expected life 2916.696949121922 and probabity 0.7604838757559946. Day:  305.0773896335641
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 22
# 306.1605299040443 new_recipient None
# A new recipient has arrived. Day:  306.1605299040443
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 22
# 319.2108548645687 leave_list 16121
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 23
# 322.7470929186437 leave_list 4970
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 24
# 326.9729123060741 leave_list 15882
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 25
# 333.61887752145014 leave_list 20581
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 26
# 348.3039977025696 new_donor None
# A donation was done with expected life 2747.5067811031226 and probabity 0.7129138510465736. Day:  348.3039977025696
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 26
# 348.9869064137601 new_donor None
# A donation was done with expected life 2745.69865505327 and probabity 0.7124414461378922. Day:  348.9869064137601
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 26
# 352.95893105560407 new_recipient None
# A new recipient has arrived. Day:  352.95893105560407
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 26
# 353.9096808821308 new_donor None
# A donation was done with expected life 2920.6395818986307 and probabity 0.7664841184478217. Day:  353.9096808821308
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 26
# 353.92159332356556 new_recipient None
# A new recipient has arrived. Day:  353.92159332356556
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 26
# 356.7226246461152 leave_list 2817
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 27
# 357.3231360454284 leave_list 21003
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 28
# 357.6716653587268 leave_list 880
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 29
# 362.79674155701247 new_donor None
# A donation was done with expected life 2923.2387230269887 and probabity 0.7630551816199252. Day:  362.79674155701247
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 29
# 364.33442454738287 new_donor None
# A donation was done with expected life 2970.0153375826826 and probabity 0.7745506055906657. Day:  364.33442454738287
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 29
# 365.1466952965788 new_donor None
# A donation was done with expected life 2496.1808430508954 and probabity 0.6684166018641062. Day:  365.1466952965788
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 29
# 369.46725828738147 leave_list 1090
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 30
# 370.8504014415669 leave_list 13771
# Number of matches: 0, recipients in wait list: 280,average time in waitlist INF, patients which leave the list 31
# 372.5204997379822 leave_list 12295
# Number of matches: 0, recipients in wait list: 279,average time in waitlist INF, patients which leave the list 32
# 377.75704152235477 leave_list 12435
# Number of matches: 0, recipients in wait list: 278,average time in waitlist INF, patients which leave the list 33
# 383.7193727452585 new_donor None
# A donation was done with expected life 2961.938850365553 and probabity 0.7750839936438141. Day:  383.7193727452585
# Number of matches: 0, recipients in wait list: 277,average time in waitlist INF, patients which leave the list 33
# 384.2585254280146 leave_list 18962
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 34
# 385.31774871610816 leave_list 19162
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 35
# 389.43351209566407 new_donor None
# A donation was done with expected life 2800.1402034541147 and probabity 0.7325438187789558. Day:  389.43351209566407
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 35
# 391.69724471751056 new_recipient None
# A new recipient has arrived. Day:  391.69724471751056
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 35
# 392.5319619194299 new_recipient None
# A new recipient has arrived. Day:  392.5319619194299
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 35
# 392.85059876748676 new_donor None
# A donation was done with expected life 2799.155073158238 and probabity 0.7324126593339727. Day:  392.85059876748676
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 35
# 394.6023447929363 new_donor None
# A donation was done with expected life 3026.165531410702 and probabity 0.7790921804578936. Day:  394.6023447929363
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 35
# 396.36506020431233 new_recipient None
# A new recipient has arrived. Day:  396.36506020431233
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 35
# 398.5414241159183 new_recipient None
# A new recipient has arrived. Day:  398.5414241159183
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 35
# 399.4463455769416 leave_list 13393
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 36
# 401.0499553576646 new_donor None
# A donation was done with expected life 2767.139655135695 and probabity 0.7325217122078062. Day:  401.0499553576646
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 36
# 401.3825304558199 new_recipient None
# A new recipient has arrived. Day:  401.3825304558199
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 36
# 405.60223542677136 leave_list 5691
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 37
# 409.24569486915954 leave_list 7395
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 38
# 411.9958469365262 leave_list 13378
# Number of matches: 0, recipients in wait list: 272,average time in waitlist INF, patients which leave the list 39
# 420.1358186500006 leave_list 5163
# Number of matches: 0, recipients in wait list: 271,average time in waitlist INF, patients which leave the list 40
# 429.0678167124243 leave_list 2948
# Number of matches: 0, recipients in wait list: 270,average time in waitlist INF, patients which leave the list 41
# 430.8104041658343 leave_list 19320
# Number of matches: 0, recipients in wait list: 269,average time in waitlist INF, patients which leave the list 42
# 438.38700315877827 leave_list 12244
# Number of matches: 0, recipients in wait list: 268,average time in waitlist INF, patients which leave the list 43
# 441.3969033902644 leave_list 9478
# Number of matches: 0, recipients in wait list: 267,average time in waitlist INF, patients which leave the list 44
# 450.28153780991806 leave_list 4833
# Number of matches: 0, recipients in wait list: 266,average time in waitlist INF, patients which leave the list 45
# 465.2134335951249 leave_list 22119
# Number of matches: 0, recipients in wait list: 265,average time in waitlist INF, patients which leave the list 46
# 484.69869485540687 new_donor None
# A donation was done with expected life 2945.086982905227 and probabity 0.76884330623034. Day:  484.69869485540687
# Number of matches: 0, recipients in wait list: 264,average time in waitlist INF, patients which leave the list 46
# 485.3242997109711 new_recipient None
# A new recipient has arrived. Day:  485.3242997109711
# Number of matches: 0, recipients in wait list: 265,average time in waitlist INF, patients which leave the list 46
# 487.46831026888816 new_donor None
# A donation was done with expected life 2717.5321654035965 and probabity 0.6997676286752912. Day:  487.46831026888816
# Number of matches: 0, recipients in wait list: 264,average time in waitlist INF, patients which leave the list 46
# 489.5363267537563 new_recipient None
# A new recipient has arrived. Day:  489.5363267537563
# Number of matches: 0, recipients in wait list: 265,average time in waitlist INF, patients which leave the list 46
# 496.10365623982614 new_donor None
# A donation was done with expected life 2699.9431426356123 and probabity 0.7198699021925511. Day:  496.10365623982614
# Number of matches: 0, recipients in wait list: 264,average time in waitlist INF, patients which leave the list 46
# 497.7136690482724 leave_list 21702
# Number of matches: 0, recipients in wait list: 263,average time in waitlist INF, patients which leave the list 47
# 502.40920497886054 new_recipient None
# A new recipient has arrived. Day:  502.40920497886054
# Number of matches: 0, recipients in wait list: 264,average time in waitlist INF, patients which leave the list 47
# 503.6463500764401 new_recipient None
# A new recipient has arrived. Day:  503.6463500764401
# Number of matches: 0, recipients in wait list: 265,average time in waitlist INF, patients which leave the list 47
# 507.89558088974303 new_recipient None
# A new recipient has arrived. Day:  507.89558088974303
# Number of matches: 0, recipients in wait list: 266,average time in waitlist INF, patients which leave the list 47
# 510.50020409671646 new_recipient None
# A new recipient has arrived. Day:  510.50020409671646
# Number of matches: 0, recipients in wait list: 267,average time in waitlist INF, patients which leave the list 47
# 510.62964706362584 leave_list 8090
# Number of matches: 0, recipients in wait list: 266,average time in waitlist INF, patients which leave the list 48
# 511.7574993872087 new_recipient None
# A new recipient has arrived. Day:  511.7574993872087
# Number of matches: 0, recipients in wait list: 267,average time in waitlist INF, patients which leave the list 48
# 518.9443809961199 new_donor None
# A donation was done with expected life 2951.926716553617 and probabity 0.7660019806648011. Day:  518.9443809961199
# Number of matches: 0, recipients in wait list: 266,average time in waitlist INF, patients which leave the list 48
# 519.3679222949476 new_recipient None
# A new recipient has arrived. Day:  519.3679222949476
# Number of matches: 0, recipients in wait list: 267,average time in waitlist INF, patients which leave the list 48
# 521.9930285944448 leave_list 9072
# Number of matches: 0, recipients in wait list: 266,average time in waitlist INF, patients which leave the list 49
# 525.2534164656183 new_recipient None
# A new recipient has arrived. Day:  525.2534164656183
# Number of matches: 0, recipients in wait list: 267,average time in waitlist INF, patients which leave the list 49
# 525.2624586441124 new_recipient None
# A new recipient has arrived. Day:  525.2624586441124
# Number of matches: 0, recipients in wait list: 268,average time in waitlist INF, patients which leave the list 49
# 525.8501014675971 new_donor None
# A donation was done with expected life 3223.061074040738 and probabity 0.8242591029345508. Day:  525.8501014675971
# Number of matches: 0, recipients in wait list: 267,average time in waitlist INF, patients which leave the list 49
# 526.4032029347014 new_recipient None
# A new recipient has arrived. Day:  526.4032029347014
# Number of matches: 0, recipients in wait list: 268,average time in waitlist INF, patients which leave the list 49
# 528.1606657793537 new_donor None
# A donation was done with expected life 2957.5397018407557 and probabity 0.7777531173710693. Day:  528.1606657793537
# Number of matches: 0, recipients in wait list: 267,average time in waitlist INF, patients which leave the list 49
# 532.022988791853 new_recipient None
# A new recipient has arrived. Day:  532.022988791853
# Number of matches: 0, recipients in wait list: 268,average time in waitlist INF, patients which leave the list 49
# 533.8487472017247 new_donor None
# A donation was done with expected life 3001.0305730530554 and probabity 0.7801119881910589. Day:  533.8487472017247
# Number of matches: 0, recipients in wait list: 267,average time in waitlist INF, patients which leave the list 49
# 538.5655822224285 new_recipient None
# A new recipient has arrived. Day:  538.5655822224285
# Number of matches: 0, recipients in wait list: 268,average time in waitlist INF, patients which leave the list 49
# 546.376452987158 new_recipient None
# A new recipient has arrived. Day:  546.376452987158
# Number of matches: 0, recipients in wait list: 269,average time in waitlist INF, patients which leave the list 49
# 547.4605422220958 new_recipient None
# A new recipient has arrived. Day:  547.4605422220958
# Number of matches: 0, recipients in wait list: 270,average time in waitlist INF, patients which leave the list 49
# 548.8624735363327 new_recipient None
# A new recipient has arrived. Day:  548.8624735363327
# Number of matches: 0, recipients in wait list: 271,average time in waitlist INF, patients which leave the list 49
# 549.8530435022027 new_recipient None
# A new recipient has arrived. Day:  549.8530435022027
# Number of matches: 0, recipients in wait list: 272,average time in waitlist INF, patients which leave the list 49
# 552.519964670361 new_recipient None
# A new recipient has arrived. Day:  552.519964670361
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 49
# 552.6290479999382 new_recipient None
# A new recipient has arrived. Day:  552.6290479999382
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 49
# 553.5196590911106 new_donor None
# A donation was done with expected life 3076.0967809948747 and probabity 0.7921769184475355. Day:  553.5196590911106
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 49
# 554.6613913642675 new_recipient None
# A new recipient has arrived. Day:  554.6613913642675
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 49
# 556.3361663842409 new_recipient None
# A new recipient has arrived. Day:  556.3361663842409
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 49
# 557.4292792970339 leave_list 21533
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 50
# 559.4653117267163 new_donor None
# A donation was done with expected life 3174.610032975892 and probabity 0.8155024026678257. Day:  559.4653117267163
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 50
# 559.6500794791868 new_recipient None
# A new recipient has arrived. Day:  559.6500794791868
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 50
# 560.211868995713 new_recipient None
# A new recipient has arrived. Day:  560.211868995713
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 50
# 561.9210249936802 new_recipient None
# A new recipient has arrived. Day:  561.9210249936802
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 50
# 565.1188922697087 new_donor None
# A donation was done with expected life 2891.3314242442443 and probabity 0.7573413724787518. Day:  565.1188922697087
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 50
# 566.5203642783354 new_recipient None
# A new recipient has arrived. Day:  566.5203642783354
# Number of matches: 0, recipients in wait list: 276,average time in waitlist INF, patients which leave the list 50
# 569.5895164333042 leave_list 11216
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 51
# 571.8885803449825 leave_list 1681
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 52
# 577.2311058539128 new_recipient None
# A new recipient has arrived. Day:  577.2311058539128
# Number of matches: 0, recipients in wait list: 275,average time in waitlist INF, patients which leave the list 52
# 582.026893524244 new_donor None
# A donation was done with expected life 2827.56233060935 and probabity 0.7385467064122956. Day:  582.026893524244
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 52
# 583.3303304332437 leave_list 1254
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 53
# 584.2759129228774 leave_list 14720
# Number of matches: 0, recipients in wait list: 272,average time in waitlist INF, patients which leave the list 54
# 586.9010736082561 new_recipient None
# A new recipient has arrived. Day:  586.9010736082561
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 54
# 587.4561254567215 new_recipient None
# A new recipient has arrived. Day:  587.4561254567215
# Number of matches: 0, recipients in wait list: 274,average time in waitlist INF, patients which leave the list 54
# 588.8095707385953 leave_list 5514
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 55
# 590.626445726679 leave_list 9059
# Number of matches: 0, recipients in wait list: 272,average time in waitlist INF, patients which leave the list 56
# 590.915200516769 leave_list 20429
# Number of matches: 0, recipients in wait list: 271,average time in waitlist INF, patients which leave the list 57
# 592.2645248175324 leave_list 1827
# Number of matches: 0, recipients in wait list: 270,average time in waitlist INF, patients which leave the list 58
# 595.671346529989 new_recipient None
# A new recipient has arrived. Day:  595.671346529989
# Number of matches: 0, recipients in wait list: 271,average time in waitlist INF, patients which leave the list 58
# 599.1133322913267 new_recipient None
# A new recipient has arrived. Day:  599.1133322913267
# Number of matches: 0, recipients in wait list: 272,average time in waitlist INF, patients which leave the list 58
# 599.7668842066457 new_recipient None
# A new recipient has arrived. Day:  599.7668842066457
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 58
# 600.2086877457974 leave_list 11851
# Number of matches: 0, recipients in wait list: 272,average time in waitlist INF, patients which leave the list 59
# 601.8992692717184 new_recipient None
# A new recipient has arrived. Day:  601.8992692717184
# Number of matches: 0, recipients in wait list: 273,average time in waitlist INF, patients which leave the list 59
# 602.0173965274463 new_donor None
# A donation was done with expected life 2860.2134076964653 and probabity 0.7539324236906255. Day:  602.0173965274463
# Number of matches: 0, recipients in wait list: 272,average time in waitlist INF, patients which leave the list 59
# 603.042916092371 new_donor None
# A donation was done with expected life 2987.7359240843134 and probabity 0.7742853924380734. Day:  603.042916092371
# Number of matches: 0, recipients in wait list: 271,average time in waitlist INF, patients which leave the list 59
# 606.3328004860812 leave_list 13987
# Number of matches: 0, recipients in wait list: 270,average time in waitlist INF, patients which leave the list 60
# 607.0298941632337 leave_list 13932
# Number of matches: 0, recipients in wait list: 269,average time in waitlist INF, patients which leave the list 61
# 610.0728265187852 leave_list 4790
# Number of matches: 0, recipients in wait list: 268,average time in waitlist INF, patients which leave the list 62
# 611.65204972143 leave_list 8967
# Number of matches: 0, recipients in wait list: 267,average time in waitlist INF, patients which leave the list 63
# 616.0628993234142 new_donor None
# A donation was done with expected life 2936.326353945158 and probabity 0.7620668475975697. Day:  616.0628993234142
# Number of matches: 0, recipients in wait list: 266,average time in waitlist INF, patients which leave the list 63
# 618.9928231191848 new_donor None
# A donation was done with expected life 2839.164701297032 and probabity 0.7297137792723136. Day:  618.9928231191848
# Number of matches: 0, recipients in wait list: 265,average time in waitlist INF, patients which leave the list 63
# 619.1898956832906 new_donor None
# A donation was done with expected life 2982.4047005440307 and probabity 0.7800663937404664. Day:  619.1898956832906
# Number of matches: 0, recipients in wait list: 264,average time in waitlist INF, patients which leave the list 63
# 622.4313493229996 new_donor None
# A donation was done with expected life 2568.110271732618 and probabity 0.6880987063028366. Day:  622.4313493229996
# Number of matches: 0, recipients in wait list: 263,average time in waitlist INF, patients which leave the list 63
# 622.7847798686282 new_recipient None
# A new recipient has arrived. Day:  622.7847798686282
# ...
# A new recipient has arrived. Day:  10764.938775992838
# Number of matches: 1077, recipients in wait list: 219,average time in waitlist 1289.4196687798776, patients which leave the list 742
# 10766.08167588911 new_donor None
# A donation was done with expected life 2899.07752306093 and probabity 0.7609007605575978. Day:  10766.08167588911
# Number of matches: 1078, recipients in wait list: 218,average time in waitlist 1289.3359069951707, patients which leave the list 742
# 10770.217222598574 new_donor None
# A donation was done with expected life 2963.7082204509975 and probabity 0.7746944161738566. Day:  10770.217222598574
# Number of matches: 1079, recipients in wait list: 217,average time in waitlist 1289.013573889975, patients which leave the list 742
# 10773.54887418801 new_recipient None
# A new recipient has arrived. Day:  10773.54887418801
# Number of matches: 1079, recipients in wait list: 218,average time in waitlist 1289.013573889975, patients which leave the list 742
# 10776.743757120135 new_recipient None
# A new recipient has arrived. Day:  10776.743757120135
# Number of matches: 1079, recipients in wait list: 219,average time in waitlist 1289.013573889975, patients which leave the list 742
# 10779.095982319133 new_recipient None
# A new recipient has arrived. Day:  10779.095982319133
# Number of matches: 1079, recipients in wait list: 220,average time in waitlist 1289.013573889975, patients which leave the list 742
# 10782.1332101046 new_donor None
# A donation was done with expected life 2592.104724984678 and probabity 0.6923759795814804. Day:  10782.1332101046
# Number of matches: 1080, recipients in wait list: 219,average time in waitlist 1288.932730166338, patients which leave the list 742
# 10783.128729525442 new_recipient None
# A new recipient has arrived. Day:  10783.128729525442
# Number of matches: 1080, recipients in wait list: 220,average time in waitlist 1288.932730166338, patients which leave the list 742
# 10784.777481995194 new_recipient None
# A new recipient has arrived. Day:  10784.777481995194
# Number of matches: 1080, recipients in wait list: 221,average time in waitlist 1288.932730166338, patients which leave the list 742
# 10785.798568380285 new_recipient None
# A new recipient has arrived. Day:  10785.798568380285
# Number of matches: 1080, recipients in wait list: 222,average time in waitlist 1288.932730166338, patients which leave the list 742
# 10787.774898529762 new_recipient None
# A new recipient has arrived. Day:  10787.774898529762
# Number of matches: 1080, recipients in wait list: 223,average time in waitlist 1288.932730166338, patients which leave the list 742
# 10787.920431377202 new_recipient None
# A new recipient has arrived. Day:  10787.920431377202
# Number of matches: 1080, recipients in wait list: 224,average time in waitlist 1288.932730166338, patients which leave the list 742
# 10788.488753464475 new_recipient None
# A new recipient has arrived. Day:  10788.488753464475
# Number of matches: 1080, recipients in wait list: 225,average time in waitlist 1288.932730166338, patients which leave the list 742
# 10788.753485569116 new_donor None
# A donation was done with expected life 2944.1708888981125 and probabity 0.7694353827028081. Day:  10788.753485569116
# Number of matches: 1081, recipients in wait list: 224,average time in waitlist 1288.6277181157093, patients which leave the list 742
# 10790.697854570342 new_donor None
# A donation was done with expected life 2872.6192625595145 and probabity 0.750281807741108. Day:  10790.697854570342
# Number of matches: 1082, recipients in wait list: 223,average time in waitlist 1288.320805589833, patients which leave the list 742
# 10793.498505027512 new_recipient None
# A new recipient has arrived. Day:  10793.498505027512
# Number of matches: 1082, recipients in wait list: 224,average time in waitlist 1288.320805589833, patients which leave the list 742
# 10797.654195996522 new_donor None
# A donation was done with expected life 3232.5522034627434 and probabity 0.8260032259443711. Day:  10797.654195996522
# Number of matches: 1083, recipients in wait list: 223,average time in waitlist 1288.0143853865839, patients which leave the list 742
# 10799.202808977761 new_recipient None
# A new recipient has arrived. Day:  10799.202808977761
# Number of matches: 1083, recipients in wait list: 224,average time in waitlist 1288.0143853865839, patients which leave the list 742
# 10808.652769428092 new_recipient None
# A new recipient has arrived. Day:  10808.652769428092
# Number of matches: 1083, recipients in wait list: 225,average time in waitlist 1288.0143853865839, patients which leave the list 742
# 10813.120326804026 new_recipient None
# A new recipient has arrived. Day:  10813.120326804026
# Number of matches: 1083, recipients in wait list: 226,average time in waitlist 1288.0143853865839, patients which leave the list 742
# 10815.88447504361 new_recipient None
# A new recipient has arrived. Day:  10815.88447504361
# Number of matches: 1083, recipients in wait list: 227,average time in waitlist 1288.0143853865839, patients which leave the list 742
# 10819.512850026016 new_donor None
# A donation was done with expected life 2967.1635374746143 and probabity 0.7743553468788718. Day:  10819.512850026016
# Number of matches: 1084, recipients in wait list: 226,average time in waitlist 1287.961834678916, patients which leave the list 742
# 10822.059314438638 new_recipient None
# A new recipient has arrived. Day:  10822.059314438638
# Number of matches: 1084, recipients in wait list: 227,average time in waitlist 1287.961834678916, patients which leave the list 742
# 10824.287936843664 new_donor None
# A donation was done with expected life 3066.0094589716387 and probabity 0.7896706764482705. Day:  10824.287936843664
# Number of matches: 1085, recipients in wait list: 226,average time in waitlist 1287.6803118605487, patients which leave the list 742
# 10824.457566019253 new_recipient None
# A new recipient has arrived. Day:  10824.457566019253
# Number of matches: 1085, recipients in wait list: 227,average time in waitlist 1287.6803118605487, patients which leave the list 742
# 10829.038997597412 new_donor None
# A donation was done with expected life 2646.0643963534776 and probabity 0.7008732934281194. Day:  10829.038997597412
# Number of matches: 1086, recipients in wait list: 226,average time in waitlist 1287.6113381559628, patients which leave the list 742
# 10833.028445692236 leave_list 9327
# ----------------------- One patient left the waitlist. Day:  10833.028445692236 9327
# Number of matches: 1086, recipients in wait list: 225,average time in waitlist 1287.6113381559628, patients which leave the list 743
# 10840.643611541464 new_donor None
# A donation was done with expected life 2965.0507735403667 and probabity 0.7760849705723697. Day:  10840.643611541464
# Number of matches: 1087, recipients in wait list: 224,average time in waitlist 1287.325378851828, patients which leave the list 743
# 10841.625746622361 new_donor None
# A donation was done with expected life 2699.9431426356123 and probabity 0.7198699021925511. Day:  10841.625746622361
# Number of matches: 1088, recipients in wait list: 223,average time in waitlist 1287.2531543222312, patients which leave the list 743
# 10841.930351265288 new_recipient None
# A new recipient has arrived. Day:  10841.930351265288
# Number of matches: 1088, recipients in wait list: 224,average time in waitlist 1287.2531543222312, patients which leave the list 743
# 10842.010468078477 new_recipient None
# A new recipient has arrived. Day:  10842.010468078477
# Number of matches: 1088, recipients in wait list: 225,average time in waitlist 1287.2531543222312, patients which leave the list 743
# 10842.32552029338 new_recipient None
# A new recipient has arrived. Day:  10842.32552029338
# Number of matches: 1088, recipients in wait list: 226,average time in waitlist 1287.2531543222312, patients which leave the list 743
# 10844.512600717631 new_recipient None
# A new recipient has arrived. Day:  10844.512600717631
# Number of matches: 1088, recipients in wait list: 227,average time in waitlist 1287.2531543222312, patients which leave the list 743
# 10845.242323657085 new_recipient None
# A new recipient has arrived. Day:  10845.242323657085
# Number of matches: 1088, recipients in wait list: 228,average time in waitlist 1287.2531543222312, patients which leave the list 743
# 10845.623959596827 leave_list 1137
# ----------------------- One patient left the waitlist. Day:  10845.623959596827 1137
# Number of matches: 1088, recipients in wait list: 227,average time in waitlist 1287.2531543222312, patients which leave the list 744
# 10849.365916709503 leave_list 11031
# ----------------------- One patient left the waitlist. Day:  10849.365916709503 11031
# Number of matches: 1088, recipients in wait list: 226,average time in waitlist 1287.2531543222312, patients which leave the list 745
# 10853.676494225641 new_donor None
# A donation was done with expected life 2880.149849222446 and probabity 0.7585081121655911. Day:  10853.676494225641
# Number of matches: 1089, recipients in wait list: 225,average time in waitlist 1286.9744481437424, patients which leave the list 745
# 10857.931318328057 new_recipient None
# A new recipient has arrived. Day:  10857.931318328057
# Number of matches: 1089, recipients in wait list: 226,average time in waitlist 1286.9744481437424, patients which leave the list 745
# 10859.176306184925 new_donor None
# A donation was done with expected life 3007.1216977979725 and probabity 0.7782353267503873. Day:  10859.176306184925
# Number of matches: 1090, recipients in wait list: 225,average time in waitlist 1286.68503048152, patients which leave the list 745
# 10861.151238738432 new_donor None
# A donation was done with expected life 2952.6497643569737 and probabity 0.7662424822094624. Day:  10861.151238738432
# Number of matches: 1091, recipients in wait list: 224,average time in waitlist 1286.3851313559044, patients which leave the list 745
# 10864.248997548619 new_recipient None
# A new recipient has arrived. Day:  10864.248997548619
# Number of matches: 1091, recipients in wait list: 225,average time in waitlist 1286.3851313559044, patients which leave the list 745
# 10866.569796771666 new_donor None
# A donation was done with expected life 3052.440605453079 and probabity 0.7805820919620491. Day:  10866.569796771666
# Number of matches: 1092, recipients in wait list: 224,average time in waitlist 1286.0760071267632, patients which leave the list 745
# 10868.049705806152 new_recipient None
# A new recipient has arrived. Day:  10868.049705806152
# Number of matches: 1092, recipients in wait list: 225,average time in waitlist 1286.0760071267632, patients which leave the list 745
# 10870.599972038186 new_recipient None
# A new recipient has arrived. Day:  10870.599972038186
# Number of matches: 1092, recipients in wait list: 226,average time in waitlist 1286.0760071267632, patients which leave the list 745
# 10871.842695791127 new_donor None
# A donation was done with expected life 2580.467436938816 and probabity 0.6907925556105977. Day:  10871.842695791127
# Number of matches: 1093, recipients in wait list: 225,average time in waitlist 1285.9807852649203, patients which leave the list 745
# 10874.951339740455 new_recipient None
# A new recipient has arrived. Day:  10874.951339740455
# Number of matches: 1093, recipients in wait list: 226,average time in waitlist 1285.9807852649203, patients which leave the list 745
# 10876.476995007919 new_recipient None
# A new recipient has arrived. Day:  10876.476995007919
# Number of matches: 1093, recipients in wait list: 227,average time in waitlist 1285.9807852649203, patients which leave the list 745
# 10877.142185191713 new_donor None
# A donation was done with expected life 2931.7991728791717 and probabity 0.7642452507383507. Day:  10877.142185191713
# Number of matches: 1094, recipients in wait list: 226,average time in waitlist 1285.682003749428, patients which leave the list 745
# 10878.111800276596 leave_list 21531
# ----------------------- One patient left the waitlist. Day:  10878.111800276596 21531
# Number of matches: 1094, recipients in wait list: 225,average time in waitlist 1285.682003749428, patients which leave the list 746
# 10878.817043067404 leave_list 15639
# ----------------------- One patient left the waitlist. Day:  10878.817043067404 15639
# Number of matches: 1094, recipients in wait list: 224,average time in waitlist 1285.682003749428, patients which leave the list 747
# 10885.151697904224 new_recipient None
# A new recipient has arrived. Day:  10885.151697904224
# Number of matches: 1094, recipients in wait list: 225,average time in waitlist 1285.682003749428, patients which leave the list 747
# 10889.152471167736 new_donor None
# A donation was done with expected life 2947.6163232934864 and probabity 0.7694761823290699. Day:  10889.152471167736
# Number of matches: 1095, recipients in wait list: 224,average time in waitlist 1286.1298968978303, patients which leave the list 747
# 10889.188057332398 new_donor None
# A donation was done with expected life 2691.012795219346 and probabity 0.7177914286651967. Day:  10889.188057332398
# Number of matches: 1096, recipients in wait list: 223,average time in waitlist 1285.83353835478, patients which leave the list 747
# 10890.298487476512 new_donor None
# A donation was done with expected life 2936.069141358577 and probabity 0.7657597005024911. Day:  10890.298487476512
# Number of matches: 1097, recipients in wait list: 222,average time in waitlist 1287.9794744333904, patients which leave the list 747
# 10898.126788489124 new_donor None
# A donation was done with expected life 2931.100887337325 and probabity 0.7609698368123555. Day:  10898.126788489124
# Number of matches: 1098, recipients in wait list: 221,average time in waitlist 1287.6842952266945, patients which leave the list 747
# 10899.192621324804 new_donor None
# A donation was done with expected life 3147.2764693757144 and probabity 0.8049562292272173. Day:  10899.192621324804
# Number of matches: 1099, recipients in wait list: 220,average time in waitlist 1287.6074005668445, patients which leave the list 747
# 10899.823631277504 new_recipient None
# A new recipient has arrived. Day:  10899.823631277504
# Number of matches: 1099, recipients in wait list: 221,average time in waitlist 1287.6074005668445, patients which leave the list 747
# 10903.39708604521 new_donor None
# A donation was done with expected life 2941.3109092629597 and probabity 0.7689331198220808. Day:  10903.39708604521
# Number of matches: 1100, recipients in wait list: 220,average time in waitlist 1287.316932339904, patients which leave the list 747
# 10909.38084392278 leave_list 15244
# ----------------------- One patient left the waitlist. Day:  10909.38084392278 15244
# Number of matches: 1100, recipients in wait list: 219,average time in waitlist 1287.316932339904, patients which leave the list 748
# 10924.948312352994 leave_list 132
# ----------------------- One patient left the waitlist. Day:  10924.948312352994 132
# Number of matches: 1100, recipients in wait list: 218,average time in waitlist 1287.316932339904, patients which leave the list 749
# 10941.03617042738 leave_list 15157
# ----------------------- One patient left the waitlist. Day:  10941.03617042738 15157
# Number of matches: 1100, recipients in wait list: 217,average time in waitlist 1287.316932339904, patients which leave the list 750
# 10941.441313630221 leave_list 12127
# ----------------------- One patient left the waitlist. Day:  10941.441313630221 12127
# Number of matches: 1100, recipients in wait list: 216,average time in waitlist 1287.316932339904, patients which leave the list 751
# 10944.952948487095 leave_list 16751
# ----------------------- One patient left the waitlist. Day:  10944.952948487095 16751
# Number of matches: 1100, recipients in wait list: 215,average time in waitlist 1287.316932339904, patients which leave the list 752
# 10965.777995494273 new_recipient None
# A new recipient has arrived. Day:  10965.777995494273
# Number of matches: 1100, recipients in wait list: 216,average time in waitlist 1287.316932339904, patients which leave the list 752
# ([1287.316932339904], [1100])

# %%
df['ethcat'] = df['ethcat'].replace(ethcat_mapping)

# %%
df_waiting_time = ((df.groupby(by=['replicate', 'ethcat'])
                   .agg(
                       waiting_time=('waiting_time', 'mean'), 
                       count=('waiting_time', 'size'), 
                       mean_survival_time=('mean_survival_time', 'mean'))
                   .reset_index())
)#.to_csv('simulation_results.csv')
df_waiting_time = df_waiting_time[['ethcat', 'waiting_time', 'count', 'mean_survival_time']].groupby('ethcat').agg(['mean', 'std'])
df_waiting_time.columns = [f"{col[0]}_{col[1]}" for col in df_waiting_time.columns] 
df_waiting_time['prop_simu'] = df_waiting_time['count_mean'] / df_waiting_time['count_mean'].sum()
df_waiting_time = df_waiting_time.merge(real_ethcat_df, on='ethcat').round(3)
df_waiting_time.columns = ['ethcat', 'wt_mean', 'wt_std', 'count_mean', 'count_std', 'st_mean', 'st_std', 'prop_simu', 'sample_proportion']
df_waiting_time
# Out:
#                                               ethcat   wt_mean  wt_std  \
# 0               Amer Ind/Alaska Native, Non-Hispanic  1197.322     NaN
# 1                                Asian, Non-Hispanic  1346.114     NaN
# 2                                Black, Non-Hispanic  1307.820     NaN
# 3                                    Hispanic/Latino  1224.672     NaN
# 4                          Multiracial, Non-Hispanic  1693.326     NaN
# 5  Native Hawaiian/Other Pacific Islander, Non-Hi...  1352.524     NaN
# 6                                White, Non-Hispanic  1289.680     NaN
#
#    count_mean  count_std   st_mean  st_std  prop_simu  sample_proportion
# 0        15.0        NaN  2923.755     NaN      0.014              0.014
# 1        48.0        NaN  2909.280     NaN      0.044              0.053
# 2       343.0        NaN  2874.206     NaN      0.312              0.325
# 3       190.0        NaN  2882.053     NaN      0.173              0.160
# 4         5.0        NaN  3003.874     NaN      0.005              0.005
# 5         3.0        NaN  2878.589     NaN      0.003              0.004
# 6       496.0        NaN  2898.710     NaN      0.451              0.439

# %%
df_gender = ((df.groupby(by=['replicate', 'gender'])
                .agg(
                    waiting_time=('waiting_time', 'mean'), 
                    count=('waiting_time', 'size'),
                    mean_survival_time=('mean_survival_time', 'mean'))
                .reset_index())
)#.to_csv('simulation_results.csv')
df_gender = df_gender[['gender', 'waiting_time', 'count', 'mean_survival_time']].groupby('gender').agg(['mean', 'std'])
df_gender.columns = [f"{col[0]}_{col[1]}" for col in df_gender.columns] 
df_gender['proportion_sim'] = df_gender['count_mean'] / df_gender['count_mean'].sum()
df_gender.reset_index(inplace=True)
df_gender = df_gender.merge(real_gender_df, on = 'gender')
df_gender.columns = ['gender', 'wt_mean', 'wt_std', 'count_mean',
       'count_std', 'st_mean', 'st_std',
       'prop_sim', 'sample_proportion']
df_gender.round(3)
# Out:
#   gender   wt_mean  wt_std  count_mean  count_std   st_mean  st_std  prop_sim  \
# 0      F  1289.999     NaN       403.0        NaN  2901.902     NaN     0.366
# 1      M  1285.766     NaN       697.0        NaN  2882.200     NaN     0.634
#
#    sample_proportion
# 0              0.352
# 1              0.648

# %%
#df.to_csv('results_decision_tree.csv')

# %%
import numpy as np 

np.quantile(np.mean(np.random.exponential(scale=(1)*365, size=100)), 0.2)
# Out:
# 392.89444882477784
