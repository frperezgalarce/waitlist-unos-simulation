# %%
import pandas as pd 

df_base = pd.read_csv('data/data_to_simulate.csv', index_col=0)
df_base.dropna(inplace=True)
print(df_base.columns)
columns = ['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON', 'AGE', 'DIAB',
                'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI', 'SERUM_CREAT',
                'CREAT_TRR', 'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC','CREAT_TRRg1.5', 'SERUM_CREATg1.2',
                'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
                'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE','TX_DATE', 'PT_CODE', 'ABO', 'ABO_DON']

predictors = ['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'WGT_KG_DON_CALC',
                    'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'COD_CAD_DON', 'ETHCAT_DON', 'ABO_MAT', 
                    'HLAMIS', 'DIALYSIS_DATE', 'AGE', 'DIAB', 'DIALYSIS_DATEle0.0', 'CREAT_TRRg1.5', 'SERUM_CREATg1.2']

donor = df_base[['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 
            'HIST_HYPERTENS_DON', 'ABO_DON', 'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2']]

print(donor.columns)
donor.to_csv('data/donors.csv')

recipient = df_base[[ 'DIALYSIS_DATE', 'AGE', 'DIAB', 'ETHCAT', 'GENDER', 'ABO', 'DIALYSIS_DATEle0.0']]
recipient.to_csv('data/recipients.csv')

ethcat_mapping = {
    1: "White, Non-Hispanic",
    2: "Black, Non-Hispanic",
    4: "Hispanic/Latino",
    5: "Asian, Non-Hispanic",
    6: "Amer Ind/Alaska Native, Non-Hispanic",
    7: "Native Hawaiian/Other Pacific Islander, Non-Hispanic",
    9: "Multiracial, Non-Hispanic",
}
# Out:
# Index(['GTIME_KI', 'GSTATUS_KI', 'AGE_DON', 'HCV_SEROSTATUS', 'GENDER_DON',
#        'AGE', 'DIAB', 'BMI_CALC', 'ETHCAT', 'GENDER', 'COLD_ISCH_KI',
#        'SERUM_CREAT', 'ABO_MAT', 'AMIS', 'BMIS', 'DRMIS', 'CREAT_TRR',
#        'delta_age', 'HIST_DIABETES_DON', 'HGT_CM_DON_CALC', 'ABO_DON',
#        'COD_CAD_DON', 'WGT_KG_DON_CALC', 'CREAT_DON', 'ETHCAT_DON',
#        'HIST_HYPERTENS_DON', 'NON_HRT_DON', 'DIALYSIS_DATE', 'TX_DATE',
#        'PT_CODE', 'COMPOSITE_DEATH_DATE', 'ABO', 'T', 'Tag_date', 'DIAB_1',
#        'DIAB_998', 'HIST_DIABETES_DON_1', 'HIST_DIABETES_DON_998',
#        'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2',
#        'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype='object')
# Index(['AGE_DON', 'CREAT_TRR', 'CREAT_TRRg1.5', 'HGT_CM_DON_CALC',
#        'HCV_SEROSTATUS', 'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'ABO_DON',
#        'AGE_DONge50', 'WGT_KG_DON_CALCl80', 'COD_CAD_DON_2', 'ETHCAT_DON_2'],
#       dtype='object')

# %%
real_gender_df = df_base.GENDER.value_counts(normalize=True).reset_index()
real_gender_df.columns = ['gender', 'sample_proportion']
real_gender_df
# Out:
#   gender  sample_proportion
# 0      M            0.64827
# 1      F            0.35173

# %%
real_ethcat_df = df_base.ETHCAT.value_counts(normalize=True).reset_index()
real_ethcat_df.ETHCAT = real_ethcat_df.ETHCAT.map(ethcat_mapping)
real_ethcat_df.columns = ['ethcat', 'sample_proportion']
real_ethcat_df
# Out:
#                                               ethcat  sample_proportion
# 0                                White, Non-Hispanic           0.439416
# 1                                Black, Non-Hispanic           0.325258
# 2                                    Hispanic/Latino           0.159551
# 3                                Asian, Non-Hispanic           0.053213
# 4               Amer Ind/Alaska Native, Non-Hispanic           0.013618
# 5                          Multiracial, Non-Hispanic           0.004764
# 6  Native Hawaiian/Other Pacific Islander, Non-Hi...           0.004180

# %%
recipient.ABO.unique()
# Out:
# array(['B', 'A', 'O', 'AB', 'A2', 'A1', 'A1B', 'A2B'], dtype=object)

# %%
blood_type_compatibility = {
    "A": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A1": ["A", "A1", "A2", "AB", "A1B", "A2B"],
    "A2": ["A", "A1", "A2", "AB", "A1B", "A2B", "B"],
    "B":  ["B", "AB", "A1B", "A2B"],
    "AB": ["AB", "A1B", "A2B"],
    "A1B": ["A1B"],
    "A2B": ["A2B", "AB"],
    "O": ["A", "A1", "A2", "B", "AB", "A1B", "A2B", "O"]
}

# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
path = Path("C:/Users/HP/Desktop/UNOS data/codes/simulation-waitline-unos").resolve()  # Get the absolute path
os.chdir(path)
import pandas as pd
import numpy as np
import scipy as sc
import recipient as rec
import prediction as pred 
import donor as don
from event import Event

# %%
def create_list_of_events(n_events = 10000):
    events = Event(number_of_events= n_events, 
                    time_between_arrivals_recipients=4, 
                    time_between_arrivals_donor= 6) #average time in days
    events.create_events()
    return events

# %%
TARGET_TIME  = 5 * 365
SIMULATION_TIME = 365*30  
predictor = pred.SurvivalPredictionModel(model_path='models/random_forest_2511.pkl')
#9.1% leave the list
#theshold_leave_list = 0.091 
recipients_for_initialization = 300
time_before_starting_simulation = 0
released_recipients = []
# Out:
# models/random_forest_2511.pkl
# ok
# Model loaded successfully from models/random_forest_2511.pkl.

# %%
def get_expected_life(predicted_survival_function): 
    return sum((predicted_survival_function[0].x[i + 1] - predicted_survival_function[0].x[i]) *
    predicted_survival_function[0].y[i] for i in range(len(predicted_survival_function[0].x) - 1))

# %%
predictor.model.feature_names_in_
# Out:
# array(['AGE_DON', 'CREAT_TRR', 'HGT_CM_DON_CALC', 'HCV_SEROSTATUS',
#        'HIST_DIABETES_DON', 'HIST_HYPERTENS_DON', 'DIALYSIS_DATE', 'AGE',
#        'DIAB', 'AGE_DONge50', 'CREAT_TRRg1.5', 'WGT_KG_DON_CALCl80',
#        'COD_CAD_DON_2', 'ETHCAT_DON_2', 'DIALYSIS_DATEle0.0'],
#       dtype=object)

# %%
df = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
df_leaves = pd.DataFrame(columns=['replicate', 'ethcat', 'gender', 'waiting_time', 'mean_survival_time', 'current_time'])
waiting_time_convergence = []
wait_list_length = []
leave_list_global = []



def run_simulation(T=10, replicates=1, verbose=False):
    waiting_time_convergence_r = []
    wait_list_length_r = []
    average_waiting_times = []
    number_of_matches_list = []
    
    for r in range(replicates):
        events = create_list_of_events(n_events = 10000)
        print('Replicate #', str(r))
        wait_list = []  # Initialize an empty waitlist for each replicate
        leave_list = []
        next_in_leave_the_list = []
        total_waiting_time = 0  # Track the total waiting time for this replicate
        num_matched_patients = 0  # Track the number of matched patients
        current_t = 0  # Start time    
    
        for i in range(recipients_for_initialization):
                new_recipient = rec.Recipient(time_before_starting_simulation) 
                new_recipient.create_recipient(i)
                wait_list.append(new_recipient)
                next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                next_in_leave_the_list = sorted(next_in_leave_the_list)
                
        while current_t < T:  
            (time_aux, _, _)  = events.list_of_events[0]
            (time2_aux, _, _) = next_in_leave_the_list[0]
            
            if time_aux + current_t < time2_aux:
                (time, event_type, counter)  = events.list_of_events.pop(0)
                ID = None
                print(time+current_t, event_type, ID)
            else: 
                (time, event_type, ID) = next_in_leave_the_list.pop(0)
                print(time, event_type, ID)
                   
            #print(time, event_type)         
            match event_type:
                case "new_donor":
                    current_t += time
                    donor = don.Donor(current_t)
                    donor.create_donor(counter)
                    
                    if len(wait_list) < 1:
                        raise('The waitlist length is 0, check the setup please')            
                    
                    survival_probs = []
                    for recipient in wait_list: 
                        if donor.blood in blood_type_compatibility[recipient.blood]: 
                            survival_probs.append(predictor.predict_survival_prob(recipient, donor, TARGET_TIME))
                        else: 
                             survival_probs.append(0)
                             
                    total_times = []           
                    
                    for recipient in wait_list:
                        if donor.blood in blood_type_compatibility[recipient.blood]:
                            _, function_pred = predictor.predict_survival_prob(recipient, donor, TARGET_TIME, surv_function=True)
                            total_ind = current_t-recipient.arrival_time + get_expected_life(function_pred)
                            total_times.append(total_ind)
                        else: 
                            total_times.append(-1)
                    
                    if len(survival_probs)>0: 
                        best_match_index = np.argmax(total_times)
                        
                        recipient_best = wait_list[best_match_index]
                        _, predicted_survival_function = predictor.predict_survival_prob(recipient_best, donor, TARGET_TIME, surv_function=True)
                        
                        mean_survival_time = sum(
                        (predicted_survival_function[0].x[i + 1] - predicted_survival_function[0].x[i]) *
                        predicted_survival_function[0].y[i]
                        for i in range(len(predicted_survival_function[0].x) - 1)
)
                        
                        best_patient = wait_list.pop(best_match_index)
                        next_leave_time = [(a, b, c) for (a, b, c) in next_in_leave_the_list if c==best_patient.ID]
                        _index = next_in_leave_the_list.index(next_leave_time[0])   
                        _ = next_in_leave_the_list.pop(_index)
                        
                        print(f'A donation was done with expected life {mean_survival_time} and probabity {survival_probs[best_match_index]}. Day: ', str(current_t))
                        waiting_time = current_t - best_patient.arrival_time
                        
                        if current_t > 8*365.25:
                            total_waiting_time += waiting_time
                            
                        best_patient.waiting_time = waiting_time
                        
                        
                        if current_t > 8*365.25:
                            df.loc[len(df)] = [r, best_patient.ethcat, best_patient.gender, best_patient.waiting_time, mean_survival_time, current_t]
                            released_recipients.append(best_patient)
                            num_matched_patients += 1
                
                case "new_recipient":            
                    current_t += time
                    new_recipient = rec.Recipient(current_t) 
                    new_recipient.create_recipient(counter)
                    wait_list.append(new_recipient)
                    next_in_leave_the_list.append((new_recipient.time_to_leave_list, new_recipient.reason_to_leave_list, new_recipient.ID))
                    next_in_leave_the_list = sorted(next_in_leave_the_list)
                    print('A new recipient has arrived. Day: ', str(current_t))
                
                case "leave_list":
                    current_t = time
                    next_leave_time = [p for p in wait_list if p.ID==ID]
                    _index = wait_list.index(next_leave_time[0])   
                    out_of_list = wait_list.pop(_index)
                    leave_list.append(out_of_list)
                    
                    if current_t > 8*365.25:
                        df_leaves.loc[len(df)] = [r, out_of_list.ethcat, out_of_list.gender, out_of_list.waiting_time, _, current_t]
                        print('----------------------- One patient left the waitlist. Day: ', str(current_t), out_of_list.ID) 
                    
                    

            if num_matched_patients>0:
                if current_t > 8*365.25:
                    average_time = total_waiting_time / num_matched_patients
                    #we collect data after 8 years
                    waiting_time_convergence_r.append([current_t, average_time])
                wait_list_length_r.append([current_t, len(wait_list)])
            else: 
                average_time = 'INF'
            if verbose:
                print(f'Number of matches: {num_matched_patients}, recipients in wait list: {len(wait_list)},'
                      f'average time in waitlist {average_time}, patients which leave the list {len(leave_list)}')        
        if num_matched_patients > 0:
            average_waiting_times.append(total_waiting_time / num_matched_patients)
            waiting_time_convergence.append(waiting_time_convergence_r)
            wait_list_length.append(wait_list_length_r)
            number_of_matches_list.append(num_matched_patients)
            leave_list_global.append(leave_list)
        else:
            average_waiting_times.append(0)
            
    return average_waiting_times, number_of_matches_list

# %%
run_simulation(T=SIMULATION_TIME, replicates=1, verbose=True)
# Out:
# Replicate # 0
# 0.013452044484706407 new_donor None
# A donation was done with expected life 2720.111178208371 and probabity 0.7161873969527908. Day:  0.013452044484706407
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 2.577410151548605 new_donor None
# A donation was done with expected life 2876.0371995853216 and probabity 0.7432762779654948. Day:  2.577410151548605
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 0
# 5.073883750718496 new_recipient None
# A new recipient has arrived. Day:  5.073883750718496
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 6.765155484159635 new_donor None
# A donation was done with expected life 2945.0584489134494 and probabity 0.7628755369390418. Day:  6.765155484159635
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 0
# 14.441771519365274 new_recipient None
# A new recipient has arrived. Day:  14.441771519365274
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 0
# 16.388872977224118 new_donor None
# A donation was done with expected life 3184.0053670211437 and probabity 0.8137564605285297. Day:  16.388872977224118
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 0
# 19.812328377794827 leave_list 11006
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 1
# 23.284586705432428 new_recipient None
# A new recipient has arrived. Day:  23.284586705432428
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 1
# 24.717963903248027 new_recipient None
# A new recipient has arrived. Day:  24.717963903248027
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 1
# 28.342635386998364 new_donor None
# A donation was done with expected life 2824.2422495878477 and probabity 0.7435475837337511. Day:  28.342635386998364
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 1
# 28.742785041069176 new_recipient None
# A new recipient has arrived. Day:  28.742785041069176
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 1
# 31.396155392542617 leave_list 19162
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 2
# 36.91205493643377 new_recipient None
# A new recipient has arrived. Day:  36.91205493643377
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 2
# 37.71042190752323 new_recipient None
# A new recipient has arrived. Day:  37.71042190752323
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 2
# 37.998237720859635 new_recipient None
# A new recipient has arrived. Day:  37.998237720859635
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 2
# 38.06344284740266 leave_list 14368
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 3
# 38.170815315473554 new_donor None
# A donation was done with expected life 3255.968665613926 and probabity 0.8295363605590884. Day:  38.170815315473554
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 3
# 38.53202629202261 new_donor None
# A donation was done with expected life 3217.3837452511434 and probabity 0.818290940685311. Day:  38.53202629202261
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 3
# 40.27819312261532 new_recipient None
# A new recipient has arrived. Day:  40.27819312261532
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 3
# 40.40538940987948 new_donor None
# A donation was done with expected life 2883.138140932326 and probabity 0.7529248214199862. Day:  40.40538940987948
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 3
# 42.93421058194383 new_recipient None
# A new recipient has arrived. Day:  42.93421058194383
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 3
# 43.634321473653905 new_donor None
# A donation was done with expected life 3027.1314304177376 and probabity 0.7913129813107819. Day:  43.634321473653905
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 3
# 47.590846034020174 new_donor None
# A donation was done with expected life 2902.383862358806 and probabity 0.7614556354179153. Day:  47.590846034020174
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 3
# 49.586228191908006 leave_list 8104
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 4
# 52.086594041039675 new_recipient None
# A new recipient has arrived. Day:  52.086594041039675
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 4
# 61.42854574086856 new_recipient None
# A new recipient has arrived. Day:  61.42854574086856
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 4
# 64.40437018573563 leave_list 3442
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 5
# 70.19807341802108 new_recipient None
# A new recipient has arrived. Day:  70.19807341802108
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 71.62819098536218 new_recipient None
# A new recipient has arrived. Day:  71.62819098536218
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 5
# 72.18259531570344 new_donor None
# A donation was done with expected life 3300.8004570374255 and probabity 0.8454627578857453. Day:  72.18259531570344
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 5
# 74.04207981409392 new_recipient None
# A new recipient has arrived. Day:  74.04207981409392
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 5
# 75.82032974558689 new_recipient None
# A new recipient has arrived. Day:  75.82032974558689
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 5
# 78.67145108708064 new_recipient None
# A new recipient has arrived. Day:  78.67145108708064
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 5
# 83.01878871385341 new_recipient None
# A new recipient has arrived. Day:  83.01878871385341
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 5
# 86.22553393809679 new_recipient None
# A new recipient has arrived. Day:  86.22553393809679
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 5
# 94.55462741046401 new_donor None
# A donation was done with expected life 2896.241324963972 and probabity 0.7585596528876266. Day:  94.55462741046401
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 5
# 95.40780760207703 new_donor None
# A donation was done with expected life 2990.626539815348 and probabity 0.7783242640113531. Day:  95.40780760207703
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 5
# 98.99696746090676 new_donor None
# A donation was done with expected life 2859.389764768759 and probabity 0.7372388411958702. Day:  98.99696746090676
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 5
# 100.44328412173907 new_recipient None
# A new recipient has arrived. Day:  100.44328412173907
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 5
# 101.51631755817733 new_recipient None
# A new recipient has arrived. Day:  101.51631755817733
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 5
# 105.41701380837381 new_recipient None
# A new recipient has arrived. Day:  105.41701380837381
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 5
# 106.663427649478 new_recipient None
# A new recipient has arrived. Day:  106.663427649478
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 5
# 108.42480032024966 new_recipient None
# A new recipient has arrived. Day:  108.42480032024966
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 5
# 110.29865304321301 new_donor None
# A donation was done with expected life 3046.2001249274663 and probabity 0.7954016664352143. Day:  110.29865304321301
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 5
# 112.94209716613636 new_recipient None
# A new recipient has arrived. Day:  112.94209716613636
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 5
# 114.26674931453462 new_donor None
# A donation was done with expected life 3246.7659897919193 and probabity 0.8311590919439147. Day:  114.26674931453462
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 5
# 114.72734483425971 new_recipient None
# A new recipient has arrived. Day:  114.72734483425971
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 5
# 114.81792732317126 leave_list 945
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 6
# 116.046432739834 new_recipient None
# A new recipient has arrived. Day:  116.046432739834
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 6
# 116.54831629388062 new_recipient None
# A new recipient has arrived. Day:  116.54831629388062
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 6
# 116.86712797532208 new_donor None
# A donation was done with expected life 3250.1373490006818 and probabity 0.8272145818964699. Day:  116.86712797532208
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 6
# 121.88745070301229 new_recipient None
# A new recipient has arrived. Day:  121.88745070301229
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 6
# 122.86484239364619 new_donor None
# A donation was done with expected life 3208.3831216225713 and probabity 0.8163430665744167. Day:  122.86484239364619
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 6
# 125.3320722651828 leave_list 15882
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 7
# 128.48040268269042 new_recipient None
# A new recipient has arrived. Day:  128.48040268269042
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 7
# 129.00971469455837 new_recipient None
# A new recipient has arrived. Day:  129.00971469455837
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 7
# 132.26783477333106 leave_list 15399
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 8
# 139.099514211157 new_recipient None
# A new recipient has arrived. Day:  139.099514211157
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 8
# 142.0486934550717 new_recipient None
# A new recipient has arrived. Day:  142.0486934550717
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 8
# 142.48039632869327 new_recipient None
# A new recipient has arrived. Day:  142.48039632869327
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 8
# 142.68345180348442 new_recipient None
# A new recipient has arrived. Day:  142.68345180348442
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 8
# 142.8093008131874 new_donor None
# A donation was done with expected life 3061.7760539880087 and probabity 0.7847030621838214. Day:  142.8093008131874
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 8
# 143.53576343214743 leave_list 3318
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 9
# 148.5998047565469 new_recipient None
# A new recipient has arrived. Day:  148.5998047565469
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 9
# 148.9794054111456 new_donor None
# A donation was done with expected life 3254.7507711405133 and probabity 0.8287443150179157. Day:  148.9794054111456
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 9
# 157.9421280798425 new_recipient None
# A new recipient has arrived. Day:  157.9421280798425
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 9
# 159.15700464181657 new_recipient None
# A new recipient has arrived. Day:  159.15700464181657
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 9
# 161.72881757855706 new_recipient None
# A new recipient has arrived. Day:  161.72881757855706
# Number of matches: 0, recipients in wait list: 310,average time in waitlist INF, patients which leave the list 9
# 163.89211589804464 new_donor None
# A donation was done with expected life 2888.89883564375 and probabity 0.7514797361221109. Day:  163.89211589804464
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 9
# 164.2506022389263 new_donor None
# A donation was done with expected life 2829.5189853107017 and probabity 0.743987386275207. Day:  164.2506022389263
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 9
# 164.5636610068119 new_recipient None
# A new recipient has arrived. Day:  164.5636610068119
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 9
# 164.57589879286283 new_donor None
# A donation was done with expected life 3016.2728253063137 and probabity 0.7874301143497306. Day:  164.57589879286283
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 9
# 167.13803256124768 new_recipient None
# A new recipient has arrived. Day:  167.13803256124768
# Number of matches: 0, recipients in wait list: 309,average time in waitlist INF, patients which leave the list 9
# 171.05728716746057 leave_list 7502
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 10
# 172.0412123305929 leave_list 12244
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 11
# 176.53496365222824 new_recipient None
# A new recipient has arrived. Day:  176.53496365222824
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 11
# 180.2392897681887 leave_list 5163
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 12
# 180.48012369633176 leave_list 16500
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 13
# 182.32466731060973 leave_list 1753
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 14
# 187.85544804685236 new_recipient None
# A new recipient has arrived. Day:  187.85544804685236
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 14
# 189.82525053566235 new_donor None
# A donation was done with expected life 3250.315537139445 and probabity 0.8340044481722272. Day:  189.82525053566235
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 14
# 191.19023502700142 new_donor None
# A donation was done with expected life 2807.5895068154737 and probabity 0.7391986322612811. Day:  191.19023502700142
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 14
# 191.53326823871177 new_recipient None
# A new recipient has arrived. Day:  191.53326823871177
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 14
# 192.88477286842607 leave_list 3442
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 15
# 194.67069098550607 new_recipient None
# A new recipient has arrived. Day:  194.67069098550607
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 15
# 197.26920649084036 new_donor None
# A donation was done with expected life 3000.0364491856094 and probabity 0.7774092461233671. Day:  197.26920649084036
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 15
# 197.39867527077539 leave_list 4153
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 16
# 198.4378728627478 new_recipient None
# A new recipient has arrived. Day:  198.4378728627478
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 16
# 199.8178218619838 new_donor None
# A donation was done with expected life 3013.4796432567 and probabity 0.7763044962339467. Day:  199.8178218619838
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 16
# 202.83400017057946 new_recipient None
# A new recipient has arrived. Day:  202.83400017057946
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 16
# 204.6686229311829 new_donor None
# A donation was done with expected life 2827.141993981541 and probabity 0.7436069887513659. Day:  204.6686229311829
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 16
# 206.4696230830392 new_donor None
# A donation was done with expected life 2984.9526551177755 and probabity 0.7808281403122236. Day:  206.4696230830392
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 16
# 207.9221965072535 new_recipient None
# A new recipient has arrived. Day:  207.9221965072535
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 16
# 215.59208713010557 new_recipient None
# A new recipient has arrived. Day:  215.59208713010557
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 16
# 218.32437920472685 new_donor None
# A donation was done with expected life 2947.7910287852246 and probabity 0.7615299764030549. Day:  218.32437920472685
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 16
# 219.47231345905715 new_recipient None
# A new recipient has arrived. Day:  219.47231345905715
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 16
# 220.8227992741949 new_recipient None
# A new recipient has arrived. Day:  220.8227992741949
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 16
# 222.58653029648255 new_recipient None
# A new recipient has arrived. Day:  222.58653029648255
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 16
# 223.04106295548144 new_recipient None
# A new recipient has arrived. Day:  223.04106295548144
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 16
# 226.6169868573347 new_recipient None
# A new recipient has arrived. Day:  226.6169868573347
# Number of matches: 0, recipients in wait list: 308,average time in waitlist INF, patients which leave the list 16
# 227.4754967916411 new_donor None
# A donation was done with expected life 3023.010543771495 and probabity 0.7732731355008556. Day:  227.4754967916411
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 16
# 228.94344517186497 new_donor None
# A donation was done with expected life 2832.6786502306527 and probabity 0.7426747213064122. Day:  228.94344517186497
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 16
# 234.4112613516494 leave_list 1753
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 17
# 243.07379418002859 new_recipient None
# A new recipient has arrived. Day:  243.07379418002859
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 17
# 243.94632252943546 new_recipient None
# A new recipient has arrived. Day:  243.94632252943546
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 17
# 243.97904755388652 leave_list 3318
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 18
# 245.0801671310707 new_donor None
# A donation was done with expected life 3021.8742760066466 and probabity 0.7857927583829617. Day:  245.0801671310707
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 18
# 245.57859430394745 new_recipient None
# A new recipient has arrived. Day:  245.57859430394745
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 18
# 246.03572077124562 new_recipient None
# A new recipient has arrived. Day:  246.03572077124562
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 18
# 246.63360562729636 leave_list 21848
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 19
# 252.94693638059985 new_recipient None
# A new recipient has arrived. Day:  252.94693638059985
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 19
# 258.82839937075556 leave_list 2594
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 20
# 266.2105494891028 new_donor None
# A donation was done with expected life 2958.4520685315274 and probabity 0.7625294992568121. Day:  266.2105494891028
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 20
# 272.62230329714475 new_recipient None
# A new recipient has arrived. Day:  272.62230329714475
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 20
# 274.05068287947273 new_recipient None
# A new recipient has arrived. Day:  274.05068287947273
# Number of matches: 0, recipients in wait list: 307,average time in waitlist INF, patients which leave the list 20
# 275.60767062678093 leave_list 21553
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 21
# 280.4420800814591 new_donor None
# A donation was done with expected life 2999.810809527751 and probabity 0.77661593546158. Day:  280.4420800814591
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 21
# 285.59742956179355 new_donor None
# A donation was done with expected life 3082.784204551499 and probabity 0.7929427129015623. Day:  285.59742956179355
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 21
# 289.7257197532725 leave_list 1373
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 22
# 289.8957332719947 leave_list 15882
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 23
# 298.7401119427073 new_recipient None
# A new recipient has arrived. Day:  298.7401119427073
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 23
# 303.0103278186697 leave_list 8901
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 24
# 308.3818573231003 new_donor None
# A donation was done with expected life 2632.1091737062975 and probabity 0.698581796988991. Day:  308.3818573231003
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 24
# 310.16825142498504 new_recipient None
# A new recipient has arrived. Day:  310.16825142498504
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 24
# 311.3422787347243 new_recipient None
# A new recipient has arrived. Day:  311.3422787347243
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 24
# 312.0179902844288 new_recipient None
# A new recipient has arrived. Day:  312.0179902844288
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 24
# 312.24131819394097 new_recipient None
# A new recipient has arrived. Day:  312.24131819394097
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 24
# 313.0103064587049 leave_list 1373
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 25
# 316.1396329404666 new_recipient None
# A new recipient has arrived. Day:  316.1396329404666
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 25
# 317.26028900699015 new_recipient None
# A new recipient has arrived. Day:  317.26028900699015
# Number of matches: 0, recipients in wait list: 306,average time in waitlist INF, patients which leave the list 25
# 318.70929018798466 new_donor None
# A donation was done with expected life 3178.7802647537983 and probabity 0.8101525912145844. Day:  318.70929018798466
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 25
# 319.2108548645687 leave_list 16121
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 26
# 319.9872092952889 new_recipient None
# A new recipient has arrived. Day:  319.9872092952889
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 26
# 322.7470929186437 leave_list 4970
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 27
# 326.38031736318334 new_donor None
# A donation was done with expected life 3023.2336473507503 and probabity 0.7852515394252175. Day:  326.38031736318334
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 27
# 328.3051826928983 new_donor None
# A donation was done with expected life 2601.3895975335668 and probabity 0.6879977951893871. Day:  328.3051826928983
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 27
# 330.6348044950162 new_recipient None
# A new recipient has arrived. Day:  330.6348044950162
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 27
# 333.61887752145014 leave_list 20581
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 28
# 341.3613952703498 new_recipient None
# A new recipient has arrived. Day:  341.3613952703498
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 28
# 342.52518368631144 new_recipient None
# A new recipient has arrived. Day:  342.52518368631144
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 28
# 343.453167461064 new_donor None
# A donation was done with expected life 2604.5710202135347 and probabity 0.687455832572041. Day:  343.453167461064
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 28
# 343.51792761268234 new_recipient None
# A new recipient has arrived. Day:  343.51792761268234
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 28
# 343.82395264665195 new_recipient None
# A new recipient has arrived. Day:  343.82395264665195
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 28
# 343.9367211612576 new_donor None
# A donation was done with expected life 2915.5346295316917 and probabity 0.7528958463709595. Day:  343.9367211612576
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 28
# 346.4039905805305 new_recipient None
# A new recipient has arrived. Day:  346.4039905805305
# Number of matches: 0, recipients in wait list: 305,average time in waitlist INF, patients which leave the list 28
# 350.84498141737936 new_donor None
# A donation was done with expected life 2872.699563383432 and probabity 0.7560844665024656. Day:  350.84498141737936
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 28
# 350.9768359461997 new_donor None
# A donation was done with expected life 2868.888576840916 and probabity 0.7447894110350727. Day:  350.9768359461997
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 28
# 356.18186951881114 new_recipient None
# A new recipient has arrived. Day:  356.18186951881114
# Number of matches: 0, recipients in wait list: 304,average time in waitlist INF, patients which leave the list 28
# 356.7226246461152 leave_list 2817
# Number of matches: 0, recipients in wait list: 303,average time in waitlist INF, patients which leave the list 29
# 357.3231360454284 leave_list 21003
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 30
# 357.6716653587268 leave_list 880
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 31
# 361.11288931970716 new_donor None
# A donation was done with expected life 2973.0152860776884 and probabity 0.7760784199301988. Day:  361.11288931970716
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 31
# 362.7112948244917 new_recipient None
# A new recipient has arrived. Day:  362.7112948244917
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 31
# 363.2669164139813 new_recipient None
# A new recipient has arrived. Day:  363.2669164139813
# Number of matches: 0, recipients in wait list: 302,average time in waitlist INF, patients which leave the list 31
# 367.66095731859855 new_donor None
# A donation was done with expected life 2828.8617347063696 and probabity 0.7435380552779395. Day:  367.66095731859855
# Number of matches: 0, recipients in wait list: 301,average time in waitlist INF, patients which leave the list 31
# 370.8504014415669 leave_list 13771
# Number of matches: 0, recipients in wait list: 300,average time in waitlist INF, patients which leave the list 32
# 372.5204997379822 leave_list 12295
# Number of matches: 0, recipients in wait list: 299,average time in waitlist INF, patients which leave the list 33
# 374.5769478310371 leave_list 22119
# Number of matches: 0, recipients in wait list: 298,average time in waitlist INF, patients which leave the list 34
# 377.75704152235477 leave_list 12435
# Number of matches: 0, recipients in wait list: 297,average time in waitlist INF, patients which leave the list 35
# 381.434310061747 new_donor None
# A donation was done with expected life 3222.2899029333303 and probabity 0.8203489108232453. Day:  381.434310061747
# Number of matches: 0, recipients in wait list: 296,average time in waitlist INF, patients which leave the list 35
# 384.2585254280146 leave_list 18962
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 36
# 389.14126757498866 new_donor None
# A donation was done with expected life 2874.7414981098013 and probabity 0.7461677873715082. Day:  389.14126757498866
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 36
# 389.8333609298618 new_recipient None
# A new recipient has arrived. Day:  389.8333609298618
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 36
# 392.2195187085091 new_donor None
# A donation was done with expected life 3131.144195953782 and probabity 0.8007142850419801. Day:  392.2195187085091
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 36
# 392.5532617905844 new_donor None
# A donation was done with expected life 3069.441199414807 and probabity 0.7886056717788975. Day:  392.5532617905844
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 36
# 392.737743180157 new_recipient None
# A new recipient has arrived. Day:  392.737743180157
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 36
# 393.25393401311396 new_recipient None
# A new recipient has arrived. Day:  393.25393401311396
# Number of matches: 0, recipients in wait list: 295,average time in waitlist INF, patients which leave the list 36
# 393.71763274720684 new_donor None
# A donation was done with expected life 2895.8913600974297 and probabity 0.7521400732342296. Day:  393.71763274720684
# Number of matches: 0, recipients in wait list: 294,average time in waitlist INF, patients which leave the list 36
# 395.36844668721307 new_donor None
# A donation was done with expected life 3139.485561083842 and probabity 0.8079299673357864. Day:  395.36844668721307
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 36
# 395.83137689829425 leave_list 5163
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 37
# 398.16545324629556 new_recipient None
# A new recipient has arrived. Day:  398.16545324629556
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 37
# 398.6581991879276 leave_list 12244
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 38
# 399.4463455769416 leave_list 13393
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 39
# 400.54327235319624 new_donor None
# A donation was done with expected life 2776.9811774506557 and probabity 0.729404454161287. Day:  400.54327235319624
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 39
# 405.60223542677136 leave_list 5691
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 40
# 409.24569486915954 leave_list 7395
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 41
# 411.9958469365262 leave_list 13378
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 42
# 424.3995402784623 new_donor None
# A donation was done with expected life 3046.024697087523 and probabity 0.7951167512712286. Day:  424.3995402784623
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 42
# 427.8691582269157 new_donor None
# A donation was done with expected life 3010.206215417363 and probabity 0.7789663314801948. Day:  427.8691582269157
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 42
# 427.99307941893306 new_recipient None
# A new recipient has arrived. Day:  427.99307941893306
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 42
# 429.0678167124243 leave_list 2948
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 43
# 430.8104041658343 leave_list 19320
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 44
# 436.6222267419789 new_recipient None
# A new recipient has arrived. Day:  436.6222267419789
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 44
# 438.6156740773031 new_recipient None
# A new recipient has arrived. Day:  438.6156740773031
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 44
# 441.3969033902644 leave_list 9478
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 45
# 445.0788417711315 new_recipient None
# A new recipient has arrived. Day:  445.0788417711315
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 45
# 446.1369187662746 leave_list 1827
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 46
# 447.7417350905919 new_recipient None
# A new recipient has arrived. Day:  447.7417350905919
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 46
# 450.28153780991806 leave_list 4833
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 47
# 452.98944745141483 new_donor None
# A donation was done with expected life 3002.4222870061135 and probabity 0.7705506030387642. Day:  452.98944745141483
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 47
# 454.1632905530988 new_recipient None
# A new recipient has arrived. Day:  454.1632905530988
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 47
# 454.3951264512416 new_donor None
# A donation was done with expected life 2929.383553100596 and probabity 0.7608513574123941. Day:  454.3951264512416
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 47
# 455.61962928033256 new_donor None
# A donation was done with expected life 3153.59494105624 and probabity 0.8101596895867905. Day:  455.61962928033256
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 47
# 458.08405423173133 new_recipient None
# A new recipient has arrived. Day:  458.08405423173133
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 47
# 458.88479517735175 new_recipient None
# A new recipient has arrived. Day:  458.88479517735175
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 47
# 462.5826256541701 new_donor None
# A donation was done with expected life 3238.407978313962 and probabity 0.8326836931405566. Day:  462.5826256541701
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 47
# 463.82908259666306 new_donor None
# A donation was done with expected life 2997.160392020168 and probabity 0.7772688523815708. Day:  463.82908259666306
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 47
# 464.86766156968815 new_donor None
# A donation was done with expected life 2954.7960314832435 and probabity 0.7750188327679447. Day:  464.86766156968815
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 47
# 465.713678360519 new_donor None
# A donation was done with expected life 2549.9405397502273 and probabity 0.6736164068050491. Day:  465.713678360519
# Number of matches: 0, recipients in wait list: 281,average time in waitlist INF, patients which leave the list 47
# 466.2786493852993 new_recipient None
# A new recipient has arrived. Day:  466.2786493852993
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 47
# 468.72228422485364 new_recipient None
# A new recipient has arrived. Day:  468.72228422485364
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 47
# 469.86662023501066 new_donor None
# A donation was done with expected life 2670.913866796829 and probabity 0.7135910735468076. Day:  469.86662023501066
# Number of matches: 0, recipients in wait list: 282,average time in waitlist INF, patients which leave the list 47
# 470.1649285627256 new_recipient None
# A new recipient has arrived. Day:  470.1649285627256
# Number of matches: 0, recipients in wait list: 283,average time in waitlist INF, patients which leave the list 47
# 474.6141697674374 new_recipient None
# A new recipient has arrived. Day:  474.6141697674374
# Number of matches: 0, recipients in wait list: 284,average time in waitlist INF, patients which leave the list 47
# 474.955670819967 new_recipient None
# A new recipient has arrived. Day:  474.955670819967
# Number of matches: 0, recipients in wait list: 285,average time in waitlist INF, patients which leave the list 47
# 483.68248229643166 new_recipient None
# A new recipient has arrived. Day:  483.68248229643166
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 47
# 485.9333501405161 new_recipient None
# A new recipient has arrived. Day:  485.9333501405161
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 47
# 489.20929375705225 new_donor None
# A donation was done with expected life 2548.0070111618516 and probabity 0.6830353027086524. Day:  489.20929375705225
# Number of matches: 0, recipients in wait list: 286,average time in waitlist INF, patients which leave the list 47
# 490.5675593715445 new_recipient None
# A new recipient has arrived. Day:  490.5675593715445
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 47
# 490.80716398728794 new_recipient None
# A new recipient has arrived. Day:  490.80716398728794
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 47
# 491.56100560129266 leave_list 20581
# Number of matches: 0, recipients in wait list: 287,average time in waitlist INF, patients which leave the list 48
# 496.3516842624757 new_recipient None
# A new recipient has arrived. Day:  496.3516842624757
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 48
# 496.44032600374885 new_recipient None
# A new recipient has arrived. Day:  496.44032600374885
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 48
# 497.6117537397386 new_recipient None
# A new recipient has arrived. Day:  497.6117537397386
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 48
# 497.7136690482724 leave_list 21702
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 49
# 502.2589120502693 new_recipient None
# A new recipient has arrived. Day:  502.2589120502693
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 49
# 505.3224294026621 leave_list 2817
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 50
# 510.62964706362584 leave_list 8090
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 51
# 518.8215729357978 new_recipient None
# A new recipient has arrived. Day:  518.8215729357978
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 51
# 523.583699513768 new_recipient None
# A new recipient has arrived. Day:  523.583699513768
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 51
# 524.3491302592796 new_donor None
# A donation was done with expected life 3199.316176005934 and probabity 0.8202263797292291. Day:  524.3491302592796
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 51
# 524.5172327553094 new_donor None
# A donation was done with expected life 2557.9739831399424 and probabity 0.6835322241007448. Day:  524.5172327553094
# Number of matches: 0, recipients in wait list: 288,average time in waitlist INF, patients which leave the list 51
# 527.680586660741 new_recipient None
# A new recipient has arrived. Day:  527.680586660741
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 51
# 528.3182622659779 new_recipient None
# A new recipient has arrived. Day:  528.3182622659779
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 51
# 528.9294278721451 new_donor None
# A donation was done with expected life 2884.585145397648 and probabity 0.7556474312145255. Day:  528.9294278721451
# Number of matches: 0, recipients in wait list: 289,average time in waitlist INF, patients which leave the list 51
# 531.7645533911916 new_recipient None
# A new recipient has arrived. Day:  531.7645533911916
# Number of matches: 0, recipients in wait list: 290,average time in waitlist INF, patients which leave the list 51
# 532.2794752199901 new_recipient None
# A new recipient has arrived. Day:  532.2794752199901
# Number of matches: 0, recipients in wait list: 291,average time in waitlist INF, patients which leave the list 51
# 535.3987914934407 new_recipient None
# A new recipient has arrived. Day:  535.3987914934407
# Number of matches: 0, recipients in wait list: 292,average time in waitlist INF, patients which leave the list 51
# 537.1393176505368 new_recipient None
# A new recipient has arrived. Day:  537.1393176505368
# Number of matches: 0, recipients in wait list: 293,average time in waitlist INF, patients which leave the list 51
# 539.9977208256632 new_recipient None
# ...
# Number of matches: 1141, recipients in wait list: 252,average time in waitlist 1233.1089855231812, patients which leave the list 740
# 10813.166971707184 new_donor None
# A donation was done with expected life 2939.575290214361 and probabity 0.7696659672966922. Day:  10813.166971707184
# Number of matches: 1142, recipients in wait list: 251,average time in waitlist 1233.015072198015, patients which leave the list 740
# 10813.794555444314 new_recipient None
# A new recipient has arrived. Day:  10813.794555444314
# Number of matches: 1142, recipients in wait list: 252,average time in waitlist 1233.015072198015, patients which leave the list 740
# 10814.502955064934 new_recipient None
# A new recipient has arrived. Day:  10814.502955064934
# Number of matches: 1142, recipients in wait list: 253,average time in waitlist 1233.015072198015, patients which leave the list 740
# 10820.399429915455 new_recipient None
# A new recipient has arrived. Day:  10820.399429915455
# Number of matches: 1142, recipients in wait list: 254,average time in waitlist 1233.015072198015, patients which leave the list 740
# 10822.492899206467 new_recipient None
# A new recipient has arrived. Day:  10822.492899206467
# Number of matches: 1142, recipients in wait list: 255,average time in waitlist 1233.015072198015, patients which leave the list 740
# 10824.813076468548 new_recipient None
# A new recipient has arrived. Day:  10824.813076468548
# Number of matches: 1142, recipients in wait list: 256,average time in waitlist 1233.015072198015, patients which leave the list 740
# 10826.400254043254 new_donor None
# A donation was done with expected life 2751.321959989792 and probabity 0.7162264757148702. Day:  10826.400254043254
# Number of matches: 1143, recipients in wait list: 255,average time in waitlist 1233.2720216715584, patients which leave the list 740
# 10831.47995632125 new_donor None
# A donation was done with expected life 2607.757619850091 and probabity 0.6994130912864785. Day:  10831.47995632125
# Number of matches: 1144, recipients in wait list: 254,average time in waitlist 1233.1633923478755, patients which leave the list 740
# 10832.487761516984 new_recipient None
# A new recipient has arrived. Day:  10832.487761516984
# Number of matches: 1144, recipients in wait list: 255,average time in waitlist 1233.1633923478755, patients which leave the list 740
# 10836.729099358477 new_donor None
# A donation was done with expected life 2645.6239228218565 and probabity 0.6868629952317289. Day:  10836.729099358477
# Number of matches: 1145, recipients in wait list: 254,average time in waitlist 1233.051785563398, patients which leave the list 740
# 10837.027855161132 new_recipient None
# A new recipient has arrived. Day:  10837.027855161132
# Number of matches: 1145, recipients in wait list: 255,average time in waitlist 1233.051785563398, patients which leave the list 740
# 10839.189948565268 new_donor None
# A donation was done with expected life 3097.6508169119966 and probabity 0.7962301508262164. Day:  10839.189948565268
# Number of matches: 1146, recipients in wait list: 254,average time in waitlist 1232.9315493072042, patients which leave the list 740
# 10844.043862569599 leave_list 9198
# ----------------------- One patient left the waitlist. Day:  10844.043862569599 9198
# Number of matches: 1146, recipients in wait list: 253,average time in waitlist 1232.9315493072042, patients which leave the list 741
# 10848.906030452725 new_recipient None
# A new recipient has arrived. Day:  10848.906030452725
# Number of matches: 1146, recipients in wait list: 254,average time in waitlist 1232.9315493072042, patients which leave the list 741
# 10850.346034803548 new_donor None
# A donation was done with expected life 2587.10872862329 and probabity 0.6857413535702552. Day:  10850.346034803548
# Number of matches: 1147, recipients in wait list: 253,average time in waitlist 1233.1110421344997, patients which leave the list 741
# 10851.933466282413 new_recipient None
# A new recipient has arrived. Day:  10851.933466282413
# Number of matches: 1147, recipients in wait list: 254,average time in waitlist 1233.1110421344997, patients which leave the list 741
# 10854.073466876864 leave_list 2121
# ----------------------- One patient left the waitlist. Day:  10854.073466876864 2121
# Number of matches: 1147, recipients in wait list: 253,average time in waitlist 1233.1110421344997, patients which leave the list 742
# 10855.505962643374 leave_list 4064
# ----------------------- One patient left the waitlist. Day:  10855.505962643374 4064
# Number of matches: 1147, recipients in wait list: 252,average time in waitlist 1233.1110421344997, patients which leave the list 743
# 10861.66077988529 new_recipient None
# A new recipient has arrived. Day:  10861.66077988529
# Number of matches: 1147, recipients in wait list: 253,average time in waitlist 1233.1110421344997, patients which leave the list 743
# 10863.062021686428 new_recipient None
# A new recipient has arrived. Day:  10863.062021686428
# Number of matches: 1147, recipients in wait list: 254,average time in waitlist 1233.1110421344997, patients which leave the list 743
# 10863.594384610698 new_recipient None
# A new recipient has arrived. Day:  10863.594384610698
# Number of matches: 1147, recipients in wait list: 255,average time in waitlist 1233.1110421344997, patients which leave the list 743
# 10869.526317680602 new_donor None
# A donation was done with expected life 2949.594034338236 and probabity 0.7637800558666409. Day:  10869.526317680602
# Number of matches: 1148, recipients in wait list: 254,average time in waitlist 1233.275554431885, patients which leave the list 743
# 10870.965852024872 new_donor None
# A donation was done with expected life 2937.339247074137 and probabity 0.7591444011133639. Day:  10870.965852024872
# Number of matches: 1149, recipients in wait list: 253,average time in waitlist 1233.4323241017762, patients which leave the list 743
# 10875.442191671655 new_recipient None
# A new recipient has arrived. Day:  10875.442191671655
# Number of matches: 1149, recipients in wait list: 254,average time in waitlist 1233.4323241017762, patients which leave the list 743
# 10878.527853010211 new_donor None
# A donation was done with expected life 2691.6691059417217 and probabity 0.7185304731954985. Day:  10878.527853010211
# Number of matches: 1150, recipients in wait list: 253,average time in waitlist 1235.4631094989313, patients which leave the list 743
# 10881.65389438012 leave_list 3224
# ----------------------- One patient left the waitlist. Day:  10881.65389438012 3224
# Number of matches: 1150, recipients in wait list: 252,average time in waitlist 1235.4631094989313, patients which leave the list 744
# 10883.209339375491 leave_list 21586
# ----------------------- One patient left the waitlist. Day:  10883.209339375491 21586
# Number of matches: 1150, recipients in wait list: 251,average time in waitlist 1235.4631094989313, patients which leave the list 745
# 10889.855037117695 new_recipient None
# A new recipient has arrived. Day:  10889.855037117695
# Number of matches: 1150, recipients in wait list: 252,average time in waitlist 1235.4631094989313, patients which leave the list 745
# 10891.646656108687 new_donor None
# A donation was done with expected life 2824.2422495878477 and probabity 0.7435475837337511. Day:  10891.646656108687
# Number of matches: 1151, recipients in wait list: 251,average time in waitlist 1235.6524312149954, patients which leave the list 745
# 10894.912841874862 leave_list 3014
# ----------------------- One patient left the waitlist. Day:  10894.912841874862 3014
# Number of matches: 1151, recipients in wait list: 250,average time in waitlist 1235.6524312149954, patients which leave the list 746
# 10898.590086215678 new_recipient None
# A new recipient has arrived. Day:  10898.590086215678
# Number of matches: 1151, recipients in wait list: 251,average time in waitlist 1235.6524312149954, patients which leave the list 746
# 10898.933557971364 leave_list 185
# ----------------------- One patient left the waitlist. Day:  10898.933557971364 185
# Number of matches: 1151, recipients in wait list: 250,average time in waitlist 1235.6524312149954, patients which leave the list 747
# 10901.228377490776 leave_list 3578
# ----------------------- One patient left the waitlist. Day:  10901.228377490776 3578
# Number of matches: 1151, recipients in wait list: 249,average time in waitlist 1235.6524312149954, patients which leave the list 748
# 10902.48856274574 leave_list 797
# ----------------------- One patient left the waitlist. Day:  10902.48856274574 797
# Number of matches: 1151, recipients in wait list: 248,average time in waitlist 1235.6524312149954, patients which leave the list 749
# 10906.200559185476 leave_list 22249
# ----------------------- One patient left the waitlist. Day:  10906.200559185476 22249
# Number of matches: 1151, recipients in wait list: 247,average time in waitlist 1235.6524312149954, patients which leave the list 750
# 10907.738009323235 leave_list 14036
# ----------------------- One patient left the waitlist. Day:  10907.738009323235 14036
# Number of matches: 1151, recipients in wait list: 246,average time in waitlist 1235.6524312149954, patients which leave the list 751
# 10912.538506217374 new_recipient None
# A new recipient has arrived. Day:  10912.538506217374
# Number of matches: 1151, recipients in wait list: 247,average time in waitlist 1235.6524312149954, patients which leave the list 751
# 10917.632739854389 new_recipient None
# A new recipient has arrived. Day:  10917.632739854389
# Number of matches: 1151, recipients in wait list: 248,average time in waitlist 1235.6524312149954, patients which leave the list 751
# 10919.97968437483 new_recipient None
# A new recipient has arrived. Day:  10919.97968437483
# Number of matches: 1151, recipients in wait list: 249,average time in waitlist 1235.6524312149954, patients which leave the list 751
# 10920.540164435459 new_recipient None
# A new recipient has arrived. Day:  10920.540164435459
# Number of matches: 1151, recipients in wait list: 250,average time in waitlist 1235.6524312149954, patients which leave the list 751
# 10921.023930138485 new_recipient None
# A new recipient has arrived. Day:  10921.023930138485
# Number of matches: 1151, recipients in wait list: 251,average time in waitlist 1235.6524312149954, patients which leave the list 751
# 10921.066021538265 new_recipient None
# A new recipient has arrived. Day:  10921.066021538265
# Number of matches: 1151, recipients in wait list: 252,average time in waitlist 1235.6524312149954, patients which leave the list 751
# 10923.96739228824 new_recipient None
# A new recipient has arrived. Day:  10923.96739228824
# Number of matches: 1151, recipients in wait list: 253,average time in waitlist 1235.6524312149954, patients which leave the list 751
# 10924.372879990187 new_recipient None
# A new recipient has arrived. Day:  10924.372879990187
# Number of matches: 1151, recipients in wait list: 254,average time in waitlist 1235.6524312149954, patients which leave the list 751
# 10924.866163510744 new_donor None
# A donation was done with expected life 2643.5034295241658 and probabity 0.6960293188036428. Day:  10924.866163510744
# Number of matches: 1152, recipients in wait list: 253,average time in waitlist 1235.774819692739, patients which leave the list 751
# 10925.50804474354 new_recipient None
# A new recipient has arrived. Day:  10925.50804474354
# Number of matches: 1152, recipients in wait list: 254,average time in waitlist 1235.774819692739, patients which leave the list 751
# 10925.68238956101 new_recipient None
# A new recipient has arrived. Day:  10925.68238956101
# Number of matches: 1152, recipients in wait list: 255,average time in waitlist 1235.774819692739, patients which leave the list 751
# 10926.153971338248 new_donor None
# A donation was done with expected life 2941.239900709538 and probabity 0.7633398834117874. Day:  10926.153971338248
# Number of matches: 1153, recipients in wait list: 254,average time in waitlist 1237.6713046802165, patients which leave the list 751
# 10927.112820296761 new_donor None
# A donation was done with expected life 2828.8557738742225 and probabity 0.7318351361041593. Day:  10927.112820296761
# Number of matches: 1154, recipients in wait list: 253,average time in waitlist 1237.901125799404, patients which leave the list 751
# 10929.811407632133 new_recipient None
# A new recipient has arrived. Day:  10929.811407632133
# Number of matches: 1154, recipients in wait list: 254,average time in waitlist 1237.901125799404, patients which leave the list 751
# 10932.192716908987 new_donor None
# A donation was done with expected life 2931.407931795468 and probabity 0.7671231626011428. Day:  10932.192716908987
# Number of matches: 1155, recipients in wait list: 253,average time in waitlist 1238.1566139878519, patients which leave the list 751
# 10934.454834074519 new_recipient None
# A new recipient has arrived. Day:  10934.454834074519
# Number of matches: 1155, recipients in wait list: 254,average time in waitlist 1238.1566139878519, patients which leave the list 751
# 10936.27721220546 new_recipient None
# A new recipient has arrived. Day:  10936.27721220546
# Number of matches: 1155, recipients in wait list: 255,average time in waitlist 1238.1566139878519, patients which leave the list 751
# 10939.120734380404 new_donor None
# A donation was done with expected life 3183.3189790433016 and probabity 0.8137449058310956. Day:  10939.120734380404
# Number of matches: 1156, recipients in wait list: 254,average time in waitlist 1238.3801810678428, patients which leave the list 751
# 10940.575197777016 new_donor None
# A donation was done with expected life 2962.65108503698 and probabity 0.7642457847845087. Day:  10940.575197777016
# Number of matches: 1157, recipients in wait list: 253,average time in waitlist 1238.4456568505302, patients which leave the list 751
# 10940.597170258654 leave_list 13274
# ----------------------- One patient left the waitlist. Day:  10940.597170258654 13274
# Number of matches: 1157, recipients in wait list: 252,average time in waitlist 1238.4456568505302, patients which leave the list 752
# 10941.134320386438 new_donor None
# A donation was done with expected life 2711.8706629541707 and probabity 0.7217702327854465. Day:  10941.134320386438
# Number of matches: 1158, recipients in wait list: 251,average time in waitlist 1238.6541195117247, patients which leave the list 752
# 10942.029337741662 new_donor None
# A donation was done with expected life 2695.3791137583216 and probabity 0.7190786333975226. Day:  10942.029337741662
# Number of matches: 1159, recipients in wait list: 250,average time in waitlist 1238.6267019917266, patients which leave the list 752
# 10942.1477455393 new_recipient None
# A new recipient has arrived. Day:  10942.1477455393
# Number of matches: 1159, recipients in wait list: 251,average time in waitlist 1238.6267019917266, patients which leave the list 752
# 10943.373433538374 new_recipient None
# A new recipient has arrived. Day:  10943.373433538374
# Number of matches: 1159, recipients in wait list: 252,average time in waitlist 1238.6267019917266, patients which leave the list 752
# 10945.23970065783 new_recipient None
# A new recipient has arrived. Day:  10945.23970065783
# Number of matches: 1159, recipients in wait list: 253,average time in waitlist 1238.6267019917266, patients which leave the list 752
# 10947.030544987705 leave_list 3829
# ----------------------- One patient left the waitlist. Day:  10947.030544987705 3829
# Number of matches: 1159, recipients in wait list: 252,average time in waitlist 1238.6267019917266, patients which leave the list 753
# 10948.976600412263 leave_list 17713
# ----------------------- One patient left the waitlist. Day:  10948.976600412263 17713
# Number of matches: 1159, recipients in wait list: 251,average time in waitlist 1238.6267019917266, patients which leave the list 754
# 10952.968923888557 new_recipient None
# A new recipient has arrived. Day:  10952.968923888557
# Number of matches: 1159, recipients in wait list: 252,average time in waitlist 1238.6267019917266, patients which leave the list 754
# ([1238.6267019917266], [1159])

# %%
df['ethcat'] = df['ethcat'].replace(ethcat_mapping)

# %%
df_waiting_time = ((df.groupby(by=['replicate', 'ethcat'])
                   .agg(
                       waiting_time=('waiting_time', 'mean'), 
                       count=('waiting_time', 'size'), 
                       mean_survival_time=('mean_survival_time', 'mean'))
                   .reset_index())
)#.to_csv('simulation_results.csv')
df_waiting_time = df_waiting_time[['ethcat', 'waiting_time', 'count', 'mean_survival_time']].groupby('ethcat').agg(['mean', 'std'])
df_waiting_time.columns = [f"{col[0]}_{col[1]}" for col in df_waiting_time.columns] 
df_waiting_time['prop_simu'] = df_waiting_time['count_mean'] / df_waiting_time['count_mean'].sum()
df_waiting_time = df_waiting_time.merge(real_ethcat_df, on='ethcat').round(3)
df_waiting_time.columns = ['ethcat', 'wt_mean', 'wt_std', 'count_mean', 'count_std', 'st_mean', 'st_std', 'prop_simu', 'sample_proportion']
df_waiting_time
# Out:
#                                               ethcat   wt_mean  wt_std  \
# 0               Amer Ind/Alaska Native, Non-Hispanic  1142.559     NaN
# 1                                Asian, Non-Hispanic  1322.702     NaN
# 2                                Black, Non-Hispanic  1292.730     NaN
# 3                                    Hispanic/Latino  1177.572     NaN
# 4                          Multiracial, Non-Hispanic  1339.688     NaN
# 5  Native Hawaiian/Other Pacific Islander, Non-Hi...  1107.611     NaN
# 6                                White, Non-Hispanic  1216.724     NaN
#
#    count_mean  count_std   st_mean  st_std  prop_simu  sample_proportion
# 0        13.0        NaN  2895.406     NaN      0.011              0.014
# 1        51.0        NaN  2916.182     NaN      0.044              0.053
# 2       363.0        NaN  2884.337     NaN      0.313              0.325
# 3       190.0        NaN  2874.511     NaN      0.164              0.160
# 4        10.0        NaN  2885.756     NaN      0.009              0.005
# 5         4.0        NaN  2877.144     NaN      0.003              0.004
# 6       528.0        NaN  2907.994     NaN      0.456              0.439

# %%
df_gender = ((df.groupby(by=['replicate', 'gender'])
                .agg(
                    waiting_time=('waiting_time', 'mean'), 
                    count=('waiting_time', 'size'),
                    mean_survival_time=('mean_survival_time', 'mean'))
                .reset_index())
)#.to_csv('simulation_results.csv')
df_gender = df_gender[['gender', 'waiting_time', 'count', 'mean_survival_time']].groupby('gender').agg(['mean', 'std'])
df_gender.columns = [f"{col[0]}_{col[1]}" for col in df_gender.columns] 
df_gender['proportion_sim'] = df_gender['count_mean'] / df_gender['count_mean'].sum()
df_gender.reset_index(inplace=True)
df_gender = df_gender.merge(real_gender_df, on = 'gender')
df_gender.columns = ['gender', 'wt_mean', 'wt_std', 'count_mean',
       'count_std', 'st_mean', 'st_std',
       'prop_sim', 'sample_proportion']
df_gender.round(3)
# Out:
#   gender   wt_mean  wt_std  count_mean  count_std   st_mean  st_std  prop_sim  \
# 0      F  1237.549     NaN       408.0        NaN  2893.894     NaN     0.352
# 1      M  1239.212     NaN       751.0        NaN  2895.626     NaN     0.648
#
#    sample_proportion
# 0              0.352
# 1              0.648

# %%
#df.to_csv('results_decision_tree.csv')

# %%
import numpy as np 

np.quantile(np.mean(np.random.exponential(scale=(1)*365, size=100)), 0.2)
# Out:
# 406.11570794795057
